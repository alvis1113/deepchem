# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gp1 = GraphPool(in_layers=[batch_norm1, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp2 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm3 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm3, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.792 s
# TIMING: dataset construction took 3.245 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.466 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.235 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.235 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 128
C2_filtnum = 256
D_nodenum = 32

graph_structure = 'GC{0}_GP_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.7065375478833955]
# computed_metrics: [2.7065375478833955]
# computed_metrics: [2.7269322666543947]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.8654848823165924]
# computed_metrics: [1.8654848823165924]
# computed_metrics: [1.9029787119585708]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.2694316000448473]
# computed_metrics: [1.2694316000448473]
# computed_metrics: [1.3267930809182147]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0442957719583819]
# computed_metrics: [1.0442957719583819]
# computed_metrics: [1.0866286915532648]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9651598626120231]
# computed_metrics: [0.9651598626120231]
# computed_metrics: [0.9873387978429967]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9423955391020045]
# computed_metrics: [0.9423955391020045]
# computed_metrics: [0.9587906770266825]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9284858914214351]
# computed_metrics: [0.9284858914214351]
# computed_metrics: [0.9493884788820867]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9143056831243247]
# computed_metrics: [0.9143056831243247]
# computed_metrics: [0.9318327355890065]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.9110091378550775]
# computed_metrics: [0.9110091378550775]
# computed_metrics: [0.9290373384444988]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8985278725058318]
# computed_metrics: [0.8985278725058318]
# computed_metrics: [0.9158878945285732]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8601841805980657]
# computed_metrics: [0.8601841805980657]
# computed_metrics: [0.8843632672111464]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8732156146059655]
# computed_metrics: [0.8732156146059655]
# computed_metrics: [0.8950346061199057]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.859822344094411]
# computed_metrics: [0.859822344094411]
# computed_metrics: [0.8949443937474659]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8547932002269412]
# computed_metrics: [0.8547932002269412]
# computed_metrics: [0.8853413143765901]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8487423272455371]
# computed_metrics: [0.8487423272455371]
# computed_metrics: [0.8745298253405538]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.840157253644685]
# computed_metrics: [0.840157253644685]
# computed_metrics: [0.8689470088013933]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.83647353201829]
# computed_metrics: [0.83647353201829]
# computed_metrics: [0.8580548536770733]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8265357472481754]
# computed_metrics: [0.8265357472481754]
# computed_metrics: [0.8551904459009187]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.8228707323800497]
# computed_metrics: [0.8228707323800497]
# computed_metrics: [0.8477320338598204]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.8140579644486061]
# computed_metrics: [0.8140579644486061]
# computed_metrics: [0.8409056007750415]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.8070071430648931]
# computed_metrics: [0.8070071430648931]
# computed_metrics: [0.8373758743263359]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.8063751939364916]
# computed_metrics: [0.8063751939364916]
# computed_metrics: [0.8355443535776587]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7962210103428419]
# computed_metrics: [0.7962210103428419]
# computed_metrics: [0.8301343666183199]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.794146347341862]
# computed_metrics: [0.794146347341862]
# computed_metrics: [0.8273037211594734]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7835330388452373]
# computed_metrics: [0.7835330388452373]
# computed_metrics: [0.8170814241694193]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.781260201052184]
# computed_metrics: [0.781260201052184]
# computed_metrics: [0.8190607467623332]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7958481492073292]
# computed_metrics: [0.7958481492073292]
# computed_metrics: [0.8219963894394668]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.8078299820350472]
# computed_metrics: [0.8078299820350472]
# computed_metrics: [0.8391170069090385]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.7910677732093485]
# computed_metrics: [0.7910677732093485]
# computed_metrics: [0.8204989571904194]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.7653686027736862]
# computed_metrics: [0.7653686027736862]
# computed_metrics: [0.803279104005575]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.7738206794534955]
# computed_metrics: [0.7738206794534955]
# computed_metrics: [0.8185341031796962]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.7534443696430114]
# computed_metrics: [0.7534443696430114]
# computed_metrics: [0.8074821427736505]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.7388627146811666]
# computed_metrics: [0.7388627146811666]
# computed_metrics: [0.7922073619850221]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.7329861164788006]
# computed_metrics: [0.7329861164788006]
# computed_metrics: [0.7851197165845867]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.7391397609842597]
# computed_metrics: [0.7391397609842597]
# computed_metrics: [0.7865218093447292]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.7176044995286482]
# computed_metrics: [0.7176044995286482]
# computed_metrics: [0.7632983982406772]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.7153863867508196]
# computed_metrics: [0.7153863867508196]
# computed_metrics: [0.7582288899701257]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.7035387190411024]
# computed_metrics: [0.7035387190411024]
# computed_metrics: [0.7465744161833032]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.7094515115577629]
# computed_metrics: [0.7094515115577629]
# computed_metrics: [0.7589700801430578]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.690105279216617]
# computed_metrics: [0.690105279216617]
# computed_metrics: [0.7272797146546851]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6840236131719382]
# computed_metrics: [0.6840236131719382]
# computed_metrics: [0.7084836046686415]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.672153485825067]
# computed_metrics: [0.672153485825067]
# computed_metrics: [0.6990381847430742]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6463572407199342]
# computed_metrics: [0.6463572407199342]
# computed_metrics: [0.6721493453423103]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.6476879826317946]
# computed_metrics: [0.6476879826317946]
# computed_metrics: [0.6748260236700495]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.6466712338874788]
# computed_metrics: [0.6466712338874788]
# computed_metrics: [0.6704214679315389]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.6272329656026141]
# computed_metrics: [0.6272329656026141]
# computed_metrics: [0.6432971880451925]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5938066811567744]
# computed_metrics: [0.5938066811567744]
# computed_metrics: [0.6074091870341183]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5722229894428275]
# computed_metrics: [0.5722229894428275]
# computed_metrics: [0.5827382950143366]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5757453500634596]
# computed_metrics: [0.5757453500634596]
# computed_metrics: [0.5931889519292908]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5635926491905989]
# computed_metrics: [0.5635926491905989]
# computed_metrics: [0.5813008476187028]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.564250135809285]
# computed_metrics: [0.564250135809285]
# computed_metrics: [0.5892027509027323]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5516862257297159]
# computed_metrics: [0.5516862257297159]
# computed_metrics: [0.5736519818692168]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5387769380017555]
# computed_metrics: [0.5387769380017555]
# computed_metrics: [0.566500740654387]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5543862042754326]
# computed_metrics: [0.5543862042754326]
# computed_metrics: [0.5769447403776805]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5635527559664726]
# computed_metrics: [0.5635527559664726]
# computed_metrics: [0.5897531766803413]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5247522999216538]
# computed_metrics: [0.5247522999216538]
# computed_metrics: [0.5581962123374375]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.6013425728441623]
# computed_metrics: [0.6013425728441623]
# computed_metrics: [0.6579492394918611]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5453396057890546]
# computed_metrics: [0.5453396057890546]
# computed_metrics: [0.5759285241337475]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5382864533397834]
# computed_metrics: [0.5382864533397834]
# computed_metrics: [0.5807901719127571]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.520730806613311]
# computed_metrics: [0.520730806613311]
# computed_metrics: [0.5576411601461828]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5133010107763545]
# computed_metrics: [0.5133010107763545]
# computed_metrics: [0.5587172841470424]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5260711779652636]
# computed_metrics: [0.5260711779652636]
# computed_metrics: [0.5767290508740793]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5061872402308003]
# computed_metrics: [0.5061872402308003]
# computed_metrics: [0.5468635458631176]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.4969175642934639]
# computed_metrics: [0.4969175642934639]
# computed_metrics: [0.5450443529529398]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.49993381866346276]
# computed_metrics: [0.49993381866346276]
# computed_metrics: [0.5670314998785072]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5201764591751353]
# computed_metrics: [0.5201764591751353]
# computed_metrics: [0.5844369354783004]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.4821832137360551]
# computed_metrics: [0.4821832137360551]
# computed_metrics: [0.5445324112208606]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.4944860039950665]
# computed_metrics: [0.4944860039950665]
# computed_metrics: [0.5688124755410112]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5112197650100765]
# computed_metrics: [0.5112197650100765]
# computed_metrics: [0.5795818433248209]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.48071423376800987]
# computed_metrics: [0.48071423376800987]
# computed_metrics: [0.5518998440502282]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.486900557212975]
# computed_metrics: [0.486900557212975]
# computed_metrics: [0.569781590595808]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.49426856844578954]
# computed_metrics: [0.49426856844578954]
# computed_metrics: [0.5680162175396944]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.49049656456122875]
# computed_metrics: [0.49049656456122875]
# computed_metrics: [0.5659656210088314]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5031529496599216]
# computed_metrics: [0.5031529496599216]
# computed_metrics: [0.5954869811387061]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.5152873514355766]
# computed_metrics: [0.5152873514355766]
# computed_metrics: [0.5812728114608514]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5572106984210486]
# computed_metrics: [0.5572106984210486]
# computed_metrics: [0.6230175100050658]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.6009300747192298]
# computed_metrics: [0.6009300747192298]
# computed_metrics: [0.6724767486732275]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.4966794863956289]
# computed_metrics: [0.4966794863956289]
# computed_metrics: [0.5449611044104689]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.4743724351742]
# computed_metrics: [0.4743724351742]
# computed_metrics: [0.5468728855039799]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.5393860395830826]
# computed_metrics: [0.5393860395830826]
# computed_metrics: [0.6212285785184875]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.49623334252299106]
# computed_metrics: [0.49623334252299106]
# computed_metrics: [0.5606410643734289]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.5017673077433695]
# computed_metrics: [0.5017673077433695]
# computed_metrics: [0.5876972020869558]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.528518763798538]
# computed_metrics: [0.528518763798538]
# computed_metrics: [0.6217025278105967]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4976439595939114]
# computed_metrics: [0.4976439595939114]
# computed_metrics: [0.5807428126189972]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.5044312210661043]
# computed_metrics: [0.5044312210661043]
# computed_metrics: [0.6203155274676239]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.527649284808364]
# computed_metrics: [0.527649284808364]
# computed_metrics: [0.6255111823102287]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.5202018421450818]
# computed_metrics: [0.5202018421450818]
# computed_metrics: [0.6312298501253008]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.5096002761158059]
# computed_metrics: [0.5096002761158059]
# computed_metrics: [0.619080193605097]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.518184078842415]
# computed_metrics: [0.518184078842415]
# computed_metrics: [0.6356230818085417]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.5526019126216688]
# computed_metrics: [0.5526019126216688]
# computed_metrics: [0.6686352802031135]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.5432541076579246]
# computed_metrics: [0.5432541076579246]
# computed_metrics: [0.6338357264057091]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.5584022531962775]
# computed_metrics: [0.5584022531962775]
# computed_metrics: [0.6568754293305984]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.5137953161770277]
# computed_metrics: [0.5137953161770277]
# computed_metrics: [0.6157584171614825]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.532020663418413]
# computed_metrics: [0.532020663418413]
# computed_metrics: [0.6524263481399957]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.5529573536282527]
# computed_metrics: [0.5529573536282527]
# computed_metrics: [0.6628499265322096]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.48561107243804047]
# computed_metrics: [0.48561107243804047]
# computed_metrics: [0.6014572459761499]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.4559124673989671]
# computed_metrics: [0.4559124673989671]
# computed_metrics: [0.5735901039417727]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.4808377014221389]
# computed_metrics: [0.4808377014221389]
# computed_metrics: [0.5812726112918858]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.44458762808918845]
# computed_metrics: [0.44458762808918845]
# computed_metrics: [0.5607034236803199]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4329654130935843]
# computed_metrics: [0.4329654130935843]
# computed_metrics: [0.5504183005069666]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.5066137318324568]
# computed_metrics: [0.5066137318324568]
# computed_metrics: [0.6001252053535575]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.5847019550166684]
# computed_metrics: [0.5847019550166684]
# computed_metrics: [0.6795266920017675]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.5433948000969017]
# computed_metrics: [0.5433948000969017]
# computed_metrics: [0.6293700749407691]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5059637844327962]
# computed_metrics: [0.5059637844327962]
# computed_metrics: [0.5961481283935751]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.44890068612845346]
# computed_metrics: [0.44890068612845346]
# computed_metrics: [0.5503588668703038]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4036802833572435]
# computed_metrics: [0.4036802833572435]
# computed_metrics: [0.5263432965991205]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.39541662420697127]
# computed_metrics: [0.39541662420697127]
# computed_metrics: [0.5278830446301181]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.392501135822269]
# computed_metrics: [0.392501135822269]
# computed_metrics: [0.5324303647803307]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.3864171517233457]
# computed_metrics: [0.3864171517233457]
# computed_metrics: [0.520210497477754]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.399918164473872]
# computed_metrics: [0.399918164473872]
# computed_metrics: [0.5567940452028818]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.3884267127214815]
# computed_metrics: [0.3884267127214815]
# computed_metrics: [0.515739207326227]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.3685148544881549]
# computed_metrics: [0.3685148544881549]
# computed_metrics: [0.5373950200207465]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.34903160308746434]
# computed_metrics: [0.34903160308746434]
# computed_metrics: [0.503331157889626]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.3423045276031171]
# computed_metrics: [0.3423045276031171]
# computed_metrics: [0.5017226445431302]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.3424307332237169]
# computed_metrics: [0.3424307332237169]
# computed_metrics: [0.5103898126266764]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.3392333163585763]
# computed_metrics: [0.3392333163585763]
# computed_metrics: [0.5154930214709247]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.3493985281930623]
# computed_metrics: [0.3493985281930623]
# computed_metrics: [0.5167100426898797]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.37881225270534963]
# computed_metrics: [0.37881225270534963]
# computed_metrics: [0.5461732795431324]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.37472640201595203]
# computed_metrics: [0.37472640201595203]
# computed_metrics: [0.5473823587502148]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.3504883832740431]
# computed_metrics: [0.3504883832740431]
# computed_metrics: [0.5239834290157599]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.4010700747154512]
# computed_metrics: [0.4010700747154512]
# computed_metrics: [0.5561830522102802]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.381078422089956]
# computed_metrics: [0.381078422089956]
# computed_metrics: [0.5503309907587431]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.33094488553413387]
# computed_metrics: [0.33094488553413387]
# computed_metrics: [0.5207068172824691]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.37779342332827387]
# computed_metrics: [0.37779342332827387]
# computed_metrics: [0.5381702565207289]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.3762705120756504]
# computed_metrics: [0.3762705120756504]
# computed_metrics: [0.5312836893717676]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.3807612441576396]
# computed_metrics: [0.3807612441576396]
# computed_metrics: [0.5796360617730875]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.3496329311759616]
# computed_metrics: [0.3496329311759616]
# computed_metrics: [0.5193538520898775]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.37922879764656214]
# computed_metrics: [0.37922879764656214]
# computed_metrics: [0.5489802890140484]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.5171874630979572]
# computed_metrics: [0.5171874630979572]
# computed_metrics: [0.650353758820352]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.4427523695556541]
# computed_metrics: [0.4427523695556541]
# computed_metrics: [0.5861573523292046]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.4329690095718893]
# computed_metrics: [0.4329690095718893]
# computed_metrics: [0.5890122493768929]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.42749453408623983]
# computed_metrics: [0.42749453408623983]
# computed_metrics: [0.6122847294038136]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.39265408027629184]
# computed_metrics: [0.39265408027629184]
# computed_metrics: [0.5597196562827307]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.3581550256221796]
# computed_metrics: [0.3581550256221796]
# computed_metrics: [0.5354190955768507]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.37496982349241964]
# computed_metrics: [0.37496982349241964]
# computed_metrics: [0.533424275916761]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3361830954514261]
# computed_metrics: [0.3361830954514261]
# computed_metrics: [0.49860176049247895]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.33066024270299443]
# computed_metrics: [0.33066024270299443]
# computed_metrics: [0.4953603820632196]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.3525705656281054]
# computed_metrics: [0.3525705656281054]
# computed_metrics: [0.5308456363670263]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.3439605734865025]
# computed_metrics: [0.3439605734865025]
# computed_metrics: [0.53084533795376]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.354979019480676]
# computed_metrics: [0.354979019480676]
# computed_metrics: [0.5318800375887613]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.3621570492575875]
# computed_metrics: [0.3621570492575875]
# computed_metrics: [0.5521933739438346]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.3147929353448675]
# computed_metrics: [0.3147929353448675]
# computed_metrics: [0.527469800581713]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3238927441423418]
# computed_metrics: [0.3238927441423418]
# computed_metrics: [0.5251059545879827]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.30779629858254665]
# computed_metrics: [0.30779629858254665]
# computed_metrics: [0.5178312589460982]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.34969540656023224]
# computed_metrics: [0.34969540656023224]
# computed_metrics: [0.5563913206354796]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.43400593022007083]
# computed_metrics: [0.43400593022007083]
# computed_metrics: [0.6077260427173874]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.49635294484960196]
# computed_metrics: [0.49635294484960196]
# computed_metrics: [0.6628105327414967]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.41858924708540357]
# computed_metrics: [0.41858924708540357]
# computed_metrics: [0.5850433698402867]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.48111879841614863]
# computed_metrics: [0.48111879841614863]
# computed_metrics: [0.6130823489738313]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.35181661307525575]
# computed_metrics: [0.35181661307525575]
# computed_metrics: [0.5012178415715447]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.33827390284673603]
# computed_metrics: [0.33827390284673603]
# computed_metrics: [0.5294377094749113]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3712506509718007]
# computed_metrics: [0.3712506509718007]
# computed_metrics: [0.5437925126559422]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.3820660534785305]
# computed_metrics: [0.3820660534785305]
# computed_metrics: [0.5479240632503657]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.4157906831279813]
# computed_metrics: [0.4157906831279813]
# computed_metrics: [0.601778734543009]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.4032024420924998]
# computed_metrics: [0.4032024420924998]
# computed_metrics: [0.5863549063386532]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.32741331642522076]
# computed_metrics: [0.32741331642522076]
# computed_metrics: [0.5313358633724965]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.3265254952045023]
# computed_metrics: [0.3265254952045023]
# computed_metrics: [0.5051697982335486]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3398423538795176]
# computed_metrics: [0.3398423538795176]
# computed_metrics: [0.5544120764103175]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.37628437454388713]
# computed_metrics: [0.37628437454388713]
# computed_metrics: [0.5616733941488827]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.3735144714264725]
# computed_metrics: [0.3735144714264725]
# computed_metrics: [0.5654286881791558]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.3499381899083549]
# computed_metrics: [0.3499381899083549]
# computed_metrics: [0.5433443277566378]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.30881704871661575]
# computed_metrics: [0.30881704871661575]
# computed_metrics: [0.4966415563589714]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3560918068810752]
# computed_metrics: [0.3560918068810752]
# computed_metrics: [0.5380726284764898]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.42734793659671383]
# computed_metrics: [0.42734793659671383]
# computed_metrics: [0.6094510985006591]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.3614181850718969]
# computed_metrics: [0.3614181850718969]
# computed_metrics: [0.5609982523410743]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.3024769913073291]
# computed_metrics: [0.3024769913073291]
# computed_metrics: [0.5223270019276987]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.29776509574446713]
# computed_metrics: [0.29776509574446713]
# computed_metrics: [0.5244030813147778]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3947826604813793]
# computed_metrics: [0.3947826604813793]
# computed_metrics: [0.6039539430659443]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.4098794690839232]
# computed_metrics: [0.4098794690839232]
# computed_metrics: [0.5992378107222606]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.3289624056979772]
# computed_metrics: [0.3289624056979772]
# computed_metrics: [0.5247195323014257]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.3407716521249174]
# computed_metrics: [0.3407716521249174]
# computed_metrics: [0.5404725024644661]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.3784176399710777]
# computed_metrics: [0.3784176399710777]
# computed_metrics: [0.5751762453919902]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3568246957614664]
# computed_metrics: [0.3568246957614664]
# computed_metrics: [0.5708155805114777]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.30914516614754073]
# computed_metrics: [0.30914516614754073]
# computed_metrics: [0.5228574130164917]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3093646994100104]
# computed_metrics: [0.3093646994100104]
# computed_metrics: [0.5284929244305933]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.4103980570724999]
# computed_metrics: [0.4103980570724999]
# computed_metrics: [0.5996637056304654]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.4134207883143236]
# computed_metrics: [0.4134207883143236]
# computed_metrics: [0.5860024205455366]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3257643402340425]
# computed_metrics: [0.3257643402340425]
# computed_metrics: [0.5234249364641845]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.3281682734672127]
# computed_metrics: [0.3281682734672127]
# computed_metrics: [0.5345909462403773]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.35036102950821923]
# computed_metrics: [0.35036102950821923]
# computed_metrics: [0.5780257606447026]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.3032930250105673]
# computed_metrics: [0.3032930250105673]
# computed_metrics: [0.5472171308449157]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.29596379297782693]
# computed_metrics: [0.29596379297782693]
# computed_metrics: [0.5437280138541711]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.3552077251855848]
# computed_metrics: [0.3552077251855848]
# computed_metrics: [0.5717089967819221]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.29481884520620744]
# computed_metrics: [0.29481884520620744]
# computed_metrics: [0.531741057166782]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.31965904873518974]
# computed_metrics: [0.31965904873518974]
# computed_metrics: [0.5364065760384753]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.35333322290801816]
# computed_metrics: [0.35333322290801816]
# computed_metrics: [0.5747766028024777]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.29203964376921315]
# computed_metrics: [0.29203964376921315]
# computed_metrics: [0.5234947634312792]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.28624588348448454]
# computed_metrics: [0.28624588348448454]
# computed_metrics: [0.5467778297609448]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.30898278629832715]
# computed_metrics: [0.30898278629832715]
# computed_metrics: [0.5514662165180558]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.3031963069115166]
# computed_metrics: [0.3031963069115166]
# computed_metrics: [0.5412214522325096]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.26763628367873615]
# computed_metrics: [0.26763628367873615]
# computed_metrics: [0.5190895552715832]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.2957497097096568]
# computed_metrics: [0.2957497097096568]
# computed_metrics: [0.5412833752386265]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.3536297363862113]
# computed_metrics: [0.3536297363862113]
# computed_metrics: [0.5853661400148709]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.2927022653931827]
# computed_metrics: [0.2927022653931827]
# computed_metrics: [0.5585691732017212]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.2668395977030557]
# computed_metrics: [0.2668395977030557]
# computed_metrics: [0.5281857805677678]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.3291811433565267]
# computed_metrics: [0.3291811433565267]
# computed_metrics: [0.5780149472600302]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.317894824039888]
# computed_metrics: [0.317894824039888]
# computed_metrics: [0.5759737408939213]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.25602517685438475]
# computed_metrics: [0.25602517685438475]
# computed_metrics: [0.5217979811167923]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.34731758701883453]
# computed_metrics: [0.34731758701883453]
# computed_metrics: [0.5918193956534558]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.33923247264789547]
# computed_metrics: [0.33923247264789547]
# computed_metrics: [0.585424108189024]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.25962583107529175]
# computed_metrics: [0.25962583107529175]
# computed_metrics: [0.530172250573714]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.2991432667893524]
# computed_metrics: [0.2991432667893524]
# computed_metrics: [0.5741331436163073]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.35599766623236306]
# computed_metrics: [0.35599766623236306]
# computed_metrics: [0.5860172415595303]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.269329544055813]
# computed_metrics: [0.269329544055813]
# computed_metrics: [0.49986662223811285]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.2787287293086693]
# computed_metrics: [0.2787287293086693]
# computed_metrics: [0.5360608220654441]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.3465468514128184]
# computed_metrics: [0.3465468514128184]
# computed_metrics: [0.593845063076904]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.2995977577180341]
# computed_metrics: [0.2995977577180341]
# computed_metrics: [0.5539545181985169]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.2741370470114733]
# computed_metrics: [0.2741370470114733]
# computed_metrics: [0.5633461277717663]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.35979161128999393]
# computed_metrics: [0.35979161128999393]
# computed_metrics: [0.6086617140749738]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.3170353450911537]
# computed_metrics: [0.3170353450911537]
# computed_metrics: [0.5571956204912175]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.2569136717337358]
# computed_metrics: [0.2569136717337358]
# computed_metrics: [0.522780705424242]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.29446465586476206]
# computed_metrics: [0.29446465586476206]
# computed_metrics: [0.5455686708420571]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.33836683796592026]
# computed_metrics: [0.33836683796592026]
# computed_metrics: [0.5816652884058523]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.26289075401230727]
# computed_metrics: [0.26289075401230727]
# computed_metrics: [0.5465525258912972]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.2694989432705006]
# computed_metrics: [0.2694989432705006]
# computed_metrics: [0.5583177861574244]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.3417095436118938]
# computed_metrics: [0.3417095436118938]
# computed_metrics: [0.5683395848354206]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.2726592189152635]
# computed_metrics: [0.2726592189152635]
# computed_metrics: [0.5472456135397327]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.24037899220731754]
# computed_metrics: [0.24037899220731754]
# computed_metrics: [0.5213692786349283]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.32032811028684877]
# computed_metrics: [0.32032811028684877]
# computed_metrics: [0.5809771371819226]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.3064242025492514]
# computed_metrics: [0.3064242025492514]
# computed_metrics: [0.5800407217511495]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.24950647687793182]
# computed_metrics: [0.24950647687793182]
# computed_metrics: [0.5435006895605986]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3027786603598772]
# computed_metrics: [0.3027786603598772]
# computed_metrics: [0.586905586092209]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.3276316028892768]
# computed_metrics: [0.3276316028892768]
# computed_metrics: [0.5704853139618677]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.24185438036038606]
# computed_metrics: [0.24185438036038606]
# computed_metrics: [0.5112676467770016]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.2846405983275726]
# computed_metrics: [0.2846405983275726]
# computed_metrics: [0.551121674276528]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.3736475586451361]
# computed_metrics: [0.3736475586451361]
# computed_metrics: [0.629544010946368]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.29030296411543904]
# computed_metrics: [0.29030296411543904]
# computed_metrics: [0.5634148442670184]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.3119696211074426]
# computed_metrics: [0.3119696211074426]
# computed_metrics: [0.594666401304992]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.39398582136161236]
# computed_metrics: [0.39398582136161236]
# computed_metrics: [0.641117758137075]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.3061518791997773]
# computed_metrics: [0.3061518791997773]
# computed_metrics: [0.5613124844117986]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.2597305263757006]
# computed_metrics: [0.2597305263757006]
# computed_metrics: [0.5302261343280168]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.3109044525479372]
# computed_metrics: [0.3109044525479372]
# computed_metrics: [0.5947497895445522]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.33042519841354995]
# computed_metrics: [0.33042519841354995]
# computed_metrics: [0.5934738847349783]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.25908758959867617]
# computed_metrics: [0.25908758959867617]
# computed_metrics: [0.57134922970339]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.3120038791454484]
# computed_metrics: [0.3120038791454484]
# computed_metrics: [0.5883082075508026]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.3019093622343396]
# computed_metrics: [0.3019093622343396]
# computed_metrics: [0.5561822198513927]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.2651479057993273]
# computed_metrics: [0.2651479057993273]
# computed_metrics: [0.5528430928970455]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.30087082800297665]
# computed_metrics: [0.30087082800297665]
# computed_metrics: [0.5603667749871961]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.3413475568203511]
# computed_metrics: [0.3413475568203511]
# computed_metrics: [0.6058901489271252]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.2785054297721112]
# computed_metrics: [0.2785054297721112]
# computed_metrics: [0.5544436347423914]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.28243908682610297]
# computed_metrics: [0.28243908682610297]
# computed_metrics: [0.5692625320292876]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.32590995852162763]
# computed_metrics: [0.32590995852162763]
# computed_metrics: [0.5889823290384325]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.3124843007963833]
# computed_metrics: [0.3124843007963833]
# computed_metrics: [0.5788097586172921]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.2663371891636171]
# computed_metrics: [0.2663371891636171]
# computed_metrics: [0.5282654973995112]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.35112777111343696]
# computed_metrics: [0.35112777111343696]
# computed_metrics: [0.6167442096510178]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.309241317321043]
# computed_metrics: [0.309241317321043]
# computed_metrics: [0.6033499142387282]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.25295971675915657]
# computed_metrics: [0.25295971675915657]
# computed_metrics: [0.5552877080071975]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.3683529264524778]
# computed_metrics: [0.3683529264524778]
# computed_metrics: [0.6107896199274416]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.3051085179508174]
# computed_metrics: [0.3051085179508174]
# computed_metrics: [0.5353087566313758]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.2615888739741701]
# computed_metrics: [0.2615888739741701]
# computed_metrics: [0.5364574526813791]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.31620068574944676]
# computed_metrics: [0.31620068574944676]
# computed_metrics: [0.5798089570119991]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.297027948572497]
# computed_metrics: [0.297027948572497]
# computed_metrics: [0.5768402701435673]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.24798322440993878]
# computed_metrics: [0.24798322440993878]
# computed_metrics: [0.5344016985941653]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.3080388284173519]
# computed_metrics: [0.3080388284173519]
# computed_metrics: [0.5779275263301525]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.26811484177786976]
# computed_metrics: [0.26811484177786976]
# computed_metrics: [0.546355127897788]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.2696762444683619]
# computed_metrics: [0.2696762444683619]
# computed_metrics: [0.5451112326122485]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.32562341281665375]
# computed_metrics: [0.32562341281665375]
# computed_metrics: [0.5865555223244502]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.25425115304799545]
# computed_metrics: [0.25425115304799545]
# computed_metrics: [0.551692853672645]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.3085762233332254]
# computed_metrics: [0.3085762233332254]
# computed_metrics: [0.5885332738648161]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.27816550304647497]
# computed_metrics: [0.27816550304647497]
# computed_metrics: [0.5501820475837491]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.2478384616463066]
# computed_metrics: [0.2478384616463066]
# computed_metrics: [0.5320056982537088]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.2827896076493225]
# computed_metrics: [0.2827896076493225]
# computed_metrics: [0.54993205291116]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.3012317630443381]
# computed_metrics: [0.3012317630443381]
# computed_metrics: [0.5818435488066777]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.24475272558345537]
# computed_metrics: [0.24475272558345537]
# computed_metrics: [0.5420419889729943]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.34029189244363095]
# computed_metrics: [0.34029189244363095]
# computed_metrics: [0.6169937359139865]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.3337587380190685]
# computed_metrics: [0.3337587380190685]
# computed_metrics: [0.573787928399544]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.2701094616301682]
# computed_metrics: [0.2701094616301682]
# computed_metrics: [0.5270242548864512]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.38406266161835]
# computed_metrics: [0.38406266161835]
# computed_metrics: [0.6421344493246893]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.2979281813650765]
# computed_metrics: [0.2979281813650765]
# computed_metrics: [0.5799135199068537]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.2953674447788376]
# computed_metrics: [0.2953674447788376]
# computed_metrics: [0.5648786990777792]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.3425334271674517]
# computed_metrics: [0.3425334271674517]
# computed_metrics: [0.594979368342545]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.2695489525826661]
# computed_metrics: [0.2695489525826661]
# computed_metrics: [0.549428456445477]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.2538810357605131]
# computed_metrics: [0.2538810357605131]
# computed_metrics: [0.5435729179127686]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.290771430273513]
# computed_metrics: [0.290771430273513]
# computed_metrics: [0.5734711394315116]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.24002132539634385]
# computed_metrics: [0.24002132539634385]
# computed_metrics: [0.5445389342578103]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.28370849930127073]
# computed_metrics: [0.28370849930127073]
# computed_metrics: [0.5510620548222257]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.30018843273134377]
# computed_metrics: [0.30018843273134377]
# computed_metrics: [0.5661363043834892]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.25098425755228027]
# computed_metrics: [0.25098425755228027]
# computed_metrics: [0.553895566450043]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.3479411501705865]
# computed_metrics: [0.3479411501705865]
# computed_metrics: [0.6149297349559186]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.2321921708307121]
# computed_metrics: [0.2321921708307121]
# computed_metrics: [0.5509374556425527]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.29298717868914165]
# computed_metrics: [0.29298717868914165]
# computed_metrics: [0.5832885874472583]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.25697475040870826]
# computed_metrics: [0.25697475040870826]
# computed_metrics: [0.5569432479178177]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.24575383659741135]
# computed_metrics: [0.24575383659741135]
# computed_metrics: [0.531598197654546]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.2816037905630916]
# computed_metrics: [0.2816037905630916]
# computed_metrics: [0.5795738311932965]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.2179115945238649]
# computed_metrics: [0.2179115945238649]
# computed_metrics: [0.5386933856223866]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.2939746062244581]
# computed_metrics: [0.2939746062244581]
# computed_metrics: [0.5877270258873909]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.2560455402265913]
# computed_metrics: [0.2560455402265913]
# computed_metrics: [0.5495180717559908]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.24538858263709126]
# computed_metrics: [0.24538858263709126]
# computed_metrics: [0.5474661736625098]
# Starting epoch 288
# ...
# computed_metrics: [0.17643263077713547]
# computed_metrics: [0.17643263077713547]
# computed_metrics: [0.564652820607395]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.27934797738166783]
# computed_metrics: [0.27934797738166783]
# computed_metrics: [0.6039424458053243]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.1927854848678571]
# computed_metrics: [0.1927854848678571]
# computed_metrics: [0.5646023163160255]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.20831676574356317]
# computed_metrics: [0.20831676574356317]
# computed_metrics: [0.5732386167668168]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.2416294046048734]
# computed_metrics: [0.2416294046048734]
# computed_metrics: [0.5740181305820484]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.18357173232759225]
# computed_metrics: [0.18357173232759225]
# computed_metrics: [0.5550299052744345]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.2772915586709607]
# computed_metrics: [0.2772915586709607]
# computed_metrics: [0.589206418720884]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.1821354036546787]
# computed_metrics: [0.1821354036546787]
# computed_metrics: [0.5443790002725226]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.22045999052954632]
# computed_metrics: [0.22045999052954632]
# computed_metrics: [0.5544717059498733]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.22149836519423582]
# computed_metrics: [0.22149836519423582]
# computed_metrics: [0.5534702210254837]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.191090526284371]
# computed_metrics: [0.191090526284371]
# computed_metrics: [0.564999484807901]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.25594196951615017]
# computed_metrics: [0.25594196951615017]
# computed_metrics: [0.5847331604931858]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.17639567822018767]
# computed_metrics: [0.17639567822018767]
# computed_metrics: [0.553150247943058]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.2519337570562732]
# computed_metrics: [0.2519337570562732]
# computed_metrics: [0.5772224737271172]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.21994533828411333]
# computed_metrics: [0.21994533828411333]
# computed_metrics: [0.5712836178061753]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.2154431002101875]
# computed_metrics: [0.2154431002101875]
# computed_metrics: [0.5830305895432664]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.25148634461359537]
# computed_metrics: [0.25148634461359537]
# computed_metrics: [0.5803539496038439]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.17272336190222484]
# computed_metrics: [0.17272336190222484]
# computed_metrics: [0.5517506960206086]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.23381586754599698]
# computed_metrics: [0.23381586754599698]
# computed_metrics: [0.5716114932170895]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.19519551916071518]
# computed_metrics: [0.19519551916071518]
# computed_metrics: [0.5425151036449137]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.21552064852167455]
# computed_metrics: [0.21552064852167455]
# computed_metrics: [0.5719801007637794]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.22055493341552332]
# computed_metrics: [0.22055493341552332]
# computed_metrics: [0.5609144001210185]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.18072675820069803]
# computed_metrics: [0.18072675820069803]
# computed_metrics: [0.5436392112883233]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.21871030890426707]
# computed_metrics: [0.21871030890426707]
# computed_metrics: [0.5620018145322911]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.18216893165040512]
# computed_metrics: [0.18216893165040512]
# computed_metrics: [0.545676590855386]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.22417283568372526]
# computed_metrics: [0.22417283568372526]
# computed_metrics: [0.5800850169299081]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.19357623347115963]
# computed_metrics: [0.19357623347115963]
# computed_metrics: [0.5531273012423801]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.18053795738393666]
# computed_metrics: [0.18053795738393666]
# computed_metrics: [0.5495869530339612]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.21851105572721044]
# computed_metrics: [0.21851105572721044]
# computed_metrics: [0.566082697938719]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.16535967280125688]
# computed_metrics: [0.16535967280125688]
# computed_metrics: [0.5608965862988687]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.23365680382657222]
# computed_metrics: [0.23365680382657222]
# computed_metrics: [0.5947175401914805]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.17299200566222278]
# computed_metrics: [0.17299200566222278]
# computed_metrics: [0.5455887505521546]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.23769745671878553]
# computed_metrics: [0.23769745671878553]
# computed_metrics: [0.5759359141726265]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.22139316386404115]
# computed_metrics: [0.22139316386404115]
# computed_metrics: [0.5608663095543338]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.1986261074799369]
# computed_metrics: [0.1986261074799369]
# computed_metrics: [0.5774454714111746]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.2735941680526214]
# computed_metrics: [0.2735941680526214]
# computed_metrics: [0.5891110141912508]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.16918365779723255]
# computed_metrics: [0.16918365779723255]
# computed_metrics: [0.5317893092854526]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.23276884120878882]
# computed_metrics: [0.23276884120878882]
# computed_metrics: [0.5711340461136355]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.2149769784306621]
# computed_metrics: [0.2149769784306621]
# computed_metrics: [0.5518045532852578]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.19420686555780745]
# computed_metrics: [0.19420686555780745]
# computed_metrics: [0.5639244386604154]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.22594965540864287]
# computed_metrics: [0.22594965540864287]
# computed_metrics: [0.5714214626039672]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.16464378912307406]
# computed_metrics: [0.16464378912307406]
# computed_metrics: [0.5484675088116905]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.22927151655440223]
# computed_metrics: [0.22927151655440223]
# computed_metrics: [0.5763280703224634]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.20737428061391525]
# computed_metrics: [0.20737428061391525]
# computed_metrics: [0.5531031430463085]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.22958891281532146]
# computed_metrics: [0.22958891281532146]
# computed_metrics: [0.5767973892988676]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.22075245730201212]
# computed_metrics: [0.22075245730201212]
# computed_metrics: [0.5641973985536732]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.18663877648344956]
# computed_metrics: [0.18663877648344956]
# computed_metrics: [0.5552001228631714]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.2281442801191925]
# computed_metrics: [0.2281442801191925]
# computed_metrics: [0.5473492561202162]
# [2.7065375478833955, 1.8654848823165924, 1.2694316000448473, 1.0442957719583819, 0.9651598626120231, 0.9423955391020045, 0.9284858914214351, 0.9143056831243247, 0.9110091378550775, 0.8985278725058318, 0.8601841805980657, 0.8732156146059655, 0.859822344094411, 0.8547932002269412, 0.8487423272455371, 0.840157253644685, 0.83647353201829, 0.8265357472481754, 0.8228707323800497, 0.8140579644486061, 0.8070071430648931, 0.8063751939364916, 0.7962210103428419, 0.794146347341862, 0.7835330388452373, 0.781260201052184, 0.7958481492073292, 0.8078299820350472, 0.7910677732093485, 0.7653686027736862, 0.7738206794534955, 0.7534443696430114, 0.7388627146811666, 0.7329861164788006, 0.7391397609842597, 0.7176044995286482, 0.7153863867508196, 0.7035387190411024, 0.7094515115577629, 0.690105279216617, 0.6840236131719382, 0.672153485825067, 0.6463572407199342, 0.6476879826317946, 0.6466712338874788, 0.6272329656026141, 0.5938066811567744, 0.5722229894428275, 0.5757453500634596, 0.5635926491905989, 0.564250135809285, 0.5516862257297159, 0.5387769380017555, 0.5543862042754326, 0.5635527559664726, 0.5247522999216538, 0.6013425728441623, 0.5453396057890546, 0.5382864533397834, 0.520730806613311, 0.5133010107763545, 0.5260711779652636, 0.5061872402308003, 0.4969175642934639, 0.49993381866346276
#  [0.20640365 0.56300934]
#  [0.17885557 0.57828719]
#  [0.22903132 0.59720294]
#  [0.16162115 0.551504  ]
#  [0.20274501 0.56345968]
#  [0.20983497 0.57248762]
#  [0.19346656 0.57617202]
#  [0.26708478 0.60786555]
#  [0.17265965 0.55095439]
#  [0.24994411 0.58953171]
#  [0.22621587 0.56404959]
#  [0.19801843 0.55748994]
#  [0.25945546 0.60206302]
#  [0.18416353 0.56864499]
#  [0.21173245 0.57882711]
#  [0.22244336 0.57088979]
#  [0.17643263 0.56465282]
#  [0.27934798 0.60394245]
#  [0.19278548 0.56460232]
#  [0.20831677 0.57323862]
#  [0.2416294  0.57401813]
#  [0.18357173 0.55502991]
#  [0.27729156 0.58920642]
#  [0.1821354  0.544379  ]
#  [0.22045999 0.55447171]
#  [0.22149837 0.55347022]
#  [0.19109053 0.56499948]
#  [0.25594197 0.58473316]
#  [0.17639568 0.55315025]
#  [0.25193376 0.57722247]
#  [0.21994534 0.57128362]
#  [0.2154431  0.58303059]
#  [0.25148634 0.58035395]
#  [0.17272336 0.5517507 ]
#  [0.23381587 0.57161149]
#  [0.19519552 0.5425151 ]
#  [0.21552065 0.5719801 ]
#  [0.22055493 0.5609144 ]
#  [0.18072676 0.54363921]
#  [0.21871031 0.56200181]
#  [0.18216893 0.54567659]
#  [0.22417284 0.58008502]
#  [0.19357623 0.5531273 ]
#  [0.18053796 0.54958695]
#  [0.21851106 0.5660827 ]
#  [0.16535967 0.56089659]
#  [0.2336568  0.59471754]
#  [0.17299201 0.54558875]
#  [0.23769746 0.57593591]
#  [0.22139316 0.56086631]
#  [0.19862611 0.57744547]
#  [0.27359417 0.58911101]
#  [0.16918366 0.53178931]
#  [0.23276884 0.57113405]
#  [0.21497698 0.55180455]
#  [0.19420687 0.56392444]
#  [0.22594966 0.57142146]
#  [0.16464379 0.54846751]
#  [0.22927152 0.57632807]
#  [0.20737428 0.55310314]
#  [0.22958891 0.57679739]
#  [0.22075246 0.5641974 ]
#  [0.18663878 0.55520012]
#  [0.22814428 0.54734926]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.4804938539721433]
# computed_metrics: [2.4804938539721433]
# computed_metrics: [2.513657510260531]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.664566445573324]
# computed_metrics: [1.664566445573324]
# computed_metrics: [1.7147046493715548]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.1862834311824362]
# computed_metrics: [1.1862834311824362]
# computed_metrics: [1.2649082950545403]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0093190277832296]
# computed_metrics: [1.0093190277832296]
# computed_metrics: [1.0541761952060316]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9566274972030095]
# computed_metrics: [0.9566274972030095]
# computed_metrics: [0.9727992283375085]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9635385989415285]
# computed_metrics: [0.9635385989415285]
# computed_metrics: [0.9843126365971037]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9380988015337002]
# computed_metrics: [0.9380988015337002]
# computed_metrics: [0.9604006379343973]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9500270666605055]
# computed_metrics: [0.9500270666605055]
# computed_metrics: [0.9689699718730017]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.9216792696362831]
# computed_metrics: [0.9216792696362831]
# computed_metrics: [0.9399805996043202]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.9157557182794156]
# computed_metrics: [0.9157557182794156]
# computed_metrics: [0.9312215256707379]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.9095370690598344]
# computed_metrics: [0.9095370690598344]
# computed_metrics: [0.9229750969797689]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.9064801553643667]
# computed_metrics: [0.9064801553643667]
# computed_metrics: [0.9222733741355703]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.890437549214798]
# computed_metrics: [0.890437549214798]
# computed_metrics: [0.905326611043418]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.902753491711552]
# computed_metrics: [0.902753491711552]
# computed_metrics: [0.9157090146471363]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8819729920512452]
# computed_metrics: [0.8819729920512452]
# computed_metrics: [0.8980717735956422]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.9092106787917626]
# computed_metrics: [0.9092106787917626]
# computed_metrics: [0.9356284937064714]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.869302568784479]
# computed_metrics: [0.869302568784479]
# computed_metrics: [0.8967981654305256]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8795808132535184]
# computed_metrics: [0.8795808132535184]
# computed_metrics: [0.9167186773814952]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.8747673265151021]
# computed_metrics: [0.8747673265151021]
# computed_metrics: [0.9087788997745024]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.8647332174740964]
# computed_metrics: [0.8647332174740964]
# computed_metrics: [0.9005583571615785]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.8590283880182352]
# computed_metrics: [0.8590283880182352]
# computed_metrics: [0.9018497552287335]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.8730896891863867]
# computed_metrics: [0.8730896891863867]
# computed_metrics: [0.9032650890110149]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.8656610120850294]
# computed_metrics: [0.8656610120850294]
# computed_metrics: [0.8975532737204241]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.8545360326383223]
# computed_metrics: [0.8545360326383223]
# computed_metrics: [0.8857533374797484]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.852195654491823]
# computed_metrics: [0.852195654491823]
# computed_metrics: [0.8816430115477161]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.8250949715024369]
# computed_metrics: [0.8250949715024369]
# computed_metrics: [0.8555101139929852]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.8314468884693879]
# computed_metrics: [0.8314468884693879]
# computed_metrics: [0.8593193943706156]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.8235282964339936]
# computed_metrics: [0.8235282964339936]
# computed_metrics: [0.8518942046788672]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.794518023817239]
# computed_metrics: [0.794518023817239]
# computed_metrics: [0.830163928378819]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.8067512205507901]
# computed_metrics: [0.8067512205507901]
# computed_metrics: [0.8396556079203679]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.7940831143314762]
# computed_metrics: [0.7940831143314762]
# computed_metrics: [0.8267546485759215]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.736155247601496]
# computed_metrics: [0.736155247601496]
# computed_metrics: [0.7850269676330559]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.7305304808151929]
# computed_metrics: [0.7305304808151929]
# computed_metrics: [0.7651004499882145]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.7189104908583671]
# computed_metrics: [0.7189104908583671]
# computed_metrics: [0.7477324518560834]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6971780182194007]
# computed_metrics: [0.6971780182194007]
# computed_metrics: [0.7273814823935477]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6910500446169209]
# computed_metrics: [0.6910500446169209]
# computed_metrics: [0.7195797918093598]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6832193237449908]
# computed_metrics: [0.6832193237449908]
# computed_metrics: [0.7122326333414108]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6681500453173812]
# computed_metrics: [0.6681500453173812]
# computed_metrics: [0.6823278787853725]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6406809553096227]
# computed_metrics: [0.6406809553096227]
# computed_metrics: [0.662515891271236]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.6477021037538493]
# computed_metrics: [0.6477021037538493]
# computed_metrics: [0.6760450766152398]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6362020849368736]
# computed_metrics: [0.6362020849368736]
# computed_metrics: [0.6650010985962871]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.6330102054211053]
# computed_metrics: [0.6330102054211053]
# computed_metrics: [0.6545876207972785]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.627850826118955]
# computed_metrics: [0.627850826118955]
# computed_metrics: [0.6568094521137988]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.6099744447750046]
# computed_metrics: [0.6099744447750046]
# computed_metrics: [0.6280871893681244]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5960135701963659]
# computed_metrics: [0.5960135701963659]
# computed_metrics: [0.6168016490902752]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5875437951444775]
# computed_metrics: [0.5875437951444775]
# computed_metrics: [0.6205586315940121]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5895288162794935]
# computed_metrics: [0.5895288162794935]
# computed_metrics: [0.6165936858236952]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5745672686153444]
# computed_metrics: [0.5745672686153444]
# computed_metrics: [0.6156122957798598]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5856707042226875]
# computed_metrics: [0.5856707042226875]
# computed_metrics: [0.6172258524001271]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5681842353355542]
# computed_metrics: [0.5681842353355542]
# computed_metrics: [0.6247380812681903]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5574501408432391]
# computed_metrics: [0.5574501408432391]
# computed_metrics: [0.613229333635951]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5955260136553583]
# computed_metrics: [0.5955260136553583]
# computed_metrics: [0.6573387674552905]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.6017472734864245]
# computed_metrics: [0.6017472734864245]
# computed_metrics: [0.6580787558790815]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5537276067896382]
# computed_metrics: [0.5537276067896382]
# computed_metrics: [0.6139908434868014]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5391484878875095]
# computed_metrics: [0.5391484878875095]
# computed_metrics: [0.5866895299749686]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5255466785312968]
# computed_metrics: [0.5255466785312968]
# computed_metrics: [0.5765166325291085]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5506090949475891]
# computed_metrics: [0.5506090949475891]
# computed_metrics: [0.6124320721493943]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5670638167999674]
# computed_metrics: [0.5670638167999674]
# computed_metrics: [0.6370869068143378]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5213109908303772]
# computed_metrics: [0.5213109908303772]
# computed_metrics: [0.5886472329581481]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5190646686986903]
# computed_metrics: [0.5190646686986903]
# computed_metrics: [0.587315726381345]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5140391805658586]
# computed_metrics: [0.5140391805658586]
# computed_metrics: [0.5897600815568337]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5871182425358639]
# computed_metrics: [0.5871182425358639]
# computed_metrics: [0.6695187476191574]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5504010872821693]
# computed_metrics: [0.5504010872821693]
# computed_metrics: [0.6385085348534596]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5021441746760554]
# computed_metrics: [0.5021441746760554]
# computed_metrics: [0.5900374797676256]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.48113581246371884]
# computed_metrics: [0.48113581246371884]
# computed_metrics: [0.5567442099009693]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.49939897646324555]
# computed_metrics: [0.49939897646324555]
# computed_metrics: [0.5994899762227348]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5808366743548995]
# computed_metrics: [0.5808366743548995]
# computed_metrics: [0.6550132528251847]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.6777801680083454]
# computed_metrics: [0.6777801680083454]
# computed_metrics: [0.7471132526183257]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5231888096628958]
# computed_metrics: [0.5231888096628958]
# computed_metrics: [0.6121610403951679]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5047315021401265]
# computed_metrics: [0.5047315021401265]
# computed_metrics: [0.5866780726663811]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5471313967629178]
# computed_metrics: [0.5471313967629178]
# computed_metrics: [0.6446901862581875]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5611564288821895]
# computed_metrics: [0.5611564288821895]
# computed_metrics: [0.6420674185463164]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.49254719454365664]
# computed_metrics: [0.49254719454365664]
# computed_metrics: [0.5786023620749702]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4954341693809646]
# computed_metrics: [0.4954341693809646]
# computed_metrics: [0.5989838795252143]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.53629836129029]
# computed_metrics: [0.53629836129029]
# computed_metrics: [0.6386064738487909]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.4949218289106341]
# computed_metrics: [0.4949218289106341]
# computed_metrics: [0.5982507142420337]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5004503883117105]
# computed_metrics: [0.5004503883117105]
# computed_metrics: [0.6039913634542596]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5269219934687591]
# computed_metrics: [0.5269219934687591]
# computed_metrics: [0.6290552479403476]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.4910725874654429]
# computed_metrics: [0.4910725874654429]
# computed_metrics: [0.6122541171880603]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4708036664595304]
# computed_metrics: [0.4708036664595304]
# computed_metrics: [0.5995228259811518]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.5039198307548443]
# computed_metrics: [0.5039198307548443]
# computed_metrics: [0.6068150254727896]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4565708772974056]
# computed_metrics: [0.4565708772974056]
# computed_metrics: [0.5824928167718032]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.5443094383584477]
# computed_metrics: [0.5443094383584477]
# computed_metrics: [0.6582362442654162]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.5495088726160359]
# computed_metrics: [0.5495088726160359]
# computed_metrics: [0.6490928626163566]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.5821771074146451]
# computed_metrics: [0.5821771074146451]
# computed_metrics: [0.6790909491202729]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.5773137168389769]
# computed_metrics: [0.5773137168389769]
# computed_metrics: [0.6942872779015837]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.45083667239840736]
# computed_metrics: [0.45083667239840736]
# computed_metrics: [0.5651616966605526]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4338741084540425]
# computed_metrics: [0.4338741084540425]
# computed_metrics: [0.556445826673965]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.4888233439684593]
# computed_metrics: [0.4888233439684593]
# computed_metrics: [0.5960926130283307]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.7159692385201]
# computed_metrics: [0.7159692385201]
# computed_metrics: [0.7687319122510694]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.5194630214602075]
# computed_metrics: [0.5194630214602075]
# computed_metrics: [0.6079610244276551]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.4445440601057693]
# computed_metrics: [0.4445440601057693]
# computed_metrics: [0.5753597524695804]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.5144030462523352]
# computed_metrics: [0.5144030462523352]
# computed_metrics: [0.6331669467372385]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4496931460556864]
# computed_metrics: [0.4496931460556864]
# computed_metrics: [0.5507342421606408]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4448775375983183]
# computed_metrics: [0.4448775375983183]
# computed_metrics: [0.55125644827589]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.4266041404088737]
# computed_metrics: [0.4266041404088737]
# computed_metrics: [0.5462920534642928]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.4022875047394346]
# computed_metrics: [0.4022875047394346]
# computed_metrics: [0.5281500595577626]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.40254682747932774]
# computed_metrics: [0.40254682747932774]
# computed_metrics: [0.521871016210714]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.3987732782238469]
# computed_metrics: [0.3987732782238469]
# computed_metrics: [0.5091091084349573]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4254110906840544]
# computed_metrics: [0.4254110906840544]
# computed_metrics: [0.5499155620233572]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4163487624725602]
# computed_metrics: [0.4163487624725602]
# computed_metrics: [0.5323958171258694]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.45781746818514457]
# computed_metrics: [0.45781746818514457]
# computed_metrics: [0.5549655634385514]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.5304044289902795]
# computed_metrics: [0.5304044289902795]
# computed_metrics: [0.6368196053525254]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.4891894686112026]
# computed_metrics: [0.4891894686112026]
# computed_metrics: [0.6075638933252349]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.6009767422557374]
# computed_metrics: [0.6009767422557374]
# computed_metrics: [0.6918220733515869]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.6002983092862816]
# computed_metrics: [0.6002983092862816]
# computed_metrics: [0.6950793321749512]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.5941664049752656]
# computed_metrics: [0.5941664049752656]
# computed_metrics: [0.6993472317984408]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.5411603286623754]
# computed_metrics: [0.5411603286623754]
# computed_metrics: [0.6447334131015486]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.5122229816842255]
# computed_metrics: [0.5122229816842255]
# computed_metrics: [0.6176562731224158]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.4304638813295209]
# computed_metrics: [0.4304638813295209]
# computed_metrics: [0.5560180964258374]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.43161024655965907]
# computed_metrics: [0.43161024655965907]
# computed_metrics: [0.5640669853575762]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.4752616406797209]
# computed_metrics: [0.4752616406797209]
# computed_metrics: [0.6184444045323281]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.5704125557356571]
# computed_metrics: [0.5704125557356571]
# computed_metrics: [0.6942823946495589]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.5459829882161255]
# computed_metrics: [0.5459829882161255]
# computed_metrics: [0.662265506109583]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.5446119270939718]
# computed_metrics: [0.5446119270939718]
# computed_metrics: [0.6549620854136379]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4183490993181768]
# computed_metrics: [0.4183490993181768]
# computed_metrics: [0.5483609626517726]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.39857176665469773]
# computed_metrics: [0.39857176665469773]
# computed_metrics: [0.5242315486247573]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.41507395806448777]
# computed_metrics: [0.41507395806448777]
# computed_metrics: [0.5674932263496455]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.4089214140804018]
# computed_metrics: [0.4089214140804018]
# computed_metrics: [0.5470150669746148]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.405169672062265]
# computed_metrics: [0.405169672062265]
# computed_metrics: [0.5331932003621028]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.35734284669300925]
# computed_metrics: [0.35734284669300925]
# computed_metrics: [0.5078284480109194]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.364968740907343]
# computed_metrics: [0.364968740907343]
# computed_metrics: [0.543068226995039]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.37290020230201015]
# computed_metrics: [0.37290020230201015]
# computed_metrics: [0.5134495471104721]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.38223461684918736]
# computed_metrics: [0.38223461684918736]
# computed_metrics: [0.5360951508288735]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.35682790382261653]
# computed_metrics: [0.35682790382261653]
# computed_metrics: [0.5126980831134204]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.3224038909819662]
# computed_metrics: [0.3224038909819662]
# computed_metrics: [0.5065381747567437]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.34960531567567965]
# computed_metrics: [0.34960531567567965]
# computed_metrics: [0.5252980583467903]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.39924429065073935]
# computed_metrics: [0.39924429065073935]
# computed_metrics: [0.544953083342983]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.4069294419435611]
# computed_metrics: [0.4069294419435611]
# computed_metrics: [0.5696033116440207]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.35605084019636235]
# computed_metrics: [0.35605084019636235]
# computed_metrics: [0.5309589701143784]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.31599660503736915]
# computed_metrics: [0.31599660503736915]
# computed_metrics: [0.5051573267605771]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.3738283414108414]
# computed_metrics: [0.3738283414108414]
# computed_metrics: [0.535153299312131]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.39016987100614975]
# computed_metrics: [0.39016987100614975]
# computed_metrics: [0.5619591872291894]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.4342695292679061]
# computed_metrics: [0.4342695292679061]
# computed_metrics: [0.5782953527817646]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.3873763757491174]
# computed_metrics: [0.3873763757491174]
# computed_metrics: [0.5378321531404122]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.31866538395861393]
# computed_metrics: [0.31866538395861393]
# computed_metrics: [0.49520720788671424]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.3213302750171779]
# computed_metrics: [0.3213302750171779]
# computed_metrics: [0.49597662224893363]
# 12.462122428710945

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.3213302750171779]
# computed_metrics: [0.49597662224893363]
# computed_metrics: [0.5884682998152002]
# {'mean-mean_absolute_error': 0.5884682998152002}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.9338563, 0.0)
# SpearmanrResult(correlation=0.9331387486705389, pvalue=0.0)
# (0.8393633, 3.3470175703754127e-48)
# SpearmanrResult(correlation=0.8553492549838826, pvalue=7.278923790673157e-52)
# (0.75654876, 4.149220008291093e-34)
# SpearmanrResult(correlation=0.7688744181335859, pvalue=7.988284704841366e-36)
