# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gp1 = GraphPool(in_layers=[batch_norm1, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp2 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm3 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm3, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.799 s
# TIMING: dataset construction took 3.249 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.463 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.230 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.224 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 32
C2_filtnum = 32
D_nodenum = 32

graph_structure = 'GC{0}_GP_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [4.02180770379307]
# computed_metrics: [4.02180770379307]
# computed_metrics: [3.952119415127019]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [2.490832473944862]
# computed_metrics: [2.490832473944862]
# computed_metrics: [2.4114858413520563]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.4619306005871977]
# computed_metrics: [1.4619306005871977]
# computed_metrics: [1.426246841348288]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0152341277464638]
# computed_metrics: [1.0152341277464638]
# computed_metrics: [1.0201161740093192]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.945770043970797]
# computed_metrics: [0.945770043970797]
# computed_metrics: [0.9533963481895432]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9202435569619825]
# computed_metrics: [0.9202435569619825]
# computed_metrics: [0.9239013016527414]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9101905707957502]
# computed_metrics: [0.9101905707957502]
# computed_metrics: [0.908869829771892]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9006282680038135]
# computed_metrics: [0.9006282680038135]
# computed_metrics: [0.8971900869045385]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.89084760860522]
# computed_metrics: [0.89084760860522]
# computed_metrics: [0.8870392718328138]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8798881096237924]
# computed_metrics: [0.8798881096237924]
# computed_metrics: [0.875652735616531]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8674715040117871]
# computed_metrics: [0.8674715040117871]
# computed_metrics: [0.8620907804900998]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8521947671812748]
# computed_metrics: [0.8521947671812748]
# computed_metrics: [0.8455098829592311]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.843182382719902]
# computed_metrics: [0.843182382719902]
# computed_metrics: [0.8336885474625747]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8343571016508446]
# computed_metrics: [0.8343571016508446]
# computed_metrics: [0.8260017216981048]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.827586800129278]
# computed_metrics: [0.827586800129278]
# computed_metrics: [0.8164407379648361]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8205600841552266]
# computed_metrics: [0.8205600841552266]
# computed_metrics: [0.8117375431440654]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8134465967627206]
# computed_metrics: [0.8134465967627206]
# computed_metrics: [0.8035320529595188]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8069938795214306]
# computed_metrics: [0.8069938795214306]
# computed_metrics: [0.797062146833658]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.800739707355571]
# computed_metrics: [0.800739707355571]
# computed_metrics: [0.7915697397838215]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7948067262958309]
# computed_metrics: [0.7948067262958309]
# computed_metrics: [0.7860616644576455]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.788352417474109]
# computed_metrics: [0.788352417474109]
# computed_metrics: [0.7818696219721767]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7791005207542316]
# computed_metrics: [0.7791005207542316]
# computed_metrics: [0.7714250453793119]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7678986012762603]
# computed_metrics: [0.7678986012762603]
# computed_metrics: [0.7618512980684434]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7562897252005535]
# computed_metrics: [0.7562897252005535]
# computed_metrics: [0.7527914424331393]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7450941545242721]
# computed_metrics: [0.7450941545242721]
# computed_metrics: [0.7443811292774354]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.7371074531094812]
# computed_metrics: [0.7371074531094812]
# computed_metrics: [0.7371294897492253]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7271378933670958]
# computed_metrics: [0.7271378933670958]
# computed_metrics: [0.7285519963818485]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.7016536459981935]
# computed_metrics: [0.7016536459981935]
# computed_metrics: [0.6932244333734964]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6901781664150476]
# computed_metrics: [0.6901781664150476]
# computed_metrics: [0.6704037728897243]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6788814224704469]
# computed_metrics: [0.6788814224704469]
# computed_metrics: [0.6657608146425378]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6746241967983941]
# computed_metrics: [0.6746241967983941]
# computed_metrics: [0.6626028982613756]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6693344655019425]
# computed_metrics: [0.6693344655019425]
# computed_metrics: [0.6535251719888262]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6681481326353257]
# computed_metrics: [0.6681481326353257]
# computed_metrics: [0.6478057245900803]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6555612640928459]
# computed_metrics: [0.6555612640928459]
# computed_metrics: [0.6333972526051672]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6542856721044588]
# computed_metrics: [0.6542856721044588]
# computed_metrics: [0.6237318896631383]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6439030477167793]
# computed_metrics: [0.6439030477167793]
# computed_metrics: [0.6173912372515783]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6499632575837136]
# computed_metrics: [0.6499632575837136]
# computed_metrics: [0.6162138782248108]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6382687695705086]
# computed_metrics: [0.6382687695705086]
# computed_metrics: [0.6096106429729332]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6444259843653648]
# computed_metrics: [0.6444259843653648]
# computed_metrics: [0.606867425865432]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.6387852265054935]
# computed_metrics: [0.6387852265054935]
# computed_metrics: [0.6069666799274303]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6232882302433665]
# computed_metrics: [0.6232882302433665]
# computed_metrics: [0.5885298795725868]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.6311599896028242]
# computed_metrics: [0.6311599896028242]
# computed_metrics: [0.5977343762090387]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6270165152649781]
# computed_metrics: [0.6270165152649781]
# computed_metrics: [0.5903603013407144]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.6225654445138775]
# computed_metrics: [0.6225654445138775]
# computed_metrics: [0.5933233421782824]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.6272283659534372]
# computed_metrics: [0.6272283659534372]
# computed_metrics: [0.5923605701942541]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.617981713772749]
# computed_metrics: [0.617981713772749]
# computed_metrics: [0.5887944346300504]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.6247919778846045]
# computed_metrics: [0.6247919778846045]
# computed_metrics: [0.5918804653508332]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.6187538434311736]
# computed_metrics: [0.6187538434311736]
# computed_metrics: [0.5909922558739595]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.6190236979632835]
# computed_metrics: [0.6190236979632835]
# computed_metrics: [0.5855187693702352]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.6202242080543543]
# computed_metrics: [0.6202242080543543]
# computed_metrics: [0.5893262745325201]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.6055389757714082]
# computed_metrics: [0.6055389757714082]
# computed_metrics: [0.5827136692036272]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.6234310629019044]
# computed_metrics: [0.6234310629019044]
# computed_metrics: [0.5952011174659897]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.594572752914135]
# computed_metrics: [0.594572752914135]
# computed_metrics: [0.5815468863274996]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.593698153863054]
# computed_metrics: [0.593698153863054]
# computed_metrics: [0.5734033857858728]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5922751077513726]
# computed_metrics: [0.5922751077513726]
# computed_metrics: [0.5750944697502914]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.578776312932265]
# computed_metrics: [0.578776312932265]
# computed_metrics: [0.564788253428666]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.6008778764052546]
# computed_metrics: [0.6008778764052546]
# computed_metrics: [0.5856656773120772]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5830821544725096]
# computed_metrics: [0.5830821544725096]
# computed_metrics: [0.5634908321064598]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5821957890594106]
# computed_metrics: [0.5821957890594106]
# computed_metrics: [0.5706548645674748]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5922031704590446]
# computed_metrics: [0.5922031704590446]
# computed_metrics: [0.5833103149521979]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5623510103470093]
# computed_metrics: [0.5623510103470093]
# computed_metrics: [0.5534705725913446]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5535526988652804]
# computed_metrics: [0.5535526988652804]
# computed_metrics: [0.5522196458921579]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5756314112755468]
# computed_metrics: [0.5756314112755468]
# computed_metrics: [0.5721741584717559]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5474223294260715]
# computed_metrics: [0.5474223294260715]
# computed_metrics: [0.5396163208309696]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5551983716502132]
# computed_metrics: [0.5551983716502132]
# computed_metrics: [0.5401289226709644]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5505468523244154]
# computed_metrics: [0.5505468523244154]
# computed_metrics: [0.5425006552154931]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5358913446998318]
# computed_metrics: [0.5358913446998318]
# computed_metrics: [0.5400071114179515]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.5347651208669775]
# computed_metrics: [0.5347651208669775]
# computed_metrics: [0.5397730083917448]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5397658262075699]
# computed_metrics: [0.5397658262075699]
# computed_metrics: [0.553254859848999]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5469963542510051]
# computed_metrics: [0.5469963542510051]
# computed_metrics: [0.5474966666729038]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5471873463908297]
# computed_metrics: [0.5471873463908297]
# computed_metrics: [0.5509111553514462]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5662682493743454]
# computed_metrics: [0.5662682493743454]
# computed_metrics: [0.5706358091840874]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.5650220012319328]
# computed_metrics: [0.5650220012319328]
# computed_metrics: [0.5695913483724099]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5836451867795895]
# computed_metrics: [0.5836451867795895]
# computed_metrics: [0.6027693668738264]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.5697324175273343]
# computed_metrics: [0.5697324175273343]
# computed_metrics: [0.5976096742432309]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5766910064436055]
# computed_metrics: [0.5766910064436055]
# computed_metrics: [0.5939837676130602]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5551854674397737]
# computed_metrics: [0.5551854674397737]
# computed_metrics: [0.579014144816677]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5427678326450066]
# computed_metrics: [0.5427678326450066]
# computed_metrics: [0.573880300621174]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.5264410326470408]
# computed_metrics: [0.5264410326470408]
# computed_metrics: [0.5555472679104794]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.5242567185373499]
# computed_metrics: [0.5242567185373499]
# computed_metrics: [0.5604338768259973]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.510419782423387]
# computed_metrics: [0.510419782423387]
# computed_metrics: [0.5503758728581603]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4946863323845861]
# computed_metrics: [0.4946863323845861]
# computed_metrics: [0.5348424860645357]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.48911355592542916]
# computed_metrics: [0.48911355592542916]
# computed_metrics: [0.5305735429335505]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4834882329287565]
# computed_metrics: [0.4834882329287565]
# computed_metrics: [0.529207706803227]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.48375084801091917]
# computed_metrics: [0.48375084801091917]
# computed_metrics: [0.527646602016724]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.48396089512008433]
# computed_metrics: [0.48396089512008433]
# computed_metrics: [0.5282876627965652]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.48602238687224386]
# computed_metrics: [0.48602238687224386]
# computed_metrics: [0.5348142024156755]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.48724603201783573]
# computed_metrics: [0.48724603201783573]
# computed_metrics: [0.5392796780182793]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.47772711190853256]
# computed_metrics: [0.47772711190853256]
# computed_metrics: [0.5376550811112155]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.48482673516801145]
# computed_metrics: [0.48482673516801145]
# computed_metrics: [0.5415064757658488]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.49426279009895924]
# computed_metrics: [0.49426279009895924]
# computed_metrics: [0.5467253289091637]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.49287658534864515]
# computed_metrics: [0.49287658534864515]
# computed_metrics: [0.5367714575549521]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.49379628593444114]
# computed_metrics: [0.49379628593444114]
# computed_metrics: [0.5546485974960641]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4955255975618545]
# computed_metrics: [0.4955255975618545]
# computed_metrics: [0.554397772561764]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4909467289924785]
# computed_metrics: [0.4909467289924785]
# computed_metrics: [0.5527931526023128]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.49655034814232474]
# computed_metrics: [0.49655034814232474]
# computed_metrics: [0.5476639518614211]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.49380346242520434]
# computed_metrics: [0.49380346242520434]
# computed_metrics: [0.5579913632185244]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.4811624309261362]
# computed_metrics: [0.4811624309261362]
# computed_metrics: [0.5391939329233303]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.48653567176788864]
# computed_metrics: [0.48653567176788864]
# computed_metrics: [0.5504317987800178]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.5108151413872557]
# computed_metrics: [0.5108151413872557]
# computed_metrics: [0.5574050642677969]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4960405619267008]
# computed_metrics: [0.4960405619267008]
# computed_metrics: [0.5714961049367909]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.48517340359050454]
# computed_metrics: [0.48517340359050454]
# computed_metrics: [0.5549257137356866]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.4773827568369277]
# computed_metrics: [0.4773827568369277]
# computed_metrics: [0.5555291840627388]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5108909399898016]
# computed_metrics: [0.5108909399898016]
# computed_metrics: [0.569049773206934]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.4750895809528282]
# computed_metrics: [0.4750895809528282]
# computed_metrics: [0.5702307701321208]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4749025312504207]
# computed_metrics: [0.4749025312504207]
# computed_metrics: [0.5557402474382216]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.47863146366221754]
# computed_metrics: [0.47863146366221754]
# computed_metrics: [0.555820549971098]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.47979231090074764]
# computed_metrics: [0.47979231090074764]
# computed_metrics: [0.5390931085320227]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.4664071967546915]
# computed_metrics: [0.4664071967546915]
# computed_metrics: [0.5666685976487862]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.4943658323503577]
# computed_metrics: [0.4943658323503577]
# computed_metrics: [0.5683937908408382]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.4681539721438446]
# computed_metrics: [0.4681539721438446]
# computed_metrics: [0.5539921563599894]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.4739186589258938]
# computed_metrics: [0.4739186589258938]
# computed_metrics: [0.5643479283402233]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.453763342190516]
# computed_metrics: [0.453763342190516]
# computed_metrics: [0.5506217571940546]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.44492372680628933]
# computed_metrics: [0.44492372680628933]
# computed_metrics: [0.5503409866748753]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.43759647428243587]
# computed_metrics: [0.43759647428243587]
# computed_metrics: [0.5516662294090902]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4390991381574058]
# computed_metrics: [0.4390991381574058]
# computed_metrics: [0.5552449821060101]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.4423550331184456]
# computed_metrics: [0.4423550331184456]
# computed_metrics: [0.5549007432029479]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.4345027597266404]
# computed_metrics: [0.4345027597266404]
# computed_metrics: [0.5482185159319878]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.44703633775065577]
# computed_metrics: [0.44703633775065577]
# computed_metrics: [0.5438530203661818]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.42534636132323045]
# computed_metrics: [0.42534636132323045]
# computed_metrics: [0.5435666021274231]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.4328304531182958]
# computed_metrics: [0.4328304531182958]
# computed_metrics: [0.5366000977655828]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.4345441509276324]
# computed_metrics: [0.4345441509276324]
# computed_metrics: [0.5521717539761518]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.4217696194959066]
# computed_metrics: [0.4217696194959066]
# computed_metrics: [0.5274403347345296]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.42621029515668196]
# computed_metrics: [0.42621029515668196]
# computed_metrics: [0.5495474135143255]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.44885171224979603]
# computed_metrics: [0.44885171224979603]
# computed_metrics: [0.5724351010231764]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.42236050269707753]
# computed_metrics: [0.42236050269707753]
# computed_metrics: [0.5619875001830933]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.426967272653371]
# computed_metrics: [0.426967272653371]
# computed_metrics: [0.5494916241686878]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.43768117837895]
# computed_metrics: [0.43768117837895]
# computed_metrics: [0.5558750278422554]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.44678547376446204]
# computed_metrics: [0.44678547376446204]
# computed_metrics: [0.5829445978177271]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.4704394447170445]
# computed_metrics: [0.4704394447170445]
# computed_metrics: [0.5973653301552276]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.4488462577836325]
# computed_metrics: [0.4488462577836325]
# computed_metrics: [0.5865064884648377]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.4706183887071193]
# computed_metrics: [0.4706183887071193]
# computed_metrics: [0.6063606823318817]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.47421497850959593]
# computed_metrics: [0.47421497850959593]
# computed_metrics: [0.6017952596958958]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.48106650521780725]
# computed_metrics: [0.48106650521780725]
# computed_metrics: [0.609398995718468]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.4898529244520179]
# computed_metrics: [0.4898529244520179]
# computed_metrics: [0.6229344176205411]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.4844612522745484]
# computed_metrics: [0.4844612522745484]
# computed_metrics: [0.6083300812263679]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.5216733603779157]
# computed_metrics: [0.5216733603779157]
# computed_metrics: [0.6278501418440174]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.5311371909988704]
# computed_metrics: [0.5311371909988704]
# computed_metrics: [0.6599727316098928]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.5399963256121305]
# computed_metrics: [0.5399963256121305]
# computed_metrics: [0.6511112445659694]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.5267381165131862]
# computed_metrics: [0.5267381165131862]
# computed_metrics: [0.6711690027439885]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.5170140118736489]
# computed_metrics: [0.5170140118736489]
# computed_metrics: [0.6410799363125611]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.5380453028363791]
# computed_metrics: [0.5380453028363791]
# computed_metrics: [0.6707152148809238]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.5190740633548276]
# computed_metrics: [0.5190740633548276]
# computed_metrics: [0.6321936477264269]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.49718352051102915]
# computed_metrics: [0.49718352051102915]
# computed_metrics: [0.6478594626471793]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.5169825767266626]
# computed_metrics: [0.5169825767266626]
# computed_metrics: [0.6316482013827531]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.4505816884302902]
# computed_metrics: [0.4505816884302902]
# computed_metrics: [0.5678013678971569]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.45585059802188116]
# computed_metrics: [0.45585059802188116]
# computed_metrics: [0.5488476995992005]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.41562460922787337]
# computed_metrics: [0.41562460922787337]
# computed_metrics: [0.5549478003870809]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.41218345587691585]
# computed_metrics: [0.41218345587691585]
# computed_metrics: [0.5696733752407764]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.41336795143509836]
# computed_metrics: [0.41336795143509836]
# computed_metrics: [0.5525780175646728]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.398229639423194]
# computed_metrics: [0.398229639423194]
# computed_metrics: [0.5298799270592778]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.39928819441089247]
# computed_metrics: [0.39928819441089247]
# computed_metrics: [0.5387520629063556]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.4078658447295898]
# computed_metrics: [0.4078658447295898]
# computed_metrics: [0.531622589484059]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.4200363681370304]
# computed_metrics: [0.4200363681370304]
# computed_metrics: [0.5462595016442486]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.43447489497155917]
# computed_metrics: [0.43447489497155917]
# computed_metrics: [0.5445627661885466]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.4294114324125267]
# computed_metrics: [0.4294114324125267]
# computed_metrics: [0.5631053479697543]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.42860556260341964]
# computed_metrics: [0.42860556260341964]
# computed_metrics: [0.55826595521431]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.45379601331064184]
# computed_metrics: [0.45379601331064184]
# computed_metrics: [0.5589676036036774]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.44620544977057586]
# computed_metrics: [0.44620544977057586]
# computed_metrics: [0.5561855527906254]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.45401398861431536]
# computed_metrics: [0.45401398861431536]
# computed_metrics: [0.5750040485022108]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.4055104824402345]
# computed_metrics: [0.4055104824402345]
# computed_metrics: [0.5350247676259939]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.41968534339613434]
# computed_metrics: [0.41968534339613434]
# computed_metrics: [0.5234561141601561]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.40788595470984473]
# computed_metrics: [0.40788595470984473]
# computed_metrics: [0.525176647965013]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.4205603681265929]
# computed_metrics: [0.4205603681265929]
# computed_metrics: [0.5277165420596599]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.4030651564121346]
# computed_metrics: [0.4030651564121346]
# computed_metrics: [0.5296963512401771]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.38593865584676523]
# computed_metrics: [0.38593865584676523]
# computed_metrics: [0.5184640323963381]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.3811017851707629]
# computed_metrics: [0.3811017851707629]
# computed_metrics: [0.5275496301770293]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3873852958626205]
# computed_metrics: [0.3873852958626205]
# computed_metrics: [0.5399377911451193]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.3723310189435968]
# computed_metrics: [0.3723310189435968]
# computed_metrics: [0.5178688674159062]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.3742521146464799]
# computed_metrics: [0.3742521146464799]
# computed_metrics: [0.5067065635875694]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.3738507528152824]
# computed_metrics: [0.3738507528152824]
# computed_metrics: [0.5275753435211284]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.3920860760988482]
# computed_metrics: [0.3920860760988482]
# computed_metrics: [0.5251669870036145]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3702236867730912]
# computed_metrics: [0.3702236867730912]
# computed_metrics: [0.519704967773692]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.3766700440502103]
# computed_metrics: [0.3766700440502103]
# computed_metrics: [0.5417442955396522]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.37136220837085865]
# computed_metrics: [0.37136220837085865]
# computed_metrics: [0.5291346922517793]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.36787734542420586]
# computed_metrics: [0.36787734542420586]
# computed_metrics: [0.5079754205085694]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3625711699141374]
# computed_metrics: [0.3625711699141374]
# computed_metrics: [0.5395841659149276]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3562698960611463]
# computed_metrics: [0.3562698960611463]
# computed_metrics: [0.5237084342411095]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.38244765557221666]
# computed_metrics: [0.38244765557221666]
# computed_metrics: [0.5381904931135278]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.3533335116388174]
# computed_metrics: [0.3533335116388174]
# computed_metrics: [0.5178971561194575]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.37177470286652414]
# computed_metrics: [0.37177470286652414]
# computed_metrics: [0.5182276208968133]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.40214434587620335]
# computed_metrics: [0.40214434587620335]
# computed_metrics: [0.572168261487777]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.37611491650536394]
# computed_metrics: [0.37611491650536394]
# computed_metrics: [0.5068661193351117]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.3714885121678489]
# computed_metrics: [0.3714885121678489]
# computed_metrics: [0.5480446189053485]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.3833363540807506]
# computed_metrics: [0.3833363540807506]
# computed_metrics: [0.530321178670119]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.36669627855941483]
# computed_metrics: [0.36669627855941483]
# computed_metrics: [0.5341044416064611]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.3665417764060897]
# computed_metrics: [0.3665417764060897]
# computed_metrics: [0.5119128005893853]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.3878462660596504]
# computed_metrics: [0.3878462660596504]
# computed_metrics: [0.5455750606649818]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.35812936502784387]
# computed_metrics: [0.35812936502784387]
# computed_metrics: [0.5273082629819104]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.3646717511103704]
# computed_metrics: [0.3646717511103704]
# computed_metrics: [0.5279392895807223]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.3534400674955026]
# computed_metrics: [0.3534400674955026]
# computed_metrics: [0.517767411454677]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.35265657903499265]
# computed_metrics: [0.35265657903499265]
# computed_metrics: [0.5133013658216249]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.34581290901673595]
# computed_metrics: [0.34581290901673595]
# computed_metrics: [0.5035013059337817]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.34800836481919406]
# computed_metrics: [0.34800836481919406]
# computed_metrics: [0.5046099931692377]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.34378492502896185]
# computed_metrics: [0.34378492502896185]
# computed_metrics: [0.5031086305078586]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.3531506536147932]
# computed_metrics: [0.3531506536147932]
# computed_metrics: [0.5196977611464402]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.3499690162183588]
# computed_metrics: [0.3499690162183588]
# computed_metrics: [0.5078798799270546]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.338097100752401]
# computed_metrics: [0.338097100752401]
# computed_metrics: [0.5118778831387598]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.3470625135526602]
# computed_metrics: [0.3470625135526602]
# computed_metrics: [0.5178295859478588]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.3356562119860617]
# computed_metrics: [0.3356562119860617]
# computed_metrics: [0.5141200342040733]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.34837590782691974]
# computed_metrics: [0.34837590782691974]
# computed_metrics: [0.5273093751843524]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.36389355573712984]
# computed_metrics: [0.36389355573712984]
# computed_metrics: [0.5329445009233648]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.3319548086091124]
# computed_metrics: [0.3319548086091124]
# computed_metrics: [0.5084483555422694]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.3293766995678225]
# computed_metrics: [0.3293766995678225]
# computed_metrics: [0.4997579989502626]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.33797349771785007]
# computed_metrics: [0.33797349771785007]
# computed_metrics: [0.5209347046817671]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.35021157620146276]
# computed_metrics: [0.35021157620146276]
# computed_metrics: [0.5280698609940887]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.3384130046604931]
# computed_metrics: [0.3384130046604931]
# computed_metrics: [0.5039358453622308]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.3356079886274189]
# computed_metrics: [0.3356079886274189]
# computed_metrics: [0.49969785749520634]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.35867977663052]
# computed_metrics: [0.35867977663052]
# computed_metrics: [0.526577783064871]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.36907735893468624]
# computed_metrics: [0.36907735893468624]
# computed_metrics: [0.5182556340332302]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.3269174523096652]
# computed_metrics: [0.3269174523096652]
# computed_metrics: [0.5003006404742968]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.33490220947616983]
# computed_metrics: [0.33490220947616983]
# computed_metrics: [0.5086560657934127]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.34636428900810406]
# computed_metrics: [0.34636428900810406]
# computed_metrics: [0.5292061900058498]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.3644351765843534]
# computed_metrics: [0.3644351765843534]
# computed_metrics: [0.5277100688555179]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.3391089278610003]
# computed_metrics: [0.3391089278610003]
# computed_metrics: [0.5113973352167188]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.3399396971888735]
# computed_metrics: [0.3399396971888735]
# computed_metrics: [0.5246769064584395]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.3512994093879494]
# computed_metrics: [0.3512994093879494]
# computed_metrics: [0.5173568727142239]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.3458868276561979]
# computed_metrics: [0.3458868276561979]
# computed_metrics: [0.504398197490175]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.3918688177536435]
# computed_metrics: [0.3918688177536435]
# computed_metrics: [0.5452774833310071]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.3775050185805016]
# computed_metrics: [0.3775050185805016]
# computed_metrics: [0.5539174481131848]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.3799213029525901]
# computed_metrics: [0.3799213029525901]
# computed_metrics: [0.5225965555098276]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3626368122563322]
# computed_metrics: [0.3626368122563322]
# computed_metrics: [0.49883259432420274]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.3241039970798191]
# computed_metrics: [0.3241039970798191]
# computed_metrics: [0.513060863264171]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.32373783884636176]
# computed_metrics: [0.32373783884636176]
# computed_metrics: [0.5044678062522244]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3177334776656462]
# computed_metrics: [0.3177334776656462]
# computed_metrics: [0.49574004180930126]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.3111523915167836]
# computed_metrics: [0.3111523915167836]
# computed_metrics: [0.500509659437978]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.3127859566821354]
# computed_metrics: [0.3127859566821354]
# computed_metrics: [0.49748281524504767]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.3075530530870189]
# computed_metrics: [0.3075530530870189]
# computed_metrics: [0.5076386522610681]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.3054913967580768]
# computed_metrics: [0.3054913967580768]
# computed_metrics: [0.5041901296659896]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.3009129235805679]
# computed_metrics: [0.3009129235805679]
# computed_metrics: [0.5121775140024224]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.3040084779239325]
# computed_metrics: [0.3040084779239325]
# computed_metrics: [0.5113890911219082]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.32429224012386587]
# computed_metrics: [0.32429224012386587]
# computed_metrics: [0.5121145387620182]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.323054524843789]
# computed_metrics: [0.323054524843789]
# computed_metrics: [0.5192939139864456]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3098337453000363]
# computed_metrics: [0.3098337453000363]
# computed_metrics: [0.5166129567176464]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.3426459665850288]
# computed_metrics: [0.3426459665850288]
# computed_metrics: [0.5454285860202354]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.3594526585261986]
# computed_metrics: [0.3594526585261986]
# computed_metrics: [0.527346486740409]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.38476923506386945]
# computed_metrics: [0.38476923506386945]
# computed_metrics: [0.5490651302035932]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.32408705448991787]
# computed_metrics: [0.32408705448991787]
# computed_metrics: [0.5113585612812426]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.3627102873151412]
# computed_metrics: [0.3627102873151412]
# computed_metrics: [0.5351648676437354]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.33523096370521405]
# computed_metrics: [0.33523096370521405]
# computed_metrics: [0.5148433391324361]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.32213934344860135]
# computed_metrics: [0.32213934344860135]
# computed_metrics: [0.5149491282322117]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.32345454712671023]
# computed_metrics: [0.32345454712671023]
# computed_metrics: [0.5183967289169765]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.324874570278971]
# computed_metrics: [0.324874570278971]
# computed_metrics: [0.5130006468083383]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.32845771637303106]
# computed_metrics: [0.32845771637303106]
# computed_metrics: [0.5083994291970902]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.3114333958222622]
# computed_metrics: [0.3114333958222622]
# computed_metrics: [0.5088786029380992]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.2971816312991397]
# computed_metrics: [0.2971816312991397]
# computed_metrics: [0.5002214844581933]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.29606879276379583]
# computed_metrics: [0.29606879276379583]
# computed_metrics: [0.5086783741592387]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.29754160077359404]
# computed_metrics: [0.29754160077359404]
# computed_metrics: [0.4947324976064501]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.3238788876709081]
# computed_metrics: [0.3238788876709081]
# computed_metrics: [0.5152345748305648]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.31700906675405593]
# computed_metrics: [0.31700906675405593]
# computed_metrics: [0.5013570163704437]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.3010462858684129]
# computed_metrics: [0.3010462858684129]
# computed_metrics: [0.5007949695537128]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.3141461673717509]
# computed_metrics: [0.3141461673717509]
# computed_metrics: [0.5068359753283482]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.3496587366383504]
# computed_metrics: [0.3496587366383504]
# computed_metrics: [0.5173880878949637]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.35827533962801783]
# computed_metrics: [0.35827533962801783]
# computed_metrics: [0.5233509742014127]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.3561598565092714]
# computed_metrics: [0.3561598565092714]
# computed_metrics: [0.5260227068678186]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.3201564501515958]
# computed_metrics: [0.3201564501515958]
# computed_metrics: [0.5057091972456186]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.3285966453563655]
# computed_metrics: [0.3285966453563655]
# computed_metrics: [0.5244637423100443]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.3161273042416865]
# computed_metrics: [0.3161273042416865]
# computed_metrics: [0.5178697047475449]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.31954706747869116]
# computed_metrics: [0.31954706747869116]
# computed_metrics: [0.503850184674853]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.3079771076930487]
# computed_metrics: [0.3079771076930487]
# computed_metrics: [0.5062424840930041]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.31150843784759863]
# computed_metrics: [0.31150843784759863]
# computed_metrics: [0.5195768641667777]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.3300302882055114]
# computed_metrics: [0.3300302882055114]
# computed_metrics: [0.5297642774133609]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.31922849928382224]
# computed_metrics: [0.31922849928382224]
# computed_metrics: [0.5201792346263913]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.2984448021337348]
# computed_metrics: [0.2984448021337348]
# computed_metrics: [0.5023029812183081]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.3387051022789456]
# computed_metrics: [0.3387051022789456]
# computed_metrics: [0.543703624639456]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.30368480825319144]
# computed_metrics: [0.30368480825319144]
# computed_metrics: [0.506408528486959]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.2980843778883735]
# computed_metrics: [0.2980843778883735]
# computed_metrics: [0.5090897111143793]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.3313322911609139]
# computed_metrics: [0.3313322911609139]
# computed_metrics: [0.5182936474463924]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.3332559137564003]
# computed_metrics: [0.3332559137564003]
# computed_metrics: [0.5325635774446023]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.32477964238556345]
# computed_metrics: [0.32477964238556345]
# computed_metrics: [0.5007893382471509]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.2859639442187139]
# computed_metrics: [0.2859639442187139]
# computed_metrics: [0.499455994878238]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.3255814412296333]
# computed_metrics: [0.3255814412296333]
# computed_metrics: [0.5275188028947574]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.3489657922222568]
# computed_metrics: [0.3489657922222568]
# computed_metrics: [0.5531302159920082]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.30465940699189775]
# computed_metrics: [0.30465940699189775]
# computed_metrics: [0.5004889530885231]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.30318722278517285]
# computed_metrics: [0.30318722278517285]
# computed_metrics: [0.5029068866353938]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.2952344826095527]
# computed_metrics: [0.2952344826095527]
# computed_metrics: [0.48245280093808757]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.3039645060800149]
# computed_metrics: [0.3039645060800149]
# computed_metrics: [0.5203444706432033]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.3263407568582863]
# computed_metrics: [0.3263407568582863]
# computed_metrics: [0.5383354940506758]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.3362465103695932]
# computed_metrics: [0.3362465103695932]
# computed_metrics: [0.5279155902670052]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.3118690565361849]
# computed_metrics: [0.3118690565361849]
# computed_metrics: [0.52168402074283]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.3040198751917173]
# computed_metrics: [0.3040198751917173]
# computed_metrics: [0.507563123555371]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.31636842941033155]
# computed_metrics: [0.31636842941033155]
# computed_metrics: [0.5042999039848295]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.31585485278835906]
# computed_metrics: [0.31585485278835906]
# computed_metrics: [0.5096454905994258]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.3030243004404055]
# computed_metrics: [0.3030243004404055]
# computed_metrics: [0.5029243753373084]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3063564833994817]
# computed_metrics: [0.3063564833994817]
# computed_metrics: [0.49023571973824903]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.30998223705777167]
# computed_metrics: [0.30998223705777167]
# computed_metrics: [0.5295384144300043]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.30025804631799974]
# computed_metrics: [0.30025804631799974]
# computed_metrics: [0.5095241117796789]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.3085474037434226]
# computed_metrics: [0.3085474037434226]
# computed_metrics: [0.5009924791300814]
# Starting epoch 288
# ...
# Starting validation epoch 452
# computed_metrics: [0.36423531225925165]
# computed_metrics: [0.36423531225925165]
# computed_metrics: [0.5672019338770682]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.35109925038392475]
# computed_metrics: [0.35109925038392475]
# computed_metrics: [0.5686270621076607]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.3010527429452485]
# computed_metrics: [0.3010527429452485]
# computed_metrics: [0.5362700024731193]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.2834853094847503]
# computed_metrics: [0.2834853094847503]
# computed_metrics: [0.528950913586292]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.27277439117937746]
# computed_metrics: [0.27277439117937746]
# computed_metrics: [0.5247399192639742]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.28867398815102246]
# computed_metrics: [0.28867398815102246]
# computed_metrics: [0.5222483880291352]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.3001943872625183]
# computed_metrics: [0.3001943872625183]
# computed_metrics: [0.5333464441285911]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.3278705721179116]
# computed_metrics: [0.3278705721179116]
# computed_metrics: [0.5661573869813745]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.39467701718208203]
# computed_metrics: [0.39467701718208203]
# computed_metrics: [0.5806980705561504]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.32346889903876014]
# computed_metrics: [0.32346889903876014]
# computed_metrics: [0.5443365890953854]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.2875014090873038]
# computed_metrics: [0.2875014090873038]
# computed_metrics: [0.5139637138564258]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.27040396192605787]
# computed_metrics: [0.27040396192605787]
# computed_metrics: [0.527096003343199]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.2653348272783887]
# computed_metrics: [0.2653348272783887]
# computed_metrics: [0.49582215050271067]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.27587254456786214]
# computed_metrics: [0.27587254456786214]
# computed_metrics: [0.5182247043416484]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.2813377459240153]
# computed_metrics: [0.2813377459240153]
# computed_metrics: [0.5174798679554398]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.32026128013026317]
# computed_metrics: [0.32026128013026317]
# computed_metrics: [0.5546837229867536]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.33797325394659367]
# computed_metrics: [0.33797325394659367]
# computed_metrics: [0.572547836226524]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.3312040457251448]
# computed_metrics: [0.3312040457251448]
# computed_metrics: [0.5687060904818727]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.2626795026921786]
# computed_metrics: [0.2626795026921786]
# computed_metrics: [0.5306183788978711]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.2785477536555732]
# computed_metrics: [0.2785477536555732]
# computed_metrics: [0.541139271784691]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.25220111877761486]
# computed_metrics: [0.25220111877761486]
# computed_metrics: [0.5110255461704251]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.2626954572372683]
# computed_metrics: [0.2626954572372683]
# computed_metrics: [0.5226848922475879]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.30550209296234027]
# computed_metrics: [0.30550209296234027]
# computed_metrics: [0.5562622079412899]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.32630814081261833]
# computed_metrics: [0.32630814081261833]
# computed_metrics: [0.5654840968340595]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.33619653303516916]
# computed_metrics: [0.33619653303516916]
# computed_metrics: [0.5738528119042561]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.3166513849579926]
# computed_metrics: [0.3166513849579926]
# computed_metrics: [0.5440091813999005]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.26535703200559746]
# computed_metrics: [0.26535703200559746]
# computed_metrics: [0.4978999126849058]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.25830704429246093]
# computed_metrics: [0.25830704429246093]
# computed_metrics: [0.5046467614051564]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.2841347402147832]
# computed_metrics: [0.2841347402147832]
# computed_metrics: [0.5119014911747939]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.310303406340092]
# computed_metrics: [0.310303406340092]
# computed_metrics: [0.5487223287855946]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.4664983184021133]
# computed_metrics: [0.4664983184021133]
# computed_metrics: [0.6347253633573501]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.4362509101544778]
# computed_metrics: [0.4362509101544778]
# computed_metrics: [0.6101122174302868]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.41676998004192967]
# computed_metrics: [0.41676998004192967]
# computed_metrics: [0.6052404995401555]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.4082943004858688]
# computed_metrics: [0.4082943004858688]
# computed_metrics: [0.6214895288454299]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.37378827983321944]
# computed_metrics: [0.37378827983321944]
# computed_metrics: [0.5989918597618946]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.3198931427835885]
# computed_metrics: [0.3198931427835885]
# computed_metrics: [0.5547510609905936]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.2880566680325848]
# computed_metrics: [0.2880566680325848]
# computed_metrics: [0.5261487163283001]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.30288477619669746]
# computed_metrics: [0.30288477619669746]
# computed_metrics: [0.5403253334647091]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.3167524243549501]
# computed_metrics: [0.3167524243549501]
# computed_metrics: [0.5649274705477799]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.3536765332522201]
# computed_metrics: [0.3536765332522201]
# computed_metrics: [0.5812615638378874]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.38135466295994735]
# computed_metrics: [0.38135466295994735]
# computed_metrics: [0.5928958714264931]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.31642584661217754]
# computed_metrics: [0.31642584661217754]
# computed_metrics: [0.533276735821864]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.2813881617230947]
# computed_metrics: [0.2813881617230947]
# computed_metrics: [0.5112710598100303]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.26754622607734974]
# computed_metrics: [0.26754622607734974]
# computed_metrics: [0.5211177515955754]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.2974508399719116]
# computed_metrics: [0.2974508399719116]
# computed_metrics: [0.5355068921216661]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.3356501813517973]
# computed_metrics: [0.3356501813517973]
# computed_metrics: [0.5706255261877043]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.3700979352127236]
# computed_metrics: [0.3700979352127236]
# computed_metrics: [0.5617498987753802]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.3117574324196934]
# computed_metrics: [0.3117574324196934]
# computed_metrics: [0.5365381888019978]
# [4.02180770379307, 2.490832473944862, 1.4619306005871977, 1.0152341277464638, 0.945770043970797, 0.9202435569619825, 0.9101905707957502, 0.9006282680038135, 0.89084760860522, 0.8798881096237924, 0.8674715040117871, 0.8521947671812748, 0.843182382719902, 0.8343571016508446, 0.827586800129278, 0.8205600841552266, 0.8134465967627206, 0.8069938795214306, 0.800739707355571, 0.7948067262958309, 0.788352417474109, 0.7791005207542316, 0.7678986012762603, 0.7562897252005535, 0.7450941545242721, 0.7371074531094812, 0.7271378933670958, 0.7016536459981935, 0.6901781664150476, 0.6788814224704469, 0.6746241967983941, 0.6693344655019425, 0.6681481326353257, 0.6555612640928459, 0.6542856721044588, 0.6439030477167793, 0.6499632575837136, 0.6382687695705086, 0.6444259843653648, 0.6387852265054935, 0.6232882302433665, 0.6311599896028242, 0.6270165152649781, 0.6225654445138775, 0.6272283659534372, 0.617981713772749, 0.6247919778846045, 0.6187538434311736, 0.6190236979632835, 0.6202242080543543, 0.6055389757714082, 0.6234310629019044, 0.594572752914135, 0.593698153863054, 0.5922751077513726, 0.578776312932265, 0.6008778764052546, 0.5830821544725096, 0.5821957890594106, 0.5922031704590446, 0.5623510103470093, 0.5535526988652804, 0.5756314112755468, 0.5474223294260715, 0.5551983716502132, 0.5505468523244154, 0.5358913446998318, 0.5347651208669775, 0.5397658262075699, 0.5469963542510051, 0.5471873463908297, 0.5662682493743454, 0.5650220012319328, 0.5836451867795895, 0.5697324175273
#  [0.37001213 0.56950147]
#  [0.36423531 0.56720193]
#  [0.35109925 0.56862706]
#  [0.30105274 0.53627   ]
#  [0.28348531 0.52895091]
#  [0.27277439 0.52473992]
#  [0.28867399 0.52224839]
#  [0.30019439 0.53334644]
#  [0.32787057 0.56615739]
#  [0.39467702 0.58069807]
#  [0.3234689  0.54433659]
#  [0.28750141 0.51396371]
#  [0.27040396 0.527096  ]
#  [0.26533483 0.49582215]
#  [0.27587254 0.5182247 ]
#  [0.28133775 0.51747987]
#  [0.32026128 0.55468372]
#  [0.33797325 0.57254784]
#  [0.33120405 0.56870609]
#  [0.2626795  0.53061838]
#  [0.27854775 0.54113927]
#  [0.25220112 0.51102555]
#  [0.26269546 0.52268489]
#  [0.30550209 0.55626221]
#  [0.32630814 0.5654841 ]
#  [0.33619653 0.57385281]
#  [0.31665138 0.54400918]
#  [0.26535703 0.49789991]
#  [0.25830704 0.50464676]
#  [0.28413474 0.51190149]
#  [0.31030341 0.54872233]
#  [0.46649832 0.63472536]
#  [0.43625091 0.61011222]
#  [0.41676998 0.6052405 ]
#  [0.4082943  0.62148953]
#  [0.37378828 0.59899186]
#  [0.31989314 0.55475106]
#  [0.28805667 0.52614872]
#  [0.30288478 0.54032533]
#  [0.31675242 0.56492747]
#  [0.35367653 0.58126156]
#  [0.38135466 0.59289587]
#  [0.31642585 0.53327674]
#  [0.28138816 0.51127106]
#  [0.26754623 0.52111775]
#  [0.29745084 0.53550689]
#  [0.33565018 0.57062553]
#  [0.37009794 0.5617499 ]
#  [0.31175743 0.53653819]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [3.5349514120734664]
# computed_metrics: [3.5349514120734664]
# computed_metrics: [3.424860376460472]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [2.3081590263373406]
# computed_metrics: [2.3081590263373406]
# computed_metrics: [2.2339218359582897]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.5673973086747306]
# computed_metrics: [1.5673973086747306]
# computed_metrics: [1.5257119915300912]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.2002740254019124]
# computed_metrics: [1.2002740254019124]
# computed_metrics: [1.2067337944144418]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [1.0241684458927385]
# computed_metrics: [1.0241684458927385]
# computed_metrics: [1.0547487686433354]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9774639510754392]
# computed_metrics: [0.9774639510754392]
# computed_metrics: [1.0121678554806157]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9578966162133656]
# computed_metrics: [0.9578966162133656]
# computed_metrics: [0.9956398331740812]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9365973116149504]
# computed_metrics: [0.9365973116149504]
# computed_metrics: [0.9727299489159971]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.9052193546911071]
# computed_metrics: [0.9052193546911071]
# computed_metrics: [0.9369261378911857]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8934744193499884]
# computed_metrics: [0.8934744193499884]
# computed_metrics: [0.9224769706575043]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8793014414795265]
# computed_metrics: [0.8793014414795265]
# computed_metrics: [0.912839499780127]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8665036981223336]
# computed_metrics: [0.8665036981223336]
# computed_metrics: [0.8969128912463916]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8467592705307588]
# computed_metrics: [0.8467592705307588]
# computed_metrics: [0.8835809715707095]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8315436523709271]
# computed_metrics: [0.8315436523709271]
# computed_metrics: [0.8650884630142174]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8042036308151314]
# computed_metrics: [0.8042036308151314]
# computed_metrics: [0.8350753615235135]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.7808639192693838]
# computed_metrics: [0.7808639192693838]
# computed_metrics: [0.8092689921919676]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7572478049213626]
# computed_metrics: [0.7572478049213626]
# computed_metrics: [0.7872723804116366]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7422173073635046]
# computed_metrics: [0.7422173073635046]
# computed_metrics: [0.7732342777017531]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7282683698906356]
# computed_metrics: [0.7282683698906356]
# computed_metrics: [0.7626538646161605]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7167619581327487]
# computed_metrics: [0.7167619581327487]
# computed_metrics: [0.750569726983284]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7062468960183689]
# computed_metrics: [0.7062468960183689]
# computed_metrics: [0.7417656643177649]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7005612684558722]
# computed_metrics: [0.7005612684558722]
# computed_metrics: [0.7334646675634335]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.6900703506737911]
# computed_metrics: [0.6900703506737911]
# computed_metrics: [0.7171241020166756]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.6812586878069389]
# computed_metrics: [0.6812586878069389]
# computed_metrics: [0.7101341132138101]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.6756738671020494]
# computed_metrics: [0.6756738671020494]
# computed_metrics: [0.7028350765584188]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6721331510366912]
# computed_metrics: [0.6721331510366912]
# computed_metrics: [0.701023369603533]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6653948135460619]
# computed_metrics: [0.6653948135460619]
# computed_metrics: [0.6927173524837418]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6609414281339946]
# computed_metrics: [0.6609414281339946]
# computed_metrics: [0.685118546465064]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6599350071976844]
# computed_metrics: [0.6599350071976844]
# computed_metrics: [0.6824256075160152]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.654984654148217]
# computed_metrics: [0.654984654148217]
# computed_metrics: [0.6726624404432255]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6449645206534995]
# computed_metrics: [0.6449645206534995]
# computed_metrics: [0.6645827104755593]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6497987110556718]
# computed_metrics: [0.6497987110556718]
# computed_metrics: [0.6675171709182719]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6369198139640863]
# computed_metrics: [0.6369198139640863]
# computed_metrics: [0.6559407041641114]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.63888580296218]
# computed_metrics: [0.63888580296218]
# computed_metrics: [0.6536360594153804]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6316067254713923]
# computed_metrics: [0.6316067254713923]
# computed_metrics: [0.6455860333173389]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6264726072307278]
# computed_metrics: [0.6264726072307278]
# computed_metrics: [0.6437503091674466]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6200527184934412]
# computed_metrics: [0.6200527184934412]
# computed_metrics: [0.6373147192046958]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6213475538080556]
# computed_metrics: [0.6213475538080556]
# computed_metrics: [0.6303245348418554]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6147471303280613]
# computed_metrics: [0.6147471303280613]
# computed_metrics: [0.6303898544466814]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.6023971464708092]
# computed_metrics: [0.6023971464708092]
# computed_metrics: [0.615556562930865]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5967741343807781]
# computed_metrics: [0.5967741343807781]
# computed_metrics: [0.6074901299676132]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.587092986471747]
# computed_metrics: [0.587092986471747]
# computed_metrics: [0.6119171695882708]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5874924052652193]
# computed_metrics: [0.5874924052652193]
# computed_metrics: [0.5981717202911464]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5874633491621138]
# computed_metrics: [0.5874633491621138]
# computed_metrics: [0.5981905313595605]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5779623193591931]
# computed_metrics: [0.5779623193591931]
# computed_metrics: [0.5882821182608616]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5759534418155733]
# computed_metrics: [0.5759534418155733]
# computed_metrics: [0.5871605140369305]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5776022324484009]
# computed_metrics: [0.5776022324484009]
# computed_metrics: [0.5880575230523996]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5640414065598514]
# computed_metrics: [0.5640414065598514]
# computed_metrics: [0.5769041092693608]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5606201648021192]
# computed_metrics: [0.5606201648021192]
# computed_metrics: [0.5727101369732813]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.572496997155354]
# computed_metrics: [0.572496997155354]
# computed_metrics: [0.5801859645888525]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.551653308468195]
# computed_metrics: [0.551653308468195]
# computed_metrics: [0.5718369602136121]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5508521416624695]
# computed_metrics: [0.5508521416624695]
# computed_metrics: [0.565115028451546]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5768432845368241]
# computed_metrics: [0.5768432845368241]
# computed_metrics: [0.5916037788877945]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5451812164176316]
# computed_metrics: [0.5451812164176316]
# computed_metrics: [0.5646717320548715]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5484576285093308]
# computed_metrics: [0.5484576285093308]
# computed_metrics: [0.5659526884507518]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5630696505841395]
# computed_metrics: [0.5630696505841395]
# computed_metrics: [0.5752640276160897]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5560020373028429]
# computed_metrics: [0.5560020373028429]
# computed_metrics: [0.5669753233211747]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5775670184459416]
# computed_metrics: [0.5775670184459416]
# computed_metrics: [0.6041877772352976]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5239765790610518]
# computed_metrics: [0.5239765790610518]
# computed_metrics: [0.5419250588344879]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.54335326759816]
# computed_metrics: [0.54335326759816]
# computed_metrics: [0.5566758436658531]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5393104837094003]
# computed_metrics: [0.5393104837094003]
# computed_metrics: [0.5548986025032353]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5282203634721266]
# computed_metrics: [0.5282203634721266]
# computed_metrics: [0.557603920294824]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5105243927414402]
# computed_metrics: [0.5105243927414402]
# computed_metrics: [0.5397218366384019]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5409601711335168]
# computed_metrics: [0.5409601711335168]
# computed_metrics: [0.5563160090374587]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5064325311168312]
# computed_metrics: [0.5064325311168312]
# computed_metrics: [0.5310723134795869]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5328587979085113]
# computed_metrics: [0.5328587979085113]
# computed_metrics: [0.5573842914940432]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5258471964624757]
# computed_metrics: [0.5258471964624757]
# computed_metrics: [0.5565729204253954]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.501070890277367]
# computed_metrics: [0.501070890277367]
# computed_metrics: [0.5203529846171733]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5163324377864582]
# computed_metrics: [0.5163324377864582]
# computed_metrics: [0.5347289404439576]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5553813510494583]
# computed_metrics: [0.5553813510494583]
# computed_metrics: [0.5749403866827757]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5321264730823803]
# computed_metrics: [0.5321264730823803]
# computed_metrics: [0.5538173015435252]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5619710431302446]
# computed_metrics: [0.5619710431302446]
# computed_metrics: [0.5843026321629955]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.5398845971377149]
# computed_metrics: [0.5398845971377149]
# computed_metrics: [0.5662043121694729]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5196755526960887]
# computed_metrics: [0.5196755526960887]
# computed_metrics: [0.5375278957259322]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.5189033833596349]
# computed_metrics: [0.5189033833596349]
# computed_metrics: [0.5497277243366804]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5120685195465268]
# computed_metrics: [0.5120685195465268]
# computed_metrics: [0.5450721989933642]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5746186499968112]
# computed_metrics: [0.5746186499968112]
# computed_metrics: [0.5883505122811007]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5272340729424909]
# computed_metrics: [0.5272340729424909]
# computed_metrics: [0.5682394669314335]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.48351283064055095]
# computed_metrics: [0.48351283064055095]
# computed_metrics: [0.5353059703881966]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4826973417979393]
# computed_metrics: [0.4826973417979393]
# computed_metrics: [0.5170473434408946]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.49463923687358147]
# computed_metrics: [0.49463923687358147]
# computed_metrics: [0.5330677050466498]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4654661255175738]
# computed_metrics: [0.4654661255175738]
# computed_metrics: [0.509224593144699]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.5109034257262465]
# computed_metrics: [0.5109034257262465]
# computed_metrics: [0.5368487092671317]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.5326205897031593]
# computed_metrics: [0.5326205897031593]
# computed_metrics: [0.5760641511019051]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.5126728578673128]
# computed_metrics: [0.5126728578673128]
# computed_metrics: [0.5534779189811597]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.5063297354246898]
# computed_metrics: [0.5063297354246898]
# computed_metrics: [0.545839272611418]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4745748689630893]
# computed_metrics: [0.4745748689630893]
# computed_metrics: [0.524022941551482]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.46736118314871006]
# computed_metrics: [0.46736118314871006]
# computed_metrics: [0.5202872073659842]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.4650924324501391]
# computed_metrics: [0.4650924324501391]
# computed_metrics: [0.5023236057167968]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.49173026044219703]
# computed_metrics: [0.49173026044219703]
# computed_metrics: [0.5410617024179477]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.48554878359977555]
# computed_metrics: [0.48554878359977555]
# computed_metrics: [0.5289744208366612]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.49516885721650006]
# computed_metrics: [0.49516885721650006]
# computed_metrics: [0.5418245695427774]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.48511990681268813]
# computed_metrics: [0.48511990681268813]
# computed_metrics: [0.540666194975933]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4841497109315263]
# computed_metrics: [0.4841497109315263]
# computed_metrics: [0.5335978146238074]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.48482483556121464]
# computed_metrics: [0.48482483556121464]
# computed_metrics: [0.5339079324379851]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.5170557161081458]
# computed_metrics: [0.5170557161081458]
# computed_metrics: [0.562756972329376]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.4749516402688225]
# computed_metrics: [0.4749516402688225]
# computed_metrics: [0.5259437815469569]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.4510233644482462]
# computed_metrics: [0.4510233644482462]
# computed_metrics: [0.5039037813344437]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.4527433754778938]
# computed_metrics: [0.4527433754778938]
# computed_metrics: [0.5336362073183446]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4569888007585333]
# computed_metrics: [0.4569888007585333]
# computed_metrics: [0.5319571224431061]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4783421755524529]
# computed_metrics: [0.4783421755524529]
# computed_metrics: [0.5459909354855281]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.5853923361947103]
# computed_metrics: [0.5853923361947103]
# computed_metrics: [0.691071337932123]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.4964940055126352]
# computed_metrics: [0.4964940055126352]
# computed_metrics: [0.5636578280554351]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5615144270427399]
# computed_metrics: [0.5615144270427399]
# computed_metrics: [0.5980394537253777]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.537380616760305]
# computed_metrics: [0.537380616760305]
# computed_metrics: [0.6020902504958036]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4941080979117516]
# computed_metrics: [0.4941080979117516]
# computed_metrics: [0.5575775360486457]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.4809608267434952]
# computed_metrics: [0.4809608267434952]
# computed_metrics: [0.5378269350131133]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.4731752488047054]
# computed_metrics: [0.4731752488047054]
# computed_metrics: [0.5227054837630014]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.4640742667590606]
# computed_metrics: [0.4640742667590606]
# computed_metrics: [0.5348138701524197]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.44908928157792477]
# computed_metrics: [0.44908928157792477]
# computed_metrics: [0.537740257144874]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.4486260417678726]
# computed_metrics: [0.4486260417678726]
# computed_metrics: [0.5363240668200585]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.45397010752379163]
# computed_metrics: [0.45397010752379163]
# computed_metrics: [0.5613556058086434]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.46570357818408026]
# computed_metrics: [0.46570357818408026]
# computed_metrics: [0.5725143597802804]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.46174352021650866]
# computed_metrics: [0.46174352021650866]
# computed_metrics: [0.5657061783276698]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.46309532406665505]
# computed_metrics: [0.46309532406665505]
# computed_metrics: [0.5582062359957227]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4820178522611462]
# computed_metrics: [0.4820178522611462]
# computed_metrics: [0.5899133187122686]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.5294639855587436]
# computed_metrics: [0.5294639855587436]
# computed_metrics: [0.6209878570252897]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.5637578068083389]
# computed_metrics: [0.5637578068083389]
# computed_metrics: [0.6724674736125025]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.5912783970324793]
# computed_metrics: [0.5912783970324793]
# computed_metrics: [0.68491535350586]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.573673568777106]
# computed_metrics: [0.573673568777106]
# computed_metrics: [0.6794871005815006]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.616429515112629]
# computed_metrics: [0.616429515112629]
# computed_metrics: [0.6909084484077065]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.587140788552341]
# computed_metrics: [0.587140788552341]
# computed_metrics: [0.6571213876329622]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.6583638623192044]
# computed_metrics: [0.6583638623192044]
# computed_metrics: [0.7339481044667918]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.5701810829847351]
# computed_metrics: [0.5701810829847351]
# computed_metrics: [0.6449085169928432]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.5918297368903934]
# computed_metrics: [0.5918297368903934]
# computed_metrics: [0.6615834710293077]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.5680318699394801]
# computed_metrics: [0.5680318699394801]
# computed_metrics: [0.6315770687580353]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.4653804486563682]
# computed_metrics: [0.4653804486563682]
# computed_metrics: [0.592515075573472]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.4854280622367582]
# computed_metrics: [0.4854280622367582]
# computed_metrics: [0.5939417623681253]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.4328047947638988]
# computed_metrics: [0.4328047947638988]
# computed_metrics: [0.5373321069126042]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.43305185610936037]
# computed_metrics: [0.43305185610936037]
# computed_metrics: [0.5409234851908554]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.41985166187078077]
# computed_metrics: [0.41985166187078077]
# computed_metrics: [0.5224345712865736]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.42168655113891707]
# computed_metrics: [0.42168655113891707]
# computed_metrics: [0.527740558103043]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.4442908315784698]
# computed_metrics: [0.4442908315784698]
# computed_metrics: [0.5379993081130038]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.44901085490275483]
# computed_metrics: [0.44901085490275483]
# computed_metrics: [0.536861874334566]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.4464181361233943]
# computed_metrics: [0.4464181361233943]
# computed_metrics: [0.532937934110142]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.4737362727838466]
# computed_metrics: [0.4737362727838466]
# computed_metrics: [0.5583223866954]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.43801648539378135]
# computed_metrics: [0.43801648539378135]
# computed_metrics: [0.5317434880107791]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.439948899407449]
# computed_metrics: [0.439948899407449]
# computed_metrics: [0.5449088705123013]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.38909610017171053]
# computed_metrics: [0.38909610017171053]
# computed_metrics: [0.4902148242676327]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.38563800510725943]
# computed_metrics: [0.38563800510725943]
# computed_metrics: [0.4940553111277761]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.40368753255679685]
# computed_metrics: [0.40368753255679685]
# computed_metrics: [0.5154712548170196]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.39857808860649363]
# computed_metrics: [0.39857808860649363]
# computed_metrics: [0.5279550639746897]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3994607993814936]
# computed_metrics: [0.3994607993814936]
# computed_metrics: [0.548831849786003]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.40567551367687305]
# computed_metrics: [0.40567551367687305]
# computed_metrics: [0.5359320530953303]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.39084770543346814]
# computed_metrics: [0.39084770543346814]
# computed_metrics: [0.5234485072557656]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.38227685193200334]
# computed_metrics: [0.38227685193200334]
# computed_metrics: [0.5294363158418037]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.40698732346451527]
# computed_metrics: [0.40698732346451527]
# computed_metrics: [0.5501407849488046]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.4346554055092453]
# computed_metrics: [0.4346554055092453]
# computed_metrics: [0.5613799541222289]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.430977270443219]
# computed_metrics: [0.430977270443219]
# computed_metrics: [0.5575318411874414]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.43467043285242246]
# computed_metrics: [0.43467043285242246]
# computed_metrics: [0.5920684766041789]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.48194969291010364]
# computed_metrics: [0.48194969291010364]
# computed_metrics: [0.6185921844627802]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.4400492274664472]
# computed_metrics: [0.4400492274664472]
# computed_metrics: [0.5722763759692924]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.4803317815947276]
# computed_metrics: [0.4803317815947276]
# computed_metrics: [0.5880943065417621]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.4681211053550295]
# computed_metrics: [0.4681211053550295]
# computed_metrics: [0.5996125429639418]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.4358822499840703]
# computed_metrics: [0.4358822499840703]
# computed_metrics: [0.5752961036257279]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.45363109447217737]
# computed_metrics: [0.45363109447217737]
# computed_metrics: [0.5907027473325422]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.47209496202350393]
# computed_metrics: [0.47209496202350393]
# computed_metrics: [0.5919934212605803]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3981608977508524]
# computed_metrics: [0.3981608977508524]
# computed_metrics: [0.5490283041104219]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.44812493479200755]
# computed_metrics: [0.44812493479200755]
# computed_metrics: [0.5810872580778751]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.41236106517033105]
# computed_metrics: [0.41236106517033105]
# computed_metrics: [0.5553355161659173]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.38655987404132336]
# computed_metrics: [0.38655987404132336]
# computed_metrics: [0.5217119591530386]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.37362047223112643]
# computed_metrics: [0.37362047223112643]
# computed_metrics: [0.513905105938733]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3975983054445534]
# computed_metrics: [0.3975983054445534]
# computed_metrics: [0.5289383664961783]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.36171565068272743]
# computed_metrics: [0.36171565068272743]
# computed_metrics: [0.5076926617433734]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.3501782408612432]
# computed_metrics: [0.3501782408612432]
# computed_metrics: [0.5144296603552575]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.4171912179363413]
# computed_metrics: [0.4171912179363413]
# computed_metrics: [0.5382690485613463]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.3586739280723639]
# computed_metrics: [0.3586739280723639]
# computed_metrics: [0.5116530388935818]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3659489557988176]
# computed_metrics: [0.3659489557988176]
# computed_metrics: [0.5265928824570575]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.39987556537818203]
# computed_metrics: [0.39987556537818203]
# computed_metrics: [0.5254038073444202]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.3486276925772206]
# computed_metrics: [0.3486276925772206]
# computed_metrics: [0.5004694779854609]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.36010016814731993]
# computed_metrics: [0.36010016814731993]
# computed_metrics: [0.5245569547671187]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.35955749117098224]
# computed_metrics: [0.35955749117098224]
# computed_metrics: [0.496613379919436]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3427448565386562]
# computed_metrics: [0.3427448565386562]
# computed_metrics: [0.5061374169969967]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.3567120653047122]
# computed_metrics: [0.3567120653047122]
# computed_metrics: [0.5464603334888367]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3393920040886741]
# computed_metrics: [0.3393920040886741]
# computed_metrics: [0.4946503549027971]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.38710180061350397]
# computed_metrics: [0.38710180061350397]
# computed_metrics: [0.5494923156443821]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3546715843701389]
# computed_metrics: [0.3546715843701389]
# computed_metrics: [0.5159504678085216]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.34034129620327896]
# computed_metrics: [0.34034129620327896]
# computed_metrics: [0.4840287825810932]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.4234163243101985]
# computed_metrics: [0.4234163243101985]
# computed_metrics: [0.5812880682080659]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.37584289420413636]
# computed_metrics: [0.37584289420413636]
# computed_metrics: [0.5330911295257901]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.35210545201346133]
# computed_metrics: [0.35210545201346133]
# computed_metrics: [0.5090236819253019]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.4299367186899995]
# computed_metrics: [0.4299367186899995]
# computed_metrics: [0.5377864666632968]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.3944373126532613]
# computed_metrics: [0.3944373126532613]
# computed_metrics: [0.5605307187194526]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.3907102682156832]
# computed_metrics: [0.3907102682156832]
# computed_metrics: [0.5422577572373891]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.36943584204544777]
# computed_metrics: [0.36943584204544777]
# computed_metrics: [0.520553122578265]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.3948568333338808]
# computed_metrics: [0.3948568333338808]
# computed_metrics: [0.5474905283371048]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.4309937906609017]
# computed_metrics: [0.4309937906609017]
# computed_metrics: [0.5620000348387825]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.3522228041940069]
# computed_metrics: [0.3522228041940069]
# computed_metrics: [0.4987455651649915]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.359377004649844]
# computed_metrics: [0.359377004649844]
# computed_metrics: [0.5037828374982509]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.4647275165294145]
# computed_metrics: [0.4647275165294145]
# computed_metrics: [0.5793419506729968]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.3766089410457727]
# computed_metrics: [0.3766089410457727]
# computed_metrics: [0.5233045291554086]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.3547586804984921]
# computed_metrics: [0.3547586804984921]
# computed_metrics: [0.5092882854942017]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.38872401416573366]
# computed_metrics: [0.38872401416573366]
# computed_metrics: [0.5210658021314172]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3643389589138017]
# computed_metrics: [0.3643389589138017]
# computed_metrics: [0.5082783446247173]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.3228037992613063]
# computed_metrics: [0.3228037992613063]
# computed_metrics: [0.49079010339385337]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.32854806756592086]
# computed_metrics: [0.32854806756592086]
# computed_metrics: [0.5077541663372342]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.3633271147033253]
# computed_metrics: [0.3633271147033253]
# computed_metrics: [0.5053392768238523]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.3228392845263729]
# computed_metrics: [0.3228392845263729]
# computed_metrics: [0.5045035430175512]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.3470112244401875]
# computed_metrics: [0.3470112244401875]
# computed_metrics: [0.506170553545237]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.33920135060396284]
# computed_metrics: [0.33920135060396284]
# computed_metrics: [0.527735398115999]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.35113200757899954]
# computed_metrics: [0.35113200757899954]
# computed_metrics: [0.5219610233435575]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.3440046117570918]
# computed_metrics: [0.3440046117570918]
# computed_metrics: [0.5174076043952441]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.3605528152855125]
# computed_metrics: [0.3605528152855125]
# computed_metrics: [0.5471235057519309]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.4072573596977801]
# computed_metrics: [0.4072573596977801]
# computed_metrics: [0.5839213050729923]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.3847923492742805]
# computed_metrics: [0.3847923492742805]
# computed_metrics: [0.5669932409871602]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.4227854281882857]
# computed_metrics: [0.4227854281882857]
# computed_metrics: [0.5972589053637858]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.4243699446018274]
# computed_metrics: [0.4243699446018274]
# computed_metrics: [0.6031682509544536]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.4610592036091369]
# computed_metrics: [0.4610592036091369]
# computed_metrics: [0.6215079145098911]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.4867152238132413]
# computed_metrics: [0.4867152238132413]
# computed_metrics: [0.6626190346279786]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.42858806752143175]
# computed_metrics: [0.42858806752143175]
# computed_metrics: [0.6118693809779387]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.4429734237846196]
# computed_metrics: [0.4429734237846196]
# computed_metrics: [0.6217455171899388]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.5550664398683518]
# computed_metrics: [0.5550664398683518]
# computed_metrics: [0.7092512441735636]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.4289884769864004]
# computed_metrics: [0.4289884769864004]
# computed_metrics: [0.5870867435405395]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.406146089115821]
# computed_metrics: [0.406146089115821]
# computed_metrics: [0.5654125561629751]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.4378375873991493]
# computed_metrics: [0.4378375873991493]
# computed_metrics: [0.558911420077764]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.3519541249328309]
# computed_metrics: [0.3519541249328309]
# computed_metrics: [0.5316276831638448]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.3564485918003322]
# computed_metrics: [0.3564485918003322]
# computed_metrics: [0.5247670772641299]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.34426709818887324]
# computed_metrics: [0.34426709818887324]
# computed_metrics: [0.5423490197493961]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.313241430250495]
# computed_metrics: [0.313241430250495]
# computed_metrics: [0.5218153162767515]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.34876972989056215]
# computed_metrics: [0.34876972989056215]
# computed_metrics: [0.542289863265638]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.30845670780718115]
# computed_metrics: [0.30845670780718115]
# computed_metrics: [0.5113024513754344]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3274447199542985]
# computed_metrics: [0.3274447199542985]
# computed_metrics: [0.5343817576585448]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.32409324183560456]
# computed_metrics: [0.32409324183560456]
# computed_metrics: [0.5085887956857538]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.3096043876304962]
# computed_metrics: [0.3096043876304962]
# computed_metrics: [0.5196802005025342]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3383123867574704]
# computed_metrics: [0.3383123867574704]
# computed_metrics: [0.5148887459064481]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.3422363183078068]
# computed_metrics: [0.3422363183078068]
# computed_metrics: [0.5141238793912198]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.3085981662141707]
# computed_metrics: [0.3085981662141707]
# computed_metrics: [0.509851081992837]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.3350722104863052]
# computed_metrics: [0.3350722104863052]
# computed_metrics: [0.5191869524428507]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.3756720735873613]
# computed_metrics: [0.3756720735873613]
# computed_metrics: [0.560204465619234]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.33459892248450573]
# computed_metrics: [0.33459892248450573]
# computed_metrics: [0.532887735375164]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.3605482488712721]
# computed_metrics: [0.3605482488712721]
# computed_metrics: [0.5348370859435605]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.37987934450375443]
# computed_metrics: [0.37987934450375443]
# computed_metrics: [0.5309930302274031]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.33541008041952775]
# computed_metrics: [0.33541008041952775]
# computed_metrics: [0.5181207693372609]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3513131404041387]
# computed_metrics: [0.3513131404041387]
# computed_metrics: [0.5125724591971093]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.3498643919924373]
# computed_metrics: [0.3498643919924373]
# computed_metrics: [0.5026218853720232]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.32345692801099574]
# computed_metrics: [0.32345692801099574]
# computed_metrics: [0.5008199696907822]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.32319789240505326]
# computed_metrics: [0.32319789240505326]
# computed_metrics: [0.5260251745920518]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.3678702326945582]
# computed_metrics: [0.3678702326945582]
# computed_metrics: [0.5254716361186725]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.31805849622879334]
# computed_metrics: [0.31805849622879334]
# computed_metrics: [0.5178986798159007]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.32047352157236775]
# computed_metrics: [0.32047352157236775]
# computed_metrics: [0.5150994608604159]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.3295216163966851]
# computed_metrics: [0.3295216163966851]
# computed_metrics: [0.5349371384619726]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.3492456369319132]
# computed_metrics: [0.3492456369319132]
# computed_metrics: [0.5588396173690162]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.3835978233144299]
# computed_metrics: [0.3835978233144299]
# computed_metrics: [0.5912466918945192]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.37973291521499375]
# computed_metrics: [0.37973291521499375]
# computed_metrics: [0.5822225088284012]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.4140690187754099]
# computed_metrics: [0.4140690187754099]
# computed_metrics: [0.5984712602466679]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.3313184839181279]
# computed_metrics: [0.3313184839181279]
# computed_metrics: [0.5614804542462722]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.3620653029732181]
# computed_metrics: [0.3620653029732181]
# computed_metrics: [0.556841673713458]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.37699497448609887]
# computed_metrics: [0.37699497448609887]
# computed_metrics: [0.5752338284134159]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.3278710273232577]
# computed_metrics: [0.3278710273232577]
# computed_metrics: [0.5286276262633297]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.3574035541524497]
# computed_metrics: [0.3574035541524497]
# computed_metrics: [0.559834014349104]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.32463571695866883]
# computed_metrics: [0.32463571695866883]
# computed_metrics: [0.49685593787917864]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.30537872150857215]
# computed_metrics: [0.30537872150857215]
# computed_metrics: [0.5136227381001379]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.2775828363556043]
# computed_metrics: [0.2775828363556043]
# computed_metrics: [0.49348975067018624]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.2803795413815104]
# computed_metrics: [0.2803795413815104]
# computed_metrics: [0.4912156323095711]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.2865423982472647]
# computed_metrics: [0.2865423982472647]
# computed_metrics: [0.5021152210489213]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.31205173892893184]
# computed_metrics: [0.31205173892893184]
# computed_metrics: [0.5387831074039761]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.30800676040416514]
# computed_metrics: [0.30800676040416514]
# computed_metrics: [0.5021723783219842]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.3361978652143391]
# computed_metrics: [0.3361978652143391]
# computed_metrics: [0.5252988011315318]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.3450329508805651]
# computed_metrics: [0.3450329508805651]
# computed_metrics: [0.5415610462690704]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.30803985756822894]
# computed_metrics: [0.30803985756822894]
# computed_metrics: [0.5012376979935189]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.352516981143604]
# computed_metrics: [0.352516981143604]
# computed_metrics: [0.550760077950887]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.37766429405095575]
# computed_metrics: [0.37766429405095575]
# computed_metrics: [0.5403577387723973]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.3302807323241843]
# computed_metrics: [0.3302807323241843]
# computed_metrics: [0.5152625785174493]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.4027689486997839]
# computed_metrics: [0.4027689486997839]
# computed_metrics: [0.563148481191053]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.372517744766064]
# computed_metrics: [0.372517744766064]
# computed_metrics: [0.5555358439066121]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.3286251830068427]
# computed_metrics: [0.3286251830068427]
# computed_metrics: [0.5200868056714414]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.3049118567654359]
# computed_metrics: [0.3049118567654359]
# computed_metrics: [0.490956704524075]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.29648539027279086]
# computed_metrics: [0.29648539027279086]
# computed_metrics: [0.5186412281483749]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.2934094970315222]
# computed_metrics: [0.2934094970315222]
# computed_metrics: [0.5142941235075367]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.2800510354932637]
# computed_metrics: [0.2800510354932637]
# computed_metrics: [0.4881493682922149]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.2962573658248292]
# computed_metrics: [0.2962573658248292]
# computed_metrics: [0.5287533570829369]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.29925943741357297]
# computed_metrics: [0.29925943741357297]
# computed_metrics: [0.5164758940432823]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.3692024048586546]
# computed_metrics: [0.3692024048586546]
# computed_metrics: [0.5629797460843959]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.3240809641136764]
# computed_metrics: [0.3240809641136764]
# computed_metrics: [0.5405912154662811]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.3639520329715304]
# computed_metrics: [0.3639520329715304]
# computed_metrics: [0.563888625702162]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.3615005878497515]
# computed_metrics: [0.3615005878497515]
# computed_metrics: [0.5678865941069628]
# 6.413188433647155

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.3615005878497515]
# computed_metrics: [0.5678865941069628]
# computed_metrics: [0.5964631955927084]
# {'mean-mean_absolute_error': 0.5964631955927084}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.93542874, 0.0)
# SpearmanrResult(correlation=0.9374655158187793, pvalue=0.0)
# (0.77544993, 8.77054761191931e-37)
# SpearmanrResult(correlation=0.8122028836320558, pvalue=8.123742987151777e-43)
# (0.7915591, 2.809303987392286e-39)
# SpearmanrResult(correlation=0.8051641784648613, pvalue=1.4582346321960411e-41)
