# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gc3 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm2, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm3 = BatchNorm(in_layers=[gc3])
    gc4 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm3, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm4 = BatchNorm(in_layers=[gc4])

    gc5 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm4, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm5 = BatchNorm(in_layers=[gc5])
    gc6 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm5, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm6 = BatchNorm(in_layers=[gc6])
    gc7 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm6, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm7 = BatchNorm(in_layers=[gc7])
    gc8 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm7, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm8 = BatchNorm(in_layers=[gc8])
    
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[batch_norm8])
    batch_norm9 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm5, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 3.233 s
# TIMING: dataset construction took 3.694 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.629 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.266 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.276 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 64
C2_filtnum = 64
D_nodenum = 32

graph_structure = 'GC{0}_GC{1}_x4_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [1.053583009704709]
# computed_metrics: [1.053583009704709]
# computed_metrics: [1.041511975021896]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [0.9258955594356373]
# computed_metrics: [0.9258955594356373]
# computed_metrics: [0.9247113535115478]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.9176710476171954]
# computed_metrics: [0.9176710476171954]
# computed_metrics: [0.9085909278309112]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.8855174631147623]
# computed_metrics: [0.8855174631147623]
# computed_metrics: [0.8676179328672398]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.8513124277992227]
# computed_metrics: [0.8513124277992227]
# computed_metrics: [0.8375992087798273]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.8347247168282936]
# computed_metrics: [0.8347247168282936]
# computed_metrics: [0.8319969345075209]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.8211583888183326]
# computed_metrics: [0.8211583888183326]
# computed_metrics: [0.8294560390131568]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.7935786141835836]
# computed_metrics: [0.7935786141835836]
# computed_metrics: [0.8108474279212701]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.7657897735056447]
# computed_metrics: [0.7657897735056447]
# computed_metrics: [0.7753525188538087]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.7408888057188838]
# computed_metrics: [0.7408888057188838]
# computed_metrics: [0.7653130297064036]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.7254461802638482]
# computed_metrics: [0.7254461802638482]
# computed_metrics: [0.7484856378755488]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.7023563080635555]
# computed_metrics: [0.7023563080635555]
# computed_metrics: [0.743988519229329]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.7049388867706411]
# computed_metrics: [0.7049388867706411]
# computed_metrics: [0.7448890217924031]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.6879944777966941]
# computed_metrics: [0.6879944777966941]
# computed_metrics: [0.7290218964242112]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.6694513546049533]
# computed_metrics: [0.6694513546049533]
# computed_metrics: [0.7275722272303532]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.6374964039256416]
# computed_metrics: [0.6374964039256416]
# computed_metrics: [0.6873930843285329]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.6413942603592462]
# computed_metrics: [0.6413942603592462]
# computed_metrics: [0.6900216300172567]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.619263924077818]
# computed_metrics: [0.619263924077818]
# computed_metrics: [0.6690028549968701]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.6308239831815692]
# computed_metrics: [0.6308239831815692]
# computed_metrics: [0.6791386908878836]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.6268793679765795]
# computed_metrics: [0.6268793679765795]
# computed_metrics: [0.6798043227132594]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.6140435446667394]
# computed_metrics: [0.6140435446667394]
# computed_metrics: [0.654309592015149]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.5922547813808825]
# computed_metrics: [0.5922547813808825]
# computed_metrics: [0.6691278374224017]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.6112197401114565]
# computed_metrics: [0.6112197401114565]
# computed_metrics: [0.6700541895424619]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.6186461381526369]
# computed_metrics: [0.6186461381526369]
# computed_metrics: [0.6769805623259368]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.6103600261361012]
# computed_metrics: [0.6103600261361012]
# computed_metrics: [0.6346289394221077]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.5620418209391952]
# computed_metrics: [0.5620418209391952]
# computed_metrics: [0.6107548709255339]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.5583607546365101]
# computed_metrics: [0.5583607546365101]
# computed_metrics: [0.60225178214586]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.5570158436160371]
# computed_metrics: [0.5570158436160371]
# computed_metrics: [0.6036561283841038]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.5602781992932969]
# computed_metrics: [0.5602781992932969]
# computed_metrics: [0.6119285330432216]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.5386459404073353]
# computed_metrics: [0.5386459404073353]
# computed_metrics: [0.5995496881897444]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.5307958354359447]
# computed_metrics: [0.5307958354359447]
# computed_metrics: [0.5793923851736226]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.5243218407191992]
# computed_metrics: [0.5243218407191992]
# computed_metrics: [0.5929842581572462]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.5140817894236673]
# computed_metrics: [0.5140817894236673]
# computed_metrics: [0.5681221883932707]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.49154913083841584]
# computed_metrics: [0.49154913083841584]
# computed_metrics: [0.5736272122589802]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.5008966151997071]
# computed_metrics: [0.5008966151997071]
# computed_metrics: [0.5590826204088993]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.4864365531042454]
# computed_metrics: [0.4864365531042454]
# computed_metrics: [0.5542390965118249]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.4669237934368663]
# computed_metrics: [0.4669237934368663]
# computed_metrics: [0.5361667673562025]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.45764966936918244]
# computed_metrics: [0.45764966936918244]
# computed_metrics: [0.5392871334962298]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.45144692875099973]
# computed_metrics: [0.45144692875099973]
# computed_metrics: [0.5365916534877253]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.47635272776881976]
# computed_metrics: [0.47635272776881976]
# computed_metrics: [0.5795474332030773]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5195310038729656]
# computed_metrics: [0.5195310038729656]
# computed_metrics: [0.6158590359482952]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.4898931786102713]
# computed_metrics: [0.4898931786102713]
# computed_metrics: [0.5668223424832901]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.48405114622466316]
# computed_metrics: [0.48405114622466316]
# computed_metrics: [0.5698882715938847]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.4655326997979971]
# computed_metrics: [0.4655326997979971]
# computed_metrics: [0.5509323591644919]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.44359459274064]
# computed_metrics: [0.44359459274064]
# computed_metrics: [0.535571566284033]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.4298760943144725]
# computed_metrics: [0.4298760943144725]
# computed_metrics: [0.5337055296880955]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.4219874200394767]
# computed_metrics: [0.4219874200394767]
# computed_metrics: [0.5257389682095754]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.41620738108138977]
# computed_metrics: [0.41620738108138977]
# computed_metrics: [0.520825890718895]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.45313329332819213]
# computed_metrics: [0.45313329332819213]
# computed_metrics: [0.5499401462877757]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.42180142739275167]
# computed_metrics: [0.42180142739275167]
# computed_metrics: [0.5344002946901535]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.4234742945356422]
# computed_metrics: [0.4234742945356422]
# computed_metrics: [0.5376105756513218]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.4436002038166766]
# computed_metrics: [0.4436002038166766]
# computed_metrics: [0.5593022224186975]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.40421626669468064]
# computed_metrics: [0.40421626669468064]
# computed_metrics: [0.5275133814464352]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.4572812924332502]
# computed_metrics: [0.4572812924332502]
# computed_metrics: [0.5689677007941312]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5167161147416778]
# computed_metrics: [0.5167161147416778]
# computed_metrics: [0.628673320233306]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.431023041337988]
# computed_metrics: [0.431023041337988]
# computed_metrics: [0.5455815220888871]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.40361929659459467]
# computed_metrics: [0.40361929659459467]
# computed_metrics: [0.5291671120338161]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.42131163573703917]
# computed_metrics: [0.42131163573703917]
# computed_metrics: [0.5225203164826572]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.37352945233861146]
# computed_metrics: [0.37352945233861146]
# computed_metrics: [0.5129310596047174]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.3961062539970965]
# computed_metrics: [0.3961062539970965]
# computed_metrics: [0.5252276837744635]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.4084672427986513]
# computed_metrics: [0.4084672427986513]
# computed_metrics: [0.5495503744890998]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.37687172514253714]
# computed_metrics: [0.37687172514253714]
# computed_metrics: [0.5242254911884979]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.3810077448920341]
# computed_metrics: [0.3810077448920341]
# computed_metrics: [0.543272880981675]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.37724421532021973]
# computed_metrics: [0.37724421532021973]
# computed_metrics: [0.540533683266738]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.41587029063972286]
# computed_metrics: [0.41587029063972286]
# computed_metrics: [0.5343339583741022]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.37677473924202365]
# computed_metrics: [0.37677473924202365]
# computed_metrics: [0.5305009963076601]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.3727586682924209]
# computed_metrics: [0.3727586682924209]
# computed_metrics: [0.5078761768613433]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.4176574516173451]
# computed_metrics: [0.4176574516173451]
# computed_metrics: [0.5340814559258055]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.42563662394838053]
# computed_metrics: [0.42563662394838053]
# computed_metrics: [0.5291205793600895]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.4657953869855216]
# computed_metrics: [0.4657953869855216]
# computed_metrics: [0.5468870172248131]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.4428661399802867]
# computed_metrics: [0.4428661399802867]
# computed_metrics: [0.5413072774795984]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.4090823377439471]
# computed_metrics: [0.4090823377439471]
# computed_metrics: [0.5327770809654037]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.4898981186929267]
# computed_metrics: [0.4898981186929267]
# computed_metrics: [0.6034243242745785]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.44404305405010563]
# computed_metrics: [0.44404305405010563]
# computed_metrics: [0.5653061071226964]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.40014764796802943]
# computed_metrics: [0.40014764796802943]
# computed_metrics: [0.5402178225615113]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.44415289743835173]
# computed_metrics: [0.44415289743835173]
# computed_metrics: [0.5676002295700533]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.41760223078750963]
# computed_metrics: [0.41760223078750963]
# computed_metrics: [0.5493935740740703]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5010344458784959]
# computed_metrics: [0.5010344458784959]
# computed_metrics: [0.6275430358328005]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.4331023587393058]
# computed_metrics: [0.4331023587393058]
# computed_metrics: [0.5902787492638486]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4352163525061239]
# computed_metrics: [0.4352163525061239]
# computed_metrics: [0.5379642508395519]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4543730639993441]
# computed_metrics: [0.4543730639993441]
# computed_metrics: [0.556307561531481]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.48071425893944564]
# computed_metrics: [0.48071425893944564]
# computed_metrics: [0.6108700198858339]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.37595019738442503]
# computed_metrics: [0.37595019738442503]
# computed_metrics: [0.551746941463216]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.41770669071725225]
# computed_metrics: [0.41770669071725225]
# computed_metrics: [0.5404998327378215]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.37830468500343306]
# computed_metrics: [0.37830468500343306]
# computed_metrics: [0.5448112592352605]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.3469658810454283]
# computed_metrics: [0.3469658810454283]
# computed_metrics: [0.4893743698715284]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.38952784527065487]
# computed_metrics: [0.38952784527065487]
# computed_metrics: [0.5427165041338984]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.35985431529110357]
# computed_metrics: [0.35985431529110357]
# computed_metrics: [0.5390824539407414]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.354006418528312]
# computed_metrics: [0.354006418528312]
# computed_metrics: [0.4891979331462416]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.371748270584271]
# computed_metrics: [0.371748270584271]
# computed_metrics: [0.5251308314614402]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.39314394920200774]
# computed_metrics: [0.39314394920200774]
# computed_metrics: [0.5623237727825744]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.4192622330059972]
# computed_metrics: [0.4192622330059972]
# computed_metrics: [0.5587274792807948]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.3995375570743439]
# computed_metrics: [0.3995375570743439]
# computed_metrics: [0.5664511945123166]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.39523302720704395]
# computed_metrics: [0.39523302720704395]
# computed_metrics: [0.5634994226629241]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.34794094554812444]
# computed_metrics: [0.34794094554812444]
# computed_metrics: [0.5304258848027366]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.3229603542847887]
# computed_metrics: [0.3229603542847887]
# computed_metrics: [0.5195655105453534]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.33246991013593813]
# computed_metrics: [0.33246991013593813]
# computed_metrics: [0.5269646534120244]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.3695616036022591]
# computed_metrics: [0.3695616036022591]
# computed_metrics: [0.5430322002689917]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.40861587268352084]
# computed_metrics: [0.40861587268352084]
# computed_metrics: [0.5678077050353432]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4768661194712732]
# computed_metrics: [0.4768661194712732]
# computed_metrics: [0.6444199276409917]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4700261010743294]
# computed_metrics: [0.4700261010743294]
# computed_metrics: [0.6180034581208402]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.4519669724500482]
# computed_metrics: [0.4519669724500482]
# computed_metrics: [0.6314495802776879]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.45125017794649663]
# computed_metrics: [0.45125017794649663]
# computed_metrics: [0.6230450765641313]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.40364391415761286]
# computed_metrics: [0.40364391415761286]
# computed_metrics: [0.6023294208618728]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.34347322290875326]
# computed_metrics: [0.34347322290875326]
# computed_metrics: [0.5421205532238674]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4200820784388799]
# computed_metrics: [0.4200820784388799]
# computed_metrics: [0.5405150438887409]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.5732743449941607]
# computed_metrics: [0.5732743449941607]
# computed_metrics: [0.6650565049410404]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.5531981479392115]
# computed_metrics: [0.5531981479392115]
# computed_metrics: [0.649719389868533]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.6722571762429461]
# computed_metrics: [0.6722571762429461]
# computed_metrics: [0.7824674796877503]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.5601605584207257]
# computed_metrics: [0.5601605584207257]
# computed_metrics: [0.6552275083946515]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.39934154807972827]
# computed_metrics: [0.39934154807972827]
# computed_metrics: [0.5378080948500297]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.40873462233123864]
# computed_metrics: [0.40873462233123864]
# computed_metrics: [0.5573840864219667]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.3988457846487216]
# computed_metrics: [0.3988457846487216]
# computed_metrics: [0.5459135159691367]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.48612242921410453]
# computed_metrics: [0.48612242921410453]
# computed_metrics: [0.5925624876188057]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.45613246428033644]
# computed_metrics: [0.45613246428033644]
# computed_metrics: [0.5908356331992527]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.6014463260594861]
# computed_metrics: [0.6014463260594861]
# computed_metrics: [0.7281042505673256]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.5190764731962537]
# computed_metrics: [0.5190764731962537]
# computed_metrics: [0.6756313781864033]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.4643508972108213]
# computed_metrics: [0.4643508972108213]
# computed_metrics: [0.6136819222404403]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.39016669354992584]
# computed_metrics: [0.39016669354992584]
# computed_metrics: [0.5621533456030737]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.4484213717320475]
# computed_metrics: [0.4484213717320475]
# computed_metrics: [0.5655955702349236]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.5616463060282748]
# computed_metrics: [0.5616463060282748]
# computed_metrics: [0.651665841582544]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.5504361295577358]
# computed_metrics: [0.5504361295577358]
# computed_metrics: [0.6562450551154803]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.40459091449676166]
# computed_metrics: [0.40459091449676166]
# computed_metrics: [0.5513890921793984]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.42354975373165454]
# computed_metrics: [0.42354975373165454]
# computed_metrics: [0.5295789424705553]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.5078635931062909]
# computed_metrics: [0.5078635931062909]
# computed_metrics: [0.6394437846096985]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.560678265082323]
# computed_metrics: [0.560678265082323]
# computed_metrics: [0.6810497823892107]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.38161343868993974]
# computed_metrics: [0.38161343868993974]
# computed_metrics: [0.5933203003347864]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.36891772214044155]
# computed_metrics: [0.36891772214044155]
# computed_metrics: [0.5213474877857246]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.4990916899445787]
# computed_metrics: [0.4990916899445787]
# computed_metrics: [0.6123778899526904]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.5903479610780085]
# computed_metrics: [0.5903479610780085]
# computed_metrics: [0.7125656642235357]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.38052667520508043]
# computed_metrics: [0.38052667520508043]
# computed_metrics: [0.5469751899635572]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.36254055344309555]
# computed_metrics: [0.36254055344309555]
# computed_metrics: [0.5210558772815284]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.4891714237579968]
# computed_metrics: [0.4891714237579968]
# computed_metrics: [0.6274384987333783]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.4733046340220599]
# computed_metrics: [0.4733046340220599]
# computed_metrics: [0.6200352328401217]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.31231785818859886]
# computed_metrics: [0.31231785818859886]
# computed_metrics: [0.5183749528457304]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3326834504066284]
# computed_metrics: [0.3326834504066284]
# computed_metrics: [0.5023491307460806]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.45425034240585677]
# computed_metrics: [0.45425034240585677]
# computed_metrics: [0.5950642929373647]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.42743344208353806]
# computed_metrics: [0.42743344208353806]
# computed_metrics: [0.5697664780445107]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.3351675738504704]
# computed_metrics: [0.3351675738504704]
# computed_metrics: [0.5266746886342183]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.5160299439526131]
# computed_metrics: [0.5160299439526131]
# computed_metrics: [0.6555535616109999]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.5124628698060971]
# computed_metrics: [0.5124628698060971]
# computed_metrics: [0.6349662270664146]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.3725007140720704]
# computed_metrics: [0.3725007140720704]
# computed_metrics: [0.5220574569842446]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3894476867213616]
# computed_metrics: [0.3894476867213616]
# computed_metrics: [0.5461669971169267]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.4613095815082459]
# computed_metrics: [0.4613095815082459]
# computed_metrics: [0.6021726680563206]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.45405853519696504]
# computed_metrics: [0.45405853519696504]
# computed_metrics: [0.6219281577792771]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.33387747922164684]
# computed_metrics: [0.33387747922164684]
# computed_metrics: [0.4996874640691782]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.5187227476250632]
# computed_metrics: [0.5187227476250632]
# computed_metrics: [0.6123859870238482]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.5494489246727815]
# computed_metrics: [0.5494489246727815]
# computed_metrics: [0.6773658869660912]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.3752593221942277]
# computed_metrics: [0.3752593221942277]
# computed_metrics: [0.5841715988685496]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.4709621283120451]
# computed_metrics: [0.4709621283120451]
# computed_metrics: [0.6048342005939796]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.5476560195990274]
# computed_metrics: [0.5476560195990274]
# computed_metrics: [0.6694267294398383]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.38369949759481203]
# computed_metrics: [0.38369949759481203]
# computed_metrics: [0.5601540584207549]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.35151161302377926]
# computed_metrics: [0.35151161302377926]
# computed_metrics: [0.5244472340954404]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.49768334366989725]
# computed_metrics: [0.49768334366989725]
# computed_metrics: [0.6535500703635077]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.36847691784573683]
# computed_metrics: [0.36847691784573683]
# computed_metrics: [0.5720489933991256]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.3585975295657225]
# computed_metrics: [0.3585975295657225]
# computed_metrics: [0.5624628283048886]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.4745800656662832]
# computed_metrics: [0.4745800656662832]
# computed_metrics: [0.5947806950381603]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.43379431631488363]
# computed_metrics: [0.43379431631488363]
# computed_metrics: [0.586301896124545]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.30713211323804646]
# computed_metrics: [0.30713211323804646]
# computed_metrics: [0.5129414432303206]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.39836596666792407]
# computed_metrics: [0.39836596666792407]
# computed_metrics: [0.5739658360512953]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.47483193627761544]
# computed_metrics: [0.47483193627761544]
# computed_metrics: [0.6162017783261815]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.30158714766395667]
# computed_metrics: [0.30158714766395667]
# computed_metrics: [0.5105488276893582]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.4390476937213692]
# computed_metrics: [0.4390476937213692]
# computed_metrics: [0.6005576402267699]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.47093489830999025]
# computed_metrics: [0.47093489830999025]
# computed_metrics: [0.6213736372098425]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.29929197335619495]
# computed_metrics: [0.29929197335619495]
# computed_metrics: [0.5134002558169664]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.35701627675206943]
# computed_metrics: [0.35701627675206943]
# computed_metrics: [0.5609704907149923]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.4201078420957894]
# computed_metrics: [0.4201078420957894]
# computed_metrics: [0.5941953640830032]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.2852473663977375]
# computed_metrics: [0.2852473663977375]
# computed_metrics: [0.5219540799575593]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.3976298780385869]
# computed_metrics: [0.3976298780385869]
# computed_metrics: [0.5863979457922585]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.503332800859154]
# computed_metrics: [0.503332800859154]
# computed_metrics: [0.6408038162503447]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.33680664049651066]
# computed_metrics: [0.33680664049651066]
# computed_metrics: [0.5396861261310222]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.36801630477870906]
# computed_metrics: [0.36801630477870906]
# computed_metrics: [0.5482491669280427]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.4599386088676954]
# computed_metrics: [0.4599386088676954]
# computed_metrics: [0.6072974287595931]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.3571434455710632]
# computed_metrics: [0.3571434455710632]
# computed_metrics: [0.5492024462446309]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3475205563067217]
# computed_metrics: [0.3475205563067217]
# computed_metrics: [0.5466349995204532]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.41244579306495044]
# computed_metrics: [0.41244579306495044]
# computed_metrics: [0.5909787077082655]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.31999367606925466]
# computed_metrics: [0.31999367606925466]
# computed_metrics: [0.5253644110305771]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3024518652258738]
# computed_metrics: [0.3024518652258738]
# computed_metrics: [0.5107722268829353]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.41497632280095526]
# computed_metrics: [0.41497632280095526]
# computed_metrics: [0.5722031602072399]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.31856748306213745]
# computed_metrics: [0.31856748306213745]
# computed_metrics: [0.5283497024525743]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.32960318442542336]
# computed_metrics: [0.32960318442542336]
# computed_metrics: [0.5403172372903658]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.43592384355877367]
# computed_metrics: [0.43592384355877367]
# computed_metrics: [0.5911645381865032]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.33630201714038466]
# computed_metrics: [0.33630201714038466]
# computed_metrics: [0.5514637355278178]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.3208431274198491]
# computed_metrics: [0.3208431274198491]
# computed_metrics: [0.5245027302130513]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.3717042445149435]
# computed_metrics: [0.3717042445149435]
# computed_metrics: [0.5596248357673465]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.29668094933205263]
# computed_metrics: [0.29668094933205263]
# computed_metrics: [0.5110147822797834]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.302991796616094]
# computed_metrics: [0.302991796616094]
# computed_metrics: [0.5475730187371599]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.3829434923441908]
# computed_metrics: [0.3829434923441908]
# computed_metrics: [0.5698969456730247]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.26381302960735553]
# computed_metrics: [0.26381302960735553]
# computed_metrics: [0.5131723206926647]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.30818608780071566]
# computed_metrics: [0.30818608780071566]
# computed_metrics: [0.5324018073905823]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.34760003942700596]
# computed_metrics: [0.34760003942700596]
# computed_metrics: [0.5526366059259668]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.25501023816087404]
# computed_metrics: [0.25501023816087404]
# computed_metrics: [0.5067350429795007]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.33916546642651924]
# computed_metrics: [0.33916546642651924]
# computed_metrics: [0.5475408145755193]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3599510729139129]
# computed_metrics: [0.3599510729139129]
# computed_metrics: [0.5813829267852954]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.252949922619098]
# computed_metrics: [0.252949922619098]
# computed_metrics: [0.5153088268631668]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.3080458854814508]
# computed_metrics: [0.3080458854814508]
# computed_metrics: [0.5458810546451262]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.365826236706517]
# computed_metrics: [0.365826236706517]
# computed_metrics: [0.5682209673859431]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.2756864995043785]
# computed_metrics: [0.2756864995043785]
# computed_metrics: [0.5100525842758545]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.3559302674188563]
# computed_metrics: [0.3559302674188563]
# computed_metrics: [0.541772738925062]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.4311870552543599]
# computed_metrics: [0.4311870552543599]
# computed_metrics: [0.6078188318803065]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.3062353632352677]
# computed_metrics: [0.3062353632352677]
# computed_metrics: [0.5187107248434973]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.3407799971928085]
# computed_metrics: [0.3407799971928085]
# computed_metrics: [0.5531256181547182]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.43937168319855757]
# computed_metrics: [0.43937168319855757]
# computed_metrics: [0.6012741477895616]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.3041795408012129]
# computed_metrics: [0.3041795408012129]
# computed_metrics: [0.5360541615808813]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.34016619857973335]
# computed_metrics: [0.34016619857973335]
# computed_metrics: [0.5357887712015956]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.45930454565955575]
# computed_metrics: [0.45930454565955575]
# computed_metrics: [0.6317692485839417]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.41303569595610146]
# computed_metrics: [0.41303569595610146]
# computed_metrics: [0.5894272850187332]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.29541338758955954]
# computed_metrics: [0.29541338758955954]
# computed_metrics: [0.5283392433992201]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.37361580972736486]
# computed_metrics: [0.37361580972736486]
# computed_metrics: [0.553737178441032]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.47696413570489093]
# computed_metrics: [0.47696413570489093]
# computed_metrics: [0.589384928846074]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.3406527261763226]
# computed_metrics: [0.3406527261763226]
# computed_metrics: [0.5539722101921039]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.2947750181993118]
# computed_metrics: [0.2947750181993118]
# computed_metrics: [0.5350721532057688]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.48967008724053784]
# computed_metrics: [0.48967008724053784]
# computed_metrics: [0.652087175835105]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.431946153613219]
# computed_metrics: [0.431946153613219]
# computed_metrics: [0.6243564270701476]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.29012741641778195]
# computed_metrics: [0.29012741641778195]
# computed_metrics: [0.5177787461461488]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.39130745732669064]
# computed_metrics: [0.39130745732669064]
# computed_metrics: [0.5661442013521242]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.44713940328178603]
# computed_metrics: [0.44713940328178603]
# computed_metrics: [0.5881678160702761]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.291572448098445]
# computed_metrics: [0.291572448098445]
# computed_metrics: [0.5186819536572583]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.3683220955479204]
# computed_metrics: [0.3683220955479204]
# computed_metrics: [0.567059888652452]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.44998014168037404]
# computed_metrics: [0.44998014168037404]
# computed_metrics: [0.6324560393557098]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.3017282553613002]
# computed_metrics: [0.3017282553613002]
# computed_metrics: [0.5398033091190362]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3014967905666533]
# computed_metrics: [0.3014967905666533]
# computed_metrics: [0.5319909567775754]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.4142292955717569]
# computed_metrics: [0.4142292955717569]
# computed_metrics: [0.5864239978484155]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.30309657524046724]
# computed_metrics: [0.30309657524046724]
# computed_metrics: [0.5421977396907945]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3142893774095816]
# computed_metrics: [0.3142893774095816]
# computed_metrics: [0.5719463383336727]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.4619264050466074]
# computed_metrics: [0.4619264050466074]
# computed_metrics: [0.6386196313733232]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.325022810019189]
# computed_metrics: [0.325022810019189]
# computed_metrics: [0.5626681651230325]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.3221127605029266]
# computed_metrics: [0.3221127605029266]
# computed_metrics: [0.527778677749277]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.47387392097264597]
# computed_metrics: [0.47387392097264597]
# computed_metrics: [0.6289847580687963]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.3548941991076846]
# computed_metrics: [0.3548941991076846]
# computed_metrics: [0.5429027089773804]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.32291128285778115]
# computed_metrics: [0.32291128285778115]
# computed_metrics: [0.5503693126122251]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.4704377083484744]
# computed_metrics: [0.4704377083484744]
# computed_metrics: [0.6634453792151572]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.35748669740008515]
# computed_metrics: [0.35748669740008515]
# computed_metrics: [0.5844970553789522]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3063419352588854]
# computed_metrics: [0.3063419352588854]
# computed_metrics: [0.5453266554802094]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.40224699882149123]
# computed_metrics: [0.40224699882149123]
# computed_metrics: [0.5812924421722799]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.36117223252109326]
# computed_metrics: [0.36117223252109326]
# computed_metrics: [0.5745977208179355]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.28484046369589405]
# computed_metrics: [0.28484046369589405]
# computed_metrics: [0.550877663468856]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.4778405685610212]
# computed_metrics: [0.4778405685610212]
# computed_metrics: [0.6529327476245717]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.371137416796933]
# computed_metrics: [0.371137416796933]
# computed_metrics: [0.5855756262639299]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.2954677780866136]
# computed_metrics: [0.2954677780866136]
# computed_metrics: [0.5294626411638962]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.46094693620495114]
# computed_metrics: [0.46094693620495114]
# computed_metrics: [0.6333541830555318]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.39843079421412075]
# computed_metrics: [0.39843079421412075]
# computed_metrics: [0.6292499044765899]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.30260441149213535]
# computed_metrics: [0.30260441149213535]
# computed_metrics: [0.5279975414955551]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.32314439987098953]
# computed_metrics: [0.32314439987098953]
# computed_metrics: [0.5615765275108083]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.3984229877281642]
# computed_metrics: [0.3984229877281642]
# computed_metrics: [0.5812480351318496]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.37492227458819716]
# computed_metrics: [0.37492227458819716]
# computed_metrics: [0.5821883119321324]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.27001131689495955]
# computed_metrics: [0.27001131689495955]
# computed_metrics: [0.5440128495178086]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.32676866162908913]
# computed_metrics: [0.32676866162908913]
# computed_metrics: [0.5682055315213862]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.3146696101623109]
# computed_metrics: [0.3146696101623109]
# computed_metrics: [0.5951957429240357]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24919677062468848]
# computed_metrics: [0.24919677062468848]
# computed_metrics: [0.5589506656693469]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.33076516182882354]
# computed_metrics: [0.33076516182882354]
# computed_metrics: [0.5792549228879155]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.41704308652250244]
# computed_metrics: [0.41704308652250244]
# computed_metrics: [0.6461644549405441]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.2920099268695866]
# computed_metrics: [0.2920099268695866]
# computed_metrics: [0.5459897452852382]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.34876997124311654]
# computed_metrics: [0.34876997124311654]
# computed_metrics: [0.5614432661820888]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.4654697678050409]
# computed_metrics: [0.4654697678050409]
# computed_metrics: [0.6326821336349738]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.3001333018745312]
# computed_metrics: [0.3001333018745312]
# computed_metrics: [0.5362793274046059]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.4378107482045309]
# computed_metrics: [0.4378107482045309]
# computed_metrics: [0.6391352295042511]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.5597718275204319]
# computed_metrics: [0.5597718275204319]
# computed_metrics: [0.7224058835808355]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.336562762525228]
# computed_metrics: [0.336562762525228]
# computed_metrics: [0.5815828967056234]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.3889521526069895]
# computed_metrics: [0.3889521526069895]
# computed_metrics: [0.5777837059801076]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.4669211563075191]
# computed_metrics: [0.4669211563075191]
# computed_metrics: [0.6331285220728391]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.26864067090709465]
# computed_metrics: [0.26864067090709465]
# computed_metrics: [0.5466520298528547]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.3500314222663015]
# computed_metrics: [0.3500314222663015]
# computed_metrics: [0.5750967706381166]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.34680482346158004]
# computed_metrics: [0.34680482346158004]
# computed_metrics: [0.5820814513472423]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.25259569617431993]
# computed_metrics: [0.25259569617431993]
# computed_metrics: [0.5269155274190553]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.34430860280942244]
# computed_metrics: [0.34430860280942244]
# computed_metrics: [0.5709287369887109]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.26741182847397166]
# computed_metrics: [0.26741182847397166]
# computed_metrics: [0.5258307847629454]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.28034344402919187]
# computed_metrics: [0.28034344402919187]
# computed_metrics: [0.5424192136110062]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.3584447164197317]
# computed_metrics: [0.3584447164197317]
# computed_metrics: [0.6051220379438695]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.2242243469805642]
# computed_metrics: [0.2242243469805642]
# computed_metrics: [0.5163003513284178]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.3084368339701675]
# computed_metrics: [0.3084368339701675]
# computed_metrics: [0.5612732509230615]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.28495081605644706]
# computed_metrics: [0.28495081605644706]
# computed_metrics: [0.5481597489420202]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.23451440887830946]
# computed_metrics: [0.23451440887830946]
# computed_metrics: [0.5316792823432991]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.3489539623289521]
# computed_metrics: [0.3489539623289521]
# computed_metrics: [0.5891520859548874]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.24480485478261077]
# computed_metrics: [0.24480485478261077]
# computed_metrics: [0.533141349445804]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.28367522034523157]
# computed_metrics: [0.28367522034523157]
# computed_metrics: [0.5423698531163146]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.3282321544918657]
# computed_metrics: [0.3282321544918657]
# computed_metrics: [0.5921795278751494]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.2271418426555658]
# computed_metrics: [0.2271418426555658]
# computed_metrics: [0.5382657915812665]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.32804292551016945]
# computed_metrics: [0.32804292551016945]
# computed_metrics: [0.5927039072922925]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.2835001050159956]
# computed_metrics: [0.2835001050159956]
# computed_metrics: [0.5590657628996663]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.25459990438141306]
# computed_metrics: [0.25459990438141306]
# computed_metrics: [0.5479602773181562]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.3594397572837489]
# computed_metrics: [0.3594397572837489]
# computed_metrics: [0.5972889926504968]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.2637907429467421]
# computed_metrics: [0.2637907429467421]
# computed_metrics: [0.5529161853052971]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.2648651838633396]
# computed_metrics: [0.2648651838633396]
# computed_metrics: [0.5486563131445062]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3481037919694047]
# computed_metrics: [0.3481037919694047]
# computed_metrics: [0.6183596581294177]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.25495455262487615]
# computed_metrics: [0.25495455262487615]
# computed_metrics: [0.5562543537199662]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.2849351431401886]
# computed_metrics: [0.2849351431401886]
# computed_metrics: [0.5534264160091106]
# Starting epoch 287
# Starting validation epoch 287
# ...
# Starting epoch 452
# Starting validation epoch 452
# computed_metrics: [0.3473813183128723]
# computed_metrics: [0.3473813183128723]
# computed_metrics: [0.5875770309454226]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.20621802048685492]
# computed_metrics: [0.20621802048685492]
# computed_metrics: [0.5154987946030574]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.3243939650262483]
# computed_metrics: [0.3243939650262483]
# computed_metrics: [0.5575143138837461]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.319176286454837]
# computed_metrics: [0.319176286454837]
# computed_metrics: [0.5645097472580879]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.2146690885292628]
# computed_metrics: [0.2146690885292628]
# computed_metrics: [0.519643859100993]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.3638347532131242]
# computed_metrics: [0.3638347532131242]
# computed_metrics: [0.5889326356100961]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.27683846913888494]
# computed_metrics: [0.27683846913888494]
# computed_metrics: [0.5378664585524768]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.2835365340068582]
# computed_metrics: [0.2835365340068582]
# computed_metrics: [0.5348235123847032]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.4181997829551032]
# computed_metrics: [0.4181997829551032]
# computed_metrics: [0.6249428937457263]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.25011488858247855]
# computed_metrics: [0.25011488858247855]
# computed_metrics: [0.5583345334808191]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.371647491130331]
# computed_metrics: [0.371647491130331]
# computed_metrics: [0.586803465673712]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.3767417503258751]
# computed_metrics: [0.3767417503258751]
# computed_metrics: [0.605642902409226]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.22003111025830024]
# computed_metrics: [0.22003111025830024]
# computed_metrics: [0.5044117010366341]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.32512582389016426]
# computed_metrics: [0.32512582389016426]
# computed_metrics: [0.5798231160563276]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.274052338438388]
# computed_metrics: [0.274052338438388]
# computed_metrics: [0.5707975097121616]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.22576306119517892]
# computed_metrics: [0.22576306119517892]
# computed_metrics: [0.548404755879672]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.38484254541652557]
# computed_metrics: [0.38484254541652557]
# computed_metrics: [0.6266285062373969]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.2548932025162811]
# computed_metrics: [0.2548932025162811]
# computed_metrics: [0.5539984289858012]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.27503379290567603]
# computed_metrics: [0.27503379290567603]
# computed_metrics: [0.5344676793770273]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.3990860988714734]
# computed_metrics: [0.3990860988714734]
# computed_metrics: [0.5858084348130057]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.2329822507889981]
# computed_metrics: [0.2329822507889981]
# computed_metrics: [0.5205771686560031]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.3092171795028719]
# computed_metrics: [0.3092171795028719]
# computed_metrics: [0.5644886775544602]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.42474127002124473]
# computed_metrics: [0.42474127002124473]
# computed_metrics: [0.6457160712183492]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.23644282940437392]
# computed_metrics: [0.23644282940437392]
# computed_metrics: [0.5168183276508178]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.33501653225518696]
# computed_metrics: [0.33501653225518696]
# computed_metrics: [0.5830309267404501]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.3369234519325733]
# computed_metrics: [0.3369234519325733]
# computed_metrics: [0.605481054906752]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.24161526404345504]
# computed_metrics: [0.24161526404345504]
# computed_metrics: [0.540605046395966]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.39469493803507777]
# computed_metrics: [0.39469493803507777]
# computed_metrics: [0.6048637696033342]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.3049687849783872]
# computed_metrics: [0.3049687849783872]
# computed_metrics: [0.5656750224643726]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.2803397301456318]
# computed_metrics: [0.2803397301456318]
# computed_metrics: [0.5619252481383752]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.4269347786881759]
# computed_metrics: [0.4269347786881759]
# computed_metrics: [0.6295997904708289]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.24756407292361968]
# computed_metrics: [0.24756407292361968]
# computed_metrics: [0.5650190904707774]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.3676599484595695]
# computed_metrics: [0.3676599484595695]
# computed_metrics: [0.5826860597830636]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.4081095633658622]
# computed_metrics: [0.4081095633658622]
# computed_metrics: [0.633935756231607]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.23987986012958423]
# computed_metrics: [0.23987986012958423]
# computed_metrics: [0.5398782463689056]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.39195384798390787]
# computed_metrics: [0.39195384798390787]
# computed_metrics: [0.6104354806878131]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.267214364805484]
# computed_metrics: [0.267214364805484]
# computed_metrics: [0.5592025414935238]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.2740208879960307]
# computed_metrics: [0.2740208879960307]
# computed_metrics: [0.5576769202226552]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.33264848258891105]
# computed_metrics: [0.33264848258891105]
# computed_metrics: [0.6063909840788382]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.21718329388596463]
# computed_metrics: [0.21718329388596463]
# computed_metrics: [0.5270872592233713]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.2734685294056683]
# computed_metrics: [0.2734685294056683]
# computed_metrics: [0.5567957270612118]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.275414792374071]
# computed_metrics: [0.275414792374071]
# computed_metrics: [0.5538658581894218]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.234790666997458]
# computed_metrics: [0.234790666997458]
# computed_metrics: [0.5676225804008358]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.39156698912688304]
# computed_metrics: [0.39156698912688304]
# computed_metrics: [0.6273198425251607]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.2944675461958082]
# computed_metrics: [0.2944675461958082]
# computed_metrics: [0.5782953400427033]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.2734206232461592]
# computed_metrics: [0.2734206232461592]
# computed_metrics: [0.5571195790753634]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.42014109459604]
# computed_metrics: [0.42014109459604]
# computed_metrics: [0.6249613954104738]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.23364964707471134]
# computed_metrics: [0.23364964707471134]
# computed_metrics: [0.5356555478793323]
# [1.053583009704709, 0.9258955594356373, 0.9176710476171954, 0.8855174631147623, 0.8513124277992227, 0.8347247168282936, 0.8211583888183326, 0.7935786141835836, 0.7657897735056447, 0.7408888057188838, 0.7254461802638482, 0.7023563080635555, 0.7049388867706411, 0.6879944777966941, 0.6694513546049533, 0.6374964039256416, 0.6413942603592462, 0.619263924077818, 0.6308239831815692, 0.6268793679765795, 0.6140435446667394, 0.5922547813808825, 0.6112197401114565, 0.6186461381526369, 0.6103600261361012, 0.5620418209391952, 0.5583607546365101, 0.5570158436160371, 0.5602781992932969, 0.5386459404073353, 0.5307958354359447, 0.5243218407191992, 0.5140817894236673, 0.49154913083841584, 0.5008966151997071, 0.4864365531042454, 0.4669237934368663, 0.45764966936918244, 0.45144692875099973, 0.47635272776881976, 0.5195310038729656, 0.4898931786102713, 0.48405114622466316, 0.4655326997979971, 0.44359459274064, 0.4298760943144725, 0.4219874200394767, 0.41620738108138977, 0.45313329332819213, 0.42180142739275167, 0.4234742945356422, 0.4436002038166766, 0.40421626669468064, 0.4572812924332502, 0.5167161147416778, 0.431023041337988, 0.40361929659459467, 0.42131163573703917, 0.37352945233861146, 0.3961062539970965, 0.4084672427986513, 0.37687172514253714, 0.3810077448920341, 0.37724421532021973, 0.41587029063972286, 0.37677473924202365, 0.3727586682924209, 0.4176574516173451, 0.42563662394838053, 0.4657953869855216, 0.4428661399802867, 0.4090823377439471, 0.4898981186929267, 0.44404305405010563, 0.40014764796802943, 0.44415289743835173, 0.41760223078750963, 0.5010344458784959, 0.4331023587393058, 0.4352163525061239, 0.4543730639993441, 0.48071425893944564, 0.37595019738442503, 0.41770669071725225, 0.37830468500343306, 0.3469658810454283, 0.38952784527065487, 0.35985431529110357, 0.354006418528312, 0
#  [0.28467366 0.5628424 ]
#  [0.2498913  0.5473095 ]
#  [0.36194592 0.6151508 ]
#  [0.22859453 0.54282123]
#  [0.27687089 0.56100997]
#  [0.29949541 0.573345  ]
#  [0.20073875 0.54299896]
#  [0.32316043 0.58597893]
#  [0.26404556 0.55820541]
#  [0.23047564 0.53826267]
#  [0.35912975 0.59211977]
#  [0.22867223 0.54071309]
#  [0.28980274 0.57032631]
#  [0.34738132 0.58757703]
#  [0.20621802 0.51549879]
#  [0.32439397 0.55751431]
#  [0.31917629 0.56450975]
#  [0.21466909 0.51964386]
#  [0.36383475 0.58893264]
#  [0.27683847 0.53786646]
#  [0.28353653 0.53482351]
#  [0.41819978 0.62494289]
#  [0.25011489 0.55833453]
#  [0.37164749 0.58680347]
#  [0.37674175 0.6056429 ]
#  [0.22003111 0.5044117 ]
#  [0.32512582 0.57982312]
#  [0.27405234 0.57079751]
#  [0.22576306 0.54840476]
#  [0.38484255 0.62662851]
#  [0.2548932  0.55399843]
#  [0.27503379 0.53446768]
#  [0.3990861  0.58580843]
#  [0.23298225 0.52057717]
#  [0.30921718 0.56448868]
#  [0.42474127 0.64571607]
#  [0.23644283 0.51681833]
#  [0.33501653 0.58303093]
#  [0.33692345 0.60548105]
#  [0.24161526 0.54060505]
#  [0.39469494 0.60486377]
#  [0.30496878 0.56567502]
#  [0.28033973 0.56192525]
#  [0.42693478 0.62959979]
#  [0.24756407 0.56501909]
#  [0.36765995 0.58268606]
#  [0.40810956 0.63393576]
#  [0.23987986 0.53987825]
#  [0.39195385 0.61043548]
#  [0.26721436 0.55920254]
#  [0.27402089 0.55767692]
#  [0.33264848 0.60639098]
#  [0.21718329 0.52708726]
#  [0.27346853 0.55679573]
#  [0.27541479 0.55386586]
#  [0.23479067 0.56762258]
#  [0.39156699 0.62731984]
#  [0.29446755 0.57829534]
#  [0.27342062 0.55711958]
#  [0.42014109 0.6249614 ]
#  [0.23364965 0.53565555]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [1.1410449144593906]
# computed_metrics: [1.1410449144593906]
# computed_metrics: [1.1343427335302028]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [0.888842225124842]
# computed_metrics: [0.888842225124842]
# computed_metrics: [0.8770457239706224]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.8256530139927643]
# computed_metrics: [0.8256530139927643]
# computed_metrics: [0.8291107533406116]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.7979773588584079]
# computed_metrics: [0.7979773588584079]
# computed_metrics: [0.7841537757421583]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.7704223519083525]
# computed_metrics: [0.7704223519083525]
# computed_metrics: [0.7897519055315035]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.7541646762013307]
# computed_metrics: [0.7541646762013307]
# computed_metrics: [0.7792247329717447]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.7134210412762101]
# computed_metrics: [0.7134210412762101]
# computed_metrics: [0.733148505988618]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.6925373881057725]
# computed_metrics: [0.6925373881057725]
# computed_metrics: [0.7291429642029509]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.6860346623470269]
# computed_metrics: [0.6860346623470269]
# computed_metrics: [0.7238205572495897]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.6797528489197955]
# computed_metrics: [0.6797528489197955]
# computed_metrics: [0.7235218482670949]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.6659226771900081]
# computed_metrics: [0.6659226771900081]
# computed_metrics: [0.7095338629399128]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.6351619516440122]
# computed_metrics: [0.6351619516440122]
# computed_metrics: [0.6826209278882517]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.6357625425445508]
# computed_metrics: [0.6357625425445508]
# computed_metrics: [0.6786672320646183]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.6114764975952074]
# computed_metrics: [0.6114764975952074]
# computed_metrics: [0.6470797236748411]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.6181081757815701]
# computed_metrics: [0.6181081757815701]
# computed_metrics: [0.6687958801810517]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.5982207871160325]
# computed_metrics: [0.5982207871160325]
# computed_metrics: [0.6273478669712726]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.609280002037996]
# computed_metrics: [0.609280002037996]
# computed_metrics: [0.6408619601577205]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.5992467927859383]
# computed_metrics: [0.5992467927859383]
# computed_metrics: [0.6425721699716785]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.6211661072664311]
# computed_metrics: [0.6211661072664311]
# computed_metrics: [0.6398581757385822]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.6099091895391011]
# computed_metrics: [0.6099091895391011]
# computed_metrics: [0.6488670601453473]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.5721815819454169]
# computed_metrics: [0.5721815819454169]
# computed_metrics: [0.6230518053967535]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.5751787595202681]
# computed_metrics: [0.5751787595202681]
# computed_metrics: [0.5953205745902636]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.5596754865210959]
# computed_metrics: [0.5596754865210959]
# computed_metrics: [0.5890759915208158]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.5585464632935332]
# computed_metrics: [0.5585464632935332]
# computed_metrics: [0.5867105389845124]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.5481198130631187]
# computed_metrics: [0.5481198130631187]
# computed_metrics: [0.5776038206588126]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.5448627836066501]
# computed_metrics: [0.5448627836066501]
# computed_metrics: [0.5828319349901132]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.5318158899597978]
# computed_metrics: [0.5318158899597978]
# computed_metrics: [0.5796338699385388]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.5005719035215336]
# computed_metrics: [0.5005719035215336]
# computed_metrics: [0.5282041350935779]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.5081477762035541]
# computed_metrics: [0.5081477762035541]
# computed_metrics: [0.5439744824295323]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.5129031001017154]
# computed_metrics: [0.5129031001017154]
# computed_metrics: [0.5482847877810912]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.49693313185332966]
# computed_metrics: [0.49693313185332966]
# computed_metrics: [0.5518485615852544]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.5057529655547642]
# computed_metrics: [0.5057529655547642]
# computed_metrics: [0.5422777060925471]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.5222178051535542]
# computed_metrics: [0.5222178051535542]
# computed_metrics: [0.5689080313410823]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.5016049232245804]
# computed_metrics: [0.5016049232245804]
# computed_metrics: [0.5455614407248459]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.5170864798127486]
# computed_metrics: [0.5170864798127486]
# computed_metrics: [0.5535389442406946]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.4669212604059476]
# computed_metrics: [0.4669212604059476]
# computed_metrics: [0.534901487318576]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.46142139228693174]
# computed_metrics: [0.46142139228693174]
# computed_metrics: [0.5341270328408966]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.4584261573133933]
# computed_metrics: [0.4584261573133933]
# computed_metrics: [0.5144731303703636]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.4383703237079036]
# computed_metrics: [0.4383703237079036]
# computed_metrics: [0.5025060749628263]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.47516372993739925]
# computed_metrics: [0.47516372993739925]
# computed_metrics: [0.5209970385752999]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5516283470498996]
# computed_metrics: [0.5516283470498996]
# computed_metrics: [0.5958814172625868]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.44332753084948917]
# computed_metrics: [0.44332753084948917]
# computed_metrics: [0.5006736647267948]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.44413804365277565]
# computed_metrics: [0.44413804365277565]
# computed_metrics: [0.5164482013779094]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.43315476498929195]
# computed_metrics: [0.43315476498929195]
# computed_metrics: [0.5116189088326063]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.41628736486651013]
# computed_metrics: [0.41628736486651013]
# computed_metrics: [0.4813790171171917]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.42416220723009634]
# computed_metrics: [0.42416220723009634]
# computed_metrics: [0.4958464910516182]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5007987668492097]
# computed_metrics: [0.5007987668492097]
# computed_metrics: [0.5628382560493711]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.44642171906056927]
# computed_metrics: [0.44642171906056927]
# computed_metrics: [0.49679786507759527]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.4156412408929934]
# computed_metrics: [0.4156412408929934]
# computed_metrics: [0.49390458334253745]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.44157666102382714]
# computed_metrics: [0.44157666102382714]
# computed_metrics: [0.5177191392972824]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.4235218086049304]
# computed_metrics: [0.4235218086049304]
# computed_metrics: [0.5018661728106134]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.39845862982597074]
# computed_metrics: [0.39845862982597074]
# computed_metrics: [0.46979117175684526]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.42137951290074294]
# computed_metrics: [0.42137951290074294]
# computed_metrics: [0.505999415027643]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.4376642107521652]
# computed_metrics: [0.4376642107521652]
# computed_metrics: [0.5180808009643346]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.4146191155393874]
# computed_metrics: [0.4146191155393874]
# computed_metrics: [0.5248954967233292]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.4293366714344702]
# computed_metrics: [0.4293366714344702]
# computed_metrics: [0.5162308535655565]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.4100477836654976]
# computed_metrics: [0.4100477836654976]
# computed_metrics: [0.5084273524801667]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.496295519950441]
# computed_metrics: [0.496295519950441]
# computed_metrics: [0.5734715624370673]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5217550143313731]
# computed_metrics: [0.5217550143313731]
# computed_metrics: [0.6051968395169274]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.4627888650948514]
# computed_metrics: [0.4627888650948514]
# computed_metrics: [0.555299591225287]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.4999484251970144]
# computed_metrics: [0.4999484251970144]
# computed_metrics: [0.5848790456247392]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.46633161421153785]
# computed_metrics: [0.46633161421153785]
# computed_metrics: [0.5665673357018074]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.48126015415379586]
# computed_metrics: [0.48126015415379586]
# computed_metrics: [0.5915689425661278]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5777135374356263]
# computed_metrics: [0.5777135374356263]
# computed_metrics: [0.70419863681361]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.4819592871329816]
# computed_metrics: [0.4819592871329816]
# computed_metrics: [0.5994106204385488]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5017328684718501]
# computed_metrics: [0.5017328684718501]
# computed_metrics: [0.6085571130198735]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.45911048536554444]
# computed_metrics: [0.45911048536554444]
# computed_metrics: [0.5553618895927661]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.45029443521181994]
# computed_metrics: [0.45029443521181994]
# computed_metrics: [0.5498381798930358]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.4514040334451327]
# computed_metrics: [0.4514040334451327]
# computed_metrics: [0.5133626172688223]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.48127393818990283]
# computed_metrics: [0.48127393818990283]
# computed_metrics: [0.5463270166309302]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.6443917169701288]
# computed_metrics: [0.6443917169701288]
# computed_metrics: [0.686101813844149]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.6523914383460044]
# computed_metrics: [0.6523914383460044]
# computed_metrics: [0.7058085718790186]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.6783866582517822]
# computed_metrics: [0.6783866582517822]
# computed_metrics: [0.7185197936464759]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.6538327161415853]
# computed_metrics: [0.6538327161415853]
# computed_metrics: [0.6918777841916813]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.612647093766689]
# computed_metrics: [0.612647093766689]
# computed_metrics: [0.6819920371819919]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5083759729001781]
# computed_metrics: [0.5083759729001781]
# computed_metrics: [0.62919972806094]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.467453003143459]
# computed_metrics: [0.467453003143459]
# computed_metrics: [0.5459884742613055]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.43676920476346387]
# computed_metrics: [0.43676920476346387]
# computed_metrics: [0.5081744789476492]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.4552722527140655]
# computed_metrics: [0.4552722527140655]
# computed_metrics: [0.5268211655803707]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.49351529177087555]
# computed_metrics: [0.49351529177087555]
# computed_metrics: [0.564434654951051]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.519947015783157]
# computed_metrics: [0.519947015783157]
# computed_metrics: [0.6215771645664512]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.44548013820916943]
# computed_metrics: [0.44548013820916943]
# computed_metrics: [0.542082043331819]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.3849440012954226]
# computed_metrics: [0.3849440012954226]
# computed_metrics: [0.4979387493552956]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.36350291661078016]
# computed_metrics: [0.36350291661078016]
# computed_metrics: [0.4811051088776963]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.39843047584375635]
# computed_metrics: [0.39843047584375635]
# computed_metrics: [0.5217889278993865]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.4157302050583404]
# computed_metrics: [0.4157302050583404]
# computed_metrics: [0.530479113521539]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.3958917945939064]
# computed_metrics: [0.3958917945939064]
# computed_metrics: [0.5650938176321842]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.3475911784199777]
# computed_metrics: [0.3475911784199777]
# computed_metrics: [0.4956716612989724]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.3518388308173194]
# computed_metrics: [0.3518388308173194]
# computed_metrics: [0.5018793243783032]
# 15.363907584926926

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.3518388308173194]
# computed_metrics: [0.5018793243783032]
# computed_metrics: [0.5358331292745665]
# {'mean-mean_absolute_error': 0.5358331292745665}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.92726845, 0.0)
# SpearmanrResult(correlation=0.9276909482371901, pvalue=0.0)
# (0.80186605, 5.419616753370415e-41)
# SpearmanrResult(correlation=0.8018437342196161, pvalue=5.467519888858295e-41)
# (0.8322481, 1.0665802412958558e-46)
# SpearmanrResult(correlation=0.827408779128237, pvalue=1.0249860806249236e-45)
