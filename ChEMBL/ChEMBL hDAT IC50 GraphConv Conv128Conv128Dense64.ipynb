# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gp1 = GraphPool(in_layers=[batch_norm1, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp2 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm3 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm3, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.844 s
# TIMING: dataset construction took 3.317 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.447 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.243 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.280 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 128
C2_filtnum = 128
D_nodenum = 64

graph_structure = 'GC{0}_GP_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [1.1342483793046236]
# computed_metrics: [1.1342483793046236]
# computed_metrics: [1.1658614077087894]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [0.948159068326382]
# computed_metrics: [0.948159068326382]
# computed_metrics: [0.9365260167853565]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.9349016088633378]
# computed_metrics: [0.9349016088633378]
# computed_metrics: [0.9278629429844824]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.9253037443638619]
# computed_metrics: [0.9253037443638619]
# computed_metrics: [0.9141762273613291]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9129681371720761]
# computed_metrics: [0.9129681371720761]
# computed_metrics: [0.9096405083308774]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9033914050993368]
# computed_metrics: [0.9033914050993368]
# computed_metrics: [0.8969701551486458]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.8865234857580643]
# computed_metrics: [0.8865234857580643]
# computed_metrics: [0.8811766620746515]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8864689835471387]
# computed_metrics: [0.8864689835471387]
# computed_metrics: [0.8837251715043668]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8691001130702231]
# computed_metrics: [0.8691001130702231]
# computed_metrics: [0.8704608107704566]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8595816923478125]
# computed_metrics: [0.8595816923478125]
# computed_metrics: [0.8577685965433277]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8531075664049148]
# computed_metrics: [0.8531075664049148]
# computed_metrics: [0.8521504231135921]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.848265672805093]
# computed_metrics: [0.848265672805093]
# computed_metrics: [0.8491666455599391]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8376240834705843]
# computed_metrics: [0.8376240834705843]
# computed_metrics: [0.8376838305081005]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8354023347713053]
# computed_metrics: [0.8354023347713053]
# computed_metrics: [0.8348480021046211]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8276591468000997]
# computed_metrics: [0.8276591468000997]
# computed_metrics: [0.8286049320109777]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8106356052990941]
# computed_metrics: [0.8106356052990941]
# computed_metrics: [0.8167396420171402]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8076228913860094]
# computed_metrics: [0.8076228913860094]
# computed_metrics: [0.8100129711145286]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7925982205697405]
# computed_metrics: [0.7925982205697405]
# computed_metrics: [0.7998695652601794]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7874720825867376]
# computed_metrics: [0.7874720825867376]
# computed_metrics: [0.7975798069112969]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7689343074157645]
# computed_metrics: [0.7689343074157645]
# computed_metrics: [0.7783802102546568]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7601867343818477]
# computed_metrics: [0.7601867343818477]
# computed_metrics: [0.7707981319441425]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7452289975047443]
# computed_metrics: [0.7452289975047443]
# computed_metrics: [0.7676335449663819]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7334649871163113]
# computed_metrics: [0.7334649871163113]
# computed_metrics: [0.7502694322195949]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7249814858376148]
# computed_metrics: [0.7249814858376148]
# computed_metrics: [0.7478576625771864]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7186139791646843]
# computed_metrics: [0.7186139791646843]
# computed_metrics: [0.7433461616247053]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.7130112267162089]
# computed_metrics: [0.7130112267162089]
# computed_metrics: [0.7339567106333454]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7013731241080403]
# computed_metrics: [0.7013731241080403]
# computed_metrics: [0.7380669273149314]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6853819143297936]
# computed_metrics: [0.6853819143297936]
# computed_metrics: [0.7181500342352053]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6739979275211548]
# computed_metrics: [0.6739979275211548]
# computed_metrics: [0.7093147235589915]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.665311336948918]
# computed_metrics: [0.665311336948918]
# computed_metrics: [0.7018498109012995]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6695036000868744]
# computed_metrics: [0.6695036000868744]
# computed_metrics: [0.6996734864071228]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6491076781755776]
# computed_metrics: [0.6491076781755776]
# computed_metrics: [0.6832505264339925]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6390083660809616]
# computed_metrics: [0.6390083660809616]
# computed_metrics: [0.6817336190532862]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6381359161767494]
# computed_metrics: [0.6381359161767494]
# computed_metrics: [0.6850344635586455]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6433451314374775]
# computed_metrics: [0.6433451314374775]
# computed_metrics: [0.6909385410662872]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6241921157445471]
# computed_metrics: [0.6241921157445471]
# computed_metrics: [0.6806807397130716]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6205733475556335]
# computed_metrics: [0.6205733475556335]
# computed_metrics: [0.6733752088007746]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6038015150645505]
# computed_metrics: [0.6038015150645505]
# computed_metrics: [0.6519875156033268]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.601921079300773]
# computed_metrics: [0.601921079300773]
# computed_metrics: [0.667440114015914]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5997421293616854]
# computed_metrics: [0.5997421293616854]
# computed_metrics: [0.6574109784845147]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5780620665472286]
# computed_metrics: [0.5780620665472286]
# computed_metrics: [0.6408656886803187]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5785509529084031]
# computed_metrics: [0.5785509529084031]
# computed_metrics: [0.6389934985716181]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5778076227061051]
# computed_metrics: [0.5778076227061051]
# computed_metrics: [0.6305126254787884]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5794115043574629]
# computed_metrics: [0.5794115043574629]
# computed_metrics: [0.6307891151821012]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5833528112447975]
# computed_metrics: [0.5833528112447975]
# computed_metrics: [0.6412710572627155]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.578360769144865]
# computed_metrics: [0.578360769144865]
# computed_metrics: [0.624935264075987]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5667328049092665]
# computed_metrics: [0.5667328049092665]
# computed_metrics: [0.6259833191491297]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5603187614211109]
# computed_metrics: [0.5603187614211109]
# computed_metrics: [0.6180832330148276]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5449265896820873]
# computed_metrics: [0.5449265896820873]
# computed_metrics: [0.6023197856519699]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5289988275733192]
# computed_metrics: [0.5289988275733192]
# computed_metrics: [0.5942001638626224]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5308912848826745]
# computed_metrics: [0.5308912848826745]
# computed_metrics: [0.5934420254109948]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5276952269951067]
# computed_metrics: [0.5276952269951067]
# computed_metrics: [0.6011047704082892]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5614556675567021]
# computed_metrics: [0.5614556675567021]
# computed_metrics: [0.6362302178808342]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5113974954837387]
# computed_metrics: [0.5113974954837387]
# computed_metrics: [0.5793219662291308]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5019600138394912]
# computed_metrics: [0.5019600138394912]
# computed_metrics: [0.5711873905470771]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5126907141410072]
# computed_metrics: [0.5126907141410072]
# computed_metrics: [0.589712489937051]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.4977225004829054]
# computed_metrics: [0.4977225004829054]
# computed_metrics: [0.5665834390939075]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5056940652868424]
# computed_metrics: [0.5056940652868424]
# computed_metrics: [0.5890061030644319]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.49403240392763725]
# computed_metrics: [0.49403240392763725]
# computed_metrics: [0.5675643013415466]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5096522158461727]
# computed_metrics: [0.5096522158461727]
# computed_metrics: [0.6008320594606146]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.4773792524672117]
# computed_metrics: [0.4773792524672117]
# computed_metrics: [0.5792515926745624]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.48642642169693584]
# computed_metrics: [0.48642642169693584]
# computed_metrics: [0.5691034161525981]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.497726536049714]
# computed_metrics: [0.497726536049714]
# computed_metrics: [0.5858880668906328]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5600647803389192]
# computed_metrics: [0.5600647803389192]
# computed_metrics: [0.6432112777281086]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5232028959772084]
# computed_metrics: [0.5232028959772084]
# computed_metrics: [0.6126825626640191]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5855143557055323]
# computed_metrics: [0.5855143557055323]
# computed_metrics: [0.6595770820477804]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.495008278523768]
# computed_metrics: [0.495008278523768]
# computed_metrics: [0.5971486127680197]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.46152689507623157]
# computed_metrics: [0.46152689507623157]
# computed_metrics: [0.5750347802268866]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.4698861445002821]
# computed_metrics: [0.4698861445002821]
# computed_metrics: [0.5626475058161624]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5357800961406215]
# computed_metrics: [0.5357800961406215]
# computed_metrics: [0.6334865374711393]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.4521273041071646]
# computed_metrics: [0.4521273041071646]
# computed_metrics: [0.5696657047643888]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.47841900530513143]
# computed_metrics: [0.47841900530513143]
# computed_metrics: [0.5909603531940002]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.4397624713536609]
# computed_metrics: [0.4397624713536609]
# computed_metrics: [0.56582173436682]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4464306827787771]
# computed_metrics: [0.4464306827787771]
# computed_metrics: [0.557559715931155]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.4405393693350286]
# computed_metrics: [0.4405393693350286]
# computed_metrics: [0.5601227982114085]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.44324712811061406]
# computed_metrics: [0.44324712811061406]
# computed_metrics: [0.5691964886434662]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.4837656980826462]
# computed_metrics: [0.4837656980826462]
# computed_metrics: [0.6062664471091198]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.43121377024605384]
# computed_metrics: [0.43121377024605384]
# computed_metrics: [0.5535332712874305]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.42924309927601917]
# computed_metrics: [0.42924309927601917]
# computed_metrics: [0.5530939234344943]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4288964270483003]
# computed_metrics: [0.4288964270483003]
# computed_metrics: [0.5532992844019575]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4463571071587432]
# computed_metrics: [0.4463571071587432]
# computed_metrics: [0.5881321343725643]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.5017539785474755]
# computed_metrics: [0.5017539785474755]
# computed_metrics: [0.6294378434737332]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.5508918047908712]
# computed_metrics: [0.5508918047908712]
# computed_metrics: [0.6508353435244915]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.6308919944930942]
# computed_metrics: [0.6308919944930942]
# computed_metrics: [0.7371383745476447]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.5190765863744597]
# computed_metrics: [0.5190765863744597]
# computed_metrics: [0.6330168343623017]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.5327180677658814]
# computed_metrics: [0.5327180677658814]
# computed_metrics: [0.6774552992868413]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4478390276143454]
# computed_metrics: [0.4478390276143454]
# computed_metrics: [0.5836231604597505]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4823551451813707]
# computed_metrics: [0.4823551451813707]
# computed_metrics: [0.576805066802291]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.6825255343035731]
# computed_metrics: [0.6825255343035731]
# computed_metrics: [0.765732036167904]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.546580066503021]
# computed_metrics: [0.546580066503021]
# computed_metrics: [0.659435497416912]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.4709551826184869]
# computed_metrics: [0.4709551826184869]
# computed_metrics: [0.614619004099591]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.4883083293552442]
# computed_metrics: [0.4883083293552442]
# computed_metrics: [0.6257300786059153]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.5679170119511542]
# computed_metrics: [0.5679170119511542]
# computed_metrics: [0.6871971413942212]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4679109891493212]
# computed_metrics: [0.4679109891493212]
# computed_metrics: [0.6162231929530438]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.49803202445454275]
# computed_metrics: [0.49803202445454275]
# computed_metrics: [0.6407441910567723]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.49572872181748345]
# computed_metrics: [0.49572872181748345]
# computed_metrics: [0.6330940145442275]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.424589171542693]
# computed_metrics: [0.424589171542693]
# computed_metrics: [0.587318079029568]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.47765376614768135]
# computed_metrics: [0.47765376614768135]
# computed_metrics: [0.6258867520222061]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.4269828464591946]
# computed_metrics: [0.4269828464591946]
# computed_metrics: [0.5943635489415139]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.44131127423351424]
# computed_metrics: [0.44131127423351424]
# computed_metrics: [0.591482569971239]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.43647237677256606]
# computed_metrics: [0.43647237677256606]
# computed_metrics: [0.6060203713700938]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.44119118008597663]
# computed_metrics: [0.44119118008597663]
# computed_metrics: [0.6247487690074827]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.46668739551307953]
# computed_metrics: [0.46668739551307953]
# computed_metrics: [0.6335365601376346]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.4918406358697202]
# computed_metrics: [0.4918406358697202]
# computed_metrics: [0.6657083125652624]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.552453022189615]
# computed_metrics: [0.552453022189615]
# computed_metrics: [0.7155316256473989]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.5661065358301879]
# computed_metrics: [0.5661065358301879]
# computed_metrics: [0.7076025361755272]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.6379440213820419]
# computed_metrics: [0.6379440213820419]
# computed_metrics: [0.7837368589120177]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.6350804909451264]
# computed_metrics: [0.6350804909451264]
# computed_metrics: [0.7461905196289428]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.5580606963168407]
# computed_metrics: [0.5580606963168407]
# computed_metrics: [0.680682459535511]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.5886778799925039]
# computed_metrics: [0.5886778799925039]
# computed_metrics: [0.7192184742395483]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.48181242689385045]
# computed_metrics: [0.48181242689385045]
# computed_metrics: [0.5847538023159294]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.4367931862007572]
# computed_metrics: [0.4367931862007572]
# computed_metrics: [0.5971113314643145]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.43641458367270464]
# computed_metrics: [0.43641458367270464]
# computed_metrics: [0.5640420368690914]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.38563712208734025]
# computed_metrics: [0.38563712208734025]
# computed_metrics: [0.5260040918392542]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.41741124621309333]
# computed_metrics: [0.41741124621309333]
# computed_metrics: [0.5752929257823872]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4264946784388541]
# computed_metrics: [0.4264946784388541]
# computed_metrics: [0.5679816833729368]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.4331353940742149]
# computed_metrics: [0.4331353940742149]
# computed_metrics: [0.5883849428923906]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.404065686416451]
# computed_metrics: [0.404065686416451]
# computed_metrics: [0.5638136038709889]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.3686238745198397]
# computed_metrics: [0.3686238745198397]
# computed_metrics: [0.5365564536696515]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.3453667832112741]
# computed_metrics: [0.3453667832112741]
# computed_metrics: [0.5340306625750151]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.35072043732035685]
# computed_metrics: [0.35072043732035685]
# computed_metrics: [0.5455424479936469]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.3720191817199153]
# computed_metrics: [0.3720191817199153]
# computed_metrics: [0.5631720044545215]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.3954647308549061]
# computed_metrics: [0.3954647308549061]
# computed_metrics: [0.5707242279680479]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.37087260446774667]
# computed_metrics: [0.37087260446774667]
# computed_metrics: [0.5380391809350469]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.3547257679949391]
# computed_metrics: [0.3547257679949391]
# computed_metrics: [0.5200119370837752]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.31476556768455105]
# computed_metrics: [0.31476556768455105]
# computed_metrics: [0.5053556358085155]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.32813318253936347]
# computed_metrics: [0.32813318253936347]
# computed_metrics: [0.5236787449680145]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.3393462203413749]
# computed_metrics: [0.3393462203413749]
# computed_metrics: [0.5404295057754535]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.32835935824114765]
# computed_metrics: [0.32835935824114765]
# computed_metrics: [0.5319779954660329]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.3590700169728509]
# computed_metrics: [0.3590700169728509]
# computed_metrics: [0.5455678020042266]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.3643658025968744]
# computed_metrics: [0.3643658025968744]
# computed_metrics: [0.5664971244880845]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.3807942939384013]
# computed_metrics: [0.3807942939384013]
# computed_metrics: [0.5761161529716164]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.40927737213278703]
# computed_metrics: [0.40927737213278703]
# computed_metrics: [0.5800245083892456]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.36052969713448635]
# computed_metrics: [0.36052969713448635]
# computed_metrics: [0.5623403064729022]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.3623620620765635]
# computed_metrics: [0.3623620620765635]
# computed_metrics: [0.5414244100020994]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.36458362754256773]
# computed_metrics: [0.36458362754256773]
# computed_metrics: [0.5519393309440849]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.345368612363383]
# computed_metrics: [0.345368612363383]
# computed_metrics: [0.5342706465232397]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.32422892583569923]
# computed_metrics: [0.32422892583569923]
# computed_metrics: [0.5315236077475712]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.3298956169073212]
# computed_metrics: [0.3298956169073212]
# computed_metrics: [0.5253010196137364]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.33892620593235623]
# computed_metrics: [0.33892620593235623]
# computed_metrics: [0.5574455745654959]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.3377063555397065]
# computed_metrics: [0.3377063555397065]
# computed_metrics: [0.5633254933861205]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.3665271360397459]
# computed_metrics: [0.3665271360397459]
# computed_metrics: [0.5633975787958632]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3439810968090862]
# computed_metrics: [0.3439810968090862]
# computed_metrics: [0.5310385832583113]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.3874989625210101]
# computed_metrics: [0.3874989625210101]
# computed_metrics: [0.5708017063948954]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.37875785132863327]
# computed_metrics: [0.37875785132863327]
# computed_metrics: [0.5722720224104216]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.3497010407901562]
# computed_metrics: [0.3497010407901562]
# computed_metrics: [0.5332720989764773]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.3281246554168947]
# computed_metrics: [0.3281246554168947]
# computed_metrics: [0.5183845661489979]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.3289017964307823]
# computed_metrics: [0.3289017964307823]
# computed_metrics: [0.5260531379935602]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.3822629067212366]
# computed_metrics: [0.3822629067212366]
# computed_metrics: [0.5768764793335553]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.46210171692885965]
# computed_metrics: [0.46210171692885965]
# computed_metrics: [0.5920710971172691]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.4509495699242422]
# computed_metrics: [0.4509495699242422]
# computed_metrics: [0.6384349996491815]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.4761428453638365]
# computed_metrics: [0.4761428453638365]
# computed_metrics: [0.6593699779460744]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.5587399214324057]
# computed_metrics: [0.5587399214324057]
# computed_metrics: [0.682986063529712]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.46637400670609347]
# computed_metrics: [0.46637400670609347]
# computed_metrics: [0.6665620934532257]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.39656169160059834]
# computed_metrics: [0.39656169160059834]
# computed_metrics: [0.5858454029037087]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.37258624059340617]
# computed_metrics: [0.37258624059340617]
# computed_metrics: [0.5753837600313992]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.40964546822845127]
# computed_metrics: [0.40964546822845127]
# computed_metrics: [0.6253806344953158]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.4898080199596542]
# computed_metrics: [0.4898080199596542]
# computed_metrics: [0.6825367841647069]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.6195601650434477]
# computed_metrics: [0.6195601650434477]
# computed_metrics: [0.7978417589158294]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.5532910730951434]
# computed_metrics: [0.5532910730951434]
# computed_metrics: [0.6964398682446219]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.5297808180012892]
# computed_metrics: [0.5297808180012892]
# computed_metrics: [0.6807891097705876]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.43088490478153213]
# computed_metrics: [0.43088490478153213]
# computed_metrics: [0.5767971785167002]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3518808392861339]
# computed_metrics: [0.3518808392861339]
# computed_metrics: [0.5356492214077553]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.3731625041349318]
# computed_metrics: [0.3731625041349318]
# computed_metrics: [0.557986093224092]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.5087778827659486]
# computed_metrics: [0.5087778827659486]
# computed_metrics: [0.6780785518988892]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.5572732963578662]
# computed_metrics: [0.5572732963578662]
# computed_metrics: [0.6784568103471637]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.4489009674280449]
# computed_metrics: [0.4489009674280449]
# computed_metrics: [0.6160059354009286]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3640196452959787]
# computed_metrics: [0.3640196452959787]
# computed_metrics: [0.5707994943752924]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.3471299481374127]
# computed_metrics: [0.3471299481374127]
# computed_metrics: [0.5803324074391659]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.3900220606723412]
# computed_metrics: [0.3900220606723412]
# computed_metrics: [0.5998303587950852]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.3902348255612772]
# computed_metrics: [0.3902348255612772]
# computed_metrics: [0.5851184215545667]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.33745547254082187]
# computed_metrics: [0.33745547254082187]
# computed_metrics: [0.5329039976758358]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3452604253676398]
# computed_metrics: [0.3452604253676398]
# computed_metrics: [0.5638596984998481]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.40347875678414186]
# computed_metrics: [0.40347875678414186]
# computed_metrics: [0.5736138852620934]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3962208177904256]
# computed_metrics: [0.3962208177904256]
# computed_metrics: [0.6006387301843865]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.3125392741177756]
# computed_metrics: [0.3125392741177756]
# computed_metrics: [0.5362510365162367]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.2967116269671057]
# computed_metrics: [0.2967116269671057]
# computed_metrics: [0.5333384047020816]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3512369137238974]
# computed_metrics: [0.3512369137238974]
# computed_metrics: [0.5788626486189705]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.38853212725446984]
# computed_metrics: [0.38853212725446984]
# computed_metrics: [0.5912158634272261]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.3485453695198147]
# computed_metrics: [0.3485453695198147]
# computed_metrics: [0.5445524855264192]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.3008999218283579]
# computed_metrics: [0.3008999218283579]
# computed_metrics: [0.5114725788923876]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.37196782453431226]
# computed_metrics: [0.37196782453431226]
# computed_metrics: [0.5814593769308856]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.4696432018396297]
# computed_metrics: [0.4696432018396297]
# computed_metrics: [0.669807479763933]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.3861826708484694]
# computed_metrics: [0.3861826708484694]
# computed_metrics: [0.5881975607985336]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.3390823148971273]
# computed_metrics: [0.3390823148971273]
# computed_metrics: [0.5643768401589248]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.3592338342491384]
# computed_metrics: [0.3592338342491384]
# computed_metrics: [0.5814677169518201]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.394644531653566]
# computed_metrics: [0.394644531653566]
# computed_metrics: [0.566579462182401]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.30860527608642635]
# computed_metrics: [0.30860527608642635]
# computed_metrics: [0.5164534398412586]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.2799531585491943]
# computed_metrics: [0.2799531585491943]
# computed_metrics: [0.5349361753025338]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.3381113270604102]
# computed_metrics: [0.3381113270604102]
# computed_metrics: [0.5608100080316766]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.38116737459927336]
# computed_metrics: [0.38116737459927336]
# computed_metrics: [0.5787632596258153]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.280339298712785]
# computed_metrics: [0.280339298712785]
# computed_metrics: [0.5477712963478921]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.3047719566764898]
# computed_metrics: [0.3047719566764898]
# computed_metrics: [0.5564770029835335]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3547505283607398]
# computed_metrics: [0.3547505283607398]
# computed_metrics: [0.605246563425696]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.33315768238620175]
# computed_metrics: [0.33315768238620175]
# computed_metrics: [0.543255937950847]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.28345645388380863]
# computed_metrics: [0.28345645388380863]
# computed_metrics: [0.5085593574275835]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.28396599299183833]
# computed_metrics: [0.28396599299183833]
# computed_metrics: [0.5354877425575711]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.40373113281899936]
# computed_metrics: [0.40373113281899936]
# computed_metrics: [0.5990995897716165]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.37714025376782156]
# computed_metrics: [0.37714025376782156]
# computed_metrics: [0.6004857642613894]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.29479663627255465]
# computed_metrics: [0.29479663627255465]
# computed_metrics: [0.5505867967741678]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.3117664082156471]
# computed_metrics: [0.3117664082156471]
# computed_metrics: [0.557557333218866]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.3354949977450159]
# computed_metrics: [0.3354949977450159]
# computed_metrics: [0.5863776251283126]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.32433789379035943]
# computed_metrics: [0.32433789379035943]
# computed_metrics: [0.5403070525227127]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.2606498596232285]
# computed_metrics: [0.2606498596232285]
# computed_metrics: [0.5155910240393496]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.29957011027135466]
# computed_metrics: [0.29957011027135466]
# computed_metrics: [0.5516741195308744]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.36476701353377194]
# computed_metrics: [0.36476701353377194]
# computed_metrics: [0.5752224146426494]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.3325398303702551]
# computed_metrics: [0.3325398303702551]
# computed_metrics: [0.5679548110109329]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.2628027152623672]
# computed_metrics: [0.2628027152623672]
# computed_metrics: [0.5302254972020503]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.33109631702513564]
# computed_metrics: [0.33109631702513564]
# computed_metrics: [0.5816470052150909]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.29451726389795024]
# computed_metrics: [0.29451726389795024]
# computed_metrics: [0.5364780005071034]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.2527990017932274]
# computed_metrics: [0.2527990017932274]
# computed_metrics: [0.5136684590141984]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.26823034021554387]
# computed_metrics: [0.26823034021554387]
# computed_metrics: [0.5287133952707576]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.3278305535442646]
# computed_metrics: [0.3278305535442646]
# computed_metrics: [0.554993187185289]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.2966582197521118]
# computed_metrics: [0.2966582197521118]
# computed_metrics: [0.5641933362060878]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.25839916208525154]
# computed_metrics: [0.25839916208525154]
# computed_metrics: [0.5442140119831256]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.35297623532773786]
# computed_metrics: [0.35297623532773786]
# computed_metrics: [0.5982306974734415]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.37072043015504064]
# computed_metrics: [0.37072043015504064]
# computed_metrics: [0.5890816967574996]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.2779861167355493]
# computed_metrics: [0.2779861167355493]
# computed_metrics: [0.5227355584960345]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.26843784932656317]
# computed_metrics: [0.26843784932656317]
# computed_metrics: [0.5220911425455916]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.3617171292778119]
# computed_metrics: [0.3617171292778119]
# computed_metrics: [0.6042109782191113]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.3483093015515339]
# computed_metrics: [0.3483093015515339]
# computed_metrics: [0.5970922702133961]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.26755685865894857]
# computed_metrics: [0.26755685865894857]
# computed_metrics: [0.5555209354820104]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.2778164996214764]
# computed_metrics: [0.2778164996214764]
# computed_metrics: [0.5547398816637882]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.3974738442952735]
# computed_metrics: [0.3974738442952735]
# computed_metrics: [0.6036984963812213]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.30675983104732296]
# computed_metrics: [0.30675983104732296]
# computed_metrics: [0.5526616254807984]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.2673197431116615]
# computed_metrics: [0.2673197431116615]
# computed_metrics: [0.5358587861793901]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.41096207752978353]
# computed_metrics: [0.41096207752978353]
# computed_metrics: [0.6156354807103604]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.3492482372972681]
# computed_metrics: [0.3492482372972681]
# computed_metrics: [0.5832600887454359]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.2940502167606002]
# computed_metrics: [0.2940502167606002]
# computed_metrics: [0.558769296110361]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.269939067458038]
# computed_metrics: [0.269939067458038]
# computed_metrics: [0.5596354235122282]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.2763294432016422]
# computed_metrics: [0.2763294432016422]
# computed_metrics: [0.5601627134117856]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.3411071623147919]
# computed_metrics: [0.3411071623147919]
# computed_metrics: [0.5771350795338581]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.2751323011385158]
# computed_metrics: [0.2751323011385158]
# computed_metrics: [0.5326230904351644]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.2455146376899599]
# computed_metrics: [0.2455146376899599]
# computed_metrics: [0.5356828832299906]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.28154024538704137]
# computed_metrics: [0.28154024538704137]
# computed_metrics: [0.5667941969762509]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.32323311622580997]
# computed_metrics: [0.32323311622580997]
# computed_metrics: [0.600324096249946]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.2778603459605543]
# computed_metrics: [0.2778603459605543]
# computed_metrics: [0.5629740337959517]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.2604002130624867]
# computed_metrics: [0.2604002130624867]
# computed_metrics: [0.54897594383008]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.3615730733544426]
# computed_metrics: [0.3615730733544426]
# computed_metrics: [0.5976988186495535]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.38367541952384876]
# computed_metrics: [0.38367541952384876]
# computed_metrics: [0.5834408750108089]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.2634924918931983]
# computed_metrics: [0.2634924918931983]
# computed_metrics: [0.5410087924113306]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.3291491123508674]
# computed_metrics: [0.3291491123508674]
# computed_metrics: [0.567038990582634]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.4671342484404667]
# computed_metrics: [0.4671342484404667]
# computed_metrics: [0.6677973049401182]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.36063985807546894]
# computed_metrics: [0.36063985807546894]
# computed_metrics: [0.6155350667012652]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.29470822535192825]
# computed_metrics: [0.29470822535192825]
# computed_metrics: [0.5593452635254554]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.2821144621056916]
# computed_metrics: [0.2821144621056916]
# computed_metrics: [0.5671430533774885]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.36052972238011943]
# computed_metrics: [0.36052972238011943]
# computed_metrics: [0.6013107409226262]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.34714776100169054]
# computed_metrics: [0.34714776100169054]
# computed_metrics: [0.5761914739289375]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.2911329491394644]
# computed_metrics: [0.2911329491394644]
# computed_metrics: [0.5443562163922855]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24470831861588352]
# computed_metrics: [0.24470831861588352]
# computed_metrics: [0.5152655472865331]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.3063577833735858]
# computed_metrics: [0.3063577833735858]
# computed_metrics: [0.5608738590420999]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.39183733876781723]
# computed_metrics: [0.39183733876781723]
# computed_metrics: [0.6051496365708146]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.32944855671061524]
# computed_metrics: [0.32944855671061524]
# computed_metrics: [0.5832587711617132]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.28655009893710365]
# computed_metrics: [0.28655009893710365]
# computed_metrics: [0.5647713696814913]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.38126036896279114]
# computed_metrics: [0.38126036896279114]
# computed_metrics: [0.623083465717421]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.45936479749796844]
# computed_metrics: [0.45936479749796844]
# computed_metrics: [0.6802596375247754]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.3395230517715769]
# computed_metrics: [0.3395230517715769]
# computed_metrics: [0.5885073363117334]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.2934676576261478]
# computed_metrics: [0.2934676576261478]
# computed_metrics: [0.5411109045236238]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.3748223455019128]
# computed_metrics: [0.3748223455019128]
# computed_metrics: [0.5867420938723091]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.4136982510310885]
# computed_metrics: [0.4136982510310885]
# computed_metrics: [0.6273766984918103]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.3737417612396379]
# computed_metrics: [0.3737417612396379]
# computed_metrics: [0.634047140448557]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.27146031210590643]
# computed_metrics: [0.27146031210590643]
# computed_metrics: [0.5657265324798335]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.2749138243356676]
# computed_metrics: [0.2749138243356676]
# computed_metrics: [0.5862684623649446]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.34667567176454606]
# computed_metrics: [0.34667567176454606]
# computed_metrics: [0.609650075653654]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.3996204881768394]
# computed_metrics: [0.3996204881768394]
# computed_metrics: [0.6034389169672382]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.2807028632911647]
# computed_metrics: [0.2807028632911647]
# computed_metrics: [0.5617471262456246]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.31124302449642166]
# computed_metrics: [0.31124302449642166]
# computed_metrics: [0.5533011436372023]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.3477719004789901]
# computed_metrics: [0.3477719004789901]
# computed_metrics: [0.5836924758488352]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.2776689781663465]
# computed_metrics: [0.2776689781663465]
# computed_metrics: [0.559398280737706]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.250507342626264]
# computed_metrics: [0.250507342626264]
# computed_metrics: [0.540959158357206]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.3246523259811703]
# computed_metrics: [0.3246523259811703]
# computed_metrics: [0.6099381586250173]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.35493554390787857]
# computed_metrics: [0.35493554390787857]
# computed_metrics: [0.59585759168325]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.29755558172540963]
# computed_metrics: [0.29755558172540963]
# computed_metrics: [0.5571349405216173]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.41844438285443886]
# computed_metrics: [0.41844438285443886]
# computed_metrics: [0.6251466446066906]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.48403878801226086]
# computed_metrics: [0.48403878801226086]
# computed_metrics: [0.6435504964973965]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.30549896724505227]
# computed_metrics: [0.30549896724505227]
# computed_metrics: [0.5688975974078079]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.3138710939735909]
# computed_metrics: [0.3138710939735909]
# computed_metrics: [0.556325548664629]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.3433646542003313]
# computed_metrics: [0.3433646542003313]
# computed_metrics: [0.6027581878363047]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.30408596018061623]
# computed_metrics: [0.30408596018061623]
# computed_metrics: [0.5557117055593872]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.2502705948963763]
# computed_metrics: [0.2502705948963763]
# computed_metrics: [0.5269337722878987]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.31205727738891204]
# computed_metrics: [0.31205727738891204]
# computed_metrics: [0.5491691433256441]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.3473097866965562]
# computed_metrics: [0.3473097866965562]
# computed_metrics: [0.5611907587411235]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.248448135591451]
# computed_metrics: [0.248448135591451]
# computed_metrics: [0.5348475265281806]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.28214027949596043]
# computed_metrics: [0.28214027949596043]
# computed_metrics: [0.5508665930828666]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3846949648095522]
# computed_metrics: [0.3846949648095522]
# computed_metrics: [0.5947109763345245]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.27040287432073873]
# computed_metrics: [0.27040287432073873]
# computed_metrics: [0.529176827230993]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.2762380213886845]
# computed_metrics: [0.2762380213886845]
# computed_metrics: [0.5504945954929418]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.396021686336803]
# computed_metrics: [0.396021686336803]
# computed_metrics: [0.6089952221201946]
# ...
# computed_metrics: [0.20231815997687774]
# computed_metrics: [0.20231815997687774]
# computed_metrics: [0.5336514259673]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.23315615139865148]
# computed_metrics: [0.23315615139865148]
# computed_metrics: [0.5358506875353275]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.2805655460531466]
# computed_metrics: [0.2805655460531466]
# computed_metrics: [0.5806879218185625]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.21211976064315852]
# computed_metrics: [0.21211976064315852]
# computed_metrics: [0.5410899611956004]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.2771739592092996]
# computed_metrics: [0.2771739592092996]
# computed_metrics: [0.5960933508578712]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.2882090564601773]
# computed_metrics: [0.2882090564601773]
# computed_metrics: [0.5745970814207764]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.21938959554986054]
# computed_metrics: [0.21938959554986054]
# computed_metrics: [0.5504128207433108]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.21129887605973086]
# computed_metrics: [0.21129887605973086]
# computed_metrics: [0.5697142948852658]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.2972565763572878]
# computed_metrics: [0.2972565763572878]
# computed_metrics: [0.5869498375794683]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.20799677791874735]
# computed_metrics: [0.20799677791874735]
# computed_metrics: [0.5390256583304651]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.239768161270444]
# computed_metrics: [0.239768161270444]
# computed_metrics: [0.5785069905106753]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.2686251702552881]
# computed_metrics: [0.2686251702552881]
# computed_metrics: [0.586690158236381]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.17707300257336844]
# computed_metrics: [0.17707300257336844]
# computed_metrics: [0.5360762536011305]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.20431621997253807]
# computed_metrics: [0.20431621997253807]
# computed_metrics: [0.5544107774009593]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.24970708130716604]
# computed_metrics: [0.24970708130716604]
# computed_metrics: [0.5729659347066859]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.18806018553967965]
# computed_metrics: [0.18806018553967965]
# computed_metrics: [0.5414459562951804]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.2574208069006943]
# computed_metrics: [0.2574208069006943]
# computed_metrics: [0.5803154968786024]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.30910527389578013]
# computed_metrics: [0.30910527389578013]
# computed_metrics: [0.5842743201261779]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.19637591249578198]
# computed_metrics: [0.19637591249578198]
# computed_metrics: [0.5565044248070175]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.2680603601409329]
# computed_metrics: [0.2680603601409329]
# computed_metrics: [0.5793728210360133]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.2974044076574544]
# computed_metrics: [0.2974044076574544]
# computed_metrics: [0.6056400163114949]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.22334146514516726]
# computed_metrics: [0.22334146514516726]
# computed_metrics: [0.5370973070092695]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.26295022284664743]
# computed_metrics: [0.26295022284664743]
# computed_metrics: [0.5708341550857761]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.2874643926540002]
# computed_metrics: [0.2874643926540002]
# computed_metrics: [0.5708246479004946]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.17908855246676197]
# computed_metrics: [0.17908855246676197]
# computed_metrics: [0.530542932771483]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.24090768074816063]
# computed_metrics: [0.24090768074816063]
# computed_metrics: [0.5671982366347041]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.29677094531278697]
# computed_metrics: [0.29677094531278697]
# computed_metrics: [0.5966679449135672]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.21158672580915208]
# computed_metrics: [0.21158672580915208]
# computed_metrics: [0.5301172705782917]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.31977423397983235]
# computed_metrics: [0.31977423397983235]
# computed_metrics: [0.5877993163299846]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.3422543311446188]
# computed_metrics: [0.3422543311446188]
# computed_metrics: [0.6178055600517]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.22655683980787505]
# computed_metrics: [0.22655683980787505]
# computed_metrics: [0.5491525862617028]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.27867328319434576]
# computed_metrics: [0.27867328319434576]
# computed_metrics: [0.6107585743987802]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.46876360418077934]
# computed_metrics: [0.46876360418077934]
# computed_metrics: [0.6800029507292408]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.2949727945009819]
# computed_metrics: [0.2949727945009819]
# computed_metrics: [0.5639017033143915]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.29742598534305104]
# computed_metrics: [0.29742598534305104]
# computed_metrics: [0.550317293146665]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.36249724300745834]
# computed_metrics: [0.36249724300745834]
# computed_metrics: [0.6298010690554279]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.303498460635369]
# computed_metrics: [0.303498460635369]
# computed_metrics: [0.592655782083102]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.25956482808744946]
# computed_metrics: [0.25956482808744946]
# computed_metrics: [0.5580821780032468]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.32594600839072757]
# computed_metrics: [0.32594600839072757]
# computed_metrics: [0.5947943637112187]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.28343563741778194]
# computed_metrics: [0.28343563741778194]
# computed_metrics: [0.5601141712718204]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.23123220092866179]
# computed_metrics: [0.23123220092866179]
# computed_metrics: [0.5295326603097346]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.3017579967691518]
# computed_metrics: [0.3017579967691518]
# computed_metrics: [0.593000545742723]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.29147706466616957]
# computed_metrics: [0.29147706466616957]
# computed_metrics: [0.598235480294177]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.20378444411193283]
# computed_metrics: [0.20378444411193283]
# computed_metrics: [0.539517211270376]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.3076218518763705]
# computed_metrics: [0.3076218518763705]
# computed_metrics: [0.6019810914893773]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.2812991042692674]
# computed_metrics: [0.2812991042692674]
# computed_metrics: [0.5678311354045695]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.23999411707597673]
# computed_metrics: [0.23999411707597673]
# computed_metrics: [0.5437869140806345]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.3491704344916097]
# computed_metrics: [0.3491704344916097]
# computed_metrics: [0.6110988711774897]
# [1.1342483793046236, 0.948159068326382, 0.9349016088633378, 0.9253037443638619, 0.9129681371720761, 0.9033914050993368, 0.8865234857580643, 0.8864689835471387, 0.8691001130702231, 0.8595816923478125, 0.8531075664049148, 0.848265672805093, 0.8376240834705843, 0.8354023347713053, 0.8276591468000997, 0.8106356052990941, 0.8076228913860094, 0.7925982205697405, 0.7874720825867376, 0.7689343074157645, 0.7601867343818477, 0.7452289975047443, 0.7334649871163113, 0.7249814858376148, 0.7186139791646843, 0.7130112267162089, 0.7013731241080403, 0.6853819143297936, 0.6739979275211548, 0.665311336948918, 0.6695036000868744, 0.6491076781755776, 0.6390083660809616, 0.6381359161767494, 0.6433451314374775, 0.6241921157445471, 0.6205733475556335, 0.6038015150645505, 0.601921079300773, 0.5997421293616854, 0.5780620665472286, 0.5785509529084031, 0.5778076227061051, 0.5794115043574629, 0.5833528112447975, 0.578360769144865, 0.5667

# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [0.9337759938588364]
# computed_metrics: [0.9337759938588364]
# computed_metrics: [0.913815986543465]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.9263427425284252]
# computed_metrics: [0.9263427425284252]
# computed_metrics: [0.9158421201239094]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.9241269788975918]
# computed_metrics: [0.9241269788975918]
# computed_metrics: [0.9064151679776562]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9111601935787584]
# computed_metrics: [0.9111601935787584]
# computed_metrics: [0.9033932620594114]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9113458203595127]
# computed_metrics: [0.9113458203595127]
# computed_metrics: [0.9115699423741948]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9055535819732535]
# computed_metrics: [0.9055535819732535]
# computed_metrics: [0.9092950981122417]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8920384117347342]
# computed_metrics: [0.8920384117347342]
# computed_metrics: [0.8943558564122309]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8970899446885783]
# computed_metrics: [0.8970899446885783]
# computed_metrics: [0.9019470224684206]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.891531559442614]
# computed_metrics: [0.891531559442614]
# computed_metrics: [0.8988903057304993]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8710041648291295]
# computed_metrics: [0.8710041648291295]
# computed_metrics: [0.8758972958404593]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8663990970329949]
# computed_metrics: [0.8663990970329949]
# computed_metrics: [0.8722893811275843]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8546653036267784]
# computed_metrics: [0.8546653036267784]
# computed_metrics: [0.860481672001742]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8472102723222922]
# computed_metrics: [0.8472102723222922]
# computed_metrics: [0.8528238807004482]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8436396274356314]
# computed_metrics: [0.8436396274356314]
# computed_metrics: [0.8486185783703879]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8298122769861614]
# computed_metrics: [0.8298122769861614]
# computed_metrics: [0.8339744403629497]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8254332997996964]
# computed_metrics: [0.8254332997996964]
# computed_metrics: [0.8315113973784485]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8210068113396446]
# computed_metrics: [0.8210068113396446]
# computed_metrics: [0.8208736760437829]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.8031533840551691]
# computed_metrics: [0.8031533840551691]
# computed_metrics: [0.8179125346563749]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.8024658558661298]
# computed_metrics: [0.8024658558661298]
# computed_metrics: [0.813034646209177]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7957762354818376]
# computed_metrics: [0.7957762354818376]
# computed_metrics: [0.8085558696980294]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7839450030288246]
# computed_metrics: [0.7839450030288246]
# computed_metrics: [0.7956987925924586]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7712225706103524]
# computed_metrics: [0.7712225706103524]
# computed_metrics: [0.7854229275872241]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7639895050462046]
# computed_metrics: [0.7639895050462046]
# computed_metrics: [0.7774776278025995]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7585474793994436]
# computed_metrics: [0.7585474793994436]
# computed_metrics: [0.7721135006473672]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.7430657662378508]
# computed_metrics: [0.7430657662378508]
# computed_metrics: [0.7551135522913953]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7290556656287559]
# computed_metrics: [0.7290556656287559]
# computed_metrics: [0.7490380164810578]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.7142467809851647]
# computed_metrics: [0.7142467809851647]
# computed_metrics: [0.7447073063785103]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.702442061526853]
# computed_metrics: [0.702442061526853]
# computed_metrics: [0.7349646976364538]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6826693746076883]
# computed_metrics: [0.6826693746076883]
# computed_metrics: [0.711796261758864]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6798604018224937]
# computed_metrics: [0.6798604018224937]
# computed_metrics: [0.7051655885107019]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.673221873135148]
# computed_metrics: [0.673221873135148]
# computed_metrics: [0.6999286979623222]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.7024639164499933]
# computed_metrics: [0.7024639164499933]
# computed_metrics: [0.7282955405487186]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.699174155371246]
# computed_metrics: [0.699174155371246]
# computed_metrics: [0.7323549536184875]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6730231706699303]
# computed_metrics: [0.6730231706699303]
# computed_metrics: [0.6946454415705821]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6540254115411935]
# computed_metrics: [0.6540254115411935]
# computed_metrics: [0.6702564303489519]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6402529732390915]
# computed_metrics: [0.6402529732390915]
# computed_metrics: [0.6595228597167276]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6572580026743554]
# computed_metrics: [0.6572580026743554]
# computed_metrics: [0.6759817662315731]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6440212031633193]
# computed_metrics: [0.6440212031633193]
# computed_metrics: [0.6691818164384958]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.6256499902283155]
# computed_metrics: [0.6256499902283155]
# computed_metrics: [0.660406849101374]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6088533904104448]
# computed_metrics: [0.6088533904104448]
# computed_metrics: [0.6435538100312205]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5965491101348102]
# computed_metrics: [0.5965491101348102]
# computed_metrics: [0.6324667888572266]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5891338159044721]
# computed_metrics: [0.5891338159044721]
# computed_metrics: [0.6353749096158039]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5810381109670207]
# computed_metrics: [0.5810381109670207]
# computed_metrics: [0.6204582875768597]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5743652984722716]
# computed_metrics: [0.5743652984722716]
# computed_metrics: [0.62013455775504]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5660858512926712]
# computed_metrics: [0.5660858512926712]
# computed_metrics: [0.6057034627542581]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5677888507505809]
# computed_metrics: [0.5677888507505809]
# computed_metrics: [0.6145317674302244]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5779136027194623]
# computed_metrics: [0.5779136027194623]
# computed_metrics: [0.6196392765024918]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5670258142634137]
# computed_metrics: [0.5670258142634137]
# computed_metrics: [0.6162904292101545]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5681755447856007]
# computed_metrics: [0.5681755447856007]
# computed_metrics: [0.63338681087227]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5607207879859213]
# computed_metrics: [0.5607207879859213]
# computed_metrics: [0.6247035094209489]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5692380740752111]
# computed_metrics: [0.5692380740752111]
# computed_metrics: [0.6221869862190834]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5512143617147884]
# computed_metrics: [0.5512143617147884]
# computed_metrics: [0.6199887723712202]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5432888044133276]
# computed_metrics: [0.5432888044133276]
# computed_metrics: [0.5960143109959645]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5282008534842381]
# computed_metrics: [0.5282008534842381]
# computed_metrics: [0.5845375162228381]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5204423132074766]
# computed_metrics: [0.5204423132074766]
# computed_metrics: [0.5845260810848945]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5287351723958427]
# computed_metrics: [0.5287351723958427]
# computed_metrics: [0.6115212880333519]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5449177036404959]
# computed_metrics: [0.5449177036404959]
# computed_metrics: [0.6225064212213183]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.6093177504751304]
# computed_metrics: [0.6093177504751304]
# computed_metrics: [0.6466979955872607]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.6018286133096771]
# computed_metrics: [0.6018286133096771]
# computed_metrics: [0.6395488892298474]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5443973522000665]
# computed_metrics: [0.5443973522000665]
# computed_metrics: [0.5905278856877698]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5158462193936538]
# computed_metrics: [0.5158462193936538]
# computed_metrics: [0.6003662706245909]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5018916642643872]
# computed_metrics: [0.5018916642643872]
# computed_metrics: [0.5966184432405229]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5642179826231818]
# computed_metrics: [0.5642179826231818]
# computed_metrics: [0.640684040360857]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5472066622275708]
# computed_metrics: [0.5472066622275708]
# computed_metrics: [0.6170826718169359]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.49910847382970824]
# computed_metrics: [0.49910847382970824]
# computed_metrics: [0.5757500102103608]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.4909182493727761]
# computed_metrics: [0.4909182493727761]
# computed_metrics: [0.5879166692222478]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.5150827144890007]
# computed_metrics: [0.5150827144890007]
# computed_metrics: [0.6024179988928346]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.497327407841825]
# computed_metrics: [0.497327407841825]
# computed_metrics: [0.5848126867064285]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.4867531696524455]
# computed_metrics: [0.4867531696524455]
# computed_metrics: [0.5576435862336598]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.533057301534466]
# computed_metrics: [0.533057301534466]
# computed_metrics: [0.6252356673916463]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5147367751617402]
# computed_metrics: [0.5147367751617402]
# computed_metrics: [0.6029249619406839]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.4835148432247369]
# computed_metrics: [0.4835148432247369]
# computed_metrics: [0.5840565904900475]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.45267406904286117]
# computed_metrics: [0.45267406904286117]
# computed_metrics: [0.5731476349900915]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.4765692556789562]
# computed_metrics: [0.4765692556789562]
# computed_metrics: [0.5867424515931128]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.4774784043344028]
# computed_metrics: [0.4774784043344028]
# computed_metrics: [0.5865811629987618]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.4659947025753339]
# computed_metrics: [0.4659947025753339]
# computed_metrics: [0.5840446157155323]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5722679315192503]
# computed_metrics: [0.5722679315192503]
# computed_metrics: [0.6622322641473397]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.48551119312800073]
# computed_metrics: [0.48551119312800073]
# computed_metrics: [0.6037393199858256]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4974710539196171]
# computed_metrics: [0.4974710539196171]
# computed_metrics: [0.6010877603618946]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.43300605806068954]
# computed_metrics: [0.43300605806068954]
# computed_metrics: [0.5442323448148474]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4253706632518062]
# computed_metrics: [0.4253706632518062]
# computed_metrics: [0.5538787041762551]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.41177212643515304]
# computed_metrics: [0.41177212643515304]
# computed_metrics: [0.5535953292065753]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4159654755456127]
# computed_metrics: [0.4159654755456127]
# computed_metrics: [0.5597301268292183]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.42866847378860073]
# computed_metrics: [0.42866847378860073]
# computed_metrics: [0.5534795291075388]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.44771228416897735]
# computed_metrics: [0.44771228416897735]
# computed_metrics: [0.5592142599818876]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.42247393887291523]
# computed_metrics: [0.42247393887291523]
# computed_metrics: [0.5290538868121788]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4299960359861313]
# computed_metrics: [0.4299960359861313]
# computed_metrics: [0.5555944626656383]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.41415582319681765]
# computed_metrics: [0.41415582319681765]
# computed_metrics: [0.5453773577799377]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.39036523193869177]
# computed_metrics: [0.39036523193869177]
# computed_metrics: [0.5480544119030214]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.4072845347519198]
# computed_metrics: [0.4072845347519198]
# computed_metrics: [0.5516493782063426]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.4086485378953879]
# computed_metrics: [0.4086485378953879]
# computed_metrics: [0.5596905122111355]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.46919219103641074]
# computed_metrics: [0.46919219103641074]
# computed_metrics: [0.6078440369295456]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4366620512965973]
# computed_metrics: [0.4366620512965973]
# computed_metrics: [0.5714661768285421]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.580187660241505]
# computed_metrics: [0.580187660241505]
# computed_metrics: [0.7068429381259117]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.438480742581217]
# computed_metrics: [0.438480742581217]
# computed_metrics: [0.5824713145330798]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.49289263007677536]
# computed_metrics: [0.49289263007677536]
# computed_metrics: [0.6459612314425696]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.4608084170607486]
# computed_metrics: [0.4608084170607486]
# computed_metrics: [0.5752451776818948]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.42123390465037724]
# computed_metrics: [0.42123390465037724]
# computed_metrics: [0.5576656370895294]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4528493406572454]
# computed_metrics: [0.4528493406572454]
# computed_metrics: [0.580136570414952]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4219890999365007]
# computed_metrics: [0.4219890999365007]
# computed_metrics: [0.580733389033668]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.41902818096631844]
# computed_metrics: [0.41902818096631844]
# computed_metrics: [0.5858743176835217]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.41848054743854973]
# computed_metrics: [0.41848054743854973]
# computed_metrics: [0.5708554084965928]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5262620977111194]
# computed_metrics: [0.5262620977111194]
# computed_metrics: [0.6372261241818342]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.525212692827917]
# computed_metrics: [0.525212692827917]
# computed_metrics: [0.6538306177246928]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.46938812407401076]
# computed_metrics: [0.46938812407401076]
# computed_metrics: [0.6171741897436551]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.4913644271784983]
# computed_metrics: [0.4913644271784983]
# computed_metrics: [0.601746079919054]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.6191928212132465]
# computed_metrics: [0.6191928212132465]
# computed_metrics: [0.7190422906943907]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.5296184966299979]
# computed_metrics: [0.5296184966299979]
# computed_metrics: [0.6598843505704384]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.5929656792744563]
# computed_metrics: [0.5929656792744563]
# computed_metrics: [0.681830752472305]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.6593085356470393]
# computed_metrics: [0.6593085356470393]
# computed_metrics: [0.7132973727895754]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.6447843535618337]
# computed_metrics: [0.6447843535618337]
# computed_metrics: [0.7171016828079704]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.7325487355829806]
# computed_metrics: [0.7325487355829806]
# computed_metrics: [0.8036117509180074]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.6554619233987448]
# computed_metrics: [0.6554619233987448]
# computed_metrics: [0.7356077190266657]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.5877225835624367]
# computed_metrics: [0.5877225835624367]
# computed_metrics: [0.6618841313086492]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.5778260545057614]
# computed_metrics: [0.5778260545057614]
# computed_metrics: [0.6794287927731743]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.4932978695003571]
# computed_metrics: [0.4932978695003571]
# computed_metrics: [0.5967600349499027]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.45722222304297994]
# computed_metrics: [0.45722222304297994]
# computed_metrics: [0.560504397480769]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.4365437308836475]
# computed_metrics: [0.4365437308836475]
# computed_metrics: [0.5817577464840643]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.49048375866424104]
# computed_metrics: [0.49048375866424104]
# computed_metrics: [0.5934298670693843]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.5412379791778649]
# computed_metrics: [0.5412379791778649]
# computed_metrics: [0.6901839580619553]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.5046936717232348]
# computed_metrics: [0.5046936717232348]
# computed_metrics: [0.6363015631876037]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.5325766629553871]
# computed_metrics: [0.5325766629553871]
# computed_metrics: [0.6657843100458001]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.6074779761830285]
# computed_metrics: [0.6074779761830285]
# computed_metrics: [0.7274774112353563]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.5233754002278923]
# computed_metrics: [0.5233754002278923]
# computed_metrics: [0.6499896268960588]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.5227366916809705]
# computed_metrics: [0.5227366916809705]
# computed_metrics: [0.6647824607714824]
# 16.40294912662215

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.5227366916809705]
# computed_metrics: [0.6647824607714824]
# computed_metrics: [0.677192628278905]
# {'mean-mean_absolute_error': 0.677192628278905}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.8841195, 0.0)
# SpearmanrResult(correlation=0.8928090276251244, pvalue=0.0)
# (0.7737471, 1.5652583926124288e-36)
# SpearmanrResult(correlation=0.7870135177340598, pvalue=1.4938698014351475e-38)
# (0.71443206, 6.076002686874625e-29)
# SpearmanrResult(correlation=0.710516032079327, pvalue=1.6467318589711388e-28)
