# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp1 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc3 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm3 = BatchNorm(in_layers=[gc3])
    gc4 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm3, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm4 = BatchNorm(in_layers=[gc4])
    gp2 = GraphPool(in_layers=[batch_norm4, self.degree_slice, self.membership]
                    + self.deg_adjs)
    
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm5 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm5, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.856 s
# TIMING: dataset construction took 3.266 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.524 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.178 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.226 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 64
C2_filtnum = 64
D_nodenum = 32

graph_structure = 'GC{0}_GC{1}_GP_GC{0}_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [1.4211336704062902]
# computed_metrics: [1.4211336704062902]
# computed_metrics: [1.5636835428320057]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.0110760234518272]
# computed_metrics: [1.0110760234518272]
# computed_metrics: [1.0483521243771279]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.9076858925494311]
# computed_metrics: [0.9076858925494311]
# computed_metrics: [0.8920925205453858]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.8561717854231613]
# computed_metrics: [0.8561717854231613]
# computed_metrics: [0.832770316151382]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.824814263830324]
# computed_metrics: [0.824814263830324]
# computed_metrics: [0.800495581763552]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.8328874984836112]
# computed_metrics: [0.8328874984836112]
# computed_metrics: [0.8020269886435951]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.818776218044838]
# computed_metrics: [0.818776218044838]
# computed_metrics: [0.8103256433183954]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8381023440771826]
# computed_metrics: [0.8381023440771826]
# computed_metrics: [0.8287841371535237]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8231847507100081]
# computed_metrics: [0.8231847507100081]
# computed_metrics: [0.7772593093398933]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.7994199550120078]
# computed_metrics: [0.7994199550120078]
# computed_metrics: [0.774117314729127]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.7201631106562816]
# computed_metrics: [0.7201631106562816]
# computed_metrics: [0.7299661020006019]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.6963612805447551]
# computed_metrics: [0.6963612805447551]
# computed_metrics: [0.7347226163857367]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.6736527579239684]
# computed_metrics: [0.6736527579239684]
# computed_metrics: [0.7038320128598347]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.653938986470668]
# computed_metrics: [0.653938986470668]
# computed_metrics: [0.6919111727025692]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.6482297944333729]
# computed_metrics: [0.6482297944333729]
# computed_metrics: [0.6892249151886812]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.6736356368281738]
# computed_metrics: [0.6736356368281738]
# computed_metrics: [0.7466955601954129]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.6590842033457185]
# computed_metrics: [0.6590842033457185]
# computed_metrics: [0.7350635277205575]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.622498023536593]
# computed_metrics: [0.622498023536593]
# computed_metrics: [0.6979805642477224]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.5941867552768723]
# computed_metrics: [0.5941867552768723]
# computed_metrics: [0.6755486919223955]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.5848542244734957]
# computed_metrics: [0.5848542244734957]
# computed_metrics: [0.6618491976936055]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.5907256312334183]
# computed_metrics: [0.5907256312334183]
# computed_metrics: [0.6787201076175716]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.5792126029671151]
# computed_metrics: [0.5792126029671151]
# computed_metrics: [0.6262866918011333]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.577189640108005]
# computed_metrics: [0.577189640108005]
# computed_metrics: [0.6257556374933556]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.5852556039063126]
# computed_metrics: [0.5852556039063126]
# computed_metrics: [0.6094849599366785]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.5719493580870203]
# computed_metrics: [0.5719493580870203]
# computed_metrics: [0.6162847774100301]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.5421268852763118]
# computed_metrics: [0.5421268852763118]
# computed_metrics: [0.6008106160457236]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.5411373904998555]
# computed_metrics: [0.5411373904998555]
# computed_metrics: [0.5996225324932473]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.5261520912197606]
# computed_metrics: [0.5261520912197606]
# computed_metrics: [0.606514501003922]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.5358254695004646]
# computed_metrics: [0.5358254695004646]
# computed_metrics: [0.6123497041021485]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.5067742754292476]
# computed_metrics: [0.5067742754292476]
# computed_metrics: [0.5991515596231207]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.5182608554444852]
# computed_metrics: [0.5182608554444852]
# computed_metrics: [0.6109458645086289]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.5098692814027311]
# computed_metrics: [0.5098692814027311]
# computed_metrics: [0.6129025107895307]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.4945348616179094]
# computed_metrics: [0.4945348616179094]
# computed_metrics: [0.5874400365293797]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.49347327358255794]
# computed_metrics: [0.49347327358255794]
# computed_metrics: [0.5797467974462562]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.5116055297313307]
# computed_metrics: [0.5116055297313307]
# computed_metrics: [0.5768720587623721]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.49378182854683805]
# computed_metrics: [0.49378182854683805]
# computed_metrics: [0.5827167818853789]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.4827242672543471]
# computed_metrics: [0.4827242672543471]
# computed_metrics: [0.5599022371175386]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.517683266045714]
# computed_metrics: [0.517683266045714]
# computed_metrics: [0.576108631828696]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.49625870977243386]
# computed_metrics: [0.49625870977243386]
# computed_metrics: [0.5736832551438084]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.4772481120096873]
# computed_metrics: [0.4772481120096873]
# computed_metrics: [0.5640967577941295]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.45804249748952774]
# computed_metrics: [0.45804249748952774]
# computed_metrics: [0.578213099168919]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.45673562868761397]
# computed_metrics: [0.45673562868761397]
# computed_metrics: [0.5551300323383866]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.48283892864165345]
# computed_metrics: [0.48283892864165345]
# computed_metrics: [0.5567129657922422]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.4773085304009587]
# computed_metrics: [0.4773085304009587]
# computed_metrics: [0.5638983653697263]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.49819687397194434]
# computed_metrics: [0.49819687397194434]
# computed_metrics: [0.5853648381236277]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.4592142223951853]
# computed_metrics: [0.4592142223951853]
# computed_metrics: [0.5618625960752281]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.46243391967629743]
# computed_metrics: [0.46243391967629743]
# computed_metrics: [0.5755592794247915]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.4433489426739117]
# computed_metrics: [0.4433489426739117]
# computed_metrics: [0.5543764296995948]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.4444442184443547]
# computed_metrics: [0.4444442184443547]
# computed_metrics: [0.5756303581729895]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.43444484943447537]
# computed_metrics: [0.43444484943447537]
# computed_metrics: [0.5708313734247218]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.4247676524257043]
# computed_metrics: [0.4247676524257043]
# computed_metrics: [0.553840139137751]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.41122878990737527]
# computed_metrics: [0.41122878990737527]
# computed_metrics: [0.533368782251833]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.4699666351249347]
# computed_metrics: [0.4699666351249347]
# computed_metrics: [0.5675856699876535]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.4609437251738089]
# computed_metrics: [0.4609437251738089]
# computed_metrics: [0.5562972981845966]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.4231963590748606]
# computed_metrics: [0.4231963590748606]
# computed_metrics: [0.5256993600854591]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.41615389904008715]
# computed_metrics: [0.41615389904008715]
# computed_metrics: [0.5559921430937386]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.43959527286685224]
# computed_metrics: [0.43959527286685224]
# computed_metrics: [0.5617165529856554]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.4252793548320142]
# computed_metrics: [0.4252793548320142]
# computed_metrics: [0.5427636590015619]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.4262745477059718]
# computed_metrics: [0.4262745477059718]
# computed_metrics: [0.5518967805148635]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.41866005994195465]
# computed_metrics: [0.41866005994195465]
# computed_metrics: [0.5578129156574272]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.38639569399823004]
# computed_metrics: [0.38639569399823004]
# computed_metrics: [0.5258455971775307]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.40186701689237575]
# computed_metrics: [0.40186701689237575]
# computed_metrics: [0.5344692098854462]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.3966973897294012]
# computed_metrics: [0.3966973897294012]
# computed_metrics: [0.5383520566097453]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.3939701613644189]
# computed_metrics: [0.3939701613644189]
# computed_metrics: [0.5530400810617653]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.4659000104716854]
# computed_metrics: [0.4659000104716854]
# computed_metrics: [0.5470735781198186]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.4044889162050464]
# computed_metrics: [0.4044889162050464]
# computed_metrics: [0.5468997939716852]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.40150831651957564]
# computed_metrics: [0.40150831651957564]
# computed_metrics: [0.5574360276369767]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.37378144212927494]
# computed_metrics: [0.37378144212927494]
# computed_metrics: [0.5371635205146656]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.38062727620523884]
# computed_metrics: [0.38062727620523884]
# computed_metrics: [0.5113864657018662]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.3785001393822705]
# computed_metrics: [0.3785001393822705]
# computed_metrics: [0.5167614478826766]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.3783734471081386]
# computed_metrics: [0.3783734471081386]
# computed_metrics: [0.5319152072833662]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.36553007104591745]
# computed_metrics: [0.36553007104591745]
# computed_metrics: [0.5238671446128919]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.4085605470077921]
# computed_metrics: [0.4085605470077921]
# computed_metrics: [0.5629827128455142]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4117573379586305]
# computed_metrics: [0.4117573379586305]
# computed_metrics: [0.5417652003667535]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.4143756295724152]
# computed_metrics: [0.4143756295724152]
# computed_metrics: [0.5620843658149637]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.37987670893328085]
# computed_metrics: [0.37987670893328085]
# computed_metrics: [0.5065557107833121]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.3679872098242361]
# computed_metrics: [0.3679872098242361]
# computed_metrics: [0.5334915314797971]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.3765996799024923]
# computed_metrics: [0.3765996799024923]
# computed_metrics: [0.5553908637423168]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.3689764229960798]
# computed_metrics: [0.3689764229960798]
# computed_metrics: [0.5202631345481877]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4167651262277624]
# computed_metrics: [0.4167651262277624]
# computed_metrics: [0.5409361639631649]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.3778641688296375]
# computed_metrics: [0.3778641688296375]
# computed_metrics: [0.5475551964782076]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.35273166534093686]
# computed_metrics: [0.35273166534093686]
# computed_metrics: [0.5369991796472224]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.3651820784487054]
# computed_metrics: [0.3651820784487054]
# computed_metrics: [0.5396720028960296]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.37070108426915627]
# computed_metrics: [0.37070108426915627]
# computed_metrics: [0.5303215240064919]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.39897767365465064]
# computed_metrics: [0.39897767365465064]
# computed_metrics: [0.5474744869851037]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.35559743555713935]
# computed_metrics: [0.35559743555713935]
# computed_metrics: [0.5275597123776997]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.3903238902697408]
# computed_metrics: [0.3903238902697408]
# computed_metrics: [0.5359972427971341]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.3632618936550885]
# computed_metrics: [0.3632618936550885]
# computed_metrics: [0.5370205802558006]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.34047862502089904]
# computed_metrics: [0.34047862502089904]
# computed_metrics: [0.5338026683014888]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.3246750625733606]
# computed_metrics: [0.3246750625733606]
# computed_metrics: [0.5311745940559849]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.33236706315435155]
# computed_metrics: [0.33236706315435155]
# computed_metrics: [0.5284109517110755]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.312586066178229]
# computed_metrics: [0.312586066178229]
# computed_metrics: [0.5145016197939833]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.3132789935309147]
# computed_metrics: [0.3132789935309147]
# computed_metrics: [0.5282313208885987]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.3616953930891496]
# computed_metrics: [0.3616953930891496]
# computed_metrics: [0.5642348292667324]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.31993826676732046]
# computed_metrics: [0.31993826676732046]
# computed_metrics: [0.5184535274519099]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.315828719289194]
# computed_metrics: [0.315828719289194]
# computed_metrics: [0.5152678143656966]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.44381332040717525]
# computed_metrics: [0.44381332040717525]
# computed_metrics: [0.6180846177080849]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.357539923763792]
# computed_metrics: [0.357539923763792]
# computed_metrics: [0.5396936259174397]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.36263129700717306]
# computed_metrics: [0.36263129700717306]
# computed_metrics: [0.5572312194147597]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.3243683009636652]
# computed_metrics: [0.3243683009636652]
# computed_metrics: [0.5293773993781954]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.32268107441316934]
# computed_metrics: [0.32268107441316934]
# computed_metrics: [0.5206630558347788]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.3493176982957263]
# computed_metrics: [0.3493176982957263]
# computed_metrics: [0.5276340030489804]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.33908644896488965]
# computed_metrics: [0.33908644896488965]
# computed_metrics: [0.5268345981304812]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.311122945200906]
# computed_metrics: [0.311122945200906]
# computed_metrics: [0.5315043712633526]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.3073113146645582]
# computed_metrics: [0.3073113146645582]
# computed_metrics: [0.5387676813976918]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.30144817852833183]
# computed_metrics: [0.30144817852833183]
# computed_metrics: [0.5370789731627351]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.2742119256520523]
# computed_metrics: [0.2742119256520523]
# computed_metrics: [0.523957696038666]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.26651517710608474]
# computed_metrics: [0.26651517710608474]
# computed_metrics: [0.5280238320059115]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.2858105784630015]
# computed_metrics: [0.2858105784630015]
# computed_metrics: [0.5334948982766669]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.3019617001512416]
# computed_metrics: [0.3019617001512416]
# computed_metrics: [0.52143662633713]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.31814188366556]
# computed_metrics: [0.31814188366556]
# computed_metrics: [0.5406649334608601]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.33387775342499093]
# computed_metrics: [0.33387775342499093]
# computed_metrics: [0.5348428314590996]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.289444533408971]
# computed_metrics: [0.289444533408971]
# computed_metrics: [0.5197609357401212]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.30157017754898924]
# computed_metrics: [0.30157017754898924]
# computed_metrics: [0.5229110150815209]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.3137289210031699]
# computed_metrics: [0.3137289210031699]
# computed_metrics: [0.5552210010402563]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.3101588046926815]
# computed_metrics: [0.3101588046926815]
# computed_metrics: [0.5723703935743564]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.3033004804643791]
# computed_metrics: [0.3033004804643791]
# computed_metrics: [0.573295233298804]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.3033819114018489]
# computed_metrics: [0.3033819114018489]
# computed_metrics: [0.5453661154100634]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.2918383624100116]
# computed_metrics: [0.2918383624100116]
# computed_metrics: [0.529043398813107]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.32416167241965893]
# computed_metrics: [0.32416167241965893]
# computed_metrics: [0.5570317572148197]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.3007756300328043]
# computed_metrics: [0.3007756300328043]
# computed_metrics: [0.5568290882143895]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.29447377360361066]
# computed_metrics: [0.29447377360361066]
# computed_metrics: [0.5674755152108544]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.3029804290280884]
# computed_metrics: [0.3029804290280884]
# computed_metrics: [0.5471767135330895]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.29971222834563654]
# computed_metrics: [0.29971222834563654]
# computed_metrics: [0.5745359729306969]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.3066747689451523]
# computed_metrics: [0.3066747689451523]
# computed_metrics: [0.5518636411519721]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.3009502500413432]
# computed_metrics: [0.3009502500413432]
# computed_metrics: [0.5806611278035685]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.2809213101056939]
# computed_metrics: [0.2809213101056939]
# computed_metrics: [0.5430877869775419]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.30173133292612275]
# computed_metrics: [0.30173133292612275]
# computed_metrics: [0.5865691629866726]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.32136320651359446]
# computed_metrics: [0.32136320651359446]
# computed_metrics: [0.5526242511181356]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.2739850753891287]
# computed_metrics: [0.2739850753891287]
# computed_metrics: [0.5564693430755163]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.2949132404508517]
# computed_metrics: [0.2949132404508517]
# computed_metrics: [0.5628024392366334]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.27446747619208745]
# computed_metrics: [0.27446747619208745]
# computed_metrics: [0.5419057597515688]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.2797958805921805]
# computed_metrics: [0.2797958805921805]
# computed_metrics: [0.5542692405260305]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.27300886745890945]
# computed_metrics: [0.27300886745890945]
# computed_metrics: [0.5386682986236778]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.28006851018213025]
# computed_metrics: [0.28006851018213025]
# computed_metrics: [0.5512139390711632]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3158149758408677]
# computed_metrics: [0.3158149758408677]
# computed_metrics: [0.5653498822729114]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.2824133883770162]
# computed_metrics: [0.2824133883770162]
# computed_metrics: [0.562260934440288]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.2767001849362401]
# computed_metrics: [0.2767001849362401]
# computed_metrics: [0.5452079222157007]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.27342582997716447]
# computed_metrics: [0.27342582997716447]
# computed_metrics: [0.5409781447866067]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.28623043011006144]
# computed_metrics: [0.28623043011006144]
# computed_metrics: [0.5403189711449926]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.303537821368154]
# computed_metrics: [0.303537821368154]
# computed_metrics: [0.5539736344982332]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.4109809728642258]
# computed_metrics: [0.4109809728642258]
# computed_metrics: [0.62218916148784]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.35423332649429795]
# computed_metrics: [0.35423332649429795]
# computed_metrics: [0.5664140871299187]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.3305281607662487]
# computed_metrics: [0.3305281607662487]
# computed_metrics: [0.5725703824501446]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.28353175199268377]
# computed_metrics: [0.28353175199268377]
# computed_metrics: [0.5140725021399278]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.3156333335737072]
# computed_metrics: [0.3156333335737072]
# computed_metrics: [0.5478841619760745]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.33481818282867926]
# computed_metrics: [0.33481818282867926]
# computed_metrics: [0.5490299608613488]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.30216341328863455]
# computed_metrics: [0.30216341328863455]
# computed_metrics: [0.5448787693334093]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.348132173020755]
# computed_metrics: [0.348132173020755]
# computed_metrics: [0.5979589023655089]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.28226365141932414]
# computed_metrics: [0.28226365141932414]
# computed_metrics: [0.5285378192971768]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.26752627127056083]
# computed_metrics: [0.26752627127056083]
# computed_metrics: [0.5406792721514757]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.291914326644468]
# computed_metrics: [0.291914326644468]
# computed_metrics: [0.5749879241929253]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.3747252003969511]
# computed_metrics: [0.3747252003969511]
# computed_metrics: [0.5998802436255135]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.331182022165373]
# computed_metrics: [0.331182022165373]
# computed_metrics: [0.578801649188979]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.3213743935105477]
# computed_metrics: [0.3213743935105477]
# computed_metrics: [0.5632643170184819]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.2700873293331488]
# computed_metrics: [0.2700873293331488]
# computed_metrics: [0.5366113789771768]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.3474107505352948]
# computed_metrics: [0.3474107505352948]
# computed_metrics: [0.5888193168371106]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3221560007974298]
# computed_metrics: [0.3221560007974298]
# computed_metrics: [0.5751988064639065]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.3437746803499298]
# computed_metrics: [0.3437746803499298]
# computed_metrics: [0.5871308162235365]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.28973811447390374]
# computed_metrics: [0.28973811447390374]
# computed_metrics: [0.549876390673978]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.2902096058561056]
# computed_metrics: [0.2902096058561056]
# computed_metrics: [0.5354007204895126]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.3178118156550795]
# computed_metrics: [0.3178118156550795]
# computed_metrics: [0.5776823225504705]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.285469764801224]
# computed_metrics: [0.285469764801224]
# computed_metrics: [0.5656063179239134]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.2830106734963232]
# computed_metrics: [0.2830106734963232]
# computed_metrics: [0.5497461169738111]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.27678310415065277]
# computed_metrics: [0.27678310415065277]
# computed_metrics: [0.5546058990153384]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.24143762137613506]
# computed_metrics: [0.24143762137613506]
# computed_metrics: [0.5221472795954125]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.2614130786817561]
# computed_metrics: [0.2614130786817561]
# computed_metrics: [0.5061544699489222]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.311092466135994]
# computed_metrics: [0.311092466135994]
# computed_metrics: [0.5331566961167828]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.2957254796266012]
# computed_metrics: [0.2957254796266012]
# computed_metrics: [0.5167025279113465]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.2575243698929333]
# computed_metrics: [0.2575243698929333]
# computed_metrics: [0.5458745113102971]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.2745823460313174]
# computed_metrics: [0.2745823460313174]
# computed_metrics: [0.5444314126114851]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.3726453548384578]
# computed_metrics: [0.3726453548384578]
# computed_metrics: [0.6065273459375322]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3580228935193491]
# computed_metrics: [0.3580228935193491]
# computed_metrics: [0.6001558520109759]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.31256575095153705]
# computed_metrics: [0.31256575095153705]
# computed_metrics: [0.5575451038391125]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.288657547890646]
# computed_metrics: [0.288657547890646]
# computed_metrics: [0.5426557839852169]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.37366866877190863]
# computed_metrics: [0.37366866877190863]
# computed_metrics: [0.5909667932543423]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3518830982606744]
# computed_metrics: [0.3518830982606744]
# computed_metrics: [0.5785834779697611]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.310985357100755]
# computed_metrics: [0.310985357100755]
# computed_metrics: [0.5547324336919051]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.2925633402943813]
# computed_metrics: [0.2925633402943813]
# computed_metrics: [0.565061976645794]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.3482017935170007]
# computed_metrics: [0.3482017935170007]
# computed_metrics: [0.5972899239422627]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.42797822542926106]
# computed_metrics: [0.42797822542926106]
# computed_metrics: [0.6639325957981685]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.2946158696180479]
# computed_metrics: [0.2946158696180479]
# computed_metrics: [0.5197348050274245]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.2976788816528383]
# computed_metrics: [0.2976788816528383]
# computed_metrics: [0.563857146622423]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.32183886150511126]
# computed_metrics: [0.32183886150511126]
# computed_metrics: [0.5472977350878754]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.2875153953028573]
# computed_metrics: [0.2875153953028573]
# computed_metrics: [0.5316655827400113]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.285911932740793]
# computed_metrics: [0.285911932740793]
# computed_metrics: [0.5731927643365594]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.3084958092237099]
# computed_metrics: [0.3084958092237099]
# computed_metrics: [0.5419930614262399]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.27645095103065925]
# computed_metrics: [0.27645095103065925]
# computed_metrics: [0.5441615456006834]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.2551745701703923]
# computed_metrics: [0.2551745701703923]
# computed_metrics: [0.5675911493431224]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.29107634782593284]
# computed_metrics: [0.29107634782593284]
# computed_metrics: [0.5577971605147294]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.23773351042465268]
# computed_metrics: [0.23773351042465268]
# computed_metrics: [0.5440641594232888]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.27376199625980563]
# computed_metrics: [0.27376199625980563]
# computed_metrics: [0.5532749089395614]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.3073279502903052]
# computed_metrics: [0.3073279502903052]
# computed_metrics: [0.5725286085895545]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.2569621284438323]
# computed_metrics: [0.2569621284438323]
# computed_metrics: [0.5472445646070883]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.25042840382475073]
# computed_metrics: [0.25042840382475073]
# computed_metrics: [0.5521688435731091]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.35164359203686524]
# computed_metrics: [0.35164359203686524]
# computed_metrics: [0.6056697985547417]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.29553220686738596]
# computed_metrics: [0.29553220686738596]
# computed_metrics: [0.5604702640960112]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.26695294710298356]
# computed_metrics: [0.26695294710298356]
# computed_metrics: [0.5491835717821492]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.33204867929522613]
# computed_metrics: [0.33204867929522613]
# computed_metrics: [0.5818202953624463]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.3148643011934399]
# computed_metrics: [0.3148643011934399]
# computed_metrics: [0.5703725590899189]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.2547013557101326]
# computed_metrics: [0.2547013557101326]
# computed_metrics: [0.5456908220591349]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.36338735319850746]
# computed_metrics: [0.36338735319850746]
# computed_metrics: [0.5694899704937851]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.2766990064936455]
# computed_metrics: [0.2766990064936455]
# computed_metrics: [0.5533879100306929]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.2741623756174036]
# computed_metrics: [0.2741623756174036]
# computed_metrics: [0.5308672828824403]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.34721991927918094]
# computed_metrics: [0.34721991927918094]
# computed_metrics: [0.5873684580444025]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.27166680294238943]
# computed_metrics: [0.27166680294238943]
# computed_metrics: [0.5720137876677449]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.2892765391735574]
# computed_metrics: [0.2892765391735574]
# computed_metrics: [0.5538298147360933]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.28093010840991683]
# computed_metrics: [0.28093010840991683]
# computed_metrics: [0.5455837343042457]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.2328244053174489]
# computed_metrics: [0.2328244053174489]
# computed_metrics: [0.5271546843176139]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.32669791327820247]
# computed_metrics: [0.32669791327820247]
# computed_metrics: [0.6066423051449304]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.26731606085170656]
# computed_metrics: [0.26731606085170656]
# computed_metrics: [0.5722096999177271]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.23863886672975]
# computed_metrics: [0.23863886672975]
# computed_metrics: [0.5405257106180512]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.2837170761590018]
# computed_metrics: [0.2837170761590018]
# computed_metrics: [0.5579397777255545]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.22919131717777608]
# computed_metrics: [0.22919131717777608]
# computed_metrics: [0.5300928817187366]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.2924293616094284]
# computed_metrics: [0.2924293616094284]
# computed_metrics: [0.5840900070678654]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.2793709490332094]
# computed_metrics: [0.2793709490332094]
# computed_metrics: [0.5623516554667624]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.2342894683265405]
# computed_metrics: [0.2342894683265405]
# computed_metrics: [0.5319318233822833]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.27502839738671153]
# computed_metrics: [0.27502839738671153]
# computed_metrics: [0.5555065760763886]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.237272299205305]
# computed_metrics: [0.237272299205305]
# computed_metrics: [0.5506808031375263]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.24860712703222693]
# computed_metrics: [0.24860712703222693]
# computed_metrics: [0.5624403908801965]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.28938339183458917]
# computed_metrics: [0.28938339183458917]
# computed_metrics: [0.5814380862234974]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.22126698613540613]
# computed_metrics: [0.22126698613540613]
# computed_metrics: [0.5394497493691516]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.26073363404691713]
# computed_metrics: [0.26073363404691713]
# computed_metrics: [0.5561693773781959]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.25759346749670214]
# computed_metrics: [0.25759346749670214]
# computed_metrics: [0.5655484449936414]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.2559653701745234]
# computed_metrics: [0.2559653701745234]
# computed_metrics: [0.5763411804549058]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.2698697005266115]
# computed_metrics: [0.2698697005266115]
# computed_metrics: [0.5605063926972035]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.22990443927612245]
# computed_metrics: [0.22990443927612245]
# computed_metrics: [0.5485979000383783]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.25488941314507685]
# computed_metrics: [0.25488941314507685]
# computed_metrics: [0.56811604238887]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.24088221029681786]
# computed_metrics: [0.24088221029681786]
# computed_metrics: [0.5558952934685387]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.2301802592346042]
# computed_metrics: [0.2301802592346042]
# computed_metrics: [0.5553996823019004]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.2930670899180688]
# computed_metrics: [0.2930670899180688]
# computed_metrics: [0.5733359433348169]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.2308406266714426]
# computed_metrics: [0.2308406266714426]
# computed_metrics: [0.5675941344650136]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.2621333336650736]
# computed_metrics: [0.2621333336650736]
# computed_metrics: [0.5597879608388159]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.23318420319434965]
# computed_metrics: [0.23318420319434965]
# computed_metrics: [0.550905132548626]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.23144009610816937]
# computed_metrics: [0.23144009610816937]
# computed_metrics: [0.5681128471970041]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.31014720818085195]
# computed_metrics: [0.31014720818085195]
# computed_metrics: [0.6008830756353875]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.23576901990281382]
# computed_metrics: [0.23576901990281382]
# computed_metrics: [0.540970856004372]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.2571853392009015]
# computed_metrics: [0.2571853392009015]
# computed_metrics: [0.5600490208827182]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.30899397848657595]
# computed_metrics: [0.30899397848657595]
# computed_metrics: [0.5962398663472988]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.23414367342075726]
# computed_metrics: [0.23414367342075726]
# computed_metrics: [0.5604856245152211]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.24983482706618426]
# computed_metrics: [0.24983482706618426]
# computed_metrics: [0.5819480749358611]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.2879963852094074]
# computed_metrics: [0.2879963852094074]
# computed_metrics: [0.6049240894656754]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.21345647434686696]
# computed_metrics: [0.21345647434686696]
# computed_metrics: [0.5495980852867648]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.23650369859106385]
# computed_metrics: [0.23650369859106385]
# computed_metrics: [0.5606710083634849]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.2640921351131166]
# computed_metrics: [0.2640921351131166]
# computed_metrics: [0.557490288189483]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.2159151017921487]
# computed_metrics: [0.2159151017921487]
# computed_metrics: [0.5702652789959742]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.2835516711581941]
# computed_metrics: [0.2835516711581941]
# computed_metrics: [0.5967574482853287]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.31414096375527195]
# computed_metrics: [0.31414096375527195]
# computed_metrics: [0.6093649938809252]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.2415446359493458]
# computed_metrics: [0.2415446359493458]
# computed_metrics: [0.5705329573180661]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24621868752975345]
# computed_metrics: [0.24621868752975345]
# computed_metrics: [0.567814559083993]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.2902676945624129]
# computed_metrics: [0.2902676945624129]
# computed_metrics: [0.5914908375836422]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.24357133032718414]
# computed_metrics: [0.24357133032718414]
# computed_metrics: [0.5904831303865017]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.26118587777253843]
# computed_metrics: [0.26118587777253843]
# computed_metrics: [0.5710925425781979]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.3006971040168874]
# computed_metrics: [0.3006971040168874]
# computed_metrics: [0.6064690371228583]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.3115944878034941]
# computed_metrics: [0.3115944878034941]
# computed_metrics: [0.5927970689833431]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.26645009706760553]
# computed_metrics: [0.26645009706760553]
# computed_metrics: [0.596631370149346]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.26913713357414637]
# computed_metrics: [0.26913713357414637]
# computed_metrics: [0.5523356591947728]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.2515478047972297]
# computed_metrics: [0.2515478047972297]
# computed_metrics: [0.5631921028425244]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.21516404793760077]
# computed_metrics: [0.21516404793760077]
# computed_metrics: [0.5512677483907631]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.21337725067716237]
# computed_metrics: [0.21337725067716237]
# computed_metrics: [0.5596374261353161]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.2292627418287097]
# computed_metrics: [0.2292627418287097]
# computed_metrics: [0.5831550360600315]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.2068054484787779]
# computed_metrics: [0.2068054484787779]
# computed_metrics: [0.5522093205313845]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.20824027284692398]
# computed_metrics: [0.20824027284692398]
# computed_metrics: [0.5531368687698646]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.24385693448859344]
# computed_metrics: [0.24385693448859344]
# computed_metrics: [0.5585166144479097]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.20256602672365562]
# computed_metrics: [0.20256602672365562]
# computed_metrics: [0.5660259711617261]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.24683702226407503]
# computed_metrics: [0.24683702226407503]
# computed_metrics: [0.5853319205683313]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.3269813068129809]
# computed_metrics: [0.3269813068129809]
# computed_metrics: [0.6181881051537863]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.2457064772300823]
# computed_metrics: [0.2457064772300823]
# computed_metrics: [0.5814090731591295]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.272162602258854]
# computed_metrics: [0.272162602258854]
# computed_metrics: [0.5920315522204784]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.3373006624309847]
# computed_metrics: [0.3373006624309847]
# computed_metrics: [0.626683068021811]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.21532139260207908]
# computed_metrics: [0.21532139260207908]
# computed_metrics: [0.5662179499538247]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.2759186193676981]
# computed_metrics: [0.2759186193676981]
# computed_metrics: [0.5604513999928016]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.31659261856927245]
# computed_metrics: [0.31659261856927245]
# computed_metrics: [0.6156703961413775]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.26095864549897774]
# computed_metrics: [0.26095864549897774]
# computed_metrics: [0.5826230375137458]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.2999136324269498]
# computed_metrics: [0.2999136324269498]
# computed_metrics: [0.5702821363261109]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.3760851547618674]
# computed_metrics: [0.3760851547618674]
# computed_metrics: [0.6401840208281285]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.25311518230326907]
# computed_metrics: [0.25311518230326907]
# computed_metrics: [0.5435914120946783]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.2619526579933953]
# computed_metrics: [0.2619526579933953]
# computed_metrics: [0.5832390955267122]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.2856744045182905]
# computed_metrics: [0.2856744045182905]
# computed_metrics: [0.6043661930316299]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.22443168265570373]
# computed_metrics: [0.22443168265570373]
# computed_metrics: [0.5563923425900478]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.24803309740430413]
# computed_metrics: [0.24803309740430413]
# computed_metrics: [0.5476812184878369]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.2493926058110232]
# computed_metrics: [0.2493926058110232]
# computed_metrics: [0.5773163822356422]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.21996868306533496]
# computed_metrics: [0.21996868306533496]
# computed_metrics: [0.5856647143480614]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.2711830203700574]
# computed_metrics: [0.2711830203700574]
# computed_metrics: [0.5874208039753389]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.20213652332484758]
# computed_metrics: [0.20213652332484758]
# computed_metrics: [0.550732802872409]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.2555695820178305]
# computed_metrics: [0.2555695820178305]
# computed_metrics: [0.5483046069314381]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.22041532584511941]
# computed_metrics: [0.22041532584511941]
# computed_metrics: [0.5528049987038326]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.2479153803155971]
# ...
# computed_metrics: [0.16655661251966358]
# computed_metrics: [0.16655661251966358]
# computed_metrics: [0.5538082151055876]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.252844577549987]
# computed_metrics: [0.252844577549987]
# computed_metrics: [0.5847682749883122]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.18474469148626504]
# computed_metrics: [0.18474469148626504]
# computed_metrics: [0.575140708920429]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.20752200970407592]
# computed_metrics: [0.20752200970407592]
# computed_metrics: [0.5919100301624031]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.24836702367568975]
# computed_metrics: [0.24836702367568975]
# computed_metrics: [0.6287930618744351]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.167668060922855]
# computed_metrics: [0.167668060922855]
# computed_metrics: [0.5971957112340096]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.22439037464574255]
# computed_metrics: [0.22439037464574255]
# computed_metrics: [0.6117076569462638]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.1866519293431545]
# computed_metrics: [0.1866519293431545]
# computed_metrics: [0.5755034166681025]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.23113828217277396]
# computed_metrics: [0.23113828217277396]
# computed_metrics: [0.6254789522011183]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.23326818497341748]
# computed_metrics: [0.23326818497341748]
# computed_metrics: [0.6313246517641318]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.16989581915061228]
# computed_metrics: [0.16989581915061228]
# computed_metrics: [0.5842008058111235]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.23515369882840043]
# computed_metrics: [0.23515369882840043]
# computed_metrics: [0.592290725638329]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.1768065330905213]
# computed_metrics: [0.1768065330905213]
# computed_metrics: [0.5914987857327864]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.2270721632422556]
# computed_metrics: [0.2270721632422556]
# computed_metrics: [0.6362904485389859]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.21236419617145624]
# computed_metrics: [0.21236419617145624]
# computed_metrics: [0.6301524773752922]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.16494531879788832]
# computed_metrics: [0.16494531879788832]
# computed_metrics: [0.6049254993225404]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.221422183921598]
# computed_metrics: [0.221422183921598]
# computed_metrics: [0.6060078871558384]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.1650413392045439]
# computed_metrics: [0.1650413392045439]
# computed_metrics: [0.5733569665541508]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.20135597135859643]
# computed_metrics: [0.20135597135859643]
# computed_metrics: [0.6120335947810246]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.19496658574138048]
# computed_metrics: [0.19496658574138048]
# computed_metrics: [0.6278935721283035]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.16105128897924517]
# computed_metrics: [0.16105128897924517]
# computed_metrics: [0.5949609458254093]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.22472403442977962]
# computed_metrics: [0.22472403442977962]
# computed_metrics: [0.6055605583121086]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.2024899773613004]
# computed_metrics: [0.2024899773613004]
# computed_metrics: [0.5790877108343223]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.1627845844362731]
# computed_metrics: [0.1627845844362731]
# computed_metrics: [0.6046734525478715]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.22649334905476098]
# computed_metrics: [0.22649334905476098]
# computed_metrics: [0.6099559792677527]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.16956787008080557]
# computed_metrics: [0.16956787008080557]
# computed_metrics: [0.6020894741564269]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.18626451650234657]
# computed_metrics: [0.18626451650234657]
# computed_metrics: [0.6007283644469504]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.2304227552280978]
# computed_metrics: [0.2304227552280978]
# computed_metrics: [0.588051135044734]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.1559847691780755]
# computed_metrics: [0.1559847691780755]
# computed_metrics: [0.5793663295170683]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.25537684028563373]
# computed_metrics: [0.25537684028563373]
# computed_metrics: [0.6218062733658732]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.19394924592259397]
# computed_metrics: [0.19394924592259397]
# computed_metrics: [0.6140794910493145]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.16209743632807164]
# computed_metrics: [0.16209743632807164]
# computed_metrics: [0.5843109283054181]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.20993634860313257]
# computed_metrics: [0.20993634860313257]
# computed_metrics: [0.6025932571444537]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.15405164189780032]
# computed_metrics: [0.15405164189780032]
# computed_metrics: [0.5850446210783755]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.25480120087531605]
# computed_metrics: [0.25480120087531605]
# computed_metrics: [0.6241667767966954]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.17277553656225886]
# computed_metrics: [0.17277553656225886]
# computed_metrics: [0.5965390476897185]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.16936256358690488]
# computed_metrics: [0.16936256358690488]
# computed_metrics: [0.5946461753611018]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.23415644453430362]
# computed_metrics: [0.23415644453430362]
# computed_metrics: [0.5994779844800974]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.1644111571721899]
# computed_metrics: [0.1644111571721899]
# computed_metrics: [0.5730141270270043]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.22564535945897365]
# computed_metrics: [0.22564535945897365]
# computed_metrics: [0.6263423724184415]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.19195354249961097]
# computed_metrics: [0.19195354249961097]
# computed_metrics: [0.5951023021111638]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.14812071420442133]
# computed_metrics: [0.14812071420442133]
# computed_metrics: [0.5730566242108417]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.19929696488310042]
# computed_metrics: [0.19929696488310042]
# computed_metrics: [0.5852460758293323]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.16405477735769386]
# computed_metrics: [0.16405477735769386]
# computed_metrics: [0.5734686375113636]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.1669945521633514]
# computed_metrics: [0.1669945521633514]
# computed_metrics: [0.6049937242013403]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.23684786953963705]
# computed_metrics: [0.23684786953963705]
# computed_metrics: [0.6129567325984897]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.19120026961663547]
# computed_metrics: [0.19120026961663547]
# computed_metrics: [0.6083345166613967]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.18482662801747043]
# computed_metrics: [0.18482662801747043]
# computed_metrics: [0.6106385693161138]
# [1.4211336704062902, 1.0110760234518272, 0.9076858925494311, 0.8561717854231613, 0.824814263830324, 0.8328874984836112, 0.818776218044838, 0.8381023440771826, 0.8231847507100081, 0.7994199550120078, 0.7201631106562816, 0.6963612805447551, 0.6736527579239684, 0.653938986470668, 0.6482297944333729, 0.6736356368281738, 0.6590842033457185, 0.622498023536593, 0.5941867552768723, 0.5848542244734957, 0.5907256312334183, 0.5792126029671151, 0.577189640108005, 0.5852556039063126, 0.5719493580870203, 0.5421268852763118, 0.5411373904998555, 0.5261520912197606, 0.5358254695004646, 0.5067742754292476, 0.5182608554444852, 0.5098692814027311, 0.4945348616179094, 0.49347327358255794, 0.5116055297313307, 0.49378182854683805, 0.4827242672543471, 0.517683266045714, 0.49625870977243386, 0.4772481120096873, 0.45804249748952774, 0.45673562868761397, 0.48283892864165345, 0.4773085304009587, 0.49819687397194434, 0.4592142223951853, 0.46243391967629743, 0.4433489426739117, 0.4444442184443547, 0.43444484943447537, 0.4247676524257043, 0.41122878990737527, 0.4699666351249347, 0.4609437251738089, 0.4231963590748606
#  [0.24694235 0.62096102]
#  [0.17475979 0.57430781]
#  [0.23692157 0.56104068]
#  [0.18393313 0.58353886]
#  [0.19937216 0.61711576]
#  [0.24938022 0.62626024]
#  [0.17325271 0.57059028]
#  [0.2693317  0.58198989]
#  [0.22200895 0.58387174]
#  [0.20004412 0.5933556 ]
#  [0.24729059 0.60433047]
#  [0.19177527 0.59584354]
#  [0.2012873  0.58674491]
#  [0.25725985 0.59322368]
#  [0.18890382 0.57269725]
#  [0.2256046  0.61669541]
#  [0.1940747  0.59946791]
#  [0.16177713 0.56584643]
#  [0.18617048 0.57309736]
#  [0.15316949 0.5837891 ]
#  [0.19562476 0.60361613]
#  [0.21236477 0.59375368]
#  [0.16655661 0.55380822]
#  [0.25284458 0.58476827]
#  [0.18474469 0.57514071]
#  [0.20752201 0.59191003]
#  [0.24836702 0.62879306]
#  [0.16766806 0.59719571]
#  [0.22439037 0.61170766]
#  [0.18665193 0.57550342]
#  [0.23113828 0.62547895]
#  [0.23326818 0.63132465]
#  [0.16989582 0.58420081]
#  [0.2351537  0.59229073]
#  [0.17680653 0.59149879]
#  [0.22707216 0.63629045]
#  [0.2123642  0.63015248]
#  [0.16494532 0.6049255 ]
#  [0.22142218 0.60600789]
#  [0.16504134 0.57335697]
#  [0.20135597 0.61203359]
#  [0.19496659 0.62789357]
#  [0.16105129 0.59496095]
#  [0.22472403 0.60556056]
#  [0.20248998 0.57908771]
#  [0.16278458 0.60467345]
#  [0.22649335 0.60995598]
#  [0.16956787 0.60208947]
#  [0.18626452 0.60072836]
#  [0.23042276 0.58805114]
#  [0.15598477 0.57936633]
#  [0.25537684 0.62180627]
#  [0.19394925 0.61407949]
#  [0.16209744 0.58431093]
#  [0.20993635 0.60259326]
#  [0.15405164 0.58504462]
#  [0.2548012  0.62416678]
#  [0.17277554 0.59653905]
#  [0.16936256 0.59464618]
#  [0.23415644 0.59947798]
#  [0.16441116 0.57301413]
#  [0.22564536 0.62634237]
#  [0.19195354 0.5951023 ]
#  [0.14812071 0.57305662]
#  [0.19929696 0.58524608]
#  [0.16405478 0.57346864]
#  [0.16699455 0.60499372]
#  [0.23684787 0.61295673]
#  [0.19120027 0.60833452]
#  [0.18482663 0.61063857]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [1.4186904622053191]
# computed_metrics: [1.4186904622053191]
# computed_metrics: [1.5632837000578785]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.031816655320773]
# computed_metrics: [1.031816655320773]
# computed_metrics: [1.0679586642367556]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [0.9349053435180927]
# computed_metrics: [0.9349053435180927]
# computed_metrics: [0.9036498269617489]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.8796941781645014]
# computed_metrics: [0.8796941781645014]
# computed_metrics: [0.8532115962264019]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.8682135992084453]
# computed_metrics: [0.8682135992084453]
# computed_metrics: [0.8486930462098404]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.8107498898692418]
# computed_metrics: [0.8107498898692418]
# computed_metrics: [0.7993306153799442]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.8343913796690149]
# computed_metrics: [0.8343913796690149]
# computed_metrics: [0.8250730883302302]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8108775657437449]
# computed_metrics: [0.8108775657437449]
# computed_metrics: [0.7991777351737243]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.7919989795265693]
# computed_metrics: [0.7919989795265693]
# computed_metrics: [0.7861166214950536]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.7725134573180458]
# computed_metrics: [0.7725134573180458]
# computed_metrics: [0.7682333714267494]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.743122053519928]
# computed_metrics: [0.743122053519928]
# computed_metrics: [0.7604230853660128]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.7322220011265552]
# computed_metrics: [0.7322220011265552]
# computed_metrics: [0.7431095549518795]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.7014401954174969]
# computed_metrics: [0.7014401954174969]
# computed_metrics: [0.7327429305102648]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.6829477371166534]
# computed_metrics: [0.6829477371166534]
# computed_metrics: [0.7053737739971899]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.6790361251614161]
# computed_metrics: [0.6790361251614161]
# computed_metrics: [0.7032721195241531]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.67482825263704]
# computed_metrics: [0.67482825263704]
# computed_metrics: [0.7350820058228638]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.6478569825628706]
# computed_metrics: [0.6478569825628706]
# computed_metrics: [0.6913361464956347]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.6409767523764687]
# computed_metrics: [0.6409767523764687]
# computed_metrics: [0.6903820747379753]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.6272004483359103]
# computed_metrics: [0.6272004483359103]
# computed_metrics: [0.6755158695312168]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.6233191019406523]
# computed_metrics: [0.6233191019406523]
# computed_metrics: [0.680815665494304]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.606134974986617]
# computed_metrics: [0.606134974986617]
# computed_metrics: [0.6718355358176987]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.6247975940419417]
# computed_metrics: [0.6247975940419417]
# computed_metrics: [0.6903222044277392]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.6063965737655049]
# computed_metrics: [0.6063965737655049]
# computed_metrics: [0.6889071224349808]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.6046409321050336]
# computed_metrics: [0.6046409321050336]
# computed_metrics: [0.6712308655217608]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.6029878642061565]
# computed_metrics: [0.6029878642061565]
# computed_metrics: [0.6780967663020083]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.5935007661182568]
# computed_metrics: [0.5935007661182568]
# computed_metrics: [0.6856009097875607]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6170539997898297]
# computed_metrics: [0.6170539997898297]
# computed_metrics: [0.7013400400095251]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6389911349428096]
# computed_metrics: [0.6389911349428096]
# computed_metrics: [0.7318394196165088]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6562333017383079]
# computed_metrics: [0.6562333017383079]
# computed_metrics: [0.7492005173957479]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6159310854484774]
# computed_metrics: [0.6159310854484774]
# computed_metrics: [0.7134345731992615]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6159934209260823]
# computed_metrics: [0.6159934209260823]
# computed_metrics: [0.7089768340068308]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6563277062719859]
# computed_metrics: [0.6563277062719859]
# computed_metrics: [0.7558728570024186]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.5629981743232636]
# computed_metrics: [0.5629981743232636]
# computed_metrics: [0.6388557816240461]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.5459545664797036]
# computed_metrics: [0.5459545664797036]
# computed_metrics: [0.6372504807265823]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.5273241834816935]
# computed_metrics: [0.5273241834816935]
# computed_metrics: [0.5929521536478516]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.551355658968126]
# computed_metrics: [0.551355658968126]
# computed_metrics: [0.5997973251748786]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.55446293409582]
# computed_metrics: [0.55446293409582]
# computed_metrics: [0.6207978275802828]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.5545994243963984]
# computed_metrics: [0.5545994243963984]
# computed_metrics: [0.6035540133266457]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.5245277149152023]
# computed_metrics: [0.5245277149152023]
# computed_metrics: [0.5754152393927194]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.49112944607967596]
# computed_metrics: [0.49112944607967596]
# computed_metrics: [0.5724848829243614]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.48748696207576603]
# computed_metrics: [0.48748696207576603]
# computed_metrics: [0.5718708541619244]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.47762216778525685]
# computed_metrics: [0.47762216778525685]
# computed_metrics: [0.5698038652367771]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.4724778262508641]
# computed_metrics: [0.4724778262508641]
# computed_metrics: [0.5720958480166406]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.4643204075926283]
# computed_metrics: [0.4643204075926283]
# computed_metrics: [0.5705342801205889]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.47770047916864355]
# computed_metrics: [0.47770047916864355]
# computed_metrics: [0.5507131485243951]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.4696481391131666]
# computed_metrics: [0.4696481391131666]
# computed_metrics: [0.5449408052154988]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.4641461455511845]
# computed_metrics: [0.4641461455511845]
# computed_metrics: [0.5701938460354313]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.46006317918323525]
# computed_metrics: [0.46006317918323525]
# computed_metrics: [0.5487801982292829]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.45882225443175967]
# computed_metrics: [0.45882225443175967]
# computed_metrics: [0.5725321507254743]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.4423006242565097]
# computed_metrics: [0.4423006242565097]
# computed_metrics: [0.5568953126793275]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.4455565534626395]
# computed_metrics: [0.4455565534626395]
# computed_metrics: [0.5395640142494724]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.4327166989397348]
# computed_metrics: [0.4327166989397348]
# computed_metrics: [0.5492812829853068]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.42671330211003305]
# computed_metrics: [0.42671330211003305]
# computed_metrics: [0.533373343898354]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.4493600391008639]
# computed_metrics: [0.4493600391008639]
# computed_metrics: [0.5638995645656835]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.46435352848163153]
# computed_metrics: [0.46435352848163153]
# computed_metrics: [0.5685429178657456]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.42752861591360614]
# computed_metrics: [0.42752861591360614]
# computed_metrics: [0.5451165785499389]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.4248872079548799]
# computed_metrics: [0.4248872079548799]
# computed_metrics: [0.5474087982962841]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.41342786861960934]
# computed_metrics: [0.41342786861960934]
# computed_metrics: [0.5346686934102843]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.39865599135030777]
# computed_metrics: [0.39865599135030777]
# computed_metrics: [0.5284874594656581]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.404170406305199]
# computed_metrics: [0.404170406305199]
# computed_metrics: [0.5206674197627301]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.39025887897014205]
# computed_metrics: [0.39025887897014205]
# computed_metrics: [0.5299992491746361]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.40395023625509835]
# computed_metrics: [0.40395023625509835]
# computed_metrics: [0.5295914954316776]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.4125662286278817]
# computed_metrics: [0.4125662286278817]
# computed_metrics: [0.5650369235929068]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.40367352172032606]
# computed_metrics: [0.40367352172032606]
# computed_metrics: [0.5250091948715988]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.4444765349104811]
# computed_metrics: [0.4444765349104811]
# computed_metrics: [0.5692441233493879]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.3936413886942923]
# computed_metrics: [0.3936413886942923]
# computed_metrics: [0.5330289413037909]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.4007060005811115]
# computed_metrics: [0.4007060005811115]
# computed_metrics: [0.514200795921469]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.43946354219737177]
# computed_metrics: [0.43946354219737177]
# computed_metrics: [0.5625190399322173]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.3841299419068567]
# computed_metrics: [0.3841299419068567]
# computed_metrics: [0.5305255040856353]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.42209615975666437]
# computed_metrics: [0.42209615975666437]
# computed_metrics: [0.5421967547852284]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.40058445921227176]
# computed_metrics: [0.40058445921227176]
# computed_metrics: [0.5268538479210914]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.4406895531515889]
# computed_metrics: [0.4406895531515889]
# computed_metrics: [0.5419955904251514]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.42898107075098996]
# computed_metrics: [0.42898107075098996]
# computed_metrics: [0.5619835208260043]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4001642090349229]
# computed_metrics: [0.4001642090349229]
# computed_metrics: [0.5552305180985629]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.41343572108362064]
# computed_metrics: [0.41343572108362064]
# computed_metrics: [0.5173182548192514]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.4018609391495081]
# computed_metrics: [0.4018609391495081]
# computed_metrics: [0.5131888985238714]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.3849249470378744]
# computed_metrics: [0.3849249470378744]
# computed_metrics: [0.530391183836138]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.40573543764321207]
# computed_metrics: [0.40573543764321207]
# computed_metrics: [0.5471975498237152]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.3683868200181188]
# computed_metrics: [0.3683868200181188]
# computed_metrics: [0.5240778614879831]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.3696946435162245]
# computed_metrics: [0.3696946435162245]
# computed_metrics: [0.5203203363067251]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.37880332839712455]
# computed_metrics: [0.37880332839712455]
# computed_metrics: [0.5082519061473939]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.3818033821866971]
# computed_metrics: [0.3818033821866971]
# computed_metrics: [0.5110302396268332]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.38275690522759553]
# computed_metrics: [0.38275690522759553]
# computed_metrics: [0.5297019033439414]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.37607346966041644]
# computed_metrics: [0.37607346966041644]
# computed_metrics: [0.5313150505352717]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.3877122814954514]
# computed_metrics: [0.3877122814954514]
# computed_metrics: [0.5327596180139906]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.3661792964852012]
# computed_metrics: [0.3661792964852012]
# computed_metrics: [0.5167183803498724]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.37604775660595685]
# computed_metrics: [0.37604775660595685]
# computed_metrics: [0.5492040801141013]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.3758190219604013]
# computed_metrics: [0.3758190219604013]
# computed_metrics: [0.5352064231938545]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.39216939854267974]
# computed_metrics: [0.39216939854267974]
# computed_metrics: [0.5252521644313073]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.36473104603558093]
# computed_metrics: [0.36473104603558093]
# computed_metrics: [0.5343406529314974]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.3728808246914374]
# computed_metrics: [0.3728808246914374]
# computed_metrics: [0.5309942185541586]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.3498063339440015]
# computed_metrics: [0.3498063339440015]
# computed_metrics: [0.5271329877067925]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.34062994389088547]
# computed_metrics: [0.34062994389088547]
# computed_metrics: [0.5330559343914403]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.34095942812955415]
# computed_metrics: [0.34095942812955415]
# computed_metrics: [0.5191087796161316]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.38757665744238323]
# computed_metrics: [0.38757665744238323]
# computed_metrics: [0.5641475625602236]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.3457474800407369]
# computed_metrics: [0.3457474800407369]
# computed_metrics: [0.5035081300080166]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.3379837814847513]
# computed_metrics: [0.3379837814847513]
# computed_metrics: [0.5192555522095309]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.31561211163393177]
# computed_metrics: [0.31561211163393177]
# computed_metrics: [0.4988374987404905]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.32629088159256964]
# computed_metrics: [0.32629088159256964]
# computed_metrics: [0.5220847092925434]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.33125162197728175]
# computed_metrics: [0.33125162197728175]
# computed_metrics: [0.4990322371627668]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.3594671610251922]
# computed_metrics: [0.3594671610251922]
# computed_metrics: [0.5375542047847311]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.38822414136083655]
# computed_metrics: [0.38822414136083655]
# computed_metrics: [0.5619858825697149]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.39082806082433724]
# computed_metrics: [0.39082806082433724]
# computed_metrics: [0.5525360175383449]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.38760488964535234]
# computed_metrics: [0.38760488964535234]
# computed_metrics: [0.548997752802612]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.3594681142805824]
# computed_metrics: [0.3594681142805824]
# computed_metrics: [0.5282953793482289]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.31867778164483207]
# computed_metrics: [0.31867778164483207]
# computed_metrics: [0.4872194599740285]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.3348305317681114]
# computed_metrics: [0.3348305317681114]
# computed_metrics: [0.528607392622222]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.35936557735193886]
# computed_metrics: [0.35936557735193886]
# computed_metrics: [0.5482437989985927]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.48629816357468675]
# computed_metrics: [0.48629816357468675]
# computed_metrics: [0.6386148613995802]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.4249929700414135]
# computed_metrics: [0.4249929700414135]
# computed_metrics: [0.5937736118371787]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.41181505537637997]
# computed_metrics: [0.41181505537637997]
# computed_metrics: [0.5726177735508069]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.42941536315089657]
# computed_metrics: [0.42941536315089657]
# computed_metrics: [0.5565618430913204]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.45167838540796534]
# computed_metrics: [0.45167838540796534]
# computed_metrics: [0.6282584788747732]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.3941100572030931]
# computed_metrics: [0.3941100572030931]
# computed_metrics: [0.5437680776083268]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.3916126848111337]
# computed_metrics: [0.3916126848111337]
# computed_metrics: [0.5922478923158487]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.3610584107050261]
# computed_metrics: [0.3610584107050261]
# computed_metrics: [0.5024632792731916]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.33894879118595195]
# computed_metrics: [0.33894879118595195]
# computed_metrics: [0.5169968132841488]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.3702569892138436]
# computed_metrics: [0.3702569892138436]
# computed_metrics: [0.5141340866606439]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.37034136085913705]
# computed_metrics: [0.37034136085913705]
# computed_metrics: [0.5165309970152693]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.3470051846973543]
# computed_metrics: [0.3470051846973543]
# computed_metrics: [0.5150899849825167]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.30843529120876145]
# computed_metrics: [0.30843529120876145]
# computed_metrics: [0.5129692873552372]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.2898176269521533]
# computed_metrics: [0.2898176269521533]
# computed_metrics: [0.49327540454465546]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.29470106099330856]
# computed_metrics: [0.29470106099330856]
# computed_metrics: [0.4953679164113786]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.3309888226963376]
# computed_metrics: [0.3309888226963376]
# computed_metrics: [0.5418874209498589]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.3156343214419486]
# computed_metrics: [0.3156343214419486]
# computed_metrics: [0.5202988011529998]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.28347633489934954]
# computed_metrics: [0.28347633489934954]
# computed_metrics: [0.5135565592530644]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.2997536341285195]
# computed_metrics: [0.2997536341285195]
# computed_metrics: [0.5095312518589414]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.37256103161583126]
# computed_metrics: [0.37256103161583126]
# computed_metrics: [0.5608749796737423]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.3826855175879245]
# computed_metrics: [0.3826855175879245]
# computed_metrics: [0.5686330216282157]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.33833492795646875]
# computed_metrics: [0.33833492795646875]
# computed_metrics: [0.5608609049096991]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.3279114221022388]
# computed_metrics: [0.3279114221022388]
# computed_metrics: [0.5279604546713615]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.3341082774785968]
# computed_metrics: [0.3341082774785968]
# computed_metrics: [0.5557090111894236]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.3130739184799472]
# computed_metrics: [0.3130739184799472]
# computed_metrics: [0.5359122300917258]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.2804943564818263]
# computed_metrics: [0.2804943564818263]
# computed_metrics: [0.5257141929622721]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.2843449870748319]
# computed_metrics: [0.2843449870748319]
# computed_metrics: [0.5208988021971148]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.29600064777248686]
# computed_metrics: [0.29600064777248686]
# computed_metrics: [0.5247153701698178]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.315700467343261]
# computed_metrics: [0.315700467343261]
# computed_metrics: [0.525949738139601]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.2952937320870466]
# computed_metrics: [0.2952937320870466]
# computed_metrics: [0.5317951462850881]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.263823863053045]
# computed_metrics: [0.263823863053045]
# computed_metrics: [0.5121984692052289]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.27750662113086]
# computed_metrics: [0.27750662113086]
# computed_metrics: [0.5271903381188888]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.29608203141218087]
# computed_metrics: [0.29608203141218087]
# computed_metrics: [0.5502731214238566]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.32495827757185475]
# computed_metrics: [0.32495827757185475]
# computed_metrics: [0.5642229096190597]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.27944282119451735]
# computed_metrics: [0.27944282119451735]
# computed_metrics: [0.5345138096209501]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.27951954672725887]
# computed_metrics: [0.27951954672725887]
# computed_metrics: [0.5228192632973644]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.31999983490940653]
# computed_metrics: [0.31999983490940653]
# computed_metrics: [0.5301905929111917]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.3730719155541264]
# computed_metrics: [0.3730719155541264]
# computed_metrics: [0.5598757039457745]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.35766887319679036]
# computed_metrics: [0.35766887319679036]
# computed_metrics: [0.548942209235596]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.30170446403283097]
# computed_metrics: [0.30170446403283097]
# computed_metrics: [0.5119295927371904]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.3151355043076613]
# computed_metrics: [0.3151355043076613]
# computed_metrics: [0.5354009514245817]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.36657603986419973]
# computed_metrics: [0.36657603986419973]
# computed_metrics: [0.5737751025535381]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.40525058947367565]
# computed_metrics: [0.40525058947367565]
# computed_metrics: [0.6201788959941194]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3461236492803197]
# computed_metrics: [0.3461236492803197]
# computed_metrics: [0.5787261856683414]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.34109963793663306]
# computed_metrics: [0.34109963793663306]
# computed_metrics: [0.571629535287813]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.34915531556668333]
# computed_metrics: [0.34915531556668333]
# computed_metrics: [0.536821980854809]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.3673092246263837]
# computed_metrics: [0.3673092246263837]
# computed_metrics: [0.5440678491999212]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.39505889580546155]
# computed_metrics: [0.39505889580546155]
# computed_metrics: [0.5712658172967993]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.4464806309306098]
# computed_metrics: [0.4464806309306098]
# computed_metrics: [0.6092911834355003]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.33367405278278833]
# computed_metrics: [0.33367405278278833]
# computed_metrics: [0.5402127387969655]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.31220740243254375]
# computed_metrics: [0.31220740243254375]
# computed_metrics: [0.5347743135419534]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.3426547754152177]
# computed_metrics: [0.3426547754152177]
# computed_metrics: [0.5998668541201032]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.3903073389523066]
# computed_metrics: [0.3903073389523066]
# computed_metrics: [0.5867756567391748]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.35721835221775394]
# computed_metrics: [0.35721835221775394]
# computed_metrics: [0.5587973979552062]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3057250907303438]
# computed_metrics: [0.3057250907303438]
# computed_metrics: [0.5565683527785652]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.3442154825908505]
# computed_metrics: [0.3442154825908505]
# computed_metrics: [0.5591332721276198]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.3067493284373913]
# computed_metrics: [0.3067493284373913]
# computed_metrics: [0.5231914159250336]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.2729369409056723]
# computed_metrics: [0.2729369409056723]
# computed_metrics: [0.518030764175867]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.28989274107931723]
# computed_metrics: [0.28989274107931723]
# computed_metrics: [0.5574978676424357]
# 8.606226228460034

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.28989274107931723]
# computed_metrics: [0.5574978676424357]
# computed_metrics: [0.548304929205539]
# {'mean-mean_absolute_error': 0.548304929205539}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.95088476, 0.0)
# SpearmanrResult(correlation=0.9543869187409901, pvalue=0.0)
# (0.7947548, 8.462214975917026e-40)
# SpearmanrResult(correlation=0.8088365729416074, pvalue=3.281062330389108e-42)
# (0.81107396, 1.3014394716344831e-42)
# SpearmanrResult(correlation=0.8105353965707176, pvalue=1.627714970898054e-42)
