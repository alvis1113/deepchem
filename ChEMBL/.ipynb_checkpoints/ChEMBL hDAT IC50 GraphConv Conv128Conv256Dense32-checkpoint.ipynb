# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gp1 = GraphPool(in_layers=[batch_norm1, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp2 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm3 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm3, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.767 s
# TIMING: dataset construction took 3.217 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.457 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.238 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.226 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 128
C2_filtnum = 128
D_nodenum = 32

graph_structure = 'GC{0}_GP_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.8619149696600994]
# computed_metrics: [2.8619149696600994]
# computed_metrics: [2.8458310569865946]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.956636215757199]
# computed_metrics: [1.956636215757199]
# computed_metrics: [1.9385806876542326]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.3600436932245252]
# computed_metrics: [1.3600436932245252]
# computed_metrics: [1.3325436985788712]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0926467192345404]
# computed_metrics: [1.0926467192345404]
# computed_metrics: [1.0759311406516967]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9887915758754027]
# computed_metrics: [0.9887915758754027]
# computed_metrics: [0.9954689370062985]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9374631092234474]
# computed_metrics: [0.9374631092234474]
# computed_metrics: [0.9513401981320225]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9317215301884703]
# computed_metrics: [0.9317215301884703]
# computed_metrics: [0.9560809981860995]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9016302108758599]
# computed_metrics: [0.9016302108758599]
# computed_metrics: [0.9312668001702326]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8850743153837946]
# computed_metrics: [0.8850743153837946]
# computed_metrics: [0.9208767100270718]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8656994356850062]
# computed_metrics: [0.8656994356850062]
# computed_metrics: [0.9048624874261243]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.857191958055372]
# computed_metrics: [0.857191958055372]
# computed_metrics: [0.8940210889957853]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8580914894100705]
# computed_metrics: [0.8580914894100705]
# computed_metrics: [0.8915304663509412]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8442546060825069]
# computed_metrics: [0.8442546060825069]
# computed_metrics: [0.8835307048151262]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8438762241045183]
# computed_metrics: [0.8438762241045183]
# computed_metrics: [0.8912451487044737]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8290463475833956]
# computed_metrics: [0.8290463475833956]
# computed_metrics: [0.8708949132344922]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8121447538690459]
# computed_metrics: [0.8121447538690459]
# computed_metrics: [0.83997230082221]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8102035572021948]
# computed_metrics: [0.8102035572021948]
# computed_metrics: [0.8563083729692204]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7930034244758978]
# computed_metrics: [0.7930034244758978]
# computed_metrics: [0.8296853566481425]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7843475776352729]
# computed_metrics: [0.7843475776352729]
# computed_metrics: [0.8225104468420149]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7723377579019092]
# computed_metrics: [0.7723377579019092]
# computed_metrics: [0.8085822934367526]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7659065961684661]
# computed_metrics: [0.7659065961684661]
# computed_metrics: [0.8013162916373181]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.750933934159654]
# computed_metrics: [0.750933934159654]
# computed_metrics: [0.7872694938804583]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7467611081873514]
# computed_metrics: [0.7467611081873514]
# computed_metrics: [0.7724167731656234]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7518311863573159]
# computed_metrics: [0.7518311863573159]
# computed_metrics: [0.7718143547141614]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7320302077509335]
# computed_metrics: [0.7320302077509335]
# computed_metrics: [0.753370998388128]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.726920184322125]
# computed_metrics: [0.726920184322125]
# computed_metrics: [0.7575568382211403]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7197968140334609]
# computed_metrics: [0.7197968140334609]
# computed_metrics: [0.7610462962118631]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.7191377605307372]
# computed_metrics: [0.7191377605307372]
# computed_metrics: [0.7501459099313453]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.7024772654717089]
# computed_metrics: [0.7024772654717089]
# computed_metrics: [0.7341612039866797]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6858739650084991]
# computed_metrics: [0.6858739650084991]
# computed_metrics: [0.7204407519560962]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6798789355272723]
# computed_metrics: [0.6798789355272723]
# computed_metrics: [0.7101708904535253]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.665303133755453]
# computed_metrics: [0.665303133755453]
# computed_metrics: [0.6974386261946367]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6541523551499416]
# computed_metrics: [0.6541523551499416]
# computed_metrics: [0.6978062171759486]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6464173602973181]
# computed_metrics: [0.6464173602973181]
# computed_metrics: [0.6917410274325122]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.634984442423598]
# computed_metrics: [0.634984442423598]
# computed_metrics: [0.6737674272534172]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6260715985373334]
# computed_metrics: [0.6260715985373334]
# computed_metrics: [0.6553631290866986]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6095468314116358]
# computed_metrics: [0.6095468314116358]
# computed_metrics: [0.6471084015513562]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6070857199944977]
# computed_metrics: [0.6070857199944977]
# computed_metrics: [0.6496054321682947]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.60317447926903]
# computed_metrics: [0.60317447926903]
# computed_metrics: [0.6400038219212247]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5904923230670833]
# computed_metrics: [0.5904923230670833]
# computed_metrics: [0.6272974589746886]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5947694934197318]
# computed_metrics: [0.5947694934197318]
# computed_metrics: [0.6304435739796503]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5841930043930441]
# computed_metrics: [0.5841930043930441]
# computed_metrics: [0.6235497790507488]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5978597338663222]
# computed_metrics: [0.5978597338663222]
# computed_metrics: [0.6058373244991738]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5807801344411294]
# computed_metrics: [0.5807801344411294]
# computed_metrics: [0.6256008955055563]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5895693816951381]
# computed_metrics: [0.5895693816951381]
# computed_metrics: [0.6370413636958379]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5670117248110533]
# computed_metrics: [0.5670117248110533]
# computed_metrics: [0.5971245728882162]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.555711323943293]
# computed_metrics: [0.555711323943293]
# computed_metrics: [0.5893719271200254]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5569975794890276]
# computed_metrics: [0.5569975794890276]
# computed_metrics: [0.6038368710435463]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5465625810655961]
# computed_metrics: [0.5465625810655961]
# computed_metrics: [0.5921633604030908]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5360089137674895]
# computed_metrics: [0.5360089137674895]
# computed_metrics: [0.5792050284463649]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5244468873714833]
# computed_metrics: [0.5244468873714833]
# computed_metrics: [0.5687690582475797]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5431338940119835]
# computed_metrics: [0.5431338940119835]
# computed_metrics: [0.5814473629954832]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5650763968475767]
# computed_metrics: [0.5650763968475767]
# computed_metrics: [0.5937055010447992]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5609756189058726]
# computed_metrics: [0.5609756189058726]
# computed_metrics: [0.5997193201832411]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5324676179068516]
# computed_metrics: [0.5324676179068516]
# computed_metrics: [0.5755223568045599]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5396294239765081]
# computed_metrics: [0.5396294239765081]
# computed_metrics: [0.5988468003145743]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.6395747158700146]
# computed_metrics: [0.6395747158700146]
# computed_metrics: [0.7186381206102654]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5392078790878677]
# computed_metrics: [0.5392078790878677]
# computed_metrics: [0.6103212090068901]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5465804799661972]
# computed_metrics: [0.5465804799661972]
# computed_metrics: [0.60511555613433]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.6197753521946402]
# computed_metrics: [0.6197753521946402]
# computed_metrics: [0.6723413390343486]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.587071345991948]
# computed_metrics: [0.587071345991948]
# computed_metrics: [0.6276179018691591]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.523690672913964]
# computed_metrics: [0.523690672913964]
# computed_metrics: [0.5877932129518045]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5134533971352553]
# computed_metrics: [0.5134533971352553]
# computed_metrics: [0.610723953253081]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.4968225854315754]
# computed_metrics: [0.4968225854315754]
# computed_metrics: [0.5770096755615343]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5077073443775237]
# computed_metrics: [0.5077073443775237]
# computed_metrics: [0.5874959206665434]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.49232135408548405]
# computed_metrics: [0.49232135408548405]
# computed_metrics: [0.596312818016526]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.47318931039116785]
# computed_metrics: [0.47318931039116785]
# computed_metrics: [0.5667323335208991]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.47736575635961376]
# computed_metrics: [0.47736575635961376]
# computed_metrics: [0.5646589544749739]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5219935831403515]
# computed_metrics: [0.5219935831403515]
# computed_metrics: [0.5834167503839287]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5756421872880806]
# computed_metrics: [0.5756421872880806]
# computed_metrics: [0.6566289466085365]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.4777749342929587]
# computed_metrics: [0.4777749342929587]
# computed_metrics: [0.5604916527803497]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.48096124904397297]
# computed_metrics: [0.48096124904397297]
# computed_metrics: [0.547361677222143]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.48179710457222596]
# computed_metrics: [0.48179710457222596]
# computed_metrics: [0.5595276392956342]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5042742405943604]
# computed_metrics: [0.5042742405943604]
# computed_metrics: [0.5901191944633722]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.47551994346888093]
# computed_metrics: [0.47551994346888093]
# computed_metrics: [0.5588067655505994]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.45199692523181884]
# computed_metrics: [0.45199692523181884]
# computed_metrics: [0.5667987289757533]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.4667150604666413]
# computed_metrics: [0.4667150604666413]
# computed_metrics: [0.5714415534974487]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.4812451903820137]
# computed_metrics: [0.4812451903820137]
# computed_metrics: [0.5839295982049097]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.4409375411685788]
# computed_metrics: [0.4409375411685788]
# computed_metrics: [0.5429470635182072]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.42889788910685583]
# computed_metrics: [0.42889788910685583]
# computed_metrics: [0.5504510144679844]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.42878770782905573]
# computed_metrics: [0.42878770782905573]
# computed_metrics: [0.5447575913572784]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4331284980037012]
# computed_metrics: [0.4331284980037012]
# computed_metrics: [0.5503048823516866]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.41898129592976596]
# computed_metrics: [0.41898129592976596]
# computed_metrics: [0.540327868643444]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.41867564591863793]
# computed_metrics: [0.41867564591863793]
# computed_metrics: [0.560276390697253]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.43733440972559934]
# computed_metrics: [0.43733440972559934]
# computed_metrics: [0.5491141914320142]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.4643165369511746]
# computed_metrics: [0.4643165369511746]
# computed_metrics: [0.5813098687543118]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.44421151623917726]
# computed_metrics: [0.44421151623917726]
# computed_metrics: [0.5492958769090875]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4109644004759384]
# computed_metrics: [0.4109644004759384]
# computed_metrics: [0.5616604895781949]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.40631001421861823]
# computed_metrics: [0.40631001421861823]
# computed_metrics: [0.5393864992240198]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.41218374479998]
# computed_metrics: [0.41218374479998]
# computed_metrics: [0.5392306477997444]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.40178852691932404]
# computed_metrics: [0.40178852691932404]
# computed_metrics: [0.5440604890110976]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.4155950223425899]
# computed_metrics: [0.4155950223425899]
# computed_metrics: [0.5471068636567501]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.41710531877433277]
# computed_metrics: [0.41710531877433277]
# computed_metrics: [0.5450994502900552]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.41689945509632537]
# computed_metrics: [0.41689945509632537]
# computed_metrics: [0.5650169427622013]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.41696162543476584]
# computed_metrics: [0.41696162543476584]
# computed_metrics: [0.5523275789117591]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.4691033623652221]
# computed_metrics: [0.4691033623652221]
# computed_metrics: [0.5723176068428824]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.543705712748462]
# computed_metrics: [0.543705712748462]
# computed_metrics: [0.6544429916228124]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.45628559204054553]
# computed_metrics: [0.45628559204054553]
# computed_metrics: [0.5919095226690901]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.4484796784170817]
# computed_metrics: [0.4484796784170817]
# computed_metrics: [0.5463687888306348]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.42058786966109674]
# computed_metrics: [0.42058786966109674]
# computed_metrics: [0.5667800773960294]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.4403063365070593]
# computed_metrics: [0.4403063365070593]
# computed_metrics: [0.580401332174602]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.4671709266852103]
# computed_metrics: [0.4671709266852103]
# computed_metrics: [0.6067946768102919]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.5122542363305679]
# computed_metrics: [0.5122542363305679]
# computed_metrics: [0.644119311257152]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5030383469542523]
# computed_metrics: [0.5030383469542523]
# computed_metrics: [0.6436598280789855]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.6002820744297274]
# computed_metrics: [0.6002820744297274]
# computed_metrics: [0.70077386103517]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.585976607752105]
# computed_metrics: [0.585976607752105]
# computed_metrics: [0.6960846339160093]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.6447621899668805]
# computed_metrics: [0.6447621899668805]
# computed_metrics: [0.7407932393068408]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.6906255603110284]
# computed_metrics: [0.6906255603110284]
# computed_metrics: [0.7874980494695053]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.5073533600208945]
# computed_metrics: [0.5073533600208945]
# computed_metrics: [0.5724519600344212]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.4717021615171557]
# computed_metrics: [0.4717021615171557]
# computed_metrics: [0.5507835587926966]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.4296859666881755]
# computed_metrics: [0.4296859666881755]
# computed_metrics: [0.5128533331939191]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.5324517786965003]
# computed_metrics: [0.5324517786965003]
# computed_metrics: [0.6513901387852999]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.4843155813694535]
# computed_metrics: [0.4843155813694535]
# computed_metrics: [0.6126042431372036]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.5326842274254948]
# computed_metrics: [0.5326842274254948]
# computed_metrics: [0.6791380327229697]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.4618435617499006]
# computed_metrics: [0.4618435617499006]
# computed_metrics: [0.6043391328424782]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4038162398637017]
# computed_metrics: [0.4038162398637017]
# computed_metrics: [0.5439001711794854]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.3870577234321135]
# computed_metrics: [0.3870577234321135]
# computed_metrics: [0.5410523250089571]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.3870749774465]
# computed_metrics: [0.3870749774465]
# computed_metrics: [0.5311482441145582]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.4015163217512797]
# computed_metrics: [0.4015163217512797]
# computed_metrics: [0.5314177166456959]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.3916849273158882]
# computed_metrics: [0.3916849273158882]
# computed_metrics: [0.528759644695439]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.37406294250907]
# computed_metrics: [0.37406294250907]
# computed_metrics: [0.514684653607311]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.3501561084106173]
# computed_metrics: [0.3501561084106173]
# computed_metrics: [0.5107287897518903]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.3668685975279538]
# computed_metrics: [0.3668685975279538]
# computed_metrics: [0.5556162384473841]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.37886430205596927]
# computed_metrics: [0.37886430205596927]
# computed_metrics: [0.5780970423015119]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.3846881471053218]
# computed_metrics: [0.3846881471053218]
# computed_metrics: [0.5786684070304112]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.3905522688095301]
# computed_metrics: [0.3905522688095301]
# computed_metrics: [0.5782269211061183]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.348022007974677]
# computed_metrics: [0.348022007974677]
# computed_metrics: [0.5519710394295061]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.35611768246689646]
# computed_metrics: [0.35611768246689646]
# computed_metrics: [0.5410060942089847]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.33811457950604235]
# computed_metrics: [0.33811457950604235]
# computed_metrics: [0.5230305307896026]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.35202812023861124]
# computed_metrics: [0.35202812023861124]
# computed_metrics: [0.5308578550916592]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.38851136551937754]
# computed_metrics: [0.38851136551937754]
# computed_metrics: [0.5433939722593051]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.39087680875462993]
# computed_metrics: [0.39087680875462993]
# computed_metrics: [0.5446384451945463]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.40848256014456213]
# computed_metrics: [0.40848256014456213]
# computed_metrics: [0.559389000733086]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.3596937397579245]
# computed_metrics: [0.3596937397579245]
# computed_metrics: [0.5235989343110801]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.35024272879312673]
# computed_metrics: [0.35024272879312673]
# computed_metrics: [0.5163256548565739]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3587820706481881]
# computed_metrics: [0.3587820706481881]
# computed_metrics: [0.5540024513291699]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.35241186617685505]
# computed_metrics: [0.35241186617685505]
# computed_metrics: [0.5698311070604443]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.3944320687392456]
# computed_metrics: [0.3944320687392456]
# computed_metrics: [0.5852768778716251]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.4842219271310721]
# computed_metrics: [0.4842219271310721]
# computed_metrics: [0.6689918633260925]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.4433368740434961]
# computed_metrics: [0.4433368740434961]
# computed_metrics: [0.6281021716026962]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.4075639142408039]
# computed_metrics: [0.4075639142408039]
# computed_metrics: [0.6141382291657315]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.3579691187419899]
# computed_metrics: [0.3579691187419899]
# computed_metrics: [0.557977317333056]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3333746514510234]
# computed_metrics: [0.3333746514510234]
# computed_metrics: [0.5463823989103156]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.3596487987783292]
# computed_metrics: [0.3596487987783292]
# computed_metrics: [0.5575346151182106]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.3627951715343003]
# computed_metrics: [0.3627951715343003]
# computed_metrics: [0.5453676563020282]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.3657250044857838]
# computed_metrics: [0.3657250044857838]
# computed_metrics: [0.5442424564266691]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.3296626702860443]
# computed_metrics: [0.3296626702860443]
# computed_metrics: [0.5429019425913099]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.3007099559976626]
# computed_metrics: [0.3007099559976626]
# computed_metrics: [0.5209299612420575]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.3200096598567513]
# computed_metrics: [0.3200096598567513]
# computed_metrics: [0.5443376340470867]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.3333479225158884]
# computed_metrics: [0.3333479225158884]
# computed_metrics: [0.5706487631660101]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.3671525483954262]
# computed_metrics: [0.3671525483954262]
# computed_metrics: [0.6002532266986133]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.36272045566079497]
# computed_metrics: [0.36272045566079497]
# computed_metrics: [0.601498242362182]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.32021803812076355]
# computed_metrics: [0.32021803812076355]
# computed_metrics: [0.5658385700920749]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.2941841555629056]
# computed_metrics: [0.2941841555629056]
# computed_metrics: [0.5371492389092801]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.32470828225487885]
# computed_metrics: [0.32470828225487885]
# computed_metrics: [0.5450240946233933]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.3355927537203838]
# computed_metrics: [0.3355927537203838]
# computed_metrics: [0.5523392433428533]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.3257184365425273]
# computed_metrics: [0.3257184365425273]
# computed_metrics: [0.544938678202143]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3471235728465194]
# computed_metrics: [0.3471235728465194]
# computed_metrics: [0.5327652773335131]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.29978336412079815]
# computed_metrics: [0.29978336412079815]
# computed_metrics: [0.5237518257588213]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.28705066196503204]
# computed_metrics: [0.28705066196503204]
# computed_metrics: [0.5182498011453799]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.32900331052757037]
# computed_metrics: [0.32900331052757037]
# computed_metrics: [0.554259987083747]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.3970186955543626]
# computed_metrics: [0.3970186955543626]
# computed_metrics: [0.6265802719482535]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3815204017039558]
# computed_metrics: [0.3815204017039558]
# computed_metrics: [0.6299880927043763]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.38866421438773185]
# computed_metrics: [0.38866421438773185]
# computed_metrics: [0.6247404477872862]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.3296800159429257]
# computed_metrics: [0.3296800159429257]
# computed_metrics: [0.5750790136184366]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.2975847235612915]
# computed_metrics: [0.2975847235612915]
# computed_metrics: [0.5650968226877584]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.3017147752976132]
# computed_metrics: [0.3017147752976132]
# computed_metrics: [0.5382237350988202]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.35919179802893286]
# computed_metrics: [0.35919179802893286]
# computed_metrics: [0.579511097330138]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.39578109982226184]
# computed_metrics: [0.39578109982226184]
# computed_metrics: [0.5949446039620256]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.4233660809427518]
# computed_metrics: [0.4233660809427518]
# computed_metrics: [0.6045501490705077]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.34790010486028367]
# computed_metrics: [0.34790010486028367]
# computed_metrics: [0.5224841668028121]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.4202596734972431]
# computed_metrics: [0.4202596734972431]
# computed_metrics: [0.593060238686896]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3398430583248551]
# computed_metrics: [0.3398430583248551]
# computed_metrics: [0.5538581321418398]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.3237809578251604]
# computed_metrics: [0.3237809578251604]
# computed_metrics: [0.5559676517261317]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3948053253296512]
# computed_metrics: [0.3948053253296512]
# computed_metrics: [0.5869544025921208]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.40401375333948963]
# computed_metrics: [0.40401375333948963]
# computed_metrics: [0.6201849590464129]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3927676661469865]
# computed_metrics: [0.3927676661469865]
# computed_metrics: [0.5855089749149481]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3090882799631947]
# computed_metrics: [0.3090882799631947]
# computed_metrics: [0.5400190233537635]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.34394016573676284]
# computed_metrics: [0.34394016573676284]
# computed_metrics: [0.5764921635355789]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.401251526632545]
# computed_metrics: [0.401251526632545]
# computed_metrics: [0.6076571201295163]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.4021101913991932]
# computed_metrics: [0.4021101913991932]
# computed_metrics: [0.6177458714190722]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.3072283814375659]
# computed_metrics: [0.3072283814375659]
# computed_metrics: [0.5107767571902514]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.3140279351895232]
# computed_metrics: [0.3140279351895232]
# computed_metrics: [0.5246864864807906]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.4010713161751164]
# computed_metrics: [0.4010713161751164]
# computed_metrics: [0.5989301411039203]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.4398275046157918]
# computed_metrics: [0.4398275046157918]
# computed_metrics: [0.6248792380897741]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.35608922413795474]
# computed_metrics: [0.35608922413795474]
# computed_metrics: [0.5785279117242923]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.32075023171508465]
# computed_metrics: [0.32075023171508465]
# computed_metrics: [0.5675597483127456]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.327241786701059]
# computed_metrics: [0.327241786701059]
# computed_metrics: [0.571872770065455]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.38877401738386685]
# computed_metrics: [0.38877401738386685]
# computed_metrics: [0.5933808216836951]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.3293014318866483]
# computed_metrics: [0.3293014318866483]
# computed_metrics: [0.5536673247704437]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.31026406383424937]
# computed_metrics: [0.31026406383424937]
# computed_metrics: [0.5307519474215695]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.3494925359991603]
# computed_metrics: [0.3494925359991603]
# computed_metrics: [0.5656986582085944]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.33692670616271464]
# computed_metrics: [0.33692670616271464]
# computed_metrics: [0.5849794453661653]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.2825092679809574]
# computed_metrics: [0.2825092679809574]
# computed_metrics: [0.5534529449841729]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.3032079286066602]
# computed_metrics: [0.3032079286066602]
# computed_metrics: [0.5731190681945605]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.34311778954351135]
# computed_metrics: [0.34311778954351135]
# computed_metrics: [0.5657345263219093]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.31788572293380113]
# computed_metrics: [0.31788572293380113]
# computed_metrics: [0.5503654119049808]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.28376763987568887]
# computed_metrics: [0.28376763987568887]
# computed_metrics: [0.5361782568987399]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.3416826684971157]
# computed_metrics: [0.3416826684971157]
# computed_metrics: [0.5736007037096353]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.3445134329429038]
# computed_metrics: [0.3445134329429038]
# computed_metrics: [0.5700979733812939]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.34591543492825455]
# computed_metrics: [0.34591543492825455]
# computed_metrics: [0.6151538316506839]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.2755313301355619]
# computed_metrics: [0.2755313301355619]
# computed_metrics: [0.5515292999709421]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.2991008581980554]
# computed_metrics: [0.2991008581980554]
# computed_metrics: [0.5558325780645629]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.33998589953389136]
# computed_metrics: [0.33998589953389136]
# computed_metrics: [0.5690158815108376]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.2771597785283052]
# computed_metrics: [0.2771597785283052]
# computed_metrics: [0.5275731880211357]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.29662881912305683]
# computed_metrics: [0.29662881912305683]
# computed_metrics: [0.5395328362620914]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.3395966186396584]
# computed_metrics: [0.3395966186396584]
# computed_metrics: [0.582367700293365]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.33819156665532013]
# computed_metrics: [0.33819156665532013]
# computed_metrics: [0.5903360218116314]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.27681591044336573]
# computed_metrics: [0.27681591044336573]
# computed_metrics: [0.5544267784029936]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.2884248398753689]
# computed_metrics: [0.2884248398753689]
# computed_metrics: [0.5471797482023681]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.32247217757909824]
# computed_metrics: [0.32247217757909824]
# computed_metrics: [0.5777926884873839]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.3108678118588127]
# computed_metrics: [0.3108678118588127]
# computed_metrics: [0.5565725984818198]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.2704405973068262]
# computed_metrics: [0.2704405973068262]
# computed_metrics: [0.5319967682498479]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.315710868405301]
# computed_metrics: [0.315710868405301]
# computed_metrics: [0.5579009318043155]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.35849979768699747]
# computed_metrics: [0.35849979768699747]
# computed_metrics: [0.6162029805932583]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.28596857969934386]
# computed_metrics: [0.28596857969934386]
# computed_metrics: [0.5757318567075114]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.26672368672064406]
# computed_metrics: [0.26672368672064406]
# computed_metrics: [0.5714684915287589]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.34767202352671756]
# computed_metrics: [0.34767202352671756]
# computed_metrics: [0.6032672648922063]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.33682518227219727]
# computed_metrics: [0.33682518227219727]
# computed_metrics: [0.5857003506816985]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.2798481337116531]
# computed_metrics: [0.2798481337116531]
# computed_metrics: [0.5304615649228572]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.33350977536998244]
# computed_metrics: [0.33350977536998244]
# computed_metrics: [0.5512588733166255]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3721572989135597]
# computed_metrics: [0.3721572989135597]
# computed_metrics: [0.5937855077514845]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.34659723579679064]
# computed_metrics: [0.34659723579679064]
# computed_metrics: [0.59990560293062]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.2859340557535841]
# computed_metrics: [0.2859340557535841]
# computed_metrics: [0.5643581161349194]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.27167604635442427]
# computed_metrics: [0.27167604635442427]
# computed_metrics: [0.5645751939845618]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.322134032572473]
# computed_metrics: [0.322134032572473]
# computed_metrics: [0.5758151664821899]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.29471692941928446]
# computed_metrics: [0.29471692941928446]
# computed_metrics: [0.5463402282126884]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.26601854002859104]
# computed_metrics: [0.26601854002859104]
# computed_metrics: [0.5499182458619233]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.2564083410633726]
# computed_metrics: [0.2564083410633726]
# computed_metrics: [0.5199242466704111]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.31381113718801357]
# computed_metrics: [0.31381113718801357]
# computed_metrics: [0.5758086024486032]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.307446137994348]
# computed_metrics: [0.307446137994348]
# computed_metrics: [0.575720231444186]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.23545519512612742]
# computed_metrics: [0.23545519512612742]
# computed_metrics: [0.5484538397626173]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.26861105978378147]
# computed_metrics: [0.26861105978378147]
# computed_metrics: [0.5813611758127101]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3187423618639431]
# computed_metrics: [0.3187423618639431]
# computed_metrics: [0.5809014370033314]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.28684610354057205]
# computed_metrics: [0.28684610354057205]
# computed_metrics: [0.5587441693757071]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.2595855896102524]
# computed_metrics: [0.2595855896102524]
# computed_metrics: [0.529173859863092]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.28942915588339596]
# computed_metrics: [0.28942915588339596]
# computed_metrics: [0.5594635601866232]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.3168338180220921]
# computed_metrics: [0.3168338180220921]
# computed_metrics: [0.5841474992584669]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.24010730738086292]
# computed_metrics: [0.24010730738086292]
# computed_metrics: [0.5441725609082451]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.25463990817108473]
# computed_metrics: [0.25463990817108473]
# computed_metrics: [0.5709383745355738]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.32705398053389906]
# computed_metrics: [0.32705398053389906]
# computed_metrics: [0.5996509411807479]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.2959742897198485]
# computed_metrics: [0.2959742897198485]
# computed_metrics: [0.557736938082255]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.24827083189619834]
# computed_metrics: [0.24827083189619834]
# computed_metrics: [0.5167999117673784]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.31290758453239315]
# computed_metrics: [0.31290758453239315]
# computed_metrics: [0.5541064708783405]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.33103216399949864]
# computed_metrics: [0.33103216399949864]
# computed_metrics: [0.5832669820839252]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.28045912236896253]
# computed_metrics: [0.28045912236896253]
# computed_metrics: [0.554042996893492]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.25638047143531667]
# computed_metrics: [0.25638047143531667]
# computed_metrics: [0.5513222038950744]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.29973052831317415]
# computed_metrics: [0.29973052831317415]
# computed_metrics: [0.5920454033233751]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.32547354535935474]
# computed_metrics: [0.32547354535935474]
# computed_metrics: [0.5749290595974652]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24370207426924473]
# computed_metrics: [0.24370207426924473]
# computed_metrics: [0.512090715729351]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.2904726405228543]
# computed_metrics: [0.2904726405228543]
# computed_metrics: [0.5437332325144351]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.3004844578210369]
# computed_metrics: [0.3004844578210369]
# computed_metrics: [0.5609149892156587]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.2546227199333655]
# computed_metrics: [0.2546227199333655]
# computed_metrics: [0.5542927532809239]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.2654355638809624]
# computed_metrics: [0.2654355638809624]
# computed_metrics: [0.5730183264818359]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.28243795853945824]
# computed_metrics: [0.28243795853945824]
# computed_metrics: [0.5444723454709539]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.29233666201023223]
# computed_metrics: [0.29233666201023223]
# computed_metrics: [0.5618915248625476]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.23117223473864684]
# computed_metrics: [0.23117223473864684]
# computed_metrics: [0.5182116794933057]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.25525430735903615]
# computed_metrics: [0.25525430735903615]
# computed_metrics: [0.5494522921233648]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.27885565244348076]
# computed_metrics: [0.27885565244348076]
# computed_metrics: [0.5667204932812415]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.24976116646290203]
# computed_metrics: [0.24976116646290203]
# computed_metrics: [0.5359595535430891]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.25337105049687775]
# computed_metrics: [0.25337105049687775]
# computed_metrics: [0.555298087892561]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.27008345678238904]
# computed_metrics: [0.27008345678238904]
# computed_metrics: [0.5670032826518618]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.29166675729039676]
# computed_metrics: [0.29166675729039676]
# computed_metrics: [0.5721325076888892]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.2295750966355455]
# computed_metrics: [0.2295750966355455]
# computed_metrics: [0.5251028928012643]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.28527260180674474]
# computed_metrics: [0.28527260180674474]
# computed_metrics: [0.5474190411351584]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.2966630470525343]
# computed_metrics: [0.2966630470525343]
# computed_metrics: [0.5665969420264579]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.26058932199319657]
# computed_metrics: [0.26058932199319657]
# computed_metrics: [0.545400136654668]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.22624348719862614]
# computed_metrics: [0.22624348719862614]
# computed_metrics: [0.5375400073322867]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.35504329382474514]
# computed_metrics: [0.35504329382474514]
# computed_metrics: [0.615001486960908]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.3079147561342206]
# computed_metrics: [0.3079147561342206]
# computed_metrics: [0.5688879540551618]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.23941665630835823]
# computed_metrics: [0.23941665630835823]
# computed_metrics: [0.511827613962443]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.29920769373571376]
# computed_metrics: [0.29920769373571376]
# computed_metrics: [0.572528244359672]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.34137728472222795]
# computed_metrics: [0.34137728472222795]
# computed_metrics: [0.5942271127825565]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.2734492951861529]
# computed_metrics: [0.2734492951861529]
# computed_metrics: [0.5514286565737879]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.26629943441202053]
# computed_metrics: [0.26629943441202053]
# computed_metrics: [0.560195592582158]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.29637085592554874]
# computed_metrics: [0.29637085592554874]
# computed_metrics: [0.5764867100038007]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.2903464391337869]
# computed_metrics: [0.2903464391337869]
# computed_metrics: [0.577040225359906]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.24818218158436464]
# computed_metrics: [0.24818218158436464]
# computed_metrics: [0.544711387533725]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.2558522834274403]
# computed_metrics: [0.2558522834274403]
# computed_metrics: [0.5453481597583872]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.3034715706988698]
# computed_metrics: [0.3034715706988698]
# computed_metrics: [0.5465940957802932]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.2452579307265818]
# computed_metrics: [0.2452579307265818]
# computed_metrics: [0.5567561753667082]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.22030883398546286]
# computed_metrics: [0.22030883398546286]
# computed_metrics: [0.5353319500434612]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.27192651033300275]
# computed_metrics: [0.27192651033300275]
# computed_metrics: [0.5677534423632297]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.30735746480638393]
# computed_metrics: [0.30735746480638393]
# computed_metrics: [0.5884459767592395]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.2755067089358282]
# computed_metrics: [0.2755067089358282]
# computed_metrics: [0.549515863389297]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.2731218288200115]
# computed_metrics: [0.2731218288200115]
# computed_metrics: [0.5288162771586251]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.27752826488877796]
# computed_metrics: [0.27752826488877796]
# computed_metrics: [0.5754096050022927]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.2791148372725156]
# computed_metrics: [0.2791148372725156]
# ...
# computed_metrics: [0.37590140150778567]
# computed_metrics: [0.37590140150778567]
# computed_metrics: [0.6083288466325759]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.3212370944450913]
# computed_metrics: [0.3212370944450913]
# computed_metrics: [0.5865620653200978]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.29228897568457235]
# computed_metrics: [0.29228897568457235]
# computed_metrics: [0.6017897726477986]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.40345841339230415]
# computed_metrics: [0.40345841339230415]
# computed_metrics: [0.6401306746756688]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.3550742722137345]
# computed_metrics: [0.3550742722137345]
# computed_metrics: [0.6370055550036142]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.26871557959961867]
# computed_metrics: [0.26871557959961867]
# computed_metrics: [0.5510812696147209]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.2903389479406955]
# computed_metrics: [0.2903389479406955]
# computed_metrics: [0.590162675363305]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.23607630602368512]
# computed_metrics: [0.23607630602368512]
# computed_metrics: [0.5781951422758391]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.2266213323658135]
# computed_metrics: [0.2266213323658135]
# computed_metrics: [0.570480758928432]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.26648345203739565]
# computed_metrics: [0.26648345203739565]
# computed_metrics: [0.5884765348570453]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.22217360731095231]
# computed_metrics: [0.22217360731095231]
# computed_metrics: [0.5665745199204809]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.24349866081301283]
# computed_metrics: [0.24349866081301283]
# computed_metrics: [0.560462461458054]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.2866946633068083]
# computed_metrics: [0.2866946633068083]
# computed_metrics: [0.5818537424482967]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.21212079254590474]
# computed_metrics: [0.21212079254590474]
# computed_metrics: [0.5757404463350153]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.2549923136725298]
# computed_metrics: [0.2549923136725298]
# computed_metrics: [0.6020711547828965]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.21687060455628707]
# computed_metrics: [0.21687060455628707]
# computed_metrics: [0.5790147094671306]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.22509992024125172]
# computed_metrics: [0.22509992024125172]
# computed_metrics: [0.5574705739338383]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.258434865537987]
# computed_metrics: [0.258434865537987]
# computed_metrics: [0.5747259531191575]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.20557394423179437]
# computed_metrics: [0.20557394423179437]
# computed_metrics: [0.5713395481068022]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.22771859506455194]
# computed_metrics: [0.22771859506455194]
# computed_metrics: [0.5848345227091212]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.18523406155195132]
# computed_metrics: [0.18523406155195132]
# computed_metrics: [0.5547660779183513]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.21756860712639453]
# computed_metrics: [0.21756860712639453]
# computed_metrics: [0.5526180575663869]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.20892013819557065]
# computed_metrics: [0.20892013819557065]
# computed_metrics: [0.5553178018442269]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.1952117460202527]
# computed_metrics: [0.1952117460202527]
# computed_metrics: [0.5662284394111217]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.22852284091686564]
# computed_metrics: [0.22852284091686564]
# computed_metrics: [0.5720593038283361]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.18160831918614523]
# computed_metrics: [0.18160831918614523]
# computed_metrics: [0.5477822189461226]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.23794007561542005]
# computed_metrics: [0.23794007561542005]
# computed_metrics: [0.5586642063506944]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.23341240116964654]
# computed_metrics: [0.23341240116964654]
# computed_metrics: [0.5588562059651014]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.20607085374654127]
# computed_metrics: [0.20607085374654127]
# computed_metrics: [0.5720557799145233]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.25087506688298683]
# computed_metrics: [0.25087506688298683]
# computed_metrics: [0.6007766800223132]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.2050796723092747]
# computed_metrics: [0.2050796723092747]
# computed_metrics: [0.5572236124116147]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.24920294496810094]
# computed_metrics: [0.24920294496810094]
# computed_metrics: [0.559939924722695]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.23969534692454217]
# computed_metrics: [0.23969534692454217]
# computed_metrics: [0.5550457384777641]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.18799165450618582]
# computed_metrics: [0.18799165450618582]
# computed_metrics: [0.5490483572962341]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.23424045077915306]
# computed_metrics: [0.23424045077915306]
# computed_metrics: [0.57048687609733]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.19910206688069607]
# computed_metrics: [0.19910206688069607]
# computed_metrics: [0.5579197728077746]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.22496231850170637]
# computed_metrics: [0.22496231850170637]
# computed_metrics: [0.5415982117889386]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.24337669340725715]
# computed_metrics: [0.24337669340725715]
# computed_metrics: [0.550032486831411]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.19248613165572323]
# computed_metrics: [0.19248613165572323]
# computed_metrics: [0.5527925872366719]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.260464140508845]
# computed_metrics: [0.260464140508845]
# computed_metrics: [0.5908193367539375]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.22233430420282746]
# computed_metrics: [0.22233430420282746]
# computed_metrics: [0.5919477567309049]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.21100215722357096]
# computed_metrics: [0.21100215722357096]
# computed_metrics: [0.5410535784924131]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.2493077992489775]
# computed_metrics: [0.2493077992489775]
# computed_metrics: [0.555082719639057]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.17716043816531796]
# computed_metrics: [0.17716043816531796]
# computed_metrics: [0.5534690576345591]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.26038088168097234]
# computed_metrics: [0.26038088168097234]
# computed_metrics: [0.5957617429716787]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.23674667749063344]
# computed_metrics: [0.23674667749063344]
# computed_metrics: [0.5680753461808437]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.2044904921361093]
# computed_metrics: [0.2044904921361093]
# computed_metrics: [0.5546050119629741]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.22937971308251187]
# computed_metrics: [0.22937971308251187]
# computed_metrics: [0.5484429281601925]
# [2.8619149696600994, 1.956636215757199, 1.3600436932245252, 1.0926467192345404, 0.9887915758754027, 0.9374631092234474, 0.9317215301884703, 0.9016302108758599, 0.8850743153837946, 0.8656994356850062, 0.857191958055372, 0.8580914894100705, 0.8442546060825069, 0.8438762241045183, 0.8290463475833956, 0.8121447538690459, 0.8102035572021948, 0.7930034244758978, 0.7843475776352729, 0.7723377579019092, 0.7659065961684661, 0.750933934159654, 0.7467611081873514, 0.7518311863573159, 0.7320302077509335, 0.726920184322125, 0.7197968140334609, 0.7191377605307372, 0.7024772654717089, 0.6858739650084991, 0.6798789355272723, 0.665303133755453, 0.6541523551499416, 0.6464173602973181, 0.634984442423598, 0.6260715985373334, 0.6095468314116358, 0.6070857199944977, 0.60317447926903, 0.5904923230670833, 0.5947694934197318, 0.5841930043930441, 0.5978597
]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.6445847794837705]
# computed_metrics: [2.6445847794837705]
# computed_metrics: [2.641361766829772]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.7842851971910407]
# computed_metrics: [1.7842851971910407]
# computed_metrics: [1.7722229842854753]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.2641871904954851]
# computed_metrics: [1.2641871904954851]
# computed_metrics: [1.2306045730324429]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0497618494512047]
# computed_metrics: [1.0497618494512047]
# computed_metrics: [1.0381845267421017]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9754174038485712]
# computed_metrics: [0.9754174038485712]
# computed_metrics: [0.9981530794327401]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9411770210443511]
# computed_metrics: [0.9411770210443511]
# computed_metrics: [0.9771246638477539]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9095850745143996]
# computed_metrics: [0.9095850745143996]
# computed_metrics: [0.9618691321633495]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9183060787523479]
# computed_metrics: [0.9183060787523479]
# computed_metrics: [0.970780614237602]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.892316982304657]
# computed_metrics: [0.892316982304657]
# computed_metrics: [0.9492185401632277]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8700644514021308]
# computed_metrics: [0.8700644514021308]
# computed_metrics: [0.9227101558521839]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8606348505180059]
# computed_metrics: [0.8606348505180059]
# computed_metrics: [0.8964867132167013]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8315178025648803]
# computed_metrics: [0.8315178025648803]
# computed_metrics: [0.8810029560558941]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8057246621124606]
# computed_metrics: [0.8057246621124606]
# computed_metrics: [0.8615533913429752]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8075249630700717]
# computed_metrics: [0.8075249630700717]
# computed_metrics: [0.8408636528157943]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.7775831152201846]
# computed_metrics: [0.7775831152201846]
# computed_metrics: [0.8314171418057043]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.7766308933386995]
# computed_metrics: [0.7766308933386995]
# computed_metrics: [0.8167379433078663]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7692716861992507]
# computed_metrics: [0.7692716861992507]
# computed_metrics: [0.814107604681512]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7450384849799389]
# computed_metrics: [0.7450384849799389]
# computed_metrics: [0.7921399665112315]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7238768617059892]
# computed_metrics: [0.7238768617059892]
# computed_metrics: [0.7719635560313188]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7500380530448184]
# computed_metrics: [0.7500380530448184]
# computed_metrics: [0.8052080852012347]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7534152766234365]
# computed_metrics: [0.7534152766234365]
# computed_metrics: [0.8063333368598538]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7380111500687362]
# computed_metrics: [0.7380111500687362]
# computed_metrics: [0.7845183452170367]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7237565223577521]
# computed_metrics: [0.7237565223577521]
# computed_metrics: [0.7619367841243658]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7240060129953906]
# computed_metrics: [0.7240060129953906]
# computed_metrics: [0.7740811542287416]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7065321671590888]
# computed_metrics: [0.7065321671590888]
# computed_metrics: [0.7526262093587539]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6971455860013961]
# computed_metrics: [0.6971455860013961]
# computed_metrics: [0.7504279169718026]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6956328186981825]
# computed_metrics: [0.6956328186981825]
# computed_metrics: [0.7438498171612824]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6847319446152318]
# computed_metrics: [0.6847319446152318]
# computed_metrics: [0.733079318119949]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6789569219670514]
# computed_metrics: [0.6789569219670514]
# computed_metrics: [0.7275292989190174]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6875996776385078]
# computed_metrics: [0.6875996776385078]
# computed_metrics: [0.7365505052785549]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6656117272119787]
# computed_metrics: [0.6656117272119787]
# computed_metrics: [0.7070087482339745]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6620273394836346]
# computed_metrics: [0.6620273394836346]
# computed_metrics: [0.7099297469927861]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6310866779920649]
# computed_metrics: [0.6310866779920649]
# computed_metrics: [0.6718313366071607]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6291186854385455]
# computed_metrics: [0.6291186854385455]
# computed_metrics: [0.6720193197713825]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6090605650046385]
# computed_metrics: [0.6090605650046385]
# computed_metrics: [0.6468996180672979]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6057700663846916]
# computed_metrics: [0.6057700663846916]
# computed_metrics: [0.6416737702915509]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.5942543738836756]
# computed_metrics: [0.5942543738836756]
# computed_metrics: [0.6459000732418798]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6052559626834627]
# computed_metrics: [0.6052559626834627]
# computed_metrics: [0.6435598625066797]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.5893129515313101]
# computed_metrics: [0.5893129515313101]
# computed_metrics: [0.6274366039702343]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5905486013358837]
# computed_metrics: [0.5905486013358837]
# computed_metrics: [0.6374855904510621]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5907970653684421]
# computed_metrics: [0.5907970653684421]
# computed_metrics: [0.6325188408487558]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.6266872377204785]
# computed_metrics: [0.6266872377204785]
# computed_metrics: [0.6601292802285145]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6215041245563464]
# computed_metrics: [0.6215041245563464]
# computed_metrics: [0.6559982374040212]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.6590617640838702]
# computed_metrics: [0.6590617640838702]
# computed_metrics: [0.6967377489055098]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.6001878717285798]
# computed_metrics: [0.6001878717285798]
# computed_metrics: [0.635931040998338]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.6134574388669105]
# computed_metrics: [0.6134574388669105]
# computed_metrics: [0.6539381302769829]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.6125500738272094]
# computed_metrics: [0.6125500738272094]
# computed_metrics: [0.6498619226104843]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.6090768363908639]
# computed_metrics: [0.6090768363908639]
# computed_metrics: [0.6375966135137351]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5932435205173159]
# computed_metrics: [0.5932435205173159]
# computed_metrics: [0.6372652477219936]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5961708040992963]
# computed_metrics: [0.5961708040992963]
# computed_metrics: [0.6238402951708854]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.6657473234442739]
# computed_metrics: [0.6657473234442739]
# computed_metrics: [0.6915738235778137]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5834443387701342]
# computed_metrics: [0.5834443387701342]
# computed_metrics: [0.632524708644469]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5926494367800327]
# computed_metrics: [0.5926494367800327]
# computed_metrics: [0.651783220287607]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5555242328578683]
# computed_metrics: [0.5555242328578683]
# computed_metrics: [0.6100428506024358]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5450991313902781]
# computed_metrics: [0.5450991313902781]
# computed_metrics: [0.6124132894421407]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5376884164893015]
# computed_metrics: [0.5376884164893015]
# computed_metrics: [0.5921853553772491]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5195496438207983]
# computed_metrics: [0.5195496438207983]
# computed_metrics: [0.5917738423154929]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5341887750524275]
# computed_metrics: [0.5341887750524275]
# computed_metrics: [0.6226191136814966]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5412275780864304]
# computed_metrics: [0.5412275780864304]
# computed_metrics: [0.6193577338451068]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5625704860858407]
# computed_metrics: [0.5625704860858407]
# computed_metrics: [0.6379771646394147]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5658014319262828]
# computed_metrics: [0.5658014319262828]
# computed_metrics: [0.6532927711192028]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5417255399790164]
# computed_metrics: [0.5417255399790164]
# computed_metrics: [0.6199317553862067]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5215105665568771]
# computed_metrics: [0.5215105665568771]
# computed_metrics: [0.6072769890324874]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5011034822731524]
# computed_metrics: [0.5011034822731524]
# computed_metrics: [0.583652087751554]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.49408747348244303]
# computed_metrics: [0.49408747348244303]
# computed_metrics: [0.5769069744688261]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.4743860006177932]
# computed_metrics: [0.4743860006177932]
# computed_metrics: [0.5651614799456313]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.46810693580783386]
# computed_metrics: [0.46810693580783386]
# computed_metrics: [0.5627756658937999]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.4658992465801175]
# computed_metrics: [0.4658992465801175]
# computed_metrics: [0.5553246286445491]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.4564116838749755]
# computed_metrics: [0.4564116838749755]
# computed_metrics: [0.5611900170301434]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.4528377180812519]
# computed_metrics: [0.4528377180812519]
# computed_metrics: [0.5553860557960416]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.45030936784402903]
# computed_metrics: [0.45030936784402903]
# computed_metrics: [0.5588110990233546]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.457610610106918]
# computed_metrics: [0.457610610106918]
# computed_metrics: [0.5541008388926646]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.45707194222307834]
# computed_metrics: [0.45707194222307834]
# computed_metrics: [0.5572143858130948]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4517263856514348]
# computed_metrics: [0.4517263856514348]
# computed_metrics: [0.5604982511151602]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.43967613513482756]
# computed_metrics: [0.43967613513482756]
# computed_metrics: [0.5349150853507622]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.43704084461132614]
# computed_metrics: [0.43704084461132614]
# computed_metrics: [0.5437984437357429]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.45288208443419287]
# computed_metrics: [0.45288208443419287]
# computed_metrics: [0.5603069461046162]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.4451900978151308]
# computed_metrics: [0.4451900978151308]
# computed_metrics: [0.5372632213262292]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.435241552595064]
# computed_metrics: [0.435241552595064]
# computed_metrics: [0.541383111765985]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4451727205575661]
# computed_metrics: [0.4451727205575661]
# computed_metrics: [0.560208561901044]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.43051763556048306]
# computed_metrics: [0.43051763556048306]
# computed_metrics: [0.5466758714438653]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4530596002994459]
# computed_metrics: [0.4530596002994459]
# computed_metrics: [0.5555191103763802]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.44271148524571313]
# computed_metrics: [0.44271148524571313]
# computed_metrics: [0.5483721673979679]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4597025341372497]
# computed_metrics: [0.4597025341372497]
# computed_metrics: [0.5560687668510292]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.434985194599325]
# computed_metrics: [0.434985194599325]
# computed_metrics: [0.5362649519142982]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.44819822200963283]
# computed_metrics: [0.44819822200963283]
# computed_metrics: [0.5454563155092691]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4305723211770302]
# computed_metrics: [0.4305723211770302]
# computed_metrics: [0.5509106392407291]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4601554298530879]
# computed_metrics: [0.4601554298530879]
# computed_metrics: [0.5331692107088429]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.4428115487303026]
# computed_metrics: [0.4428115487303026]
# computed_metrics: [0.5219633654366005]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.48375571776881615]
# computed_metrics: [0.48375571776881615]
# computed_metrics: [0.6276717189279256]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.4572725546896431]
# computed_metrics: [0.4572725546896431]
# computed_metrics: [0.5366757212740277]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.44490202520995986]
# computed_metrics: [0.44490202520995986]
# computed_metrics: [0.5416672109221117]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.44758839638776343]
# computed_metrics: [0.44758839638776343]
# computed_metrics: [0.5669557428339252]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4448484534379083]
# computed_metrics: [0.4448484534379083]
# computed_metrics: [0.5495916965518117]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.47924270674973857]
# computed_metrics: [0.47924270674973857]
# computed_metrics: [0.5466914179283147]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.47163525049926]
# computed_metrics: [0.47163525049926]
# computed_metrics: [0.5613711498567473]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.4364623479487179]
# computed_metrics: [0.4364623479487179]
# computed_metrics: [0.5430195637028632]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.45346817711594123]
# computed_metrics: [0.45346817711594123]
# computed_metrics: [0.5756324857385198]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.40546649025933473]
# computed_metrics: [0.40546649025933473]
# computed_metrics: [0.554705581894689]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.42024047112339297]
# computed_metrics: [0.42024047112339297]
# computed_metrics: [0.5610975585897041]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.41572626552908626]
# computed_metrics: [0.41572626552908626]
# computed_metrics: [0.537147797912091]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.3923199189835025]
# computed_metrics: [0.3923199189835025]
# computed_metrics: [0.5264425355198938]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.3787686823268488]
# computed_metrics: [0.3787686823268488]
# computed_metrics: [0.5196220423828899]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.379483151367112]
# computed_metrics: [0.379483151367112]
# computed_metrics: [0.5227984328761413]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.3707294082864196]
# computed_metrics: [0.3707294082864196]
# computed_metrics: [0.518648184801204]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4002079886132366]
# computed_metrics: [0.4002079886132366]
# computed_metrics: [0.542112152660317]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.3565312687370414]
# computed_metrics: [0.3565312687370414]
# computed_metrics: [0.5023188140708482]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.35551769459371696]
# computed_metrics: [0.35551769459371696]
# computed_metrics: [0.49617478558135514]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.36264526145326487]
# computed_metrics: [0.36264526145326487]
# computed_metrics: [0.4966607973023519]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.35841609486421777]
# computed_metrics: [0.35841609486421777]
# computed_metrics: [0.5053964170414468]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.3512324619071255]
# computed_metrics: [0.3512324619071255]
# computed_metrics: [0.495630477256334]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.3524732280024698]
# computed_metrics: [0.3524732280024698]
# computed_metrics: [0.5030206065123309]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.3878306663921167]
# computed_metrics: [0.3878306663921167]
# computed_metrics: [0.5359711060085454]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.37090867318384796]
# computed_metrics: [0.37090867318384796]
# computed_metrics: [0.5038550195845786]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.41435432863055016]
# computed_metrics: [0.41435432863055016]
# computed_metrics: [0.5241619726318696]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.40011521254236787]
# computed_metrics: [0.40011521254236787]
# computed_metrics: [0.5289742214452956]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.36689184649847456]
# computed_metrics: [0.36689184649847456]
# computed_metrics: [0.5085342814556617]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.3795168482404455]
# computed_metrics: [0.3795168482404455]
# computed_metrics: [0.5076366870130662]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.36087056950036184]
# computed_metrics: [0.36087056950036184]
# computed_metrics: [0.5031399737986394]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.340383855494902]
# computed_metrics: [0.340383855494902]
# computed_metrics: [0.5059931925921234]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.33339266878173623]
# computed_metrics: [0.33339266878173623]
# computed_metrics: [0.48082129810568824]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.3155962508256005]
# computed_metrics: [0.3155962508256005]
# computed_metrics: [0.4840314073921415]
# 12.326813196207022

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.3155962508256005]
# computed_metrics: [0.4840314073921415]
# computed_metrics: [0.5381489101803689]
# {'mean-mean_absolute_error': 0.5381489101803689}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.9309073, 0.0)
# SpearmanrResult(correlation=0.9317021173379213, pvalue=0.0)
# (0.85220927, 4.124236246483767e-51)
# SpearmanrResult(correlation=0.8562761515316867, pvalue=4.328106620643375e-52)
# (0.7635317, 4.559373429691778e-35)
# SpearmanrResult(correlation=0.7676632420781101, pvalue=1.1904566779105135e-35)
