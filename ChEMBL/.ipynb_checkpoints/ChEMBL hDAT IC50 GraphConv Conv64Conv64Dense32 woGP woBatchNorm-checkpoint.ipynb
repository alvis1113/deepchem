# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gc1, self.degree_slice, self.membership] + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gc2])
    
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[dense, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 3.197 s
# TIMING: dataset construction took 3.646 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.598 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.275 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.218 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 64
C2_filtnum = 64
D_nodenum = 32

graph_structure = 'GC{0}_GC{1}_D{2}_woBatchNorm'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.8177381449147063]
# computed_metrics: [2.8177381449147063]
# computed_metrics: [2.7858169017210597]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.3651999666750085]
# computed_metrics: [1.3651999666750085]
# computed_metrics: [1.3106072000690083]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.0431546265407439]
# computed_metrics: [1.0431546265407439]
# computed_metrics: [1.0013908537556604]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.9628905105986985]
# computed_metrics: [0.9628905105986985]
# computed_metrics: [0.9481970541253935]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9263142696008925]
# computed_metrics: [0.9263142696008925]
# computed_metrics: [0.9206934177473399]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9144731887770637]
# computed_metrics: [0.9144731887770637]
# computed_metrics: [0.912312834102031]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.902248468269679]
# computed_metrics: [0.902248468269679]
# computed_metrics: [0.9014378764106831]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8871223350203861]
# computed_metrics: [0.8871223350203861]
# computed_metrics: [0.8931041387629047]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8736567350859936]
# computed_metrics: [0.8736567350859936]
# computed_metrics: [0.8814349127748925]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8649257121205086]
# computed_metrics: [0.8649257121205086]
# computed_metrics: [0.8723146374861501]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8497494094037444]
# computed_metrics: [0.8497494094037444]
# computed_metrics: [0.8645013859010746]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8397313948264875]
# computed_metrics: [0.8397313948264875]
# computed_metrics: [0.8440654626245655]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.826542038398278]
# computed_metrics: [0.826542038398278]
# computed_metrics: [0.8271773615910046]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8132466064581917]
# computed_metrics: [0.8132466064581917]
# computed_metrics: [0.8094819583457199]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.812792777252682]
# computed_metrics: [0.812792777252682]
# computed_metrics: [0.8136759691167939]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8052568188435248]
# computed_metrics: [0.8052568188435248]
# computed_metrics: [0.8014162729958553]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7799178688449862]
# computed_metrics: [0.7799178688449862]
# computed_metrics: [0.7700435229924096]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7689280308776347]
# computed_metrics: [0.7689280308776347]
# computed_metrics: [0.7704937646456858]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.759445079001862]
# computed_metrics: [0.759445079001862]
# computed_metrics: [0.7542066875182099]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7527773320467007]
# computed_metrics: [0.7527773320467007]
# computed_metrics: [0.7553502577700049]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7363702629782415]
# computed_metrics: [0.7363702629782415]
# computed_metrics: [0.7512868145989069]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7259156258551358]
# computed_metrics: [0.7259156258551358]
# computed_metrics: [0.7303794251090789]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7289457785147647]
# computed_metrics: [0.7289457785147647]
# computed_metrics: [0.7469252372063633]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7086888503974287]
# computed_metrics: [0.7086888503974287]
# computed_metrics: [0.7162549756786756]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.6943355417445385]
# computed_metrics: [0.6943355417445385]
# computed_metrics: [0.7073687537481311]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6817950666055054]
# computed_metrics: [0.6817950666055054]
# computed_metrics: [0.696878359252775]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6692948728995862]
# computed_metrics: [0.6692948728995862]
# computed_metrics: [0.6893098645739061]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.662129439710608]
# computed_metrics: [0.662129439710608]
# computed_metrics: [0.6909690340518122]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.656979820409178]
# computed_metrics: [0.656979820409178]
# computed_metrics: [0.6845647713854939]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6386307113178576]
# computed_metrics: [0.6386307113178576]
# computed_metrics: [0.6722905249908034]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6288912273868132]
# computed_metrics: [0.6288912273868132]
# computed_metrics: [0.677032869905271]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.61916189190028]
# computed_metrics: [0.61916189190028]
# computed_metrics: [0.6736086350795386]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.616688870446958]
# computed_metrics: [0.616688870446958]
# computed_metrics: [0.6694207031212971]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6029057965262763]
# computed_metrics: [0.6029057965262763]
# computed_metrics: [0.661768696423492]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6007273275527603]
# computed_metrics: [0.6007273275527603]
# computed_metrics: [0.6586994104997734]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.5994001254140617]
# computed_metrics: [0.5994001254140617]
# computed_metrics: [0.6506898647245065]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.5965433297884063]
# computed_metrics: [0.5965433297884063]
# computed_metrics: [0.6569391880619033]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6005442709151042]
# computed_metrics: [0.6005442709151042]
# computed_metrics: [0.6664036642511583]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.5986154116461223]
# computed_metrics: [0.5986154116461223]
# computed_metrics: [0.6712486117871092]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5944035120458087]
# computed_metrics: [0.5944035120458087]
# computed_metrics: [0.6741233441686343]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6114235283175393]
# computed_metrics: [0.6114235283175393]
# computed_metrics: [0.6779692727659397]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5884359697233887]
# computed_metrics: [0.5884359697233887]
# computed_metrics: [0.6744901906276682]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6132160625620856]
# computed_metrics: [0.6132160625620856]
# computed_metrics: [0.6858800674950273]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5742364977540007]
# computed_metrics: [0.5742364977540007]
# computed_metrics: [0.6474824598785806]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5896516379359846]
# computed_metrics: [0.5896516379359846]
# computed_metrics: [0.6641857818729688]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5646894922431946]
# computed_metrics: [0.5646894922431946]
# computed_metrics: [0.6416952687244146]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5769619299308231]
# computed_metrics: [0.5769619299308231]
# computed_metrics: [0.6537831609503867]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5663020667881394]
# computed_metrics: [0.5663020667881394]
# computed_metrics: [0.6479591969994305]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.549973870296525]
# computed_metrics: [0.549973870296525]
# computed_metrics: [0.6287087282045843]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5459060460608152]
# computed_metrics: [0.5459060460608152]
# computed_metrics: [0.6305238858516824]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5391498272759325]
# computed_metrics: [0.5391498272759325]
# computed_metrics: [0.6210722522192405]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5363929322467763]
# computed_metrics: [0.5363929322467763]
# computed_metrics: [0.63120187056191]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.537988657062442]
# computed_metrics: [0.537988657062442]
# computed_metrics: [0.6226630191401457]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5289417125867286]
# computed_metrics: [0.5289417125867286]
# computed_metrics: [0.6220867390038662]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5299840716722723]
# computed_metrics: [0.5299840716722723]
# computed_metrics: [0.6254772332834765]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5207078733385768]
# computed_metrics: [0.5207078733385768]
# computed_metrics: [0.6069259388523714]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5150330392043106]
# computed_metrics: [0.5150330392043106]
# computed_metrics: [0.610556053589889]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5096105121432369]
# computed_metrics: [0.5096105121432369]
# computed_metrics: [0.5997570532750099]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5088211512377436]
# computed_metrics: [0.5088211512377436]
# computed_metrics: [0.6064283016089913]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5114672027437287]
# computed_metrics: [0.5114672027437287]
# computed_metrics: [0.6083001429364143]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.509023047081627]
# computed_metrics: [0.509023047081627]
# computed_metrics: [0.6030031242187064]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5002502828602052]
# computed_metrics: [0.5002502828602052]
# computed_metrics: [0.5957473073447858]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.4968899462286269]
# computed_metrics: [0.4968899462286269]
# computed_metrics: [0.5955209936710508]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.4946650526383338]
# computed_metrics: [0.4946650526383338]
# computed_metrics: [0.5950276329761205]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.499231672284554]
# computed_metrics: [0.499231672284554]
# computed_metrics: [0.5869493583145122]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5023640378618355]
# computed_metrics: [0.5023640378618355]
# computed_metrics: [0.591469753928384]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.49806150442171]
# computed_metrics: [0.49806150442171]
# computed_metrics: [0.5966964996076773]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.492873218021496]
# computed_metrics: [0.492873218021496]
# computed_metrics: [0.5851813205407568]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.48869570557477415]
# computed_metrics: [0.48869570557477415]
# computed_metrics: [0.5865517440543181]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.48416272627996737]
# computed_metrics: [0.48416272627996737]
# computed_metrics: [0.5868968092295523]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.47808677008205525]
# computed_metrics: [0.47808677008205525]
# computed_metrics: [0.5777883971108774]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.4835169085701056]
# computed_metrics: [0.4835169085701056]
# computed_metrics: [0.5946162695715896]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.47854798444172925]
# computed_metrics: [0.47854798444172925]
# computed_metrics: [0.5871717126586953]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4737667441302105]
# computed_metrics: [0.4737667441302105]
# computed_metrics: [0.5868190263624153]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.48793434446795364]
# computed_metrics: [0.48793434446795364]
# computed_metrics: [0.5947354036403444]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.46890438743789314]
# computed_metrics: [0.46890438743789314]
# computed_metrics: [0.5736355539326451]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.49154417523420246]
# computed_metrics: [0.49154417523420246]
# computed_metrics: [0.5925533770124757]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.47664919510998144]
# computed_metrics: [0.47664919510998144]
# computed_metrics: [0.5824496821248099]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.46781907347081936]
# computed_metrics: [0.46781907347081936]
# computed_metrics: [0.5766221417550681]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.4767851458596307]
# computed_metrics: [0.4767851458596307]
# computed_metrics: [0.58479737088544]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4741372623711075]
# computed_metrics: [0.4741372623711075]
# computed_metrics: [0.5786467259188651]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.471204819169283]
# computed_metrics: [0.471204819169283]
# computed_metrics: [0.5715174346589879]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.48501299313004037]
# computed_metrics: [0.48501299313004037]
# computed_metrics: [0.5910975722721045]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4665739387522398]
# computed_metrics: [0.4665739387522398]
# computed_metrics: [0.5782611414421829]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.47017381120673485]
# computed_metrics: [0.47017381120673485]
# computed_metrics: [0.5835469452684349]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.4939281488252668]
# computed_metrics: [0.4939281488252668]
# computed_metrics: [0.6002822554347966]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4761351024524052]
# computed_metrics: [0.4761351024524052]
# computed_metrics: [0.6009871059943261]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.5017998390606074]
# computed_metrics: [0.5017998390606074]
# computed_metrics: [0.6140553184966948]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.4861779796905534]
# computed_metrics: [0.4861779796905534]
# computed_metrics: [0.5859574476256748]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.48806797689045905]
# computed_metrics: [0.48806797689045905]
# computed_metrics: [0.5970777884028816]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.4767945560884377]
# computed_metrics: [0.4767945560884377]
# computed_metrics: [0.582971548496281]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.5116053241749311]
# computed_metrics: [0.5116053241749311]
# computed_metrics: [0.6021947905958452]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.5293549401213319]
# computed_metrics: [0.5293549401213319]
# computed_metrics: [0.6191811369411895]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.5143635588552237]
# computed_metrics: [0.5143635588552237]
# computed_metrics: [0.6239795830482764]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4999154567782406]
# computed_metrics: [0.4999154567782406]
# computed_metrics: [0.6079133423443813]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.5654975833833196]
# computed_metrics: [0.5654975833833196]
# computed_metrics: [0.6503468969419163]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.5747378824588988]
# computed_metrics: [0.5747378824588988]
# computed_metrics: [0.6686013089612807]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.48961452305917297]
# computed_metrics: [0.48961452305917297]
# computed_metrics: [0.5970807970569341]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.5715694720747366]
# computed_metrics: [0.5715694720747366]
# computed_metrics: [0.6813565747454767]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.5355437620608843]
# computed_metrics: [0.5355437620608843]
# computed_metrics: [0.6542256982355185]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.5612305298068995]
# computed_metrics: [0.5612305298068995]
# computed_metrics: [0.6657568693102678]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.5145369938119227]
# computed_metrics: [0.5145369938119227]
# computed_metrics: [0.6447339847286016]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.5200054015241218]
# computed_metrics: [0.5200054015241218]
# computed_metrics: [0.6355400402613839]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5367237531622489]
# computed_metrics: [0.5367237531622489]
# computed_metrics: [0.6437327007137316]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.5229572836063979]
# computed_metrics: [0.5229572836063979]
# computed_metrics: [0.630043375990722]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4933386889974478]
# computed_metrics: [0.4933386889974478]
# computed_metrics: [0.614301312968373]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.48394244073699055]
# computed_metrics: [0.48394244073699055]
# computed_metrics: [0.6002587514615129]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.4927546918734548]
# computed_metrics: [0.4927546918734548]
# computed_metrics: [0.6118948520871634]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.4541212097749979]
# computed_metrics: [0.4541212097749979]
# computed_metrics: [0.5925016277318751]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.4652986833744516]
# computed_metrics: [0.4652986833744516]
# computed_metrics: [0.5959956582958874]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.4513627960511375]
# computed_metrics: [0.4513627960511375]
# computed_metrics: [0.5875192874233265]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.4448474099545295]
# computed_metrics: [0.4448474099545295]
# computed_metrics: [0.581042570971768]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.44153403396058216]
# computed_metrics: [0.44153403396058216]
# computed_metrics: [0.5997651614432397]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.45371106789919624]
# computed_metrics: [0.45371106789919624]
# computed_metrics: [0.5731264339956426]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.48198483341163734]
# computed_metrics: [0.48198483341163734]
# computed_metrics: [0.6297320501625261]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4869510739300119]
# computed_metrics: [0.4869510739300119]
# computed_metrics: [0.6252594194619621]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.5215491215505856]
# computed_metrics: [0.5215491215505856]
# computed_metrics: [0.6543025499699062]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.5063557661822207]
# computed_metrics: [0.5063557661822207]
# computed_metrics: [0.6363574044375687]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.5058497155675176]
# computed_metrics: [0.5058497155675176]
# computed_metrics: [0.6393291433983812]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.5153482122997114]
# computed_metrics: [0.5153482122997114]
# computed_metrics: [0.6687518044355071]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.4739178899734737]
# computed_metrics: [0.4739178899734737]
# computed_metrics: [0.6313213117997192]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.4649048501600463]
# computed_metrics: [0.4649048501600463]
# computed_metrics: [0.623288599189067]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.4402082511970268]
# computed_metrics: [0.4402082511970268]
# computed_metrics: [0.5966622419675358]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.41243800930296726]
# computed_metrics: [0.41243800930296726]
# computed_metrics: [0.5891415968094219]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.4296577041355812]
# computed_metrics: [0.4296577041355812]
# computed_metrics: [0.5853295336248261]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.4669439057072384]
# computed_metrics: [0.4669439057072384]
# computed_metrics: [0.5872994138124572]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.4799100353009068]
# computed_metrics: [0.4799100353009068]
# computed_metrics: [0.6100486952495083]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.5013194135165577]
# computed_metrics: [0.5013194135165577]
# computed_metrics: [0.6070687141009993]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.5074658910217799]
# computed_metrics: [0.5074658910217799]
# computed_metrics: [0.6266809731024232]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.4585434746227579]
# computed_metrics: [0.4585434746227579]
# computed_metrics: [0.6044852515917898]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.41580399409506497]
# computed_metrics: [0.41580399409506497]
# computed_metrics: [0.5667995215624219]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.406189094891615]
# computed_metrics: [0.406189094891615]
# computed_metrics: [0.5680783745947561]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.4329092543359168]
# computed_metrics: [0.4329092543359168]
# computed_metrics: [0.5958384301847934]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.4563271453489105]
# computed_metrics: [0.4563271453489105]
# computed_metrics: [0.6186312480519401]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.4448416570889846]
# computed_metrics: [0.4448416570889846]
# computed_metrics: [0.6143794173485416]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.4120253978119986]
# computed_metrics: [0.4120253978119986]
# computed_metrics: [0.5898518000125459]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.40946874571951863]
# computed_metrics: [0.40946874571951863]
# computed_metrics: [0.5944097118818722]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.38907469605171835]
# computed_metrics: [0.38907469605171835]
# computed_metrics: [0.5649981965026085]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.3899528786138602]
# computed_metrics: [0.3899528786138602]
# computed_metrics: [0.583336165444292]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.3940536110138523]
# computed_metrics: [0.3940536110138523]
# computed_metrics: [0.5735389177048948]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.44464808592164395]
# computed_metrics: [0.44464808592164395]
# computed_metrics: [0.6004499598990221]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.46934730596597707]
# computed_metrics: [0.46934730596597707]
# computed_metrics: [0.6123585175539193]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.4518252257303529]
# computed_metrics: [0.4518252257303529]
# computed_metrics: [0.6200659317242181]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.41407282679195934]
# computed_metrics: [0.41407282679195934]
# computed_metrics: [0.5706327280955128]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.384849607218289]
# computed_metrics: [0.384849607218289]
# computed_metrics: [0.5648929127993114]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.37152917014056086]
# computed_metrics: [0.37152917014056086]
# computed_metrics: [0.5781068884038804]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.3813035818987439]
# computed_metrics: [0.3813035818987439]
# computed_metrics: [0.5744264444242181]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.40679646166449673]
# computed_metrics: [0.40679646166449673]
# computed_metrics: [0.5963676233564099]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.4215273000924113]
# computed_metrics: [0.4215273000924113]
# computed_metrics: [0.611542365529341]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.41678993695261163]
# computed_metrics: [0.41678993695261163]
# computed_metrics: [0.5991045250493965]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.39744657228028824]
# computed_metrics: [0.39744657228028824]
# computed_metrics: [0.5955853285662478]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3957616910674654]
# computed_metrics: [0.3957616910674654]
# computed_metrics: [0.6021132628698005]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.4177639089984476]
# computed_metrics: [0.4177639089984476]
# computed_metrics: [0.613343531716757]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.37297087522296735]
# computed_metrics: [0.37297087522296735]
# computed_metrics: [0.57922035803526]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.36362542582845153]
# computed_metrics: [0.36362542582845153]
# computed_metrics: [0.5726007929471282]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.36876595061081]
# computed_metrics: [0.36876595061081]
# computed_metrics: [0.5741863587818868]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.3876091191583944]
# computed_metrics: [0.3876091191583944]
# computed_metrics: [0.5822594828096154]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.39716596093029877]
# computed_metrics: [0.39716596093029877]
# computed_metrics: [0.5800411914204014]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.4354121376027325]
# computed_metrics: [0.4354121376027325]
# computed_metrics: [0.6010444061425726]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.43764224162395243]
# computed_metrics: [0.43764224162395243]
# computed_metrics: [0.5991602196185932]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.43046484423161613]
# computed_metrics: [0.43046484423161613]
# computed_metrics: [0.5964740246967871]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.44333644253528764]
# computed_metrics: [0.44333644253528764]
# computed_metrics: [0.6266756593255887]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3914547570676821]
# computed_metrics: [0.3914547570676821]
# computed_metrics: [0.5647811494192072]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.39423194417162616]
# computed_metrics: [0.39423194417162616]
# computed_metrics: [0.6058272512296106]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.3913976545689415]
# computed_metrics: [0.3913976545689415]
# computed_metrics: [0.6117146380477374]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.361257146671639]
# computed_metrics: [0.361257146671639]
# computed_metrics: [0.580600138226129]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.3560245741530013]
# computed_metrics: [0.3560245741530013]
# computed_metrics: [0.5853575934454178]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3636543273048908]
# computed_metrics: [0.3636543273048908]
# computed_metrics: [0.5786236543473787]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.3758310377625133]
# computed_metrics: [0.3758310377625133]
# computed_metrics: [0.5974195533574553]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.3763239906155208]
# computed_metrics: [0.3763239906155208]
# computed_metrics: [0.6056172968062007]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.36854510889005493]
# computed_metrics: [0.36854510889005493]
# computed_metrics: [0.5944753168573507]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.37736784455584066]
# computed_metrics: [0.37736784455584066]
# computed_metrics: [0.6010822489744715]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.37539368419620345]
# computed_metrics: [0.37539368419620345]
# computed_metrics: [0.6015984169512619]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.355399488992303]
# computed_metrics: [0.355399488992303]
# computed_metrics: [0.5861805427006443]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.337624931980304]
# computed_metrics: [0.337624931980304]
# computed_metrics: [0.5819201975237075]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.33957246147296805]
# computed_metrics: [0.33957246147296805]
# computed_metrics: [0.5737057498190614]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3361764798176251]
# computed_metrics: [0.3361764798176251]
# computed_metrics: [0.5680530018583263]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.36789935705504273]
# computed_metrics: [0.36789935705504273]
# computed_metrics: [0.5694563667194965]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.3489572562968931]
# computed_metrics: [0.3489572562968931]
# computed_metrics: [0.5745124750674863]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.38746014449864496]
# computed_metrics: [0.38746014449864496]
# computed_metrics: [0.5913764545851625]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.4194700087745934]
# computed_metrics: [0.4194700087745934]
# computed_metrics: [0.6149085553441032]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.3754340331709966]
# computed_metrics: [0.3754340331709966]
# computed_metrics: [0.6001794423065727]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.4036090852379125]
# computed_metrics: [0.4036090852379125]
# computed_metrics: [0.6040833786499709]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.4163343719943157]
# computed_metrics: [0.4163343719943157]
# computed_metrics: [0.5914648861694074]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.3704825083643501]
# computed_metrics: [0.3704825083643501]
# computed_metrics: [0.5709587599130084]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.3795893087902255]
# computed_metrics: [0.3795893087902255]
# computed_metrics: [0.5901717265453339]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.3610630665704235]
# computed_metrics: [0.3610630665704235]
# computed_metrics: [0.5645764095450061]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.3524443871669864]
# computed_metrics: [0.3524443871669864]
# computed_metrics: [0.5809461701034907]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.352561933214667]
# computed_metrics: [0.352561933214667]
# computed_metrics: [0.5884834898680421]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.33689401079063447]
# computed_metrics: [0.33689401079063447]
# computed_metrics: [0.5791364480711468]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.3612653117574527]
# computed_metrics: [0.3612653117574527]
# computed_metrics: [0.5795252666430372]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.3522161975505187]
# computed_metrics: [0.3522161975505187]
# computed_metrics: [0.5717279818532035]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.34486966502606925]
# computed_metrics: [0.34486966502606925]
# computed_metrics: [0.5820738490869861]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3597244995254318]
# computed_metrics: [0.3597244995254318]
# computed_metrics: [0.5856106820593969]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.3656553664842727]
# computed_metrics: [0.3656553664842727]
# computed_metrics: [0.5867925605924578]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.362190703992464]
# computed_metrics: [0.362190703992464]
# computed_metrics: [0.5883123257202598]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.3601554462193029]
# computed_metrics: [0.3601554462193029]
# computed_metrics: [0.5967684877701118]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.36616058675268265]
# computed_metrics: [0.36616058675268265]
# computed_metrics: [0.6075976999360369]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.36655529941472126]
# computed_metrics: [0.36655529941472126]
# computed_metrics: [0.616018756511419]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.37564846205749386]
# computed_metrics: [0.37564846205749386]
# computed_metrics: [0.6293487893475506]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.3503712235328347]
# computed_metrics: [0.3503712235328347]
# computed_metrics: [0.6078098287976684]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.34208851535420276]
# computed_metrics: [0.34208851535420276]
# computed_metrics: [0.5921849480499969]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.32665031848431236]
# computed_metrics: [0.32665031848431236]
# computed_metrics: [0.5784343005359354]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.3310300136535884]
# computed_metrics: [0.3310300136535884]
# computed_metrics: [0.5827808375895578]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.3230023800259846]
# computed_metrics: [0.3230023800259846]
# computed_metrics: [0.576349571987247]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.3803049596308712]
# computed_metrics: [0.3803049596308712]
# computed_metrics: [0.6084025898424834]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.37268855801017425]
# computed_metrics: [0.37268855801017425]
# computed_metrics: [0.6118080431702461]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.42242591388789785]
# computed_metrics: [0.42242591388789785]
# computed_metrics: [0.6120208360818195]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.44474048351303]
# computed_metrics: [0.44474048351303]
# computed_metrics: [0.6146575786805263]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.38165927111057374]
# computed_metrics: [0.38165927111057374]
# computed_metrics: [0.5961723610137396]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.35224354261682017]
# computed_metrics: [0.35224354261682017]
# computed_metrics: [0.6008682893821949]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.4517803185594012]
# computed_metrics: [0.4517803185594012]
# computed_metrics: [0.5997949613043511]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.421070404174652]
# computed_metrics: [0.421070404174652]
# computed_metrics: [0.6140454552143769]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.40615069982443014]
# computed_metrics: [0.40615069982443014]
# computed_metrics: [0.6099646958026318]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.3739468146532914]
# computed_metrics: [0.3739468146532914]
# computed_metrics: [0.5805343044164332]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.3526598843800578]
# computed_metrics: [0.3526598843800578]
# computed_metrics: [0.5803743464418943]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.3401317266200002]
# computed_metrics: [0.3401317266200002]
# computed_metrics: [0.5678354250001824]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.33161913714659785]
# computed_metrics: [0.33161913714659785]
# computed_metrics: [0.56957511351309]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.35533993742493025]
# computed_metrics: [0.35533993742493025]
# computed_metrics: [0.585762960234697]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.37318797914832424]
# computed_metrics: [0.37318797914832424]
# computed_metrics: [0.6002741269148623]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.3719387330515112]
# computed_metrics: [0.3719387330515112]
# computed_metrics: [0.6149517963825254]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.3707501823620338]
# computed_metrics: [0.3707501823620338]
# computed_metrics: [0.6053761342337829]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.33417337546379994]
# computed_metrics: [0.33417337546379994]
# computed_metrics: [0.5913613385043529]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.33123439341546196]
# computed_metrics: [0.33123439341546196]
# computed_metrics: [0.5842924788534898]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3155001953531171]
# computed_metrics: [0.3155001953531171]
# computed_metrics: [0.5758577799432903]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.3098388162523799]
# computed_metrics: [0.3098388162523799]
# computed_metrics: [0.562814490725272]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.31643574508225464]
# computed_metrics: [0.31643574508225464]
# computed_metrics: [0.5872268944542576]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.32767184035428715]
# computed_metrics: [0.32767184035428715]
# computed_metrics: [0.5822096217660246]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.3189520068656769]
# computed_metrics: [0.3189520068656769]
# computed_metrics: [0.5691558895583048]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.35103475260289596]
# computed_metrics: [0.35103475260289596]
# computed_metrics: [0.5742554115356625]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.36010361648972516]
# computed_metrics: [0.36010361648972516]
# computed_metrics: [0.5951488812525918]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.32940671770572827]
# computed_metrics: [0.32940671770572827]
# computed_metrics: [0.5838352438643459]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.34853122082898624]
# computed_metrics: [0.34853122082898624]
# computed_metrics: [0.5771810936551588]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3249271787455268]
# computed_metrics: [0.3249271787455268]
# computed_metrics: [0.5647792250172471]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.3119855157869232]
# computed_metrics: [0.3119855157869232]
# computed_metrics: [0.5821408551144645]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.3106200151027198]
# computed_metrics: [0.3106200151027198]
# computed_metrics: [0.5687886525532369]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.345832486830976]
# computed_metrics: [0.345832486830976]
# computed_metrics: [0.5995275614584705]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.35541719125560034]
# computed_metrics: [0.35541719125560034]
# computed_metrics: [0.6006988185987121]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.36457226165349177]
# computed_metrics: [0.36457226165349177]
# computed_metrics: [0.6131587446548816]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.37758512368949576]
# computed_metrics: [0.37758512368949576]
# computed_metrics: [0.6176008718059908]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.3776847414707338]
# computed_metrics: [0.3776847414707338]
# computed_metrics: [0.619274181621747]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.3663048261686874]
# computed_metrics: [0.3663048261686874]
# computed_metrics: [0.5919178766646964]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.3754348218371589]
# computed_metrics: [0.3754348218371589]
# computed_metrics: [0.6164677868993083]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.3315413102434174]
# computed_metrics: [0.3315413102434174]
# computed_metrics: [0.5796957363954376]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.3256609847990727]
# computed_metrics: [0.3256609847990727]
# computed_metrics: [0.5663078327012036]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.32641478238211225]
# computed_metrics: [0.32641478238211225]
# computed_metrics: [0.5764482399051194]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.3294425788104022]
# computed_metrics: [0.3294425788104022]
# computed_metrics: [0.57438024060644]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.38822740650680687]
# computed_metrics: [0.38822740650680687]
# computed_metrics: [0.6078324133479351]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.42164316231549076]
# computed_metrics: [0.42164316231549076]
# computed_metrics: [0.6358296900303304]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.39713108770370814]
# computed_metrics: [0.39713108770370814]
# computed_metrics: [0.6179057556009144]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.43345529950176565]
# computed_metrics: [0.43345529950176565]
# computed_metrics: [0.6267721052068276]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.4268827330802275]
# computed_metrics: [0.4268827330802275]
# computed_metrics: [0.6235541403686451]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.345071567272052]
# computed_metrics: [0.345071567272052]
# computed_metrics: [0.5805845308421467]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.3453106179767388]
# computed_metrics: [0.3453106179767388]
# computed_metrics: [0.5859868542428391]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.35256351835793853]
# computed_metrics: [0.35256351835793853]
# computed_metrics: [0.6009525382944204]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.3930720997337856]
# computed_metrics: [0.3930720997337856]
# computed_metrics: [0.6427768408722296]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.41787740607278195]
# computed_metrics: [0.41787740607278195]
# computed_metrics: [0.6480450870088797]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.40753320767684553]
# computed_metrics: [0.40753320767684553]
# computed_metrics: [0.6130886853437796]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.37479002751839335]
# computed_metrics: [0.37479002751839335]
# computed_metrics: [0.6155110899527108]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.3287827363178881]
# computed_metrics: [0.3287827363178881]
# computed_metrics: [0.5871608709044713]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.3270837178360494]
# computed_metrics: [0.3270837178360494]
# computed_metrics: [0.5737463926511646]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.34757076353884886]
# computed_metrics: [0.34757076353884886]
# computed_metrics: [0.5853776685729557]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.41464667692253393]
# computed_metrics: [0.41464667692253393]
# computed_metrics: [0.6304349135737808]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.39135726716368313]
# computed_metrics: [0.39135726716368313]
# computed_metrics: [0.5949887413702389]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.3467409823281641]
# computed_metrics: [0.3467409823281641]
# computed_metrics: [0.5759759134664424]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.322255767373467]
# computed_metrics: [0.322255767373467]
# computed_metrics: [0.5690652384543338]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.35061263025097267]
# computed_metrics: [0.35061263025097267]
# computed_metrics: [0.6101210285386233]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.3793197224747057]
# computed_metrics: [0.3793197224747057]
# computed_metrics: [0.6235067850848077]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.3905116161400279]
# computed_metrics: [0.3905116161400279]
# computed_metrics: [0.6250636046109024]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.3552829122678415]
# computed_metrics: [0.3552829122678415]
# computed_metrics: [0.5968106544577542]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.3196634035333394]
# computed_metrics: [0.3196634035333394]
# computed_metrics: [0.5912902589508999]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.32013539918482103]
# computed_metrics: [0.32013539918482103]
# computed_metrics: [0.583746243644053]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.30491563550088663]
# computed_metrics: [0.30491563550088663]
# computed_metrics: [0.5868804538440618]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.3081815021137886]
# computed_metrics: [0.3081815021137886]
# computed_metrics: [0.5698540602987437]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.3471934366797801]
# computed_metrics: [0.3471934366797801]
# computed_metrics: [0.5917464206408478]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.3678816168354093]
# computed_metrics: [0.3678816168354093]
# computed_metrics: [0.5977426516425137]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.33366018353839827]
# computed_metrics: [0.33366018353839827]
# computed_metrics: [0.5806546780415869]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.30946275120804295]
# computed_metrics: [0.30946275120804295]
# computed_metrics: [0.575955480939944]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.3364918565608691]
# computed_metrics: [0.3364918565608691]
# computed_metrics: [0.6003618654585042]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.4042991368984564]
# computed_metrics: [0.4042991368984564]
# computed_metrics: [0.6325289750613508]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.4020119912214304]
# computed_metrics: [0.4020119912214304]
# computed_metrics: [0.6353955035849631]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.36004543786043675]
# computed_metrics: [0.36004543786043675]
# computed_metrics: [0.6106772469337761]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.3128323441488939]
# computed_metrics: [0.3128323441488939]
# computed_metrics: [0.5780265771281646]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.3417572949076877]
# computed_metrics: [0.3417572949076877]
# computed_metrics: [0.6117681718200004]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3717455291787317]
# computed_metrics: [0.3717455291787317]
# computed_metrics: [0.6005976481225294]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.3778037900134806]
# computed_metrics: [0.3778037900134806]
# computed_metrics: [0.6173819485497235]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.31501354890574856]
# computed_metrics: [0.31501354890574856]
# computed_metrics: [0.5789519100843982]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.2990870709608118]
# computed_metrics: [0.2990870709608118]
# computed_metrics: [0.5732679071944117]
# Starting epoch 288
# ...
# Starting validation epoch 452
# computed_metrics: [0.3149441030056937]
# computed_metrics: [0.3149441030056937]
# computed_metrics: [0.6063293803996188]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.2796228003384851]
# computed_metrics: [0.2796228003384851]
# computed_metrics: [0.5803140156852046]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.27050964897885255]
# computed_metrics: [0.27050964897885255]
# computed_metrics: [0.5819631335759942]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.30383533324221196]
# computed_metrics: [0.30383533324221196]
# computed_metrics: [0.6222861114921505]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.35596600448740245]
# computed_metrics: [0.35596600448740245]
# computed_metrics: [0.6446496930783419]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.3301375473071969]
# computed_metrics: [0.3301375473071969]
# computed_metrics: [0.6190681832025641]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.2689756464736303]
# computed_metrics: [0.2689756464736303]
# computed_metrics: [0.6118525806489324]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.28245331319330363]
# computed_metrics: [0.28245331319330363]
# computed_metrics: [0.5890548539423326]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.34282706048488426]
# computed_metrics: [0.34282706048488426]
# computed_metrics: [0.6285368197080152]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.34034253622046284]
# computed_metrics: [0.34034253622046284]
# computed_metrics: [0.6259090944161769]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.29467521704873806]
# computed_metrics: [0.29467521704873806]
# computed_metrics: [0.5856007850805803]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.2808150121248199]
# computed_metrics: [0.2808150121248199]
# computed_metrics: [0.5907761456188382]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.3604041558388961]
# computed_metrics: [0.3604041558388961]
# computed_metrics: [0.6491630778382611]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.354846778501869]
# computed_metrics: [0.354846778501869]
# computed_metrics: [0.6586033601484085]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.2800078984997221]
# computed_metrics: [0.2800078984997221]
# computed_metrics: [0.6115432171078705]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.2656780945822707]
# computed_metrics: [0.2656780945822707]
# computed_metrics: [0.5842668392171618]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.3264883639066722]
# computed_metrics: [0.3264883639066722]
# computed_metrics: [0.6151196328086442]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.34313346377840315]
# computed_metrics: [0.34313346377840315]
# computed_metrics: [0.6267356810098451]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.2969546043872867]
# computed_metrics: [0.2969546043872867]
# computed_metrics: [0.5870649496827668]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.26667097236253084]
# computed_metrics: [0.26667097236253084]
# computed_metrics: [0.5830102874358124]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.3079038862649357]
# computed_metrics: [0.3079038862649357]
# computed_metrics: [0.6238203047901407]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.30971942513425055]
# computed_metrics: [0.30971942513425055]
# computed_metrics: [0.6399847021962718]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.25788788220684555]
# computed_metrics: [0.25788788220684555]
# computed_metrics: [0.6024006944740067]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.2884768533481519]
# computed_metrics: [0.2884768533481519]
# computed_metrics: [0.6117796000643304]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.3379166327696269]
# computed_metrics: [0.3379166327696269]
# computed_metrics: [0.6253049948638393]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.3056473448763507]
# computed_metrics: [0.3056473448763507]
# computed_metrics: [0.6057399823179017]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.27199980769894894]
# computed_metrics: [0.27199980769894894]
# computed_metrics: [0.5898710605573719]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.31087883810327127]
# computed_metrics: [0.31087883810327127]
# computed_metrics: [0.6350821582623294]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.3372198458349408]
# computed_metrics: [0.3372198458349408]
# computed_metrics: [0.662938147123114]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.2769782981325091]
# computed_metrics: [0.2769782981325091]
# computed_metrics: [0.5993318385629681]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.26734737453242713]
# computed_metrics: [0.26734737453242713]
# computed_metrics: [0.5913565943301015]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.3287185679377677]
# computed_metrics: [0.3287185679377677]
# computed_metrics: [0.616212463779823]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.34209123800942176]
# computed_metrics: [0.34209123800942176]
# computed_metrics: [0.6228095879573223]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.2683725552160754]
# computed_metrics: [0.2683725552160754]
# computed_metrics: [0.5881664920963167]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.30255867408921644]
# computed_metrics: [0.30255867408921644]
# computed_metrics: [0.6218764137656846]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0
#  [0.2969546  0.58706495]
#  [0.26667097 0.58301029]
#  [0.30790389 0.6238203 ]
#  [0.30971943 0.6399847 ]
#  [0.25788788 0.60240069]
#  [0.28847685 0.6117796 ]
#  [0.33791663 0.62530499]
#  [0.30564734 0.60573998]
#  [0.27199981 0.58987106]
#  [0.31087884 0.63508216]
#  [0.33721985 0.66293815]
#  [0.2769783  0.59933184]
#  [0.26734737 0.59135659]
#  [0.32871857 0.61621246]
#  [0.34209124 0.62280959]
#  [0.26837256 0.58816649]
#  [0.30255867 0.62187641]
#  [0.31091141 0.616222  ]
#  [0.27097114 0.62251572]
#  [0.25327617 0.59165731]
#  [0.31015269 0.60463857]
#  [0.30861343 0.62024759]
#  [0.26464903 0.58618391]
#  [0.28593436 0.61140487]
#  [0.31545479 0.6347529 ]
#  [0.2848689  0.62578525]
#  [0.25531747 0.59510459]
#  [0.32613459 0.62714445]
#  [0.30511686 0.61503616]
#  [0.29565737 0.60129503]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.561701694569259]
# computed_metrics: [2.561701694569259]
# computed_metrics: [2.52298495517027]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.359776561538934]
# computed_metrics: [1.359776561538934]
# computed_metrics: [1.2986256034661763]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.0451598339203143]
# computed_metrics: [1.0451598339203143]
# computed_metrics: [0.9964358505978846]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [0.9628530885093146]
# computed_metrics: [0.9628530885093146]
# computed_metrics: [0.9459262623988512]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9409081080762655]
# computed_metrics: [0.9409081080762655]
# computed_metrics: [0.935296669578578]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9353899084499133]
# computed_metrics: [0.9353899084499133]
# computed_metrics: [0.9361750762628086]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9265633241556852]
# computed_metrics: [0.9265633241556852]
# computed_metrics: [0.9240259784316676]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.929057323270544]
# computed_metrics: [0.929057323270544]
# computed_metrics: [0.9296859776179895]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.917780002909332]
# computed_metrics: [0.917780002909332]
# computed_metrics: [0.9268234194706789]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8991675056366752]
# computed_metrics: [0.8991675056366752]
# computed_metrics: [0.8902514494968278]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8974580211641582]
# computed_metrics: [0.8974580211641582]
# computed_metrics: [0.8947214006642403]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8945859737723832]
# computed_metrics: [0.8945859737723832]
# computed_metrics: [0.8800454760599052]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8716377541978773]
# computed_metrics: [0.8716377541978773]
# computed_metrics: [0.8544471504521843]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8706622632080822]
# computed_metrics: [0.8706622632080822]
# computed_metrics: [0.8636310655118662]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8561744827363245]
# computed_metrics: [0.8561744827363245]
# computed_metrics: [0.8396157871169403]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8542999456449499]
# computed_metrics: [0.8542999456449499]
# computed_metrics: [0.8483986985865399]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8379308298227142]
# computed_metrics: [0.8379308298227142]
# computed_metrics: [0.8242878866209773]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8254637850117209]
# computed_metrics: [0.8254637850117209]
# computed_metrics: [0.8135573331609629]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.8099958074198783]
# computed_metrics: [0.8099958074198783]
# computed_metrics: [0.7994881129680339]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.8091239654599165]
# computed_metrics: [0.8091239654599165]
# computed_metrics: [0.806926608289847]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7938888378690608]
# computed_metrics: [0.7938888378690608]
# computed_metrics: [0.7893332726333232]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7791822063172112]
# computed_metrics: [0.7791822063172112]
# computed_metrics: [0.7807813374641172]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7722734311946385]
# computed_metrics: [0.7722734311946385]
# computed_metrics: [0.7882015951374642]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7498952325993588]
# computed_metrics: [0.7498952325993588]
# computed_metrics: [0.7718957408211887]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7287623320944238]
# computed_metrics: [0.7287623320944238]
# computed_metrics: [0.7554543232825758]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.710689690183565]
# computed_metrics: [0.710689690183565]
# computed_metrics: [0.7440145843483374]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6989481075421481]
# computed_metrics: [0.6989481075421481]
# computed_metrics: [0.7392322760035238]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6850021118738965]
# computed_metrics: [0.6850021118738965]
# computed_metrics: [0.7292220296350833]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6776417150970251]
# computed_metrics: [0.6776417150970251]
# computed_metrics: [0.7166800742774465]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6707894946341988]
# computed_metrics: [0.6707894946341988]
# computed_metrics: [0.7181358668653636]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6654507339248704]
# computed_metrics: [0.6654507339248704]
# computed_metrics: [0.7134837690840586]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6619322523492965]
# computed_metrics: [0.6619322523492965]
# computed_metrics: [0.7116206183463917]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6555367482714097]
# computed_metrics: [0.6555367482714097]
# computed_metrics: [0.7114755288951383]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6496876356328537]
# computed_metrics: [0.6496876356328537]
# computed_metrics: [0.7030474649925812]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6399592179930874]
# computed_metrics: [0.6399592179930874]
# computed_metrics: [0.6985596701713883]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6301882027962545]
# computed_metrics: [0.6301882027962545]
# computed_metrics: [0.6932488626793404]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6245397505358579]
# computed_metrics: [0.6245397505358579]
# computed_metrics: [0.6868214353913614]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6145205149773834]
# computed_metrics: [0.6145205149773834]
# computed_metrics: [0.6894129000972516]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6127654044028503]
# computed_metrics: [0.6127654044028503]
# computed_metrics: [0.6790932755271308]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.6060243769659576]
# computed_metrics: [0.6060243769659576]
# computed_metrics: [0.6832994374767283]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6067959490525521]
# computed_metrics: [0.6067959490525521]
# computed_metrics: [0.679079195169615]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.595723831669513]
# computed_metrics: [0.595723831669513]
# computed_metrics: [0.6766256813411226]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5955851958104268]
# computed_metrics: [0.5955851958104268]
# computed_metrics: [0.6713172081563654]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5907703993124385]
# computed_metrics: [0.5907703993124385]
# computed_metrics: [0.6750774403541883]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5908374540320005]
# computed_metrics: [0.5908374540320005]
# computed_metrics: [0.6729931290179523]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5927541970843592]
# computed_metrics: [0.5927541970843592]
# computed_metrics: [0.6673970528288025]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.605456100482354]
# computed_metrics: [0.605456100482354]
# computed_metrics: [0.6793412311798925]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.593875588662934]
# computed_metrics: [0.593875588662934]
# computed_metrics: [0.6701002302198054]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.6169321601818958]
# computed_metrics: [0.6169321601818958]
# computed_metrics: [0.6816298551215638]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.6077338770238047]
# computed_metrics: [0.6077338770238047]
# computed_metrics: [0.6804154762479644]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.6017477968644089]
# computed_metrics: [0.6017477968644089]
# computed_metrics: [0.668670864906075]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.6280567646392778]
# computed_metrics: [0.6280567646392778]
# computed_metrics: [0.6892499349736895]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5993363591721447]
# computed_metrics: [0.5993363591721447]
# computed_metrics: [0.6651274653845571]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.6069154573830737]
# computed_metrics: [0.6069154573830737]
# computed_metrics: [0.6632079397484416]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5967578882567567]
# computed_metrics: [0.5967578882567567]
# computed_metrics: [0.6584408769983217]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.6046713097645501]
# computed_metrics: [0.6046713097645501]
# computed_metrics: [0.659233378016825]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5925259531440062]
# computed_metrics: [0.5925259531440062]
# computed_metrics: [0.6630925893535116]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5928218088194512]
# computed_metrics: [0.5928218088194512]
# computed_metrics: [0.6560712287367153]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5949894380931383]
# computed_metrics: [0.5949894380931383]
# computed_metrics: [0.6519898943696154]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.573815188483534]
# computed_metrics: [0.573815188483534]
# computed_metrics: [0.6438679982111609]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5694513661689655]
# computed_metrics: [0.5694513661689655]
# computed_metrics: [0.6426398827522602]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5562875601643916]
# computed_metrics: [0.5562875601643916]
# computed_metrics: [0.6285796839794048]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5624348442916873]
# computed_metrics: [0.5624348442916873]
# computed_metrics: [0.630335378408218]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5464245802233406]
# computed_metrics: [0.5464245802233406]
# computed_metrics: [0.6273483637331967]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5358778510836768]
# computed_metrics: [0.5358778510836768]
# computed_metrics: [0.615774464018863]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5249021483519124]
# computed_metrics: [0.5249021483519124]
# computed_metrics: [0.6164250239202673]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5221815141862093]
# computed_metrics: [0.5221815141862093]
# computed_metrics: [0.6159200870465775]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.5213050112669855]
# computed_metrics: [0.5213050112669855]
# computed_metrics: [0.6124575722008699]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.5175045082655967]
# computed_metrics: [0.5175045082655967]
# computed_metrics: [0.614215185372748]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5133172959175611]
# computed_metrics: [0.5133172959175611]
# computed_metrics: [0.6146706458578075]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5032465520297879]
# computed_metrics: [0.5032465520297879]
# computed_metrics: [0.6133767735766265]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5093187253929728]
# computed_metrics: [0.5093187253929728]
# computed_metrics: [0.6261487990816524]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.5073473110417883]
# computed_metrics: [0.5073473110417883]
# computed_metrics: [0.61664200973795]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5160680538795817]
# computed_metrics: [0.5160680538795817]
# computed_metrics: [0.6341170454090143]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.5105311319421008]
# computed_metrics: [0.5105311319421008]
# computed_metrics: [0.6320575389597961]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5091472718788257]
# computed_metrics: [0.5091472718788257]
# computed_metrics: [0.6396632732528562]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5122311832598702]
# computed_metrics: [0.5122311832598702]
# computed_metrics: [0.6384763357534363]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5077473415623092]
# computed_metrics: [0.5077473415623092]
# computed_metrics: [0.6276563024826246]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.507104199267809]
# computed_metrics: [0.507104199267809]
# computed_metrics: [0.6233282237718639]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.49724801440012756]
# computed_metrics: [0.49724801440012756]
# computed_metrics: [0.6177495194106453]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4994078497297785]
# computed_metrics: [0.4994078497297785]
# computed_metrics: [0.6243953280013308]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4936885845942361]
# computed_metrics: [0.4936885845942361]
# computed_metrics: [0.6194751515100424]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.490404262614893]
# computed_metrics: [0.490404262614893]
# computed_metrics: [0.6232767193332877]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.48272639395141564]
# computed_metrics: [0.48272639395141564]
# computed_metrics: [0.6083138676689036]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.4678676966603571]
# computed_metrics: [0.4678676966603571]
# computed_metrics: [0.5973359400505336]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.46702132849059586]
# computed_metrics: [0.46702132849059586]
# computed_metrics: [0.602167654371495]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4607527612953094]
# computed_metrics: [0.4607527612953094]
# computed_metrics: [0.60076312846872]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4642283531825445]
# computed_metrics: [0.4642283531825445]
# computed_metrics: [0.5916868834869585]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.45904617210509874]
# computed_metrics: [0.45904617210509874]
# computed_metrics: [0.5973321274852742]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.4628787441431697]
# computed_metrics: [0.4628787441431697]
# computed_metrics: [0.6034014055923679]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.4661071421296666]
# computed_metrics: [0.4661071421296666]
# computed_metrics: [0.6041876564995607]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.46458159590698633]
# computed_metrics: [0.46458159590698633]
# computed_metrics: [0.5905213449119153]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.46514069046069234]
# computed_metrics: [0.46514069046069234]
# computed_metrics: [0.5911197709664436]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4744290503936399]
# computed_metrics: [0.4744290503936399]
# computed_metrics: [0.6079057572988209]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4691687135492276]
# computed_metrics: [0.4691687135492276]
# computed_metrics: [0.6018055491019435]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.4658933722832691]
# computed_metrics: [0.4658933722832691]
# computed_metrics: [0.6039425682847755]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.5110444798476524]
# computed_metrics: [0.5110444798476524]
# computed_metrics: [0.6301099448934572]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.4608051866817766]
# computed_metrics: [0.4608051866817766]
# computed_metrics: [0.598991013350405]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.5384104058227304]
# computed_metrics: [0.5384104058227304]
# computed_metrics: [0.6513255345010553]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.49120469469848005]
# computed_metrics: [0.49120469469848005]
# computed_metrics: [0.6146916952260969]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.5267605988360401]
# computed_metrics: [0.5267605988360401]
# computed_metrics: [0.6309523929487612]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.5072918280714868]
# computed_metrics: [0.5072918280714868]
# computed_metrics: [0.6251210116617244]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.5919374583683625]
# computed_metrics: [0.5919374583683625]
# computed_metrics: [0.6766041752173657]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.5428623533495649]
# computed_metrics: [0.5428623533495649]
# computed_metrics: [0.6430983503825246]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.6071546572880037]
# computed_metrics: [0.6071546572880037]
# computed_metrics: [0.6809838356013669]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.5453086427463891]
# computed_metrics: [0.5453086427463891]
# computed_metrics: [0.6310796790789659]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.5702182521445658]
# computed_metrics: [0.5702182521445658]
# computed_metrics: [0.6553163762560223]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.5399333056307406]
# computed_metrics: [0.5399333056307406]
# computed_metrics: [0.6257342344817832]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.5154867042454038]
# computed_metrics: [0.5154867042454038]
# computed_metrics: [0.6210214375981855]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.5041071971493679]
# computed_metrics: [0.5041071971493679]
# computed_metrics: [0.6006530829853578]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.4943750238228072]
# computed_metrics: [0.4943750238228072]
# computed_metrics: [0.588788005104683]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.46284096033588046]
# computed_metrics: [0.46284096033588046]
# computed_metrics: [0.5863722498661776]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.4527551740976709]
# computed_metrics: [0.4527551740976709]
# computed_metrics: [0.5761163246391616]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.43640360801329003]
# computed_metrics: [0.43640360801329003]
# computed_metrics: [0.5805629270898711]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.43667356534708024]
# computed_metrics: [0.43667356534708024]
# computed_metrics: [0.5888569312383811]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.4508571704688094]
# computed_metrics: [0.4508571704688094]
# computed_metrics: [0.607184229248198]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.45289941377199966]
# computed_metrics: [0.45289941377199966]
# computed_metrics: [0.6218524134176026]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.4894213212515887]
# computed_metrics: [0.4894213212515887]
# computed_metrics: [0.6563174010490239]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.46765277367726027]
# computed_metrics: [0.46765277367726027]
# computed_metrics: [0.6426501837856462]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.4969683049960359]
# computed_metrics: [0.4969683049960359]
# computed_metrics: [0.6566314111518362]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.47804113251380026]
# computed_metrics: [0.47804113251380026]
# computed_metrics: [0.6410239224990487]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.4861159554255035]
# computed_metrics: [0.4861159554255035]
# computed_metrics: [0.6394675212541038]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.4442281567704039]
# computed_metrics: [0.4442281567704039]
# computed_metrics: [0.6155977040433873]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.41492064904200054]
# computed_metrics: [0.41492064904200054]
# computed_metrics: [0.5993507657554235]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.4082911617379429]
# computed_metrics: [0.4082911617379429]
# computed_metrics: [0.5863955070613373]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.39976387684852127]
# computed_metrics: [0.39976387684852127]
# computed_metrics: [0.6020927338457718]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.4125639216413261]
# computed_metrics: [0.4125639216413261]
# computed_metrics: [0.5849228641158337]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.41571718202475244]
# computed_metrics: [0.41571718202475244]
# computed_metrics: [0.6047019618616826]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.4080053327109142]
# computed_metrics: [0.4080053327109142]
# computed_metrics: [0.576511671832508]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.41631912158768813]
# computed_metrics: [0.41631912158768813]
# computed_metrics: [0.576851745438942]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.41933037411413154]
# computed_metrics: [0.41933037411413154]
# computed_metrics: [0.5948383230935423]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.4090304103432615]
# computed_metrics: [0.4090304103432615]
# computed_metrics: [0.5745344552784036]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.43442884364260465]
# computed_metrics: [0.43442884364260465]
# computed_metrics: [0.598808839420924]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.393201693373974]
# computed_metrics: [0.393201693373974]
# computed_metrics: [0.5748533937286113]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.42306842634136044]
# computed_metrics: [0.42306842634136044]
# computed_metrics: [0.5917958622759534]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.4172384521822545]
# computed_metrics: [0.4172384521822545]
# computed_metrics: [0.5810151659575473]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.3865881424495732]
# computed_metrics: [0.3865881424495732]
# computed_metrics: [0.5570186616159094]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.38489439996528496]
# computed_metrics: [0.38489439996528496]
# computed_metrics: [0.5681495176394861]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.3741387422839536]
# computed_metrics: [0.3741387422839536]
# computed_metrics: [0.5838638610829942]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.37204643217838596]
# computed_metrics: [0.37204643217838596]
# computed_metrics: [0.5756219979241667]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.3709848431407076]
# computed_metrics: [0.3709848431407076]
# computed_metrics: [0.5851931907948028]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.37660124986615284]
# computed_metrics: [0.37660124986615284]
# computed_metrics: [0.591957879573838]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.36853268345448675]
# computed_metrics: [0.36853268345448675]
# computed_metrics: [0.5901200191159874]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.3790782429422329]
# computed_metrics: [0.3790782429422329]
# computed_metrics: [0.6029666612139424]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.3972726077290036]
# computed_metrics: [0.3972726077290036]
# computed_metrics: [0.6030786902833217]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.38609570367497]
# computed_metrics: [0.38609570367497]
# computed_metrics: [0.6146062801376236]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.39249999174661887]
# computed_metrics: [0.39249999174661887]
# computed_metrics: [0.6136876668590906]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.3944425074315882]
# computed_metrics: [0.3944425074315882]
# computed_metrics: [0.6129050501282004]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.39750035925499766]
# computed_metrics: [0.39750035925499766]
# computed_metrics: [0.6265558601636776]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.40605191343729563]
# computed_metrics: [0.40605191343729563]
# computed_metrics: [0.6273499058277329]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.38033377535534924]
# computed_metrics: [0.38033377535534924]
# computed_metrics: [0.6161945382199366]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3790515895972973]
# computed_metrics: [0.3790515895972973]
# computed_metrics: [0.6056826300294851]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.40614932499010176]
# computed_metrics: [0.40614932499010176]
# computed_metrics: [0.6318146523924597]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.3853529677160772]
# computed_metrics: [0.3853529677160772]
# computed_metrics: [0.6183098686679384]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.3572660862721086]
# computed_metrics: [0.3572660862721086]
# computed_metrics: [0.599190148571985]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.36638269559430797]
# computed_metrics: [0.36638269559430797]
# computed_metrics: [0.6018330207436203]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.3753228578788368]
# computed_metrics: [0.3753228578788368]
# computed_metrics: [0.6204983453142654]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3640602863411592]
# computed_metrics: [0.3640602863411592]
# computed_metrics: [0.6038365202636455]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.39559237941048014]
# computed_metrics: [0.39559237941048014]
# computed_metrics: [0.6412254576476195]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.36468010185784266]
# computed_metrics: [0.36468010185784266]
# computed_metrics: [0.6125238759438455]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.36517417991449874]
# computed_metrics: [0.36517417991449874]
# computed_metrics: [0.5909206204416061]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.3812494631504117]
# computed_metrics: [0.3812494631504117]
# computed_metrics: [0.6205502398603985]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3780948543990088]
# computed_metrics: [0.3780948543990088]
# computed_metrics: [0.6001340274509599]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.3594374281042357]
# computed_metrics: [0.3594374281042357]
# computed_metrics: [0.5921159675191618]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.41335898612050875]
# computed_metrics: [0.41335898612050875]
# computed_metrics: [0.6188813969330561]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.38010929494978496]
# computed_metrics: [0.38010929494978496]
# computed_metrics: [0.597883173838111]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.4043680340258204]
# computed_metrics: [0.4043680340258204]
# computed_metrics: [0.6146972040568291]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3940680298907754]
# computed_metrics: [0.3940680298907754]
# computed_metrics: [0.6127447959749494]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.42637769567890327]
# computed_metrics: [0.42637769567890327]
# computed_metrics: [0.6304409220383562]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.410094964422528]
# computed_metrics: [0.410094964422528]
# computed_metrics: [0.612023329204512]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.4043993842789638]
# computed_metrics: [0.4043993842789638]
# computed_metrics: [0.6123714803560273]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.393566576564626]
# computed_metrics: [0.393566576564626]
# computed_metrics: [0.6129114811316092]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.3635628846477786]
# computed_metrics: [0.3635628846477786]
# computed_metrics: [0.5998510264333725]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.3409409843445652]
# computed_metrics: [0.3409409843445652]
# computed_metrics: [0.5893168631576821]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.34942176513555107]
# computed_metrics: [0.34942176513555107]
# computed_metrics: [0.6145248619267167]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.35066639429588775]
# computed_metrics: [0.35066639429588775]
# computed_metrics: [0.6088909716339632]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.37904549725595177]
# computed_metrics: [0.37904549725595177]
# computed_metrics: [0.6158452760156045]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.375985019327889]
# computed_metrics: [0.375985019327889]
# computed_metrics: [0.6182829199747822]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.4194241639631503]
# computed_metrics: [0.4194241639631503]
# computed_metrics: [0.6402550884453342]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.38363976279445605]
# computed_metrics: [0.38363976279445605]
# computed_metrics: [0.6309604532321993]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.41696662639967286]
# computed_metrics: [0.41696662639967286]
# computed_metrics: [0.6251724248255173]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.36124241531064516]
# computed_metrics: [0.36124241531064516]
# computed_metrics: [0.612654233491716]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.3919281711647864]
# computed_metrics: [0.3919281711647864]
# computed_metrics: [0.6400492752710092]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.3680989126150503]
# computed_metrics: [0.3680989126150503]
# computed_metrics: [0.6042325390720632]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.33133624728834826]
# computed_metrics: [0.33133624728834826]
# computed_metrics: [0.6050550673813718]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.330475196862794]
# computed_metrics: [0.330475196862794]
# computed_metrics: [0.6014573189353982]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.3281630880280326]
# computed_metrics: [0.3281630880280326]
# computed_metrics: [0.6028904542764941]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.31645143730187775]
# computed_metrics: [0.31645143730187775]
# computed_metrics: [0.5946780182777659]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.3139952781008283]
# computed_metrics: [0.3139952781008283]
# computed_metrics: [0.5985774519595461]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.33396421063271836]
# computed_metrics: [0.33396421063271836]
# computed_metrics: [0.6010034268231688]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.32131873668491073]
# computed_metrics: [0.32131873668491073]
# computed_metrics: [0.6000594783400762]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.3292647944037286]
# computed_metrics: [0.3292647944037286]
# computed_metrics: [0.5945221481585097]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.37861407650817896]
# computed_metrics: [0.37861407650817896]
# computed_metrics: [0.6287217957744585]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3586188296244589]
# computed_metrics: [0.3586188296244589]
# computed_metrics: [0.6053359799469942]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.3677503543130504]
# computed_metrics: [0.3677503543130504]
# computed_metrics: [0.6000447171125605]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.32538032987737087]
# computed_metrics: [0.32538032987737087]
# computed_metrics: [0.5865757334663958]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.35931306533049306]
# computed_metrics: [0.35931306533049306]
# computed_metrics: [0.5969195091355333]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.3411784674871886]
# computed_metrics: [0.3411784674871886]
# computed_metrics: [0.6099505376822422]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.3217361998588369]
# computed_metrics: [0.3217361998588369]
# computed_metrics: [0.5930654917165092]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.3189891486177742]
# computed_metrics: [0.3189891486177742]
# computed_metrics: [0.5995580583909906]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.33290302970119806]
# computed_metrics: [0.33290302970119806]
# computed_metrics: [0.5905267876374336]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.3280892599552216]
# computed_metrics: [0.3280892599552216]
# computed_metrics: [0.6042483491549955]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.33084380219037424]
# computed_metrics: [0.33084380219037424]
# computed_metrics: [0.6030328701457291]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.41104088938903854]
# computed_metrics: [0.41104088938903854]
# computed_metrics: [0.6565282671628497]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.35143227373508773]
# computed_metrics: [0.35143227373508773]
# computed_metrics: [0.6219618461617175]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.37005436615904386]
# computed_metrics: [0.37005436615904386]
# computed_metrics: [0.6412860026178758]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.408696953642628]
# computed_metrics: [0.408696953642628]
# computed_metrics: [0.6415204398794544]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.33375227798855567]
# computed_metrics: [0.33375227798855567]
# computed_metrics: [0.6138261642776479]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.3461678792949846]
# computed_metrics: [0.3461678792949846]
# computed_metrics: [0.6144419513547257]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.3293306710160524]
# computed_metrics: [0.3293306710160524]
# computed_metrics: [0.6084914454290796]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.31235354227436285]
# computed_metrics: [0.31235354227436285]
# computed_metrics: [0.6083217463728632]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.3112353819918081]
# computed_metrics: [0.3112353819918081]
# computed_metrics: [0.61444690722077]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.32460341269859844]
# computed_metrics: [0.32460341269859844]
# computed_metrics: [0.6165116933745053]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.3155773134089915]
# computed_metrics: [0.3155773134089915]
# computed_metrics: [0.6122278180018326]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.3810796834425186]
# computed_metrics: [0.3810796834425186]
# computed_metrics: [0.6515827456390907]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.37607076207833046]
# computed_metrics: [0.37607076207833046]
# computed_metrics: [0.6397154045108028]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.4288701198038799]
# computed_metrics: [0.4288701198038799]
# computed_metrics: [0.6484147287898864]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.40355341815036183]
# computed_metrics: [0.40355341815036183]
# computed_metrics: [0.6201746829300597]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.4174447111074297]
# computed_metrics: [0.4174447111074297]
# computed_metrics: [0.6280252070587821]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.5002943649719126]
# computed_metrics: [0.5002943649719126]
# computed_metrics: [0.6857191461438337]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.3562376757857356]
# computed_metrics: [0.3562376757857356]
# computed_metrics: [0.5953819182445026]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.409184397531389]
# computed_metrics: [0.409184397531389]
# computed_metrics: [0.6017666589307132]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.3440293404252627]
# computed_metrics: [0.3440293404252627]
# computed_metrics: [0.5885556289089094]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.33221731888888856]
# computed_metrics: [0.33221731888888856]
# computed_metrics: [0.5769796766087834]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3284181746331074]
# computed_metrics: [0.3284181746331074]
# computed_metrics: [0.5878038523386877]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.33768119074986525]
# computed_metrics: [0.33768119074986525]
# computed_metrics: [0.6081855740804828]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.3402810649036065]
# computed_metrics: [0.3402810649036065]
# computed_metrics: [0.6068066437442725]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.40750640556710516]
# computed_metrics: [0.40750640556710516]
# computed_metrics: [0.6527802363686537]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.3448045633412436]
# computed_metrics: [0.3448045633412436]
# computed_metrics: [0.6082938196627428]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.3945185164900075]
# computed_metrics: [0.3945185164900075]
# computed_metrics: [0.639223384047159]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.34136740367083235]
# computed_metrics: [0.34136740367083235]
# computed_metrics: [0.6136172576959485]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.32849583681434474]
# computed_metrics: [0.32849583681434474]
# computed_metrics: [0.6305590155654498]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.30838851111262333]
# computed_metrics: [0.30838851111262333]
# computed_metrics: [0.619070584739209]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.3117609032747633]
# computed_metrics: [0.3117609032747633]
# computed_metrics: [0.6053345297639878]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.33509247461207464]
# computed_metrics: [0.33509247461207464]
# computed_metrics: [0.633473706781401]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.3510061909557188]
# computed_metrics: [0.3510061909557188]
# computed_metrics: [0.6124479256874791]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.39869708589613795]
# computed_metrics: [0.39869708589613795]
# computed_metrics: [0.6287695215327006]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.3380024965023419]
# computed_metrics: [0.3380024965023419]
# computed_metrics: [0.5895074775341058]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.32042903839502074]
# computed_metrics: [0.32042903839502074]
# computed_metrics: [0.5848578521690343]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.30127756701816133]
# computed_metrics: [0.30127756701816133]
# computed_metrics: [0.5958121560072308]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.30810981762918377]
# computed_metrics: [0.30810981762918377]
# computed_metrics: [0.5986726457694731]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.3330449999503281]
# computed_metrics: [0.3330449999503281]
# computed_metrics: [0.6230973441386551]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.37461651234384613]
# computed_metrics: [0.37461651234384613]
# computed_metrics: [0.6518081890080313]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.4126706263922892]
# computed_metrics: [0.4126706263922892]
# computed_metrics: [0.6810946233672606]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.33360387263799857]
# computed_metrics: [0.33360387263799857]
# computed_metrics: [0.632958615475009]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.3280440584348853]
# computed_metrics: [0.3280440584348853]
# computed_metrics: [0.6523608377743648]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.30502558676457037]
# computed_metrics: [0.30502558676457037]
# computed_metrics: [0.6259940879503744]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.3403441898353787]
# computed_metrics: [0.3403441898353787]
# computed_metrics: [0.6316880319475727]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.3775143704533551]
# computed_metrics: [0.3775143704533551]
# computed_metrics: [0.6461541491847052]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.38690206266414556]
# computed_metrics: [0.38690206266414556]
# computed_metrics: [0.6449983502383647]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.43673800848553856]
# computed_metrics: [0.43673800848553856]
# computed_metrics: [0.6715554433751906]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.3379614621702049]
# computed_metrics: [0.3379614621702049]
# computed_metrics: [0.5813156899403299]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.343336855993589]
# computed_metrics: [0.343336855993589]
# computed_metrics: [0.6022927069908826]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.3279642384085609]
# computed_metrics: [0.3279642384085609]
# computed_metrics: [0.610515067470983]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.3597944775754777]
# computed_metrics: [0.3597944775754777]
# computed_metrics: [0.6479068221787999]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.37256064227710084]
# computed_metrics: [0.37256064227710084]
# computed_metrics: [0.6461012637695921]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.39477694794694823]
# computed_metrics: [0.39477694794694823]
# computed_metrics: [0.6794178545102556]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.3316852058417208]
# computed_metrics: [0.3316852058417208]
# computed_metrics: [0.6362983111315129]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.3041501996570586]
# computed_metrics: [0.3041501996570586]
# computed_metrics: [0.6356411214003812]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.3251261678592629]
# computed_metrics: [0.3251261678592629]
# computed_metrics: [0.6352227641271531]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.3573127381369808]
# computed_metrics: [0.3573127381369808]
# computed_metrics: [0.6251969947959669]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.3891499630562784]
# computed_metrics: [0.3891499630562784]
# computed_metrics: [0.6360358243234202]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.3450156937653367]
# computed_metrics: [0.3450156937653367]
# computed_metrics: [0.6102375102952196]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.2995231500584972]
# computed_metrics: [0.2995231500584972]
# computed_metrics: [0.5988085367915338]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.314242587134162]
# computed_metrics: [0.314242587134162]
# computed_metrics: [0.6185601463319897]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.31715234340253495]
# computed_metrics: [0.31715234340253495]
# computed_metrics: [0.6255036785104461]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.38083920573341845]
# computed_metrics: [0.38083920573341845]
# computed_metrics: [0.6579442057855437]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.31758050732050724]
# computed_metrics: [0.31758050732050724]
# computed_metrics: [0.6274129843982661]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.2857944765506414]
# computed_metrics: [0.2857944765506414]
# computed_metrics: [0.6197332191958381]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.324574942829645]
# computed_metrics: [0.324574942829645]
# computed_metrics: [0.6511666484981999]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.36243713365099717]
# computed_metrics: [0.36243713365099717]
# computed_metrics: [0.633296485103703]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.3580801932857237]
# computed_metrics: [0.3580801932857237]
# computed_metrics: [0.6102232526283013]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.3143288010307414]
# computed_metrics: [0.3143288010307414]
# computed_metrics: [0.5956082875722466]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.2948700773065999]
# computed_metrics: [0.2948700773065999]
# computed_metrics: [0.6110345599279643]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.3562176105287177]
# computed_metrics: [0.3562176105287177]
# computed_metrics: [0.6381053692690639]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.4055941322172689]
# computed_metrics: [0.4055941322172689]
# computed_metrics: [0.6769488567370011]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.3253484284847866]
# computed_metrics: [0.3253484284847866]
# computed_metrics: [0.6310219418716859]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.29541954550308075]
# computed_metrics: [0.29541954550308075]
# computed_metrics: [0.6253767866741322]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.29931619978100665]
# computed_metrics: [0.29931619978100665]
# computed_metrics: [0.6386829516490334]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.3414138189667948]
# computed_metrics: [0.3414138189667948]
# computed_metrics: [0.6240190252210445]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.3707095471225138]
# computed_metrics: [0.3707095471225138]
# computed_metrics: [0.6326723462200652]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.3232238925721037]
# computed_metrics: [0.3232238925721037]
# computed_metrics: [0.5874766914473631]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.2952015391714565]
# computed_metrics: [0.2952015391714565]
# computed_metrics: [0.6019880216681319]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.3404277470040342]
# computed_metrics: [0.3404277470040342]
# computed_metrics: [0.635515241137123]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3487629924842438]
# computed_metrics: [0.3487629924842438]
# computed_metrics: [0.6408216709640547]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.34049506023049647]
# computed_metrics: [0.34049506023049647]
# computed_metrics: [0.6414759043614866]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.3016623276365413]
# computed_metrics: [0.3016623276365413]
# computed_metrics: [0.6259561747071477]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.2983343186439133]
# computed_metrics: [0.2983343186439133]
# computed_metrics: [0.6320426660855484]
# ...
# Starting validation epoch 315
# computed_metrics: [0.3360967999633597]
# computed_metrics: [0.3360967999633597]
# computed_metrics: [0.6688821810167639]
# Starting epoch 316
# Starting validation epoch 316
# computed_metrics: [0.3028155490871173]
# computed_metrics: [0.3028155490871173]
# computed_metrics: [0.6357434803188596]
# Starting epoch 317
# Starting validation epoch 317
# computed_metrics: [0.3818616435693138]
# computed_metrics: [0.3818616435693138]
# computed_metrics: [0.6933852346053034]
# Starting epoch 318
# Starting validation epoch 318
# computed_metrics: [0.3463930369658551]
# computed_metrics: [0.3463930369658551]
# computed_metrics: [0.6377889449218844]
# Starting epoch 319
# Starting validation epoch 319
# computed_metrics: [0.36937880173649107]
# computed_metrics: [0.36937880173649107]
# computed_metrics: [0.6274745614461148]
# Starting epoch 320
# Starting validation epoch 320
# computed_metrics: [0.3033142319797477]
# computed_metrics: [0.3033142319797477]
# computed_metrics: [0.6076691029822135]
# Starting epoch 321
# Starting validation epoch 321
# computed_metrics: [0.3060345142187357]
# computed_metrics: [0.3060345142187357]
# computed_metrics: [0.6070488564556623]
# Starting epoch 322
# Starting validation epoch 322
# computed_metrics: [0.3435548163910205]
# computed_metrics: [0.3435548163910205]
# computed_metrics: [0.6326090443366272]
# Starting epoch 323
# Starting validation epoch 323
# computed_metrics: [0.3636262559329516]
# computed_metrics: [0.3636262559329516]
# computed_metrics: [0.6586597994753757]
# Starting epoch 324
# Starting validation epoch 324
# computed_metrics: [0.3564946714429253]
# computed_metrics: [0.3564946714429253]
# computed_metrics: [0.6704322367304536]
# Starting epoch 325
# Starting validation epoch 325
# computed_metrics: [0.29136735899325916]
# computed_metrics: [0.29136735899325916]
# computed_metrics: [0.6476910330074381]
# Starting epoch 326
# Starting validation epoch 326
# computed_metrics: [0.32425095916916197]
# computed_metrics: [0.32425095916916197]
# computed_metrics: [0.6618140664698753]
# Starting epoch 327
# Starting validation epoch 327
# computed_metrics: [0.39984678143601593]
# computed_metrics: [0.39984678143601593]
# computed_metrics: [0.6748651677625229]
# Starting epoch 328
# Starting validation epoch 328
# computed_metrics: [0.3816755252283989]
# computed_metrics: [0.3816755252283989]
# computed_metrics: [0.6248865947122362]
# Starting epoch 329
# Starting validation epoch 329
# computed_metrics: [0.302425200255814]
# computed_metrics: [0.302425200255814]
# computed_metrics: [0.5980232420934307]
# Starting epoch 330
# Starting validation epoch 330
# computed_metrics: [0.30945862255046386]
# computed_metrics: [0.30945862255046386]
# computed_metrics: [0.6229804683595015]
# Starting epoch 331
# Starting validation epoch 331
# computed_metrics: [0.4146876918338258]
# computed_metrics: [0.4146876918338258]
# computed_metrics: [0.6904271052940945]
# Starting epoch 332
# Starting validation epoch 332
# computed_metrics: [0.348507259539028]
# computed_metrics: [0.348507259539028]
# computed_metrics: [0.6674633420638846]
# Starting epoch 333
# Starting validation epoch 333
# computed_metrics: [0.29461387729441696]
# computed_metrics: [0.29461387729441696]
# computed_metrics: [0.6211063692514681]
# Starting epoch 334
# Starting validation epoch 334
# computed_metrics: [0.3251897895247413]
# computed_metrics: [0.3251897895247413]
# computed_metrics: [0.6505992715445867]
# Starting epoch 335
# Starting validation epoch 335
# computed_metrics: [0.3474808438283893]
# computed_metrics: [0.3474808438283893]
# computed_metrics: [0.6521794628322]
# Starting epoch 336
# Starting validation epoch 336
# computed_metrics: [0.3416378246600633]
# computed_metrics: [0.3416378246600633]
# computed_metrics: [0.6187974094219739]
# Starting epoch 337
# Starting validation epoch 337
# computed_metrics: [0.2756286058315575]
# computed_metrics: [0.2756286058315575]
# computed_metrics: [0.6062094982352365]
# Starting epoch 338
# Starting validation epoch 338
# computed_metrics: [0.31752226954447205]
# computed_metrics: [0.31752226954447205]
# computed_metrics: [0.6424438668559387]
# Starting epoch 339
# Starting validation epoch 339
# computed_metrics: [0.3544907728526763]
# computed_metrics: [0.3544907728526763]
# computed_metrics: [0.6691731128196423]
# Starting epoch 340
# Starting validation epoch 340
# computed_metrics: [0.33317432780185896]
# computed_metrics: [0.33317432780185896]
# computed_metrics: [0.6499992756393483]
# Starting epoch 341
# Starting validation epoch 341
# computed_metrics: [0.28782359977756555]
# computed_metrics: [0.28782359977756555]
# computed_metrics: [0.6287503592753046]
# Starting epoch 342
# Starting validation epoch 342
# computed_metrics: [0.3725269446087765]
# computed_metrics: [0.3725269446087765]
# computed_metrics: [0.6995334840219086]
# Starting epoch 343
# Starting validation epoch 343
# computed_metrics: [0.35920630862764924]
# computed_metrics: [0.35920630862764924]
# computed_metrics: [0.6183035824269624]
# Starting epoch 344
# Starting validation epoch 344
# computed_metrics: [0.2864838304092624]
# computed_metrics: [0.2864838304092624]
# computed_metrics: [0.6004153964510531]
# Starting epoch 345
# Starting validation epoch 345
# computed_metrics: [0.29577688672544755]
# computed_metrics: [0.29577688672544755]
# computed_metrics: [0.6189679963127522]
# Starting epoch 346
# Starting validation epoch 346
# computed_metrics: [0.36096585753736293]
# computed_metrics: [0.36096585753736293]
# computed_metrics: [0.6619174727823777]
# Starting epoch 347
# Starting validation epoch 347
# computed_metrics: [0.3257039464130008]
# computed_metrics: [0.3257039464130008]
# computed_metrics: [0.6444017657548974]
# Starting epoch 348
# Starting validation epoch 348
# computed_metrics: [0.2892534100656858]
# computed_metrics: [0.2892534100656858]
# computed_metrics: [0.6267328230943703]
# Starting epoch 349
# Starting validation epoch 349
# computed_metrics: [0.2830616847561954]
# computed_metrics: [0.2830616847561954]
# computed_metrics: [0.6246292194271557]
# Starting epoch 350
# Starting validation epoch 350
# computed_metrics: [0.31468244056877337]
# computed_metrics: [0.31468244056877337]
# computed_metrics: [0.6283168418983702]
# Starting epoch 351
# Starting validation epoch 351
# computed_metrics: [0.26526074506001757]
# computed_metrics: [0.26526074506001757]
# computed_metrics: [0.5964919495384288]
# Starting epoch 352
# Starting validation epoch 352
# computed_metrics: [0.2656430010952203]
# computed_metrics: [0.2656430010952203]
# computed_metrics: [0.6058615993846952]
# Starting epoch 353
# Starting validation epoch 353
# computed_metrics: [0.31120195141139506]
# computed_metrics: [0.31120195141139506]
# computed_metrics: [0.6362223127442578]
# Starting epoch 354
# Starting validation epoch 354
# computed_metrics: [0.30789703922357964]
# computed_metrics: [0.30789703922357964]
# computed_metrics: [0.6461865287289444]
# Starting epoch 355
# Starting validation epoch 355
# computed_metrics: [0.28089509982006333]
# computed_metrics: [0.28089509982006333]
# computed_metrics: [0.6516486130940783]
# Starting epoch 356
# Starting validation epoch 356
# computed_metrics: [0.3147629903822836]
# computed_metrics: [0.3147629903822836]
# computed_metrics: [0.6586782351735442]
# Starting epoch 357
# Starting validation epoch 357
# computed_metrics: [0.34119641059386374]
# computed_metrics: [0.34119641059386374]
# computed_metrics: [0.640790858348208]
# Starting epoch 358
# Starting validation epoch 358
# computed_metrics: [0.2721135035066605]
# computed_metrics: [0.2721135035066605]
# computed_metrics: [0.601817864531841]
# Starting epoch 359
# Starting validation epoch 359
# computed_metrics: [0.2942704897122202]
# computed_metrics: [0.2942704897122202]
# computed_metrics: [0.6259618813550387]
# Starting epoch 360
# Starting validation epoch 360
# computed_metrics: [0.32811030965189686]
# computed_metrics: [0.32811030965189686]
# computed_metrics: [0.6556452422020372]
# Starting epoch 361
# Starting validation epoch 361
# computed_metrics: [0.2967669635178425]
# computed_metrics: [0.2967669635178425]
# computed_metrics: [0.6441967671592786]
# Starting epoch 362
# Starting validation epoch 362
# computed_metrics: [0.2806751954367474]
# computed_metrics: [0.2806751954367474]
# computed_metrics: [0.6452081856612402]
# Starting epoch 363
# Starting validation epoch 363
# computed_metrics: [0.3272111250446169]
# computed_metrics: [0.3272111250446169]
# computed_metrics: [0.6513703310729655]
# Starting epoch 364
# Starting validation epoch 364
# computed_metrics: [0.30480082977022954]
# computed_metrics: [0.30480082977022954]
# computed_metrics: [0.6138251469871809]
# Starting epoch 365
# Starting validation epoch 365
# computed_metrics: [0.2609755616115815]
# computed_metrics: [0.2609755616115815]
# computed_metrics: [0.6013880352633337]
# Starting epoch 366
# Starting validation epoch 366
# computed_metrics: [0.3027463471891223]
# computed_metrics: [0.3027463471891223]
# computed_metrics: [0.6393671729476695]
# Starting epoch 367
# Starting validation epoch 367
# computed_metrics: [0.31306125357386355]
# computed_metrics: [0.31306125357386355]
# computed_metrics: [0.6608316180855073]
# Starting epoch 368
# Starting validation epoch 368
# computed_metrics: [0.27295144483382927]
# computed_metrics: [0.27295144483382927]
# computed_metrics: [0.6332445933168097]
# Starting epoch 369
# Starting validation epoch 369
# computed_metrics: [0.3075412619659604]
# computed_metrics: [0.3075412619659604]
# computed_metrics: [0.6583842665486891]
# Starting epoch 370
# Starting validation epoch 370
# computed_metrics: [0.3289445198306291]
# computed_metrics: [0.3289445198306291]
# computed_metrics: [0.631698328814774]
# Starting epoch 371
# Starting validation epoch 371
# computed_metrics: [0.27789090151441714]
# computed_metrics: [0.27789090151441714]
# computed_metrics: [0.5944600819711396]
# Starting epoch 372
# Starting validation epoch 372
# computed_metrics: [0.2854383388034857]
# computed_metrics: [0.2854383388034857]
# computed_metrics: [0.6286977692199361]
# Starting epoch 373
# Starting validation epoch 373
# computed_metrics: [0.3147684755447678]
# computed_metrics: [0.3147684755447678]
# computed_metrics: [0.6569550116153764]
# Starting epoch 374
# Starting validation epoch 374
# computed_metrics: [0.3103172392931325]
# computed_metrics: [0.3103172392931325]
# computed_metrics: [0.6527984387231838]
# Starting epoch 375
# Starting validation epoch 375
# computed_metrics: [0.2826507521656071]
# computed_metrics: [0.2826507521656071]
# computed_metrics: [0.6566383052881877]
# Starting epoch 376
# Starting validation epoch 376
# computed_metrics: [0.28393286895942704]
# computed_metrics: [0.28393286895942704]
# computed_metrics: [0.6347395558518087]
# Starting epoch 377
# Starting validation epoch 377
# computed_metrics: [0.3085966550267025]
# computed_metrics: [0.3085966550267025]
# computed_metrics: [0.6269071830856703]
# Starting epoch 378
# Starting validation epoch 378
# computed_metrics: [0.2669456256108102]
# computed_metrics: [0.2669456256108102]
# computed_metrics: [0.6053805245493352]
# Starting epoch 379
# Starting validation epoch 379
# computed_metrics: [0.2646406549119346]
# computed_metrics: [0.2646406549119346]
# computed_metrics: [0.6157439484999303]
# Starting epoch 380
# Starting validation epoch 380
# computed_metrics: [0.31326855989593244]
# computed_metrics: [0.31326855989593244]
# computed_metrics: [0.6551871318646352]
# Starting epoch 381
# Starting validation epoch 381
# computed_metrics: [0.2943241611480516]
# computed_metrics: [0.2943241611480516]
# computed_metrics: [0.6590976648401826]
# Starting epoch 382
# Starting validation epoch 382
# computed_metrics: [0.3035464616888211]
# computed_metrics: [0.3035464616888211]
# computed_metrics: [0.6936827084740543]
# Starting epoch 383
# Starting validation epoch 383
# computed_metrics: [0.3289246687274116]
# computed_metrics: [0.3289246687274116]
# computed_metrics: [0.6467303947165852]
# Starting epoch 384
# Starting validation epoch 384
# computed_metrics: [0.37041699094385966]
# computed_metrics: [0.37041699094385966]
# computed_metrics: [0.6442032266971063]
# Starting epoch 385
# Starting validation epoch 385
# computed_metrics: [0.2800003123837636]
# computed_metrics: [0.2800003123837636]
# computed_metrics: [0.6149219616528905]
# Starting epoch 386
# Starting validation epoch 386
# computed_metrics: [0.28093397706925655]
# computed_metrics: [0.28093397706925655]
# computed_metrics: [0.6365539852557827]
# Starting epoch 387
# Starting validation epoch 387
# computed_metrics: [0.30241757678900294]
# computed_metrics: [0.30241757678900294]
# computed_metrics: [0.638885915620189]
# Starting epoch 388
# Starting validation epoch 388
# computed_metrics: [0.2958388699217939]
# computed_metrics: [0.2958388699217939]
# computed_metrics: [0.6461614896031043]
# Starting epoch 389
# Starting validation epoch 389
# computed_metrics: [0.26504680159583804]
# computed_metrics: [0.26504680159583804]
# computed_metrics: [0.6292268321058347]
# Starting epoch 390
# Starting validation epoch 390
# computed_metrics: [0.29701454651218]
# computed_metrics: [0.29701454651218]
# computed_metrics: [0.6521678780188804]
# Starting epoch 391
# Starting validation epoch 391
# computed_metrics: [0.3185947921429739]
# computed_metrics: [0.3185947921429739]
# computed_metrics: [0.6357743244281009]
# Starting epoch 392
# Starting validation epoch 392
# computed_metrics: [0.2646608018832618]
# computed_metrics: [0.2646608018832618]
# computed_metrics: [0.6039011251832135]
# Starting epoch 393
# Starting validation epoch 393
# computed_metrics: [0.26029979787270835]
# computed_metrics: [0.26029979787270835]
# computed_metrics: [0.6147282753629991]
# Starting epoch 394
# Starting validation epoch 394
# computed_metrics: [0.31070421290082817]
# computed_metrics: [0.31070421290082817]
# computed_metrics: [0.6505114537670114]
# Starting epoch 395
# Starting validation epoch 395
# computed_metrics: [0.2924090849312091]
# computed_metrics: [0.2924090849312091]
# computed_metrics: [0.6525343239189031]
# Starting epoch 396
# Starting validation epoch 396
# computed_metrics: [0.25634486257959516]
# computed_metrics: [0.25634486257959516]
# computed_metrics: [0.6465836166677931]
# Starting epoch 397
# Starting validation epoch 397
# computed_metrics: [0.2994184159956497]
# computed_metrics: [0.2994184159956497]
# computed_metrics: [0.6417994509661599]
# Starting epoch 398
# Starting validation epoch 398
# computed_metrics: [0.3220417483211955]
# computed_metrics: [0.3220417483211955]
# computed_metrics: [0.6376651633290762]
# Starting epoch 399
# Starting validation epoch 399
# computed_metrics: [0.2844733059760468]
# computed_metrics: [0.2844733059760468]
# computed_metrics: [0.6045380721667807]
# Starting epoch 400
# Starting validation epoch 400
# computed_metrics: [0.2629514538741905]
# computed_metrics: [0.2629514538741905]
# computed_metrics: [0.5950609006294704]
# Starting epoch 401
# Starting validation epoch 401
# computed_metrics: [0.2928989105438133]
# computed_metrics: [0.2928989105438133]
# computed_metrics: [0.6400128254255146]
# Starting epoch 402
# Starting validation epoch 402
# computed_metrics: [0.3145477306898866]
# computed_metrics: [0.3145477306898866]
# computed_metrics: [0.6549982831688254]
# Starting epoch 403
# Starting validation epoch 403
# computed_metrics: [0.25991470456061566]
# computed_metrics: [0.25991470456061566]
# computed_metrics: [0.650383103830964]
# Starting epoch 404
# Starting validation epoch 404
# computed_metrics: [0.29533680051124395]
# computed_metrics: [0.29533680051124395]
# computed_metrics: [0.6452113423938292]
# Starting epoch 405
# Starting validation epoch 405
# computed_metrics: [0.34772215919720445]
# computed_metrics: [0.34772215919720445]
# computed_metrics: [0.6681064052128214]
# Starting epoch 406
# Starting validation epoch 406
# computed_metrics: [0.28256419022989154]
# computed_metrics: [0.28256419022989154]
# computed_metrics: [0.6069597780649368]
# Starting epoch 407
# Starting validation epoch 407
# computed_metrics: [0.272420341321888]
# computed_metrics: [0.272420341321888]
# computed_metrics: [0.6085653039691095]
# Starting epoch 408
# Starting validation epoch 408
# computed_metrics: [0.34811568195106296]
# computed_metrics: [0.34811568195106296]
# computed_metrics: [0.6828546688969425]
# Starting epoch 409
# Starting validation epoch 409
# computed_metrics: [0.3281556236219589]
# computed_metrics: [0.3281556236219589]
# computed_metrics: [0.6699014186202203]
# Starting epoch 410
# Starting validation epoch 410
# computed_metrics: [0.272712578613943]
# computed_metrics: [0.272712578613943]
# computed_metrics: [0.6534802616731]
# 6.904351895934214

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.272712578613943]
# computed_metrics: [0.6534802616731]
# computed_metrics: [0.5705398660036292]
# {'mean-mean_absolute_error': 0.5705398660036292}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.9466623, 0.0)
# SpearmanrResult(correlation=0.9491852676791694, pvalue=0.0)
# (0.7155725, 4.530534482441958e-29)
# SpearmanrResult(correlation=0.7209066355293579, pvalue=1.1259764309919683e-29)
# (0.7979023, 2.541654474001395e-40)
# SpearmanrResult(correlation=0.8169520153694159, pvalue=1.0798801893803404e-43)
