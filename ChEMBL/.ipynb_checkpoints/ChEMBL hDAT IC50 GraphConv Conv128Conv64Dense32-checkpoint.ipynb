# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gp1 = GraphPool(in_layers=[batch_norm1, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp2 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm3 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm3, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.814 s
# TIMING: dataset construction took 3.387 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.455 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.230 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.221 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 128
C2_filtnum = 64
D_nodenum = 32

graph_structure = 'GC{0}_GP_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.696751141195311]
# computed_metrics: [2.696751141195311]
# computed_metrics: [2.8140994515608244]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.79219262012552]
# computed_metrics: [1.79219262012552]
# computed_metrics: [1.8948659480694692]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.2501885678487306]
# computed_metrics: [1.2501885678487306]
# computed_metrics: [1.3157244864198143]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.0335321009691254]
# computed_metrics: [1.0335321009691254]
# computed_metrics: [1.0799793310431671]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9548400076553218]
# computed_metrics: [0.9548400076553218]
# computed_metrics: [0.9956298959105685]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9352449345346242]
# computed_metrics: [0.9352449345346242]
# computed_metrics: [0.9749377267398357]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9274556038883585]
# computed_metrics: [0.9274556038883585]
# computed_metrics: [0.9666460292841156]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9216561559798073]
# computed_metrics: [0.9216561559798073]
# computed_metrics: [0.9623336561228946]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.9167404092037645]
# computed_metrics: [0.9167404092037645]
# computed_metrics: [0.96104700000233]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.9006008912442985]
# computed_metrics: [0.9006008912442985]
# computed_metrics: [0.9473442910287151]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8896736365321705]
# computed_metrics: [0.8896736365321705]
# computed_metrics: [0.9404115830942913]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.869110020470806]
# computed_metrics: [0.869110020470806]
# computed_metrics: [0.9163233528268532]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8493605722433212]
# computed_metrics: [0.8493605722433212]
# computed_metrics: [0.9026219168426237]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8387249982409064]
# computed_metrics: [0.8387249982409064]
# computed_metrics: [0.8786005569135035]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8474932327002592]
# computed_metrics: [0.8474932327002592]
# computed_metrics: [0.9060189485292252]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8225907165786707]
# computed_metrics: [0.8225907165786707]
# computed_metrics: [0.8817028200235218]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7913259012685672]
# computed_metrics: [0.7913259012685672]
# computed_metrics: [0.8399810960209085]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7739198902977418]
# computed_metrics: [0.7739198902977418]
# computed_metrics: [0.815866143013425]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.783081536684942]
# computed_metrics: [0.783081536684942]
# computed_metrics: [0.8345037276465184]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7551828049114981]
# computed_metrics: [0.7551828049114981]
# computed_metrics: [0.7924323453522251]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.742220706690663]
# computed_metrics: [0.742220706690663]
# computed_metrics: [0.7803383674535957]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7347937000869487]
# computed_metrics: [0.7347937000869487]
# computed_metrics: [0.7742355725940582]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7239349246610887]
# computed_metrics: [0.7239349246610887]
# computed_metrics: [0.7613354423924504]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7174067459861098]
# computed_metrics: [0.7174067459861098]
# computed_metrics: [0.7644081045176523]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.6991248322213225]
# computed_metrics: [0.6991248322213225]
# computed_metrics: [0.7403730707075136]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6894254767131582]
# computed_metrics: [0.6894254767131582]
# computed_metrics: [0.7251670367151575]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.675468096470414]
# computed_metrics: [0.675468096470414]
# computed_metrics: [0.7161737946576711]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6838321852719037]
# computed_metrics: [0.6838321852719037]
# computed_metrics: [0.7169808475087075]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6671649978659046]
# computed_metrics: [0.6671649978659046]
# computed_metrics: [0.7034906185012513]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6483220992672717]
# computed_metrics: [0.6483220992672717]
# computed_metrics: [0.6884907133930889]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6329784459066925]
# computed_metrics: [0.6329784459066925]
# computed_metrics: [0.6752098942164633]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6237981867042129]
# computed_metrics: [0.6237981867042129]
# computed_metrics: [0.6626903218736453]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6187925972196235]
# computed_metrics: [0.6187925972196235]
# computed_metrics: [0.6608771796513105]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6110086216040208]
# computed_metrics: [0.6110086216040208]
# computed_metrics: [0.649107416179343]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6079998558050196]
# computed_metrics: [0.6079998558050196]
# computed_metrics: [0.6552094143418725]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6002348886818172]
# computed_metrics: [0.6002348886818172]
# computed_metrics: [0.6498005006612795]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.604299171006131]
# computed_metrics: [0.604299171006131]
# computed_metrics: [0.6603057059139038]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.606038855151243]
# computed_metrics: [0.606038855151243]
# computed_metrics: [0.6574222243258371]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6054784939086685]
# computed_metrics: [0.6054784939086685]
# computed_metrics: [0.655204278015633]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5991590877766324]
# computed_metrics: [0.5991590877766324]
# computed_metrics: [0.6526871669081803]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5753080437590492]
# computed_metrics: [0.5753080437590492]
# computed_metrics: [0.634334004820947]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5659538758677755]
# computed_metrics: [0.5659538758677755]
# computed_metrics: [0.6195641148206148]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5747682775123619]
# computed_metrics: [0.5747682775123619]
# computed_metrics: [0.6463704181642822]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5805995013711478]
# computed_metrics: [0.5805995013711478]
# computed_metrics: [0.656803873981325]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5982351544644721]
# computed_metrics: [0.5982351544644721]
# computed_metrics: [0.6738278985978444]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.6084282137106546]
# computed_metrics: [0.6084282137106546]
# computed_metrics: [0.6944011924529747]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5895313490280489]
# computed_metrics: [0.5895313490280489]
# computed_metrics: [0.666627911980399]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5581299332449677]
# computed_metrics: [0.5581299332449677]
# computed_metrics: [0.6243145844107557]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5413331345039792]
# computed_metrics: [0.5413331345039792]
# computed_metrics: [0.6023799836589679]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5737040627040442]
# computed_metrics: [0.5737040627040442]
# computed_metrics: [0.657492152647272]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.633257387296089]
# computed_metrics: [0.633257387296089]
# computed_metrics: [0.7354579993594267]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.6029679053572532]
# computed_metrics: [0.6029679053572532]
# computed_metrics: [0.6913903540923598]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5706702107303824]
# computed_metrics: [0.5706702107303824]
# computed_metrics: [0.6547557222965933]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5318503143340771]
# computed_metrics: [0.5318503143340771]
# computed_metrics: [0.5962043903362917]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5446076032801325]
# computed_metrics: [0.5446076032801325]
# computed_metrics: [0.6058667632803566]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5408044976498607]
# computed_metrics: [0.5408044976498607]
# computed_metrics: [0.6131604969881325]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5716096256023504]
# computed_metrics: [0.5716096256023504]
# computed_metrics: [0.6667803346983315]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.6292027672382365]
# computed_metrics: [0.6292027672382365]
# computed_metrics: [0.7332694225563435]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.6569867644152007]
# computed_metrics: [0.6569867644152007]
# computed_metrics: [0.7750333529026819]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.6069557826538953]
# computed_metrics: [0.6069557826538953]
# computed_metrics: [0.7161608636048556]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5188051459728616]
# computed_metrics: [0.5188051459728616]
# computed_metrics: [0.5813638808173223]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5131349277569234]
# computed_metrics: [0.5131349277569234]
# computed_metrics: [0.5794419266013601]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5457282282554295]
# computed_metrics: [0.5457282282554295]
# computed_metrics: [0.6284047262174728]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.6430687487188997]
# computed_metrics: [0.6430687487188997]
# computed_metrics: [0.7626870274817329]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.5740989753412388]
# computed_metrics: [0.5740989753412388]
# computed_metrics: [0.6784209212593909]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.5101683069597494]
# computed_metrics: [0.5101683069597494]
# computed_metrics: [0.5859375505087693]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5021999588729028]
# computed_metrics: [0.5021999588729028]
# computed_metrics: [0.6053376459658573]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.5827729212803322]
# computed_metrics: [0.5827729212803322]
# computed_metrics: [0.6815277529036264]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.6390239376982906]
# computed_metrics: [0.6390239376982906]
# computed_metrics: [0.771046333411435]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5213728646126435]
# computed_metrics: [0.5213728646126435]
# computed_metrics: [0.6291010050724006]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5940776816538847]
# computed_metrics: [0.5940776816538847]
# computed_metrics: [0.6881647798132566]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5801521422090679]
# computed_metrics: [0.5801521422090679]
# computed_metrics: [0.6825062802383649]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.539547923458434]
# computed_metrics: [0.539547923458434]
# computed_metrics: [0.6430555569473233]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5228777175831815]
# computed_metrics: [0.5228777175831815]
# computed_metrics: [0.6070536017533466]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.6361098080777461]
# computed_metrics: [0.6361098080777461]
# computed_metrics: [0.7637545997734424]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5399651145930234]
# computed_metrics: [0.5399651145930234]
# computed_metrics: [0.6188290699654785]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.588419369555372]
# computed_metrics: [0.588419369555372]
# computed_metrics: [0.7037943888280851]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5544798318765175]
# computed_metrics: [0.5544798318765175]
# computed_metrics: [0.6694422700002282]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.5240196114263171]
# computed_metrics: [0.5240196114263171]
# computed_metrics: [0.6376296096196452]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.525053285957431]
# computed_metrics: [0.525053285957431]
# computed_metrics: [0.6368327142951459]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.5500449591945479]
# computed_metrics: [0.5500449591945479]
# computed_metrics: [0.6703924049737641]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4797087501328077]
# computed_metrics: [0.4797087501328077]
# computed_metrics: [0.5953956114407417]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.4715991350908804]
# computed_metrics: [0.4715991350908804]
# computed_metrics: [0.5616817816862235]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.5069321210734362]
# computed_metrics: [0.5069321210734362]
# computed_metrics: [0.6470790212303639]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.4687155365806145]
# computed_metrics: [0.4687155365806145]
# computed_metrics: [0.5990857022508993]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.45312214814975643]
# computed_metrics: [0.45312214814975643]
# computed_metrics: [0.5653084714892619]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4785168604606649]
# computed_metrics: [0.4785168604606649]
# computed_metrics: [0.570775947097484]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4503551465689275]
# computed_metrics: [0.4503551465689275]
# computed_metrics: [0.5597747678711672]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.473619205196402]
# computed_metrics: [0.473619205196402]
# computed_metrics: [0.5983033529836096]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.4734571548906745]
# computed_metrics: [0.4734571548906745]
# computed_metrics: [0.5830044267144419]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.49598666685363263]
# computed_metrics: [0.49598666685363263]
# computed_metrics: [0.6052984312367907]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.485632425241789]
# computed_metrics: [0.485632425241789]
# computed_metrics: [0.5986678903782149]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.5399025283423592]
# computed_metrics: [0.5399025283423592]
# computed_metrics: [0.5904349621917445]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.4748717102937094]
# computed_metrics: [0.4748717102937094]
# computed_metrics: [0.577507631761337]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.5453659537036248]
# computed_metrics: [0.5453659537036248]
# computed_metrics: [0.6103680227151167]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.5310393001007233]
# computed_metrics: [0.5310393001007233]
# computed_metrics: [0.5951833328967138]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.6214014708403655]
# computed_metrics: [0.6214014708403655]
# computed_metrics: [0.668536336384257]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.6770888162871765]
# computed_metrics: [0.6770888162871765]
# computed_metrics: [0.6952703320920223]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.5781676040493149]
# computed_metrics: [0.5781676040493149]
# computed_metrics: [0.5972937936946384]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.5299034278155831]
# computed_metrics: [0.5299034278155831]
# computed_metrics: [0.5843714834237074]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.5192535731927083]
# computed_metrics: [0.5192535731927083]
# computed_metrics: [0.5685539899871342]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.45293329616471034]
# computed_metrics: [0.45293329616471034]
# computed_metrics: [0.537919583249715]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.4327858473932787]
# computed_metrics: [0.4327858473932787]
# computed_metrics: [0.5318205914458939]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.42502031086548825]
# computed_metrics: [0.42502031086548825]
# computed_metrics: [0.520924580806628]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.41167675881083715]
# computed_metrics: [0.41167675881083715]
# computed_metrics: [0.5287604092173934]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.40945677631760813]
# computed_metrics: [0.40945677631760813]
# computed_metrics: [0.5296335059810904]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.39120908364038987]
# computed_metrics: [0.39120908364038987]
# computed_metrics: [0.5115212769980839]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.3725156261086705]
# computed_metrics: [0.3725156261086705]
# computed_metrics: [0.4996425528732301]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.37761374985298163]
# computed_metrics: [0.37761374985298163]
# computed_metrics: [0.49612105384923744]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.38959876983556946]
# computed_metrics: [0.38959876983556946]
# computed_metrics: [0.5126602588598252]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.3761378486406039]
# computed_metrics: [0.3761378486406039]
# computed_metrics: [0.49892228815979167]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.3944712384031676]
# computed_metrics: [0.3944712384031676]
# computed_metrics: [0.528230803365714]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.42144966299875886]
# computed_metrics: [0.42144966299875886]
# computed_metrics: [0.5043858936548842]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.4013731538155558]
# computed_metrics: [0.4013731538155558]
# computed_metrics: [0.516533211279173]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.39861610417006554]
# computed_metrics: [0.39861610417006554]
# computed_metrics: [0.4946092100889395]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.38052032637207256]
# computed_metrics: [0.38052032637207256]
# computed_metrics: [0.5148993075901561]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.38416308027562]
# computed_metrics: [0.38416308027562]
# computed_metrics: [0.4984238906016771]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.35403769162365717]
# computed_metrics: [0.35403769162365717]
# computed_metrics: [0.4986014021951836]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.3593907357819851]
# computed_metrics: [0.3593907357819851]
# computed_metrics: [0.4983663864338351]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.33773605630959164]
# computed_metrics: [0.33773605630959164]
# computed_metrics: [0.5030115289541793]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.3465327683521918]
# computed_metrics: [0.3465327683521918]
# computed_metrics: [0.5236942370017539]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.3376268954971241]
# computed_metrics: [0.3376268954971241]
# computed_metrics: [0.5003645126631825]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.3479377410336425]
# computed_metrics: [0.3479377410336425]
# computed_metrics: [0.4937542149636379]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.3411767208432639]
# computed_metrics: [0.3411767208432639]
# computed_metrics: [0.5053582420078225]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.337483348795505]
# computed_metrics: [0.337483348795505]
# computed_metrics: [0.5110447433872313]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.330645152454707]
# computed_metrics: [0.330645152454707]
# computed_metrics: [0.5099336165026882]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.3444244705447822]
# computed_metrics: [0.3444244705447822]
# computed_metrics: [0.5405680251101415]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.38545243072354707]
# computed_metrics: [0.38545243072354707]
# computed_metrics: [0.5661150889840488]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.3555558984256788]
# computed_metrics: [0.3555558984256788]
# computed_metrics: [0.5120965000674441]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.3666186844719534]
# computed_metrics: [0.3666186844719534]
# computed_metrics: [0.48820312304998875]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.36009188265970626]
# computed_metrics: [0.36009188265970626]
# computed_metrics: [0.5507671224914096]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.37400669096037753]
# computed_metrics: [0.37400669096037753]
# computed_metrics: [0.5488105984485185]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.35787796446935927]
# computed_metrics: [0.35787796446935927]
# computed_metrics: [0.5077527301399897]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.33764319241052126]
# computed_metrics: [0.33764319241052126]
# computed_metrics: [0.5166808992873175]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.3395127177713107]
# computed_metrics: [0.3395127177713107]
# computed_metrics: [0.5227004461950813]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3255996975517666]
# computed_metrics: [0.3255996975517666]
# computed_metrics: [0.48497572400084726]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.334148501598871]
# computed_metrics: [0.334148501598871]
# computed_metrics: [0.5280968870881019]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.3272334966405395]
# computed_metrics: [0.3272334966405395]
# computed_metrics: [0.5208111302471111]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.31767353163460055]
# computed_metrics: [0.31767353163460055]
# computed_metrics: [0.49131597331571186]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.3166984443671999]
# computed_metrics: [0.3166984443671999]
# computed_metrics: [0.5076968310937319]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.3087681060190881]
# computed_metrics: [0.3087681060190881]
# computed_metrics: [0.482967844534072]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.31823472293634975]
# computed_metrics: [0.31823472293634975]
# computed_metrics: [0.5261518398932955]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.3272491124012501]
# computed_metrics: [0.3272491124012501]
# computed_metrics: [0.5162566766581157]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.3511029750780056]
# computed_metrics: [0.3511029750780056]
# computed_metrics: [0.4708930806365338]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.3404596185809606]
# computed_metrics: [0.3404596185809606]
# computed_metrics: [0.5245369500498169]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.35005460514879183]
# computed_metrics: [0.35005460514879183]
# computed_metrics: [0.5820874930872231]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.3279175776062778]
# computed_metrics: [0.3279175776062778]
# computed_metrics: [0.4801333622689857]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.3435523920667934]
# computed_metrics: [0.3435523920667934]
# computed_metrics: [0.4937865165561457]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.3136137681518728]
# computed_metrics: [0.3136137681518728]
# computed_metrics: [0.5124808187303255]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.34753793809605]
# computed_metrics: [0.34753793809605]
# computed_metrics: [0.4764218797289783]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.3114219564965924]
# computed_metrics: [0.3114219564965924]
# computed_metrics: [0.49378608831650106]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3247107460619881]
# computed_metrics: [0.3247107460619881]
# computed_metrics: [0.5003495344392545]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.3555473806364011]
# computed_metrics: [0.3555473806364011]
# computed_metrics: [0.5043973392298561]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.3479238303312308]
# computed_metrics: [0.3479238303312308]
# computed_metrics: [0.5310927519431105]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.3171888008003191]
# computed_metrics: [0.3171888008003191]
# computed_metrics: [0.522438729547852]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.3167918469950089]
# computed_metrics: [0.3167918469950089]
# computed_metrics: [0.4839298515479226]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.4086594094072788]
# computed_metrics: [0.4086594094072788]
# computed_metrics: [0.5208326610023768]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.3398900721138694]
# computed_metrics: [0.3398900721138694]
# computed_metrics: [0.5687599047136871]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.4011512204887256]
# computed_metrics: [0.4011512204887256]
# computed_metrics: [0.5061414555347072]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.33498006385042367]
# computed_metrics: [0.33498006385042367]
# computed_metrics: [0.488252719149445]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.3467548637155577]
# computed_metrics: [0.3467548637155577]
# computed_metrics: [0.49825631576675905]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.3425458070532158]
# computed_metrics: [0.3425458070532158]
# computed_metrics: [0.5553841400072439]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.3059783749197043]
# computed_metrics: [0.3059783749197043]
# computed_metrics: [0.47461792487409415]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.35685640473201585]
# computed_metrics: [0.35685640473201585]
# computed_metrics: [0.5110605182162685]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.30863995539894623]
# computed_metrics: [0.30863995539894623]
# computed_metrics: [0.5147193880005277]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.2916799733194752]
# computed_metrics: [0.2916799733194752]
# computed_metrics: [0.522177478542037]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.28929818110342675]
# computed_metrics: [0.28929818110342675]
# computed_metrics: [0.48829774296316236]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.27983087687221075]
# computed_metrics: [0.27983087687221075]
# computed_metrics: [0.5058239774243991]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.2811075685922353]
# computed_metrics: [0.2811075685922353]
# computed_metrics: [0.5143975701050507]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.27842372330262816]
# computed_metrics: [0.27842372330262816]
# computed_metrics: [0.5037197294238559]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.27185850509437315]
# computed_metrics: [0.27185850509437315]
# computed_metrics: [0.521938073001606]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.31673629614427407]
# computed_metrics: [0.31673629614427407]
# computed_metrics: [0.5531870557496045]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.31519792105995476]
# computed_metrics: [0.31519792105995476]
# computed_metrics: [0.5425036207171722]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.29651300725114893]
# computed_metrics: [0.29651300725114893]
# computed_metrics: [0.5060790977038211]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.3217436365549283]
# computed_metrics: [0.3217436365549283]
# computed_metrics: [0.5479495272565903]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.32439762192060656]
# computed_metrics: [0.32439762192060656]
# computed_metrics: [0.5548424997153517]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.30566574963887283]
# computed_metrics: [0.30566574963887283]
# computed_metrics: [0.5370121647115571]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.3167462303070163]
# computed_metrics: [0.3167462303070163]
# computed_metrics: [0.5450137614338917]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.3132809024520744]
# computed_metrics: [0.3132809024520744]
# computed_metrics: [0.5275261221336303]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.4903196794724887]
# computed_metrics: [0.4903196794724887]
# computed_metrics: [0.6766694470788128]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.32791692158520097]
# computed_metrics: [0.32791692158520097]
# computed_metrics: [0.5324968562201465]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.3721857304557007]
# computed_metrics: [0.3721857304557007]
# computed_metrics: [0.5284835770816494]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.39953699348003924]
# computed_metrics: [0.39953699348003924]
# computed_metrics: [0.5894644172986496]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.35400905145370315]
# computed_metrics: [0.35400905145370315]
# computed_metrics: [0.5562606718214422]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.33527925033484945]
# computed_metrics: [0.33527925033484945]
# computed_metrics: [0.5127661021421062]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.34738505042177964]
# computed_metrics: [0.34738505042177964]
# computed_metrics: [0.5622124950297548]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.3002018891496942]
# computed_metrics: [0.3002018891496942]
# computed_metrics: [0.518865652313086]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.2776214165200232]
# computed_metrics: [0.2776214165200232]
# computed_metrics: [0.5056291788276249]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.29938132562133496]
# computed_metrics: [0.29938132562133496]
# computed_metrics: [0.5242800784266515]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.2929767986882739]
# computed_metrics: [0.2929767986882739]
# computed_metrics: [0.508594957811248]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.29107652740055834]
# computed_metrics: [0.29107652740055834]
# computed_metrics: [0.49950219899167597]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.2983426721082327]
# computed_metrics: [0.2983426721082327]
# computed_metrics: [0.5360158155343031]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.28246572362151035]
# computed_metrics: [0.28246572362151035]
# computed_metrics: [0.4893157875848076]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.3469179796051183]
# computed_metrics: [0.3469179796051183]
# computed_metrics: [0.531961877380578]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.29513257721201125]
# computed_metrics: [0.29513257721201125]
# computed_metrics: [0.5055448693690263]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.3171304382111297]
# computed_metrics: [0.3171304382111297]
# computed_metrics: [0.5141479143809903]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.35466100438084325]
# computed_metrics: [0.35466100438084325]
# computed_metrics: [0.5185002066535535]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.32624117149597415]
# computed_metrics: [0.32624117149597415]
# computed_metrics: [0.5167405774252151]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.36527934121979666]
# computed_metrics: [0.36527934121979666]
# computed_metrics: [0.5160400356645706]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.3819260933611929]
# computed_metrics: [0.3819260933611929]
# computed_metrics: [0.5624168207544099]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.3049612535154053]
# computed_metrics: [0.3049612535154053]
# computed_metrics: [0.5087990165034078]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.34491499782041957]
# computed_metrics: [0.34491499782041957]
# computed_metrics: [0.5059903143114169]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.2882825750389236]
# computed_metrics: [0.2882825750389236]
# computed_metrics: [0.527491752518674]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.286863459847235]
# computed_metrics: [0.286863459847235]
# computed_metrics: [0.5212149510690421]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.2899464052567305]
# computed_metrics: [0.2899464052567305]
# computed_metrics: [0.5063335583716668]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.34808081557701215]
# computed_metrics: [0.34808081557701215]
# computed_metrics: [0.5817449281813998]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.3295626385265422]
# computed_metrics: [0.3295626385265422]
# computed_metrics: [0.5622889348921357]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.40854988337397485]
# computed_metrics: [0.40854988337397485]
# computed_metrics: [0.6012635322335508]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.3716679729119614]
# computed_metrics: [0.3716679729119614]
# computed_metrics: [0.594004774285899]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.3710686105724735]
# computed_metrics: [0.3710686105724735]
# computed_metrics: [0.59321292732421]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.3933956784170246]
# computed_metrics: [0.3933956784170246]
# computed_metrics: [0.6091150146657986]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.3241971426609874]
# computed_metrics: [0.3241971426609874]
# computed_metrics: [0.5549423692919662]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.2990477011903626]
# computed_metrics: [0.2990477011903626]
# computed_metrics: [0.5517891461984663]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.3373824132643344]
# computed_metrics: [0.3373824132643344]
# computed_metrics: [0.5298648561908019]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.393523910786183]
# computed_metrics: [0.393523910786183]
# computed_metrics: [0.5493640116950823]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.423085483810197]
# computed_metrics: [0.423085483810197]
# computed_metrics: [0.5621882246663132]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.46383422758188214]
# computed_metrics: [0.46383422758188214]
# computed_metrics: [0.5828750440529481]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.40770435549111084]
# computed_metrics: [0.40770435549111084]
# computed_metrics: [0.5669785619514753]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.3256050098370849]
# computed_metrics: [0.3256050098370849]
# computed_metrics: [0.5237734303543932]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.35522710591484036]
# computed_metrics: [0.35522710591484036]
# computed_metrics: [0.5256585774833218]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.2977284554916953]
# computed_metrics: [0.2977284554916953]
# computed_metrics: [0.5207291834678325]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.315205012087944]
# computed_metrics: [0.315205012087944]
# computed_metrics: [0.5331153445378487]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.39781212533288635]
# computed_metrics: [0.39781212533288635]
# computed_metrics: [0.6249305257363731]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.4024901964157934]
# computed_metrics: [0.4024901964157934]
# computed_metrics: [0.605743346670952]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.3499672089544142]
# computed_metrics: [0.3499672089544142]
# computed_metrics: [0.598860518457233]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.29495760697088574]
# computed_metrics: [0.29495760697088574]
# computed_metrics: [0.5324894660485958]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.31157729910560533]
# computed_metrics: [0.31157729910560533]
# computed_metrics: [0.5287933010803955]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.36647066121562627]
# computed_metrics: [0.36647066121562627]
# computed_metrics: [0.5287907442100342]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.35665831352894783]
# computed_metrics: [0.35665831352894783]
# computed_metrics: [0.5331311069797585]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.32276048948739827]
# computed_metrics: [0.32276048948739827]
# computed_metrics: [0.5056296847745392]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.26107249265129545]
# computed_metrics: [0.26107249265129545]
# computed_metrics: [0.5036816812754095]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.29184611214385014]
# computed_metrics: [0.29184611214385014]
# computed_metrics: [0.5422530612684264]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.3448737151777321]
# computed_metrics: [0.3448737151777321]
# computed_metrics: [0.5670098869982346]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.33454524754757226]
# computed_metrics: [0.33454524754757226]
# computed_metrics: [0.5963252738624457]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.2905748862323148]
# computed_metrics: [0.2905748862323148]
# computed_metrics: [0.5455693951482068]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.2776718044522995]
# computed_metrics: [0.2776718044522995]
# computed_metrics: [0.49573352711389457]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.3167246018722063]
# computed_metrics: [0.3167246018722063]
# computed_metrics: [0.5429087613196355]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.3170984565496329]
# computed_metrics: [0.3170984565496329]
# computed_metrics: [0.499361529519792]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.2865640432059895]
# computed_metrics: [0.2865640432059895]
# computed_metrics: [0.5022213099625247]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.262156322338872]
# computed_metrics: [0.262156322338872]
# computed_metrics: [0.5055698255740054]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.24628575665563548]
# computed_metrics: [0.24628575665563548]
# computed_metrics: [0.5012366318033927]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.2837848966247972]
# computed_metrics: [0.2837848966247972]
# computed_metrics: [0.5592353791576977]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.30186733795813603]
# computed_metrics: [0.30186733795813603]
# computed_metrics: [0.5370459727956727]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.2709214634196613]
# computed_metrics: [0.2709214634196613]
# computed_metrics: [0.5426988881969975]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.24210500186702125]
# computed_metrics: [0.24210500186702125]
# computed_metrics: [0.5041388050499865]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.26633406452547304]
# computed_metrics: [0.26633406452547304]
# computed_metrics: [0.48737958727811614]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.29902365593537644]
# computed_metrics: [0.29902365593537644]
# computed_metrics: [0.49953589345518823]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.3057678090378585]
# computed_metrics: [0.3057678090378585]
# computed_metrics: [0.4992078508629204]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.2659917753996048]
# computed_metrics: [0.2659917753996048]
# computed_metrics: [0.4783470651262592]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24250731889115534]
# computed_metrics: [0.24250731889115534]
# computed_metrics: [0.5160023954783131]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.2741150813259056]
# computed_metrics: [0.2741150813259056]
# computed_metrics: [0.529381955558308]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.2927695745563864]
# computed_metrics: [0.2927695745563864]
# computed_metrics: [0.5550153957990701]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.30640017728026747]
# computed_metrics: [0.30640017728026747]
# computed_metrics: [0.5364787374289368]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.2737536944367525]
# computed_metrics: [0.2737536944367525]
# computed_metrics: [0.5378065033622693]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.253294518547468]
# computed_metrics: [0.253294518547468]
# computed_metrics: [0.5187452097166737]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.2653476369750913]
# computed_metrics: [0.2653476369750913]
# computed_metrics: [0.49784870636353173]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.32157370065400437]
# computed_metrics: [0.32157370065400437]
# computed_metrics: [0.5228976096096091]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.3332727726056297]
# computed_metrics: [0.3332727726056297]
# computed_metrics: [0.5156783317004903]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.2967994715307647]
# computed_metrics: [0.2967994715307647]
# computed_metrics: [0.5015929100194696]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.25029194312713154]
# computed_metrics: [0.25029194312713154]
# computed_metrics: [0.4962474770495799]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.27200172252636984]
# computed_metrics: [0.27200172252636984]
# computed_metrics: [0.5335717333982254]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.300342666788849]
# computed_metrics: [0.300342666788849]
# computed_metrics: [0.5643874168029591]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.3735180025534536]
# computed_metrics: [0.3735180025534536]
# computed_metrics: [0.589307393658643]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.293709668894483]
# computed_metrics: [0.293709668894483]
# computed_metrics: [0.5170624944460896]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.296276891403966]
# computed_metrics: [0.296276891403966]
# computed_metrics: [0.5621424650267273]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.2954033546484821]
# computed_metrics: [0.2954033546484821]
# computed_metrics: [0.4975301847195595]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.3051297670475463]
# computed_metrics: [0.3051297670475463]
# computed_metrics: [0.5144069550163008]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.2945097145975943]
# computed_metrics: [0.2945097145975943]
# computed_metrics: [0.5077648134894266]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.2894687482407436]
# computed_metrics: [0.2894687482407436]
# computed_metrics: [0.4761710840364847]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.2567220481344145]
# computed_metrics: [0.2567220481344145]
# computed_metrics: [0.5287347045086893]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.23059976148368902]
# computed_metrics: [0.23059976148368902]
# computed_metrics: [0.49485433792332784]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.25451223714020477]
# computed_metrics: [0.25451223714020477]
# computed_metrics: [0.5343922916285464]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.2624483153754871]
# computed_metrics: [0.2624483153754871]
# computed_metrics: [0.5299686216231293]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.2453150033549747]
# computed_metrics: [0.2453150033549747]
# computed_metrics: [0.5097057984986657]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.2511003361919053]
# computed_metrics: [0.2511003361919053]
# computed_metrics: [0.519598822027409]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.25300771565254354]
# computed_metrics: [0.25300771565254354]
# computed_metrics: [0.4802156289382311]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.23445946848907992]
# computed_metrics: [0.23445946848907992]
# computed_metrics: [0.5126516096086001]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.25365936615129053]
# computed_metrics: [0.25365936615129053]
# computed_metrics: [0.48424446304339314]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.21882402017916494]
# computed_metrics: [0.21882402017916494]
# computed_metrics: [0.4805435742869021]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.20987598017679274]
# computed_metrics: [0.20987598017679274]
# computed_metrics: [0.49535376022328215]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.23323865277584654]
# computed_metrics: [0.23323865277584654]
# computed_metrics: [0.5252638337212967]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.274813249189823]
# computed_metrics: [0.274813249189823]
# computed_metrics: [0.5602618858241103]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.25452647879577806]
# computed_metrics: [0.25452647879577806]
# computed_metrics: [0.5354286805036856]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.2366106606765072]
# computed_metrics: [0.2366106606765072]
# computed_metrics: [0.5259616710977871]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.22718176301971574]
# computed_metrics: [0.22718176301971574]
# computed_metrics: [0.5063852863638793]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.2517055495326921]
# computed_metrics: [0.2517055495326921]
# computed_metrics: [0.5179048646207897]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.2931834481353834]
# computed_metrics: [0.2931834481353834]
# computed_metrics: [0.4923448801640467]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.3041310422096654]
# computed_metrics: [0.3041310422096654]
# computed_metrics: [0.5137375055623151]
# Starting epoch 288
# ...
# computed_metrics: [0.21714476556268178]
# computed_metrics: [0.21714476556268178]
# computed_metrics: [0.5090367540089094]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.252853140436554]
# computed_metrics: [0.252853140436554]
# computed_metrics: [0.5405706095732742]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.20618282284225276]
# computed_metrics: [0.20618282284225276]
# computed_metrics: [0.5212728142628528]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.19878707277397561]
# computed_metrics: [0.19878707277397561]
# computed_metrics: [0.5012063657229023]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.21731773723487952]
# computed_metrics: [0.21731773723487952]
# computed_metrics: [0.5269885416050338]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.20396353494476183]
# computed_metrics: [0.20396353494476183]
# computed_metrics: [0.5068592765269272]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.17651595220036562]
# computed_metrics: [0.17651595220036562]
# computed_metrics: [0.5026595799738853]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.22709854116695202]
# computed_metrics: [0.22709854116695202]
# computed_metrics: [0.5384418690968231]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.21651949649289867]
# computed_metrics: [0.21651949649289867]
# computed_metrics: [0.5367967368928876]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.18135725297084412]
# computed_metrics: [0.18135725297084412]
# computed_metrics: [0.516609733787919]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.2780729037292843]
# computed_metrics: [0.2780729037292843]
# computed_metrics: [0.5299680128770534]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.27632554488336225]
# computed_metrics: [0.27632554488336225]
# computed_metrics: [0.520613377172444]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.2535675811019107]
# computed_metrics: [0.2535675811019107]
# computed_metrics: [0.5211453478457665]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.21318687686349577]
# computed_metrics: [0.21318687686349577]
# computed_metrics: [0.5623197212578699]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.24525606808353953]
# computed_metrics: [0.24525606808353953]
# computed_metrics: [0.5363236922569883]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.23688475122338978]
# computed_metrics: [0.23688475122338978]
# computed_metrics: [0.5330853140992731]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.21328112600354165]
# computed_metrics: [0.21328112600354165]
# computed_metrics: [0.5223468803389831]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.21521557195284016]
# computed_metrics: [0.21521557195284016]
# computed_metrics: [0.5014358903094963]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.20663169023254363]
# computed_metrics: [0.20663169023254363]
# computed_metrics: [0.5109473594988299]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.19607301615078135]
# computed_metrics: [0.19607301615078135]
# computed_metrics: [0.4997749762062833]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.17723675723004]
# computed_metrics: [0.17723675723004]
# computed_metrics: [0.519390676230576]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.22164663984486213]
# computed_metrics: [0.22164663984486213]
# computed_metrics: [0.5269578557551958]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.2168859982252358]
# computed_metrics: [0.2168859982252358]
# computed_metrics: [0.5233668556321004]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.19044264321496665]
# computed_metrics: [0.19044264321496665]
# computed_metrics: [0.5081647217756593]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.2262971048547224]
# computed_metrics: [0.2262971048547224]
# computed_metrics: [0.5183082087293386]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.26197507300727435]
# computed_metrics: [0.26197507300727435]
# computed_metrics: [0.5208778242928597]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.22746334225616344]
# computed_metrics: [0.22746334225616344]
# computed_metrics: [0.5060318756683748]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.21329114857864886]
# computed_metrics: [0.21329114857864886]
# computed_metrics: [0.5399873847175614]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.2545053597046875]
# computed_metrics: [0.2545053597046875]
# computed_metrics: [0.5350470816747852]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.2146745012090486]
# computed_metrics: [0.2146745012090486]
# computed_metrics: [0.5203355986011821]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.18158384501238237]
# computed_metrics: [0.18158384501238237]
# computed_metrics: [0.5083409885422684]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.20319571708401715]
# computed_metrics: [0.20319571708401715]
# computed_metrics: [0.5171836677247518]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.21102704815261014]
# computed_metrics: [0.21102704815261014]
# computed_metrics: [0.5119713767078864]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.18284827697967104]
# computed_metrics: [0.18284827697967104]
# computed_metrics: [0.4981698235341182]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.2070677439906348]
# computed_metrics: [0.2070677439906348]
# computed_metrics: [0.5413027890905393]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.25488199982436033]
# computed_metrics: [0.25488199982436033]
# computed_metrics: [0.5437445359147066]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.2025508714658039]
# computed_metrics: [0.2025508714658039]
# computed_metrics: [0.5241908627864494]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.19598587037575124]
# computed_metrics: [0.19598587037575124]
# computed_metrics: [0.5147437253958274]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.2632680931332908]
# computed_metrics: [0.2632680931332908]
# computed_metrics: [0.5253522222747273]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.25247857103059324]
# computed_metrics: [0.25247857103059324]
# computed_metrics: [0.5265574483799055]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.1887378384047202]
# computed_metrics: [0.1887378384047202]
# computed_metrics: [0.50247884983408]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.21662043160839778]
# computed_metrics: [0.21662043160839778]
# computed_metrics: [0.5101462054080024]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.2485472022545266]
# computed_metrics: [0.2485472022545266]
# computed_metrics: [0.5502068671507605]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.20190573832938297]
# computed_metrics: [0.20190573832938297]
# computed_metrics: [0.5003066800635143]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.18885200795970572]
# computed_metrics: [0.18885200795970572]
# computed_metrics: [0.5220222237160518]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.24232886047749386]
# computed_metrics: [0.24232886047749386]
# computed_metrics: [0.5287852289394125]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.2066160329975851]
# computed_metrics: [0.2066160329975851]
# computed_metrics: [0.4944716478633959]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.17353563266044006]
# computed_metrics: [0.17353563266044006]
# computed_metrics: [0.5008520906047246]
# [2.696751141195311, 1.79219262012552, 1.2501885678487306, 1.0335321009691254, 0.9548400076553218, 0.9352449345346242, 0.9274556038883585, 0.9216561559798073, 0.9167404092037645, 0.9006008912442985, 0.8896736365321705, 0.869110020470806, 0.8493605722433212, 0.8387249982409064, 0.8474932327002592, 0.8225907165786707, 0.7913259012685672, 0.7739198902977418, 0.783081536684942, 0.7551828049114981, 0.742220706690663, 0.7347937000869487, 0.7239349246610887, 0.7174067459861098, 0.6991248322213225, 0.6894254767131582, 0.675468096470414, 0.6838321852719037, 0.6671649978659046, 0.6483220992672717, 0.6329784459066925, 0.6237981867042129, 0.6187925972196235, 0.6110086216040208, 0.6079998558050196, 0.6002348886818172, 0.604299171006131, 0.606038855151243, 0.6054784939086685, 0.5991590877766324, 0.5753080437590492, 0.5659538758677755, 0.5747682775123619, 0.5805995013711478, 0.5982351544644721, 0.6084282137106546, 0.5895313490280489, 0.5581299332449677, 0.5413331345039792, 0.5737040627040442, 0.633257387296089, 0.6029679053572532, 0.5706702107303824, 0.5318503143340771, 0.5446076032801325, 0.5408044976498607, 0.5716096256023504, 0.6292027672382365, 0.6569867644152007, 0.6069557826538953, 0.5188051459728616, 0.5131349277569234, 0.5457282282554295, 0.6430687487188997, 0.5740989753412388, 0.5101683069597494, 0.5021999588729028, 0.5827729212803322, 0.6390239376982906, 0.5213728646126435, 0.5940776816538847, 0.5801521422090679, 0.539547923458434, 0.5228777175831815, 0.6361098080777461, 0.5399651145930234, 0.588419369555372
#  [0.20618282 0.52127281]
#  [0.19878707 0.50120637]
#  [0.21731774 0.52698854]
#  [0.20396353 0.50685928]
#  [0.17651595 0.50265958]
#  [0.22709854 0.53844187]
#  [0.2165195  0.53679674]
#  [0.18135725 0.51660973]
#  [0.2780729  0.52996801]
#  [0.27632554 0.52061338]
#  [0.25356758 0.52114535]
#  [0.21318688 0.56231972]
#  [0.24525607 0.53632369]
#  [0.23688475 0.53308531]
#  [0.21328113 0.52234688]
#  [0.21521557 0.50143589]
#  [0.20663169 0.51094736]
#  [0.19607302 0.49977498]
#  [0.17723676 0.51939068]
#  [0.22164664 0.52695786]
#  [0.216886   0.52336686]
#  [0.19044264 0.50816472]
#  [0.2262971  0.51830821]
#  [0.26197507 0.52087782]
#  [0.22746334 0.50603188]
#  [0.21329115 0.53998738]
#  [0.25450536 0.53504708]
#  [0.2146745  0.5203356 ]
#  [0.18158385 0.50834099]
#  [0.20319572 0.51718367]
#  [0.21102705 0.51197138]
#  [0.18284828 0.49816982]
#  [0.20706774 0.54130279]
#  [0.254882   0.54374454]
#  [0.20255087 0.52419086]
#  [0.19598587 0.51474373]
#  [0.26326809 0.52535222]
#  [0.25247857 0.52655745]
#  [0.18873784 0.50247885]
#  [0.21662043 0.51014621]
#  [0.2485472  0.55020687]
#  [0.20190574 0.50030668]
#  [0.18885201 0.52202222]
#  [0.24232886 0.52878523]
#  [0.20661603 0.49447165]
#  [0.17353563 0.50085209]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [2.572370112974029]
# computed_metrics: [2.572370112974029]
# computed_metrics: [2.6930230522371943]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [1.7364504205708693]
# computed_metrics: [1.7364504205708693]
# computed_metrics: [1.8285835306143907]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.2378558264736514]
# computed_metrics: [1.2378558264736514]
# computed_metrics: [1.3084194976539123]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.032663619199558]
# computed_metrics: [1.032663619199558]
# computed_metrics: [1.0850603833321966]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [0.9480761668693904]
# computed_metrics: [0.9480761668693904]
# computed_metrics: [0.9832783855817455]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [0.9105151863368844]
# computed_metrics: [0.9105151863368844]
# computed_metrics: [0.9410258966645907]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.8803018347768844]
# computed_metrics: [0.8803018347768844]
# computed_metrics: [0.9066460304361187]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.8659430979359917]
# computed_metrics: [0.8659430979359917]
# computed_metrics: [0.8920936275748379]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8485221150753021]
# computed_metrics: [0.8485221150753021]
# computed_metrics: [0.8754963334403328]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.82081529832622]
# computed_metrics: [0.82081529832622]
# computed_metrics: [0.856899512758457]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8169343214712105]
# computed_metrics: [0.8169343214712105]
# computed_metrics: [0.8527262258013008]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8439609823025683]
# computed_metrics: [0.8439609823025683]
# computed_metrics: [0.8859036858884124]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8306459441022855]
# computed_metrics: [0.8306459441022855]
# computed_metrics: [0.8705006883503721]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8066253929875018]
# computed_metrics: [0.8066253929875018]
# computed_metrics: [0.8425009424136043]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.811037846192097]
# computed_metrics: [0.811037846192097]
# computed_metrics: [0.8388303014474477]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.7956179515962591]
# computed_metrics: [0.7956179515962591]
# computed_metrics: [0.8259077085526223]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7876010424976225]
# computed_metrics: [0.7876010424976225]
# computed_metrics: [0.8131502157783507]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7880727779801265]
# computed_metrics: [0.7880727779801265]
# computed_metrics: [0.8277482945460662]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7811018868976961]
# computed_metrics: [0.7811018868976961]
# computed_metrics: [0.8197106119066101]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7630495144812659]
# computed_metrics: [0.7630495144812659]
# computed_metrics: [0.7981216080820511]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7456875387413737]
# computed_metrics: [0.7456875387413737]
# computed_metrics: [0.781497746423894]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.749451863158849]
# computed_metrics: [0.749451863158849]
# computed_metrics: [0.7849317844898609]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7356753767690847]
# computed_metrics: [0.7356753767690847]
# computed_metrics: [0.7690569407423873]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7403401259744685]
# computed_metrics: [0.7403401259744685]
# computed_metrics: [0.7635225659141358]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7103614352347442]
# computed_metrics: [0.7103614352347442]
# computed_metrics: [0.7406632755863222]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6958191929012589]
# computed_metrics: [0.6958191929012589]
# computed_metrics: [0.7308363069179687]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6936872976403285]
# computed_metrics: [0.6936872976403285]
# computed_metrics: [0.7374288029105011]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.680628456469197]
# computed_metrics: [0.680628456469197]
# computed_metrics: [0.7260223664919602]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6760501964020355]
# computed_metrics: [0.6760501964020355]
# computed_metrics: [0.7266961326695981]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6695815364489864]
# computed_metrics: [0.6695815364489864]
# computed_metrics: [0.720670963754756]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6563258652947875]
# computed_metrics: [0.6563258652947875]
# computed_metrics: [0.6985719523102786]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6613082822052057]
# computed_metrics: [0.6613082822052057]
# computed_metrics: [0.7106126776854056]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6358476346486337]
# computed_metrics: [0.6358476346486337]
# computed_metrics: [0.6848034553137348]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.668763542054648]
# computed_metrics: [0.668763542054648]
# computed_metrics: [0.7182437521157317]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6271872956538863]
# computed_metrics: [0.6271872956538863]
# computed_metrics: [0.6965762399145444]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6126047181396912]
# computed_metrics: [0.6126047181396912]
# computed_metrics: [0.6741200805191796]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.6365334896520893]
# computed_metrics: [0.6365334896520893]
# computed_metrics: [0.6938244653216274]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.6174504618959743]
# computed_metrics: [0.6174504618959743]
# computed_metrics: [0.6775574916010999]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.6127654022124319]
# computed_metrics: [0.6127654022124319]
# computed_metrics: [0.6723569450708969]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.627920532473522]
# computed_metrics: [0.627920532473522]
# computed_metrics: [0.6989870537028536]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.606658602886979]
# computed_metrics: [0.606658602886979]
# computed_metrics: [0.6686004623960372]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.6077307638870844]
# computed_metrics: [0.6077307638870844]
# computed_metrics: [0.6693348787551114]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6215621171282956]
# computed_metrics: [0.6215621171282956]
# computed_metrics: [0.6729346008880608]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5816140458749663]
# computed_metrics: [0.5816140458749663]
# computed_metrics: [0.6367577205969613]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.6003576155610334]
# computed_metrics: [0.6003576155610334]
# computed_metrics: [0.6569419812005384]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.6017037919476486]
# computed_metrics: [0.6017037919476486]
# computed_metrics: [0.6686712322443606]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.6134602893631709]
# computed_metrics: [0.6134602893631709]
# computed_metrics: [0.6873151953992811]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5785270874994072]
# computed_metrics: [0.5785270874994072]
# computed_metrics: [0.6599195407199423]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5681879609957639]
# computed_metrics: [0.5681879609957639]
# computed_metrics: [0.6599099379433853]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.5442858133814749]
# computed_metrics: [0.5442858133814749]
# computed_metrics: [0.6229838625833164]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5423088626302767]
# computed_metrics: [0.5423088626302767]
# computed_metrics: [0.6084465011302347]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5311974104423695]
# computed_metrics: [0.5311974104423695]
# computed_metrics: [0.6066066206297477]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.5242955049365906]
# computed_metrics: [0.5242955049365906]
# computed_metrics: [0.5989474336210705]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.518560007976991]
# computed_metrics: [0.518560007976991]
# computed_metrics: [0.5844847737521018]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5273885595598785]
# computed_metrics: [0.5273885595598785]
# computed_metrics: [0.5875781765984597]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5308384776526656]
# computed_metrics: [0.5308384776526656]
# computed_metrics: [0.60490863818703]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5891720584855434]
# computed_metrics: [0.5891720584855434]
# computed_metrics: [0.6723807739634303]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5553884103915998]
# computed_metrics: [0.5553884103915998]
# computed_metrics: [0.6293108722189403]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.5783804871141334]
# computed_metrics: [0.5783804871141334]
# computed_metrics: [0.6394529572772235]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5618293656663929]
# computed_metrics: [0.5618293656663929]
# computed_metrics: [0.6393777926934651]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5328073856411333]
# computed_metrics: [0.5328073856411333]
# computed_metrics: [0.6007009445597986]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.5235913917155127]
# computed_metrics: [0.5235913917155127]
# computed_metrics: [0.5898252702236346]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5173166701493946]
# computed_metrics: [0.5173166701493946]
# computed_metrics: [0.5914878205875765]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.5044988713055758]
# computed_metrics: [0.5044988713055758]
# computed_metrics: [0.5746199667818243]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.4986128686909138]
# computed_metrics: [0.4986128686909138]
# computed_metrics: [0.5543676603696199]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.4980373367407119]
# computed_metrics: [0.4980373367407119]
# computed_metrics: [0.5794106587654125]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5207325019567925]
# computed_metrics: [0.5207325019567925]
# computed_metrics: [0.5787756752640766]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.4998072128407324]
# computed_metrics: [0.4998072128407324]
# computed_metrics: [0.5602561510618852]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.48786100711422126]
# computed_metrics: [0.48786100711422126]
# computed_metrics: [0.5707948315959422]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.5148610927278433]
# computed_metrics: [0.5148610927278433]
# computed_metrics: [0.5630746519851875]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.5097233158221224]
# computed_metrics: [0.5097233158221224]
# computed_metrics: [0.5879630746504305]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5390730656313097]
# computed_metrics: [0.5390730656313097]
# computed_metrics: [0.5824750798224885]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.5376511470802874]
# computed_metrics: [0.5376511470802874]
# computed_metrics: [0.5952507452529593]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5692369083931107]
# computed_metrics: [0.5692369083931107]
# computed_metrics: [0.6268908980758507]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.597032561194733]
# computed_metrics: [0.597032561194733]
# computed_metrics: [0.6383320084412946]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5599633350681167]
# computed_metrics: [0.5599633350681167]
# computed_metrics: [0.6023673904827394]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5414865533949852]
# computed_metrics: [0.5414865533949852]
# computed_metrics: [0.6009855749328188]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.4968265645977551]
# computed_metrics: [0.4968265645977551]
# computed_metrics: [0.5888969257496254]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.48516796327724193]
# computed_metrics: [0.48516796327724193]
# computed_metrics: [0.5642773803387973]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.48106963537156006]
# computed_metrics: [0.48106963537156006]
# computed_metrics: [0.5632063403704152]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4841010731726916]
# computed_metrics: [0.4841010731726916]
# computed_metrics: [0.566984303359247]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.45724587688862406]
# computed_metrics: [0.45724587688862406]
# computed_metrics: [0.5661227320230826]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.4516872956025329]
# computed_metrics: [0.4516872956025329]
# computed_metrics: [0.5672591594455451]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.4482593799111359]
# computed_metrics: [0.4482593799111359]
# computed_metrics: [0.5632870868636087]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.44133491789576573]
# computed_metrics: [0.44133491789576573]
# computed_metrics: [0.5508327023067922]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.4442006453894499]
# computed_metrics: [0.4442006453894499]
# computed_metrics: [0.5804812597808526]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4481429917928847]
# computed_metrics: [0.4481429917928847]
# computed_metrics: [0.5908594464736301]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4363420032253726]
# computed_metrics: [0.4363420032253726]
# computed_metrics: [0.5454647808785287]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.4346699801495654]
# computed_metrics: [0.4346699801495654]
# computed_metrics: [0.560145723087781]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.43501174089420724]
# computed_metrics: [0.43501174089420724]
# computed_metrics: [0.5495287572876475]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.43401696513925286]
# computed_metrics: [0.43401696513925286]
# computed_metrics: [0.5619281213641394]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.47847831616143904]
# computed_metrics: [0.47847831616143904]
# computed_metrics: [0.5766672052589243]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.4636447992578636]
# computed_metrics: [0.4636447992578636]
# computed_metrics: [0.5925492646594264]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.43104712523190025]
# computed_metrics: [0.43104712523190025]
# computed_metrics: [0.562757072600503]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4425231102651443]
# computed_metrics: [0.4425231102651443]
# computed_metrics: [0.5738469068807375]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.4324972260247847]
# computed_metrics: [0.4324972260247847]
# computed_metrics: [0.5493585085262176]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.41045432210323557]
# computed_metrics: [0.41045432210323557]
# computed_metrics: [0.5346673639046193]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.40266147982222134]
# computed_metrics: [0.40266147982222134]
# computed_metrics: [0.5264846879626005]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.39523895627451705]
# computed_metrics: [0.39523895627451705]
# computed_metrics: [0.5223295869700058]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.3967737663225681]
# computed_metrics: [0.3967737663225681]
# computed_metrics: [0.5141593673400473]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.3979042149647041]
# computed_metrics: [0.3979042149647041]
# computed_metrics: [0.5346976737137199]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.41217201864277714]
# computed_metrics: [0.41217201864277714]
# computed_metrics: [0.5250867292335967]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.3953805398877454]
# computed_metrics: [0.3953805398877454]
# computed_metrics: [0.543177565932949]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.4011346244321819]
# computed_metrics: [0.4011346244321819]
# computed_metrics: [0.547083966940584]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.41682581972095883]
# computed_metrics: [0.41682581972095883]
# computed_metrics: [0.5803658009440193]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.4132011561616255]
# computed_metrics: [0.4132011561616255]
# computed_metrics: [0.5207396463194183]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.4486008625142945]
# computed_metrics: [0.4486008625142945]
# computed_metrics: [0.5637537965879568]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.39495218155448614]
# computed_metrics: [0.39495218155448614]
# computed_metrics: [0.5534705968118527]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.39293315225911174]
# computed_metrics: [0.39293315225911174]
# computed_metrics: [0.5467898988384713]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.40063709592991475]
# computed_metrics: [0.40063709592991475]
# computed_metrics: [0.52220327526479]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.3754370336071444]
# computed_metrics: [0.3754370336071444]
# computed_metrics: [0.5187058423231203]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.3857244944976673]
# computed_metrics: [0.3857244944976673]
# computed_metrics: [0.5422337170521779]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.40149579541952685]
# computed_metrics: [0.40149579541952685]
# computed_metrics: [0.5335049870551083]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.44491880428985253]
# computed_metrics: [0.44491880428985253]
# computed_metrics: [0.5314236262769753]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.4144898780783545]
# computed_metrics: [0.4144898780783545]
# computed_metrics: [0.5444858146028865]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.38789570018113595]
# computed_metrics: [0.38789570018113595]
# computed_metrics: [0.5653504682201566]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.4219852807746939]
# computed_metrics: [0.4219852807746939]
# computed_metrics: [0.5885353742091337]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.4277953494237595]
# computed_metrics: [0.4277953494237595]
# computed_metrics: [0.5391080191644582]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.47344599606584864]
# computed_metrics: [0.47344599606584864]
# computed_metrics: [0.532897137952389]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.4348477793970626]
# computed_metrics: [0.4348477793970626]
# computed_metrics: [0.5419703725592381]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.41725602468258954]
# computed_metrics: [0.41725602468258954]
# computed_metrics: [0.5762362917617225]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.4357462496735926]
# computed_metrics: [0.4357462496735926]
# computed_metrics: [0.595518008190082]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.4376531185993305]
# computed_metrics: [0.4376531185993305]
# computed_metrics: [0.5345141398171438]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.47052024600695624]
# computed_metrics: [0.47052024600695624]
# computed_metrics: [0.5998332874037454]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.39696224457540674]
# computed_metrics: [0.39696224457540674]
# computed_metrics: [0.5627225477468644]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.39145486371033106]
# computed_metrics: [0.39145486371033106]
# computed_metrics: [0.5468725268221954]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.5308540978423353]
# computed_metrics: [0.5308540978423353]
# computed_metrics: [0.6232574075144386]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.3734537043389797]
# computed_metrics: [0.3734537043389797]
# computed_metrics: [0.5219211160378001]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.4334706081365223]
# computed_metrics: [0.4334706081365223]
# computed_metrics: [0.5543662979272409]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.3780099668939123]
# computed_metrics: [0.3780099668939123]
# computed_metrics: [0.5406884182827636]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.3702244160407793]
# computed_metrics: [0.3702244160407793]
# computed_metrics: [0.546560603879927]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.4245343912968156]
# computed_metrics: [0.4245343912968156]
# computed_metrics: [0.5655470992110718]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.3627377855722559]
# computed_metrics: [0.3627377855722559]
# computed_metrics: [0.5395336419668296]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.3709160859797692]
# computed_metrics: [0.3709160859797692]
# computed_metrics: [0.529098852544634]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.36162909318925357]
# computed_metrics: [0.36162909318925357]
# computed_metrics: [0.5577160999312416]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.3855347860504902]
# computed_metrics: [0.3855347860504902]
# computed_metrics: [0.5566593453521648]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.3911847434949065]
# computed_metrics: [0.3911847434949065]
# computed_metrics: [0.5683200918349295]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.46206760136731134]
# computed_metrics: [0.46206760136731134]
# computed_metrics: [0.6466563722959668]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.47995697375157265]
# computed_metrics: [0.47995697375157265]
# computed_metrics: [0.6391386259063149]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.4525805920910764]
# computed_metrics: [0.4525805920910764]
# computed_metrics: [0.6241487170985495]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.4872253054669921]
# computed_metrics: [0.4872253054669921]
# computed_metrics: [0.6403131071014239]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.3982404538404218]
# computed_metrics: [0.3982404538404218]
# computed_metrics: [0.5928411579401304]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.45567180442129607]
# computed_metrics: [0.45567180442129607]
# computed_metrics: [0.598498138627645]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.4391912714766244]
# computed_metrics: [0.4391912714766244]
# computed_metrics: [0.61786846248497]
# 12.815560375566536

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.4391912714766244]
# computed_metrics: [0.61786846248497]
# computed_metrics: [0.5594944676762298]
# {'mean-mean_absolute_error': 0.5594944676762298}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.9025114, 0.0)
# SpearmanrResult(correlation=0.9015053029246195, pvalue=0.0)
# (0.78732014, 1.3363501772777171e-38)
# SpearmanrResult(correlation=0.7790745006869735, pvalue=2.5127258325444188e-37)
# (0.8184601, 5.62003857458745e-44)
# SpearmanrResult(correlation=0.8243844993099966, pvalue=4.068677986316998e-45)
