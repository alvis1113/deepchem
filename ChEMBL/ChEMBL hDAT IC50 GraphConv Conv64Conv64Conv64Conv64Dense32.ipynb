# %%
import collections

import numpy as np
import six
import tensorflow as tf

from deepchem.data import NumpyDataset
from deepchem.feat.graph_features import ConvMolFeaturizer
from deepchem.feat.mol_graphs import ConvMol
from deepchem.metrics import to_one_hot
from deepchem.models.tensorgraph.graph_layers import WeaveGather, DTNNEmbedding, DTNNStep, DTNNGather, DAGLayer, DAGGather, DTNNExtract, MessagePassing, SetGather
from deepchem.models.tensorgraph.graph_layers import WeaveLayerFactory
from deepchem.models.tensorgraph.layers import Dense, Concat, SoftMax, SoftMaxCrossEntropy, GraphConv, BatchNorm, GraphPool, GraphGather, WeightedError, Dropout, BatchNormalization, Stack, Flatten, GraphCNN, GraphCNNPool
from deepchem.models.tensorgraph.layers import L2Loss, Label, Weights, Feature
from deepchem.models.tensorgraph.tensor_graph import TensorGraph
from deepchem.trans import undo_transforms


class GraphConvTensorGraph(TensorGraph):

  def __init__(self, n_tasks, mode="classification",C1_filtnum=64,C2_filtnum=64,D_nodenum=32, **kwargs):
    """
    Parameters
    ----------
    n_tasks: int
      Number of tasks
    mode: str
      Either "classification" or "regression"
    Cn_filtnum: int
      Number of Conv filters in nth layer
    D_nodenum: int
      Number of nodes in dense layer
    
    """
    self.n_tasks = n_tasks
    self.mode = mode
    self.C1_filtnum = C1_filtnum
    self.C2_filtnum = C2_filtnum
    self.D_nodenum = D_nodenum
       
    self.error_bars = True if 'error_bars' in kwargs and kwargs['error_bars'] else False
    kwargs['use_queue'] = False
    super(GraphConvTensorGraph, self).__init__(**kwargs)
    self.build_graph()


  def build_graph(self):
    """
    Building graph structures:
    """
    self.atom_features = Feature(shape=(None, 75))
    self.degree_slice = Feature(shape=(None, 2), dtype=tf.int32)
    self.membership = Feature(shape=(None,), dtype=tf.int32)

    self.deg_adjs = []
    for i in range(0, 10 + 1):
      deg_adj = Feature(shape=(None, i + 1), dtype=tf.int32)
      self.deg_adjs.append(deg_adj)
    gc1 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[self.atom_features, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm1 = BatchNorm(in_layers=[gc1])
    gc2 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm1, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm2 = BatchNorm(in_layers=[gc2])
    gp1 = GraphPool(in_layers=[batch_norm2, self.degree_slice, self.membership]
                    + self.deg_adjs)
    gc3 = GraphConv(
        self.C1_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[gp1, self.degree_slice, self.membership] +
        self.deg_adjs)
    batch_norm3 = BatchNorm(in_layers=[gc3])
    gc4 = GraphConv(
        self.C2_filtnum,
        activation_fn=tf.nn.relu,
        in_layers=[batch_norm3, self.degree_slice, self.membership] + self.deg_adjs)
    batch_norm4 = BatchNorm(in_layers=[gc4])
    gp2 = GraphPool(in_layers=[batch_norm4, self.degree_slice, self.membership]
                    + self.deg_adjs)
    
    dense = Dense(out_channels=self.D_nodenum, activation_fn=tf.nn.relu, in_layers=[gp2])
    batch_norm5 = BatchNorm(in_layers=[dense])
    readout = GraphGather(
        batch_size=self.batch_size,
        activation_fn=tf.nn.tanh,
        in_layers=[batch_norm5, self.degree_slice, self.membership] +
        self.deg_adjs)

    if self.error_bars == True:
      readout = Dropout(in_layers=[readout], dropout_prob=0.2)

    costs = []
    self.my_labels = []
    for task in range(self.n_tasks):
      if self.mode == 'classification':
        classification = Dense(
            out_channels=2, activation_fn=None, in_layers=[readout])

        softmax = SoftMax(in_layers=[classification])
        self.add_output(softmax)

        label = Label(shape=(None, 2))
        self.my_labels.append(label)
        cost = SoftMaxCrossEntropy(in_layers=[label, classification])
        costs.append(cost)
      if self.mode == 'regression':
        regression = Dense(
            out_channels=1, activation_fn=None, in_layers=[readout])
        self.add_output(regression)

        label = Label(shape=(None, 1))
        self.my_labels.append(label)
        cost = L2Loss(in_layers=[label, regression])
        costs.append(cost)
    if self.mode == "classification":
      entropy = Concat(in_layers=costs, axis=-1)
    elif self.mode == "regression":
      entropy = Stack(in_layers=costs, axis=1)
    self.my_task_weights = Weights(shape=(None, self.n_tasks))
    loss = WeightedError(in_layers=[entropy, self.my_task_weights])
    self.set_loss(loss)



  def default_generator(self,
                        traindataset,
                        validdataset,
                        metrics,
                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    
    modified to add validation step after one epoch training
    
    """
    
    
    global train_metric
    global valid_metric
    train_metric=[]
    valid_metric=[]

    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          traindataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d
      if not predict:
        print('Starting validation epoch %i' % epoch)
        
        if 'mean-mean_absolute_error' in self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False):
            train_metric.append(self.evaluate(dataset=traindataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])
            valid_metric.append(self.evaluate(dataset=validdataset, metrics=metrics, transformers=transformers, per_task_metrics=False)['mean-mean_absolute_error'])

        
  def default_generator_2(self,
#                        traindataset,
                        validdataset,
#                        metrics,
#                        transformers=[],
                        epochs=1,
                        predict=False,
                        deterministic=True,
                        pad_batches=True):
    """
    the same as unmodified default_generator
    used for prediction
    """
    
    
    for epoch in range(epochs):
      if not predict:
        print('Starting epoch %i' % epoch)
      for ind, (X_b, y_b, w_b, ids_b) in enumerate(
          validdataset.iterbatches(
              self.batch_size,
              pad_batches=pad_batches,
              deterministic=deterministic)):
        d = {}
        for index, label in enumerate(self.my_labels):
          if self.mode == 'classification':
            d[label] = to_one_hot(y_b[:, index])
          if self.mode == 'regression':
            d[label] = np.expand_dims(y_b[:, index], -1)
        d[self.my_task_weights] = w_b
        multiConvMol = ConvMol.agglomerate_mols(X_b)
        d[self.atom_features] = multiConvMol.get_atom_features()
        d[self.degree_slice] = multiConvMol.deg_slice
        d[self.membership] = multiConvMol.membership
        for i in range(1, len(multiConvMol.get_deg_adjacency_lists())):
          d[self.deg_adjs[i - 1]] = multiConvMol.get_deg_adjacency_lists()[i]
        yield d

  def fit2(self,
          traindataset,
          validdataset,
          metrics,
          transformers=[],
          nb_epoch=10,
          max_checkpoints_to_keep=5,
          checkpoint_interval=1000,
          deterministic=False,
          restore=False,
          submodel=None,
          **kwargs):
    """Train this model on a dataset using modifed default_generator.
    validation step using metrics is performed after one epoch training. 
    

    Parameters
    ----------
    dataset: Dataset
      the Dataset to train on
    nb_epoch: int
      the number of epochs to train for
    max_checkpoints_to_keep: int
      the maximum number of checkpoints to keep.  Older checkpoints are discarded.
    checkpoint_interval: int
      the frequency at which to write checkpoints, measured in training steps.
      Set this to 0 to disable automatic checkpointing.
    deterministic: bool
      if True, the samples are processed in order.  If False, a different random
      order is used for each epoch.
    restore: bool
      if True, restore the model from the most recent checkpoint and continue training
      from there.  If False, retrain the model from scratch.
    submodel: Submodel
      an alternate training objective to use.  This should have been created by
      calling create_submodel().
    """
    return self.fit_generator(
        self.default_generator(
            traindataset,validdataset,metrics,transformers, epochs=nb_epoch, deterministic=deterministic, **kwargs),
        max_checkpoints_to_keep, checkpoint_interval, restore, submodel)


  def predict_on_generator(self, generator, transformers=[], outputs=None):
    if not self.built:
      self.build()
    if outputs is None:
      outputs = self.outputs
    elif not isinstance(outputs, collections.Sequence):
      outputs = [outputs]
    with self._get_tf("Graph").as_default():
      # Gather results for each output
      results = [[] for out in outputs]
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        # Recording the number of samples in the input batch
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 0.0
        feed_results = self.session.run(outputs, feed_dict=feed_dict)
        if len(feed_results) > 1:
          if len(transformers):
            raise ValueError("Does not support transformations "
                             "for multiple outputs.")
        elif len(feed_results) == 1:
          result = undo_transforms(feed_results[0], transformers)
          feed_results = [result]
        for ind, result in enumerate(feed_results):
          # GraphConvTensorGraph constantly outputs batch_size number of
          # results, only valid samples should be appended to final results
          results[ind].append(result[:n_samples])

      final_results = []
      for result_list in results:
        final_results.append(np.concatenate(result_list, axis=0))
      # If only one output, just return array
      if len(final_results) == 1:
        return final_results[0]
      else:
        return final_results



  def predict_proba_on_generator(self, generator, transformers=[],
                                 outputs=None):
    if not self.built:
      self.build()
    with self._get_tf("Graph").as_default():
      out_tensors = [x.out_tensor for x in self.outputs]
      results = []
      for feed_dict in generator:
        feed_dict = {
            self.layers[k.name].out_tensor: v
            for k, v in six.iteritems(feed_dict)
        }
        n_samples = max(feed_dict[self.membership.out_tensor]) + 1
        feed_dict[self._training_placeholder] = 1.0  ##
        result = np.array(self.session.run(out_tensors, feed_dict=feed_dict))
        if len(result.shape) == 3:
          result = np.transpose(result, axes=[1, 0, 2])
        if len(transformers) > 0:
          result = undo_transforms(result, transformers)
        results.append(result[:n_samples])
      return np.concatenate(results, axis=0)



  def evaluate(self, dataset, metrics, transformers=[], per_task_metrics=False):
    if not self.built:
      self.build()
    return self.evaluate_generator(
        self.default_generator_2(dataset, predict=True),
        metrics,
        labels=self.my_labels,
        weights=[self.my_task_weights],
        per_task_metrics=per_task_metrics)



  def bayesian_predict(self,
                       dataset,
                       transformers=[],
                       n_passes=4,
                       untransform=False):
    """Generates predictions and confidences on a dataset object
     https://arxiv.org/pdf/1506.02142.pdf

    # Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    X = dataset.X
    max_index = X.shape[0] - 1
    num_batches = (max_index // self.batch_size) + 1

    mus = []
    sigmas = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      batch = X[start:end]
      mu, sigma = self.bayesian_predict_on_batch(
          batch, transformers=[], n_passes=n_passes)
      mus.append(mu)
      sigmas.append(sigma)
    mu = np.concatenate(mus, axis=0)
    sigma = np.concatenate(sigmas, axis=0) + 0.55

    if untransform:
      mu = undo_transforms(mu, transformers)
      for i in range(sigma.shape[1]):
        sigma[:, i] = sigma[:, i] * transformers[0].y_stds[i]

    return mu[:max_index + 1], sigma[:max_index + 1]



  def bayesian_predict_on_batch(self, X, transformers=[], n_passes=4):
    """
    Returns:
      mu: numpy ndarray of shape (n_samples, n_tasks)
      sigma: numpy ndarray of shape (n_samples, n_tasks)
    """
    dataset = NumpyDataset(X=X, y=None, n_tasks=len(self.outputs))
    y_ = []
    for i in range(n_passes):
      generator = self.default_generator_2(
          dataset, predict=True, pad_batches=True)
      y_.append(self.predict_on_generator(generator, transformers))

    # Concatenates along 0-th dimension
    y_ = np.array(y_)
    mu = np.mean(y_, axis=0)
    sigma = np.std(y_, axis=0)

    return mu, sigma



  def predict_on_smiles(self, smiles, transformers=[], untransform=False):
    """Generates predictions on a numpy array of smile strings

    # Returns:
      y_: numpy ndarray of shape (n_samples, n_tasks)
    """
    max_index = len(smiles) - 1
    n_tasks = len(self.outputs)
    num_batches = (max_index // self.batch_size) + 1
    featurizer = ConvMolFeaturizer()

    y_ = []
    for i in range(num_batches):
      start = i * self.batch_size
      end = min((i + 1) * self.batch_size, max_index + 1)
      smiles_batch = smiles[start:end]
      y_.append(
          self.predict_on_smiles_batch(smiles_batch, featurizer, transformers))
    y_ = np.concatenate(y_, axis=0)[:max_index + 1]
    y_ = y_.reshape(-1, n_tasks)

    if untransform:
      y_ = undo_transforms(y_, transformers)

    return y_

  def predict(self, dataset, transformers=[], outputs=None):
    """
    Uses self to make predictions on provided Dataset object.

    Parameters
    ----------
    dataset: dc.data.Dataset
      Dataset to make prediction on
    transformers: list
      List of dc.trans.Transformers.
    outputs: object
      If outputs is None, then will assume outputs = self.outputs[0] (single
      output). If outputs is a Layer/Tensor, then will evaluate and return as a
      single ndarray. If outputs is a list of Layers/Tensors, will return a list
      of ndarrays.

    Returns
    -------
    results: numpy ndarray or list of numpy ndarrays
    """
    generator = self.default_generator_2(dataset, predict=True, pad_batches=False)
    return self.predict_on_generator(generator, transformers, outputs)

# %%
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import os

import numpy as np
import tensorflow as tf
import deepchem as dc

from deepchem.utils.save import load_from_disk
from deepchem.feat.graph_features import ConvMolFeaturizer, WeaveFeaturizer

input_data='../ChEMBL/hDAT_pIC50.csv'

tasks = ['affinity']
#featurizer=WeaveFeaturizer()
featurizer=ConvMolFeaturizer()


loader = dc.data.CSVLoader(tasks=tasks, smiles_field="canonical_smiles",featurizer=featurizer)
dataset=loader.featurize(input_data)
# Out:
# Loading raw samples now.
# shard_size: 8192
# About to start loading CSV from ../ChEMBL/hDAT_pIC50.csv
# Loading shard 1 of size 8192.
# Featurizing sample 0
# Featurizing sample 1000
# TIMING: featurizing shard 0 took 2.858 s
# TIMING: dataset construction took 3.261 s
# Loading dataset from disk.

# %%
import deepchem as dc
import tempfile, shutil
from deepchem.splits.splitters import RandomSplitter

splitter=RandomSplitter()
train_data,valid_data,test_data=splitter.train_valid_test_split(dataset)
# Out:
# TIMING: dataset construction took 0.514 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.226 s
# Loading dataset from disk.
# TIMING: dataset construction took 0.233 s
# Loading dataset from disk.

# %%
out_path = '../ChEMBL/hDAT/logdir/'

C1_filtnum = 64
C2_filtnum = 64
D_nodenum = 32

graph_structure = 'GC{0}_GC{1}_GP_GC{0}_GC{1}_GP_D{2}'.format(C1_filtnum,C2_filtnum,D_nodenum)

model_dir = out_path+graph_structure+'/'

np.random.seed(0)
random_seed = 0

model = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression', 
                             C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                             random_seed=random_seed)
#model = WeaveTensorGraph(len(tasks), dropout=0.5, batch_size=100, mode='regression')

from sklearn.metrics import mean_absolute_error
from deepchem.metrics import rms_score
import deepchem.hyper.grid_search

metric = dc.metrics.Metric(
    mean_absolute_error, task_averager=np.mean, mode="regression")

# %%
model.build()
model.save()
model.fit2(train_data,valid_data, metrics=[metric], nb_epoch=500, deterministic=True)

print(train_metric)
print(valid_metric)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [4.098811251787589]
# computed_metrics: [4.098811251787589]
# computed_metrics: [4.1026252907149106]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [2.8731160689696864]
# computed_metrics: [2.8731160689696864]
# computed_metrics: [2.8764735455167743]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [2.078290556517881]
# computed_metrics: [2.078290556517881]
# computed_metrics: [2.074317437942915]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.4835527430324777]
# computed_metrics: [1.4835527430324777]
# computed_metrics: [1.4740554912812027]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [1.162819141747877]
# computed_metrics: [1.162819141747877]
# computed_metrics: [1.1348846627084808]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [1.0202905211684017]
# computed_metrics: [1.0202905211684017]
# computed_metrics: [0.9759014164367349]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9504758428380553]
# computed_metrics: [0.9504758428380553]
# computed_metrics: [0.8968202722522969]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.925883911507642]
# computed_metrics: [0.925883911507642]
# computed_metrics: [0.8617465570891334]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8982001323030782]
# computed_metrics: [0.8982001323030782]
# computed_metrics: [0.8198663321999056]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.9065828642640801]
# computed_metrics: [0.9065828642640801]
# computed_metrics: [0.8404545312369217]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8772657852931609]
# computed_metrics: [0.8772657852931609]
# computed_metrics: [0.8033265724702909]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8810359480037786]
# computed_metrics: [0.8810359480037786]
# computed_metrics: [0.8135920019892413]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.8516353522444089]
# computed_metrics: [0.8516353522444089]
# computed_metrics: [0.7764136304600203]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8408593638948197]
# computed_metrics: [0.8408593638948197]
# computed_metrics: [0.7547154419397952]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8339927875688158]
# computed_metrics: [0.8339927875688158]
# computed_metrics: [0.766889939559366]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.8258077353579099]
# computed_metrics: [0.8258077353579099]
# computed_metrics: [0.7667032396747172]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.8287466064023056]
# computed_metrics: [0.8287466064023056]
# computed_metrics: [0.773090760209574]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.8140294731968424]
# computed_metrics: [0.8140294731968424]
# computed_metrics: [0.7528137042534242]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7990224706098646]
# computed_metrics: [0.7990224706098646]
# computed_metrics: [0.7314468051862932]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.782607394938645]
# computed_metrics: [0.782607394938645]
# computed_metrics: [0.7193062923599617]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7712198094079423]
# computed_metrics: [0.7712198094079423]
# computed_metrics: [0.7209226895750926]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7631316918790679]
# computed_metrics: [0.7631316918790679]
# computed_metrics: [0.7031166864159636]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7569306560845352]
# computed_metrics: [0.7569306560845352]
# computed_metrics: [0.6893783644646144]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7532434659827163]
# computed_metrics: [0.7532434659827163]
# computed_metrics: [0.7143321884684921]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7381326690284045]
# computed_metrics: [0.7381326690284045]
# computed_metrics: [0.6799179283728406]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.7160394456894811]
# computed_metrics: [0.7160394456894811]
# computed_metrics: [0.6544345035513864]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.7080604202697303]
# computed_metrics: [0.7080604202697303]
# computed_metrics: [0.6238210078815408]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.6719118647892474]
# computed_metrics: [0.6719118647892474]
# computed_metrics: [0.5979293590651797]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6627342250626095]
# computed_metrics: [0.6627342250626095]
# computed_metrics: [0.5929347161144307]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.663883382137517]
# computed_metrics: [0.663883382137517]
# computed_metrics: [0.5802595153991628]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6397392704692098]
# computed_metrics: [0.6397392704692098]
# computed_metrics: [0.572750702351733]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6404297635931513]
# computed_metrics: [0.6404297635931513]
# computed_metrics: [0.5766748968471788]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6297717348904599]
# computed_metrics: [0.6297717348904599]
# computed_metrics: [0.5802060236358249]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6266658142484177]
# computed_metrics: [0.6266658142484177]
# computed_metrics: [0.5689806039448083]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6319631270649243]
# computed_metrics: [0.6319631270649243]
# computed_metrics: [0.5763269413632612]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.5885165355088263]
# computed_metrics: [0.5885165355088263]
# computed_metrics: [0.5393673667941491]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.5938673973031634]
# computed_metrics: [0.5938673973031634]
# computed_metrics: [0.5713023806700647]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.5831584898628939]
# computed_metrics: [0.5831584898628939]
# computed_metrics: [0.5399255462785705]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.5710589946476395]
# computed_metrics: [0.5710589946476395]
# computed_metrics: [0.5464507173482321]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.642053144868223]
# computed_metrics: [0.642053144868223]
# computed_metrics: [0.6100874496121077]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.6092265282382182]
# computed_metrics: [0.6092265282382182]
# computed_metrics: [0.5573678327592495]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.6116928939851248]
# computed_metrics: [0.6116928939851248]
# computed_metrics: [0.5536345526152465]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.6141990198808875]
# computed_metrics: [0.6141990198808875]
# computed_metrics: [0.5893893385146513]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.6222714992310604]
# computed_metrics: [0.6222714992310604]
# computed_metrics: [0.5775805472340979]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5889163834276494]
# computed_metrics: [0.5889163834276494]
# computed_metrics: [0.5836731681341867]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.6346570070489295]
# computed_metrics: [0.6346570070489295]
# computed_metrics: [0.6236192933552365]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.6076043803527348]
# computed_metrics: [0.6076043803527348]
# computed_metrics: [0.5496740694137411]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.5954199985270363]
# computed_metrics: [0.5954199985270363]
# computed_metrics: [0.5868197464481076]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.6299640239173462]
# computed_metrics: [0.6299640239173462]
# computed_metrics: [0.6464795418051081]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.6176242975009621]
# computed_metrics: [0.6176242975009621]
# computed_metrics: [0.6079728306354757]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.6524427626179177]
# computed_metrics: [0.6524427626179177]
# computed_metrics: [0.6665060417961058]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.6245544315123169]
# computed_metrics: [0.6245544315123169]
# computed_metrics: [0.6352712779202322]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.6284957312763928]
# computed_metrics: [0.6284957312763928]
# computed_metrics: [0.6465045445299022]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.6095503060538391]
# computed_metrics: [0.6095503060538391]
# computed_metrics: [0.6044667372110311]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.524125083787698]
# computed_metrics: [0.524125083787698]
# computed_metrics: [0.5238107252734386]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5284625395179054]
# computed_metrics: [0.5284625395179054]
# computed_metrics: [0.5620188530260934]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5043802858616109]
# computed_metrics: [0.5043802858616109]
# computed_metrics: [0.5295620924706129]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.4981748136884643]
# computed_metrics: [0.4981748136884643]
# computed_metrics: [0.531285138109738]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.4916319040099186]
# computed_metrics: [0.4916319040099186]
# computed_metrics: [0.5470250169600529]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.4894728668345155]
# computed_metrics: [0.4894728668345155]
# computed_metrics: [0.5516038946886554]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5056559481953151]
# computed_metrics: [0.5056559481953151]
# computed_metrics: [0.5694027276088377]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.4713667129919088]
# computed_metrics: [0.4713667129919088]
# computed_metrics: [0.5411468343123]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.4540154562196538]
# computed_metrics: [0.4540154562196538]
# computed_metrics: [0.5123211850039457]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.44900255254438276]
# computed_metrics: [0.44900255254438276]
# computed_metrics: [0.5373103446622436]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.4553933473447242]
# computed_metrics: [0.4553933473447242]
# computed_metrics: [0.5545422920740999]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.46629654197088255]
# computed_metrics: [0.46629654197088255]
# computed_metrics: [0.5536093301558069]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.44853098803681984]
# computed_metrics: [0.44853098803681984]
# computed_metrics: [0.5506150710377424]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.44263590930514446]
# computed_metrics: [0.44263590930514446]
# computed_metrics: [0.5331011332804476]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.42719038281073685]
# computed_metrics: [0.42719038281073685]
# computed_metrics: [0.5123314131983498]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.4347483562861141]
# computed_metrics: [0.4347483562861141]
# computed_metrics: [0.5032529001547255]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.44124567147085986]
# computed_metrics: [0.44124567147085986]
# computed_metrics: [0.5250543183465117]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.416003948613809]
# computed_metrics: [0.416003948613809]
# computed_metrics: [0.4933851099632771]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.4387005638496505]
# computed_metrics: [0.4387005638496505]
# computed_metrics: [0.5617517166358208]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.4293444375734126]
# computed_metrics: [0.4293444375734126]
# computed_metrics: [0.5354892956120361]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.4709579450926727]
# computed_metrics: [0.4709579450926727]
# computed_metrics: [0.5669627053754701]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.4417522883614653]
# computed_metrics: [0.4417522883614653]
# computed_metrics: [0.5284580824725232]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.5015906655159011]
# computed_metrics: [0.5015906655159011]
# computed_metrics: [0.5922848062235374]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.4958388481122979]
# computed_metrics: [0.4958388481122979]
# computed_metrics: [0.5655506940245937]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.490714650323043]
# computed_metrics: [0.490714650323043]
# computed_metrics: [0.5650097540996836]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.43578301258575575]
# computed_metrics: [0.43578301258575575]
# computed_metrics: [0.5161736914250316]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.4211504157429972]
# computed_metrics: [0.4211504157429972]
# computed_metrics: [0.5385415646666046]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.4079903599681886]
# computed_metrics: [0.4079903599681886]
# computed_metrics: [0.5140008079531234]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.37793430577008263]
# computed_metrics: [0.37793430577008263]
# computed_metrics: [0.4863967863724983]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.36823020982912735]
# computed_metrics: [0.36823020982912735]
# computed_metrics: [0.4862374311398421]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.3778562829738878]
# computed_metrics: [0.3778562829738878]
# computed_metrics: [0.5246408220297933]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.38936189134375465]
# computed_metrics: [0.38936189134375465]
# computed_metrics: [0.5322120757099592]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.37973944439934343]
# computed_metrics: [0.37973944439934343]
# computed_metrics: [0.528685316312667]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4192061579386739]
# computed_metrics: [0.4192061579386739]
# computed_metrics: [0.5533204587148272]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.3879031246996197]
# computed_metrics: [0.3879031246996197]
# computed_metrics: [0.4974967780658267]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.4158826885880867]
# computed_metrics: [0.4158826885880867]
# computed_metrics: [0.5559241377437334]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.3757903360456924]
# computed_metrics: [0.3757903360456924]
# computed_metrics: [0.532643201575089]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.3875917131775895]
# computed_metrics: [0.3875917131775895]
# computed_metrics: [0.532299693885652]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.399396023851722]
# computed_metrics: [0.399396023851722]
# computed_metrics: [0.547113505874362]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.38676975730761187]
# computed_metrics: [0.38676975730761187]
# computed_metrics: [0.560267370769116]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.38969875693081324]
# computed_metrics: [0.38969875693081324]
# computed_metrics: [0.5627599003945628]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.3752860946395338]
# computed_metrics: [0.3752860946395338]
# computed_metrics: [0.5353497951777602]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.3351827113244048]
# computed_metrics: [0.3351827113244048]
# computed_metrics: [0.5074778619977641]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.32948511934438096]
# computed_metrics: [0.32948511934438096]
# computed_metrics: [0.5171611115929605]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.3599034164374721]
# computed_metrics: [0.3599034164374721]
# computed_metrics: [0.512252717377934]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.4062235396109564]
# computed_metrics: [0.4062235396109564]
# computed_metrics: [0.5527414888285911]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.44141163994284205]
# computed_metrics: [0.44141163994284205]
# computed_metrics: [0.599099451645217]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.45006034709079]
# computed_metrics: [0.45006034709079]
# computed_metrics: [0.5610731107918641]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.4247508232794527]
# computed_metrics: [0.4247508232794527]
# computed_metrics: [0.5710304360893106]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.4568843395743285]
# computed_metrics: [0.4568843395743285]
# computed_metrics: [0.554228230355737]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.47070822911900345]
# computed_metrics: [0.47070822911900345]
# computed_metrics: [0.6458264459307541]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.44172741908458757]
# computed_metrics: [0.44172741908458757]
# computed_metrics: [0.5580558812873576]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.46470037132057157]
# computed_metrics: [0.46470037132057157]
# computed_metrics: [0.6377213827203092]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.35725616593813336]
# computed_metrics: [0.35725616593813336]
# computed_metrics: [0.4827429586857324]
# Starting epoch 108
# Starting validation epoch 108
# computed_metrics: [0.37337211635723994]
# computed_metrics: [0.37337211635723994]
# computed_metrics: [0.5330929235278462]
# Starting epoch 109
# Starting validation epoch 109
# computed_metrics: [0.3532225207980143]
# computed_metrics: [0.3532225207980143]
# computed_metrics: [0.5060079639405126]
# Starting epoch 110
# Starting validation epoch 110
# computed_metrics: [0.35816272961674767]
# computed_metrics: [0.35816272961674767]
# computed_metrics: [0.5489526881132898]
# Starting epoch 111
# Starting validation epoch 111
# computed_metrics: [0.3705720495030992]
# computed_metrics: [0.3705720495030992]
# computed_metrics: [0.5178262775498237]
# Starting epoch 112
# Starting validation epoch 112
# computed_metrics: [0.40399802462794693]
# computed_metrics: [0.40399802462794693]
# computed_metrics: [0.5613133409446389]
# Starting epoch 113
# Starting validation epoch 113
# computed_metrics: [0.45551372603789875]
# computed_metrics: [0.45551372603789875]
# computed_metrics: [0.5962578200592416]
# Starting epoch 114
# Starting validation epoch 114
# computed_metrics: [0.46055464580270594]
# computed_metrics: [0.46055464580270594]
# computed_metrics: [0.6075729221292077]
# Starting epoch 115
# Starting validation epoch 115
# computed_metrics: [0.3822546283902692]
# computed_metrics: [0.3822546283902692]
# computed_metrics: [0.5414903135414105]
# Starting epoch 116
# Starting validation epoch 116
# computed_metrics: [0.32754715271750706]
# computed_metrics: [0.32754715271750706]
# computed_metrics: [0.49181717362930083]
# Starting epoch 117
# Starting validation epoch 117
# computed_metrics: [0.38195877894324964]
# computed_metrics: [0.38195877894324964]
# computed_metrics: [0.5196410091723759]
# Starting epoch 118
# Starting validation epoch 118
# computed_metrics: [0.38541117070445685]
# computed_metrics: [0.38541117070445685]
# computed_metrics: [0.568887171885891]
# Starting epoch 119
# Starting validation epoch 119
# computed_metrics: [0.38605094083454183]
# computed_metrics: [0.38605094083454183]
# computed_metrics: [0.5351673330369202]
# Starting epoch 120
# Starting validation epoch 120
# computed_metrics: [0.37152706780716127]
# computed_metrics: [0.37152706780716127]
# computed_metrics: [0.4954152779346624]
# Starting epoch 121
# Starting validation epoch 121
# computed_metrics: [0.33394634164168213]
# computed_metrics: [0.33394634164168213]
# computed_metrics: [0.4945275861713291]
# Starting epoch 122
# Starting validation epoch 122
# computed_metrics: [0.3052866468205049]
# computed_metrics: [0.3052866468205049]
# computed_metrics: [0.4925638004459053]
# Starting epoch 123
# Starting validation epoch 123
# computed_metrics: [0.32685484408380944]
# computed_metrics: [0.32685484408380944]
# computed_metrics: [0.5018299611164642]
# Starting epoch 124
# Starting validation epoch 124
# computed_metrics: [0.338149344100946]
# computed_metrics: [0.338149344100946]
# computed_metrics: [0.5203736641073514]
# Starting epoch 125
# Starting validation epoch 125
# computed_metrics: [0.3380994678907772]
# computed_metrics: [0.3380994678907772]
# computed_metrics: [0.5221671014705409]
# Starting epoch 126
# Starting validation epoch 126
# computed_metrics: [0.3156974867424983]
# computed_metrics: [0.3156974867424983]
# computed_metrics: [0.5019145534364242]
# Starting epoch 127
# Starting validation epoch 127
# computed_metrics: [0.28530521188566293]
# computed_metrics: [0.28530521188566293]
# computed_metrics: [0.4980127797815497]
# Starting epoch 128
# Starting validation epoch 128
# computed_metrics: [0.3466908991888529]
# computed_metrics: [0.3466908991888529]
# computed_metrics: [0.5459013403333892]
# Starting epoch 129
# Starting validation epoch 129
# computed_metrics: [0.373883941053264]
# computed_metrics: [0.373883941053264]
# computed_metrics: [0.56706857161268]
# Starting epoch 130
# Starting validation epoch 130
# computed_metrics: [0.3436638329708452]
# computed_metrics: [0.3436638329708452]
# computed_metrics: [0.5155389491339218]
# Starting epoch 131
# Starting validation epoch 131
# computed_metrics: [0.3180972811164841]
# computed_metrics: [0.3180972811164841]
# computed_metrics: [0.5251879431593913]
# Starting epoch 132
# Starting validation epoch 132
# computed_metrics: [0.34309935025931093]
# computed_metrics: [0.34309935025931093]
# computed_metrics: [0.5619478046104704]
# Starting epoch 133
# Starting validation epoch 133
# computed_metrics: [0.4067648182797483]
# computed_metrics: [0.4067648182797483]
# computed_metrics: [0.5767101722065759]
# Starting epoch 134
# Starting validation epoch 134
# computed_metrics: [0.3331142476911984]
# computed_metrics: [0.3331142476911984]
# computed_metrics: [0.5026431620431158]
# Starting epoch 135
# Starting validation epoch 135
# computed_metrics: [0.35358713706071554]
# computed_metrics: [0.35358713706071554]
# computed_metrics: [0.5591683982738878]
# Starting epoch 136
# Starting validation epoch 136
# computed_metrics: [0.3102875963620961]
# computed_metrics: [0.3102875963620961]
# computed_metrics: [0.5276401222585907]
# Starting epoch 137
# Starting validation epoch 137
# computed_metrics: [0.2847520725200329]
# computed_metrics: [0.2847520725200329]
# computed_metrics: [0.5248938843704326]
# Starting epoch 138
# Starting validation epoch 138
# computed_metrics: [0.30528343191053275]
# computed_metrics: [0.30528343191053275]
# computed_metrics: [0.5261751030320908]
# Starting epoch 139
# Starting validation epoch 139
# computed_metrics: [0.3542432177659203]
# computed_metrics: [0.3542432177659203]
# computed_metrics: [0.5739842682612019]
# Starting epoch 140
# Starting validation epoch 140
# computed_metrics: [0.32011223926647747]
# computed_metrics: [0.32011223926647747]
# computed_metrics: [0.5441274897977917]
# Starting epoch 141
# Starting validation epoch 141
# computed_metrics: [0.32949888835556557]
# computed_metrics: [0.32949888835556557]
# computed_metrics: [0.5587383592641789]
# Starting epoch 142
# Starting validation epoch 142
# computed_metrics: [0.32038596003419084]
# computed_metrics: [0.32038596003419084]
# computed_metrics: [0.572441131111995]
# Starting epoch 143
# Starting validation epoch 143
# computed_metrics: [0.2796989041924285]
# computed_metrics: [0.2796989041924285]
# computed_metrics: [0.49243277359333837]
# Starting epoch 144
# Starting validation epoch 144
# computed_metrics: [0.27418936258116894]
# computed_metrics: [0.27418936258116894]
# computed_metrics: [0.5262254468196054]
# Starting epoch 145
# Starting validation epoch 145
# computed_metrics: [0.3738731347261581]
# computed_metrics: [0.3738731347261581]
# computed_metrics: [0.5862073505924741]
# Starting epoch 146
# Starting validation epoch 146
# computed_metrics: [0.29710224834383364]
# computed_metrics: [0.29710224834383364]
# computed_metrics: [0.5377217274808738]
# Starting epoch 147
# Starting validation epoch 147
# computed_metrics: [0.27276426666429726]
# computed_metrics: [0.27276426666429726]
# computed_metrics: [0.5312428510546267]
# Starting epoch 148
# Starting validation epoch 148
# computed_metrics: [0.2692384654880242]
# computed_metrics: [0.2692384654880242]
# computed_metrics: [0.4994577085346713]
# Starting epoch 149
# Starting validation epoch 149
# computed_metrics: [0.3008016022723721]
# computed_metrics: [0.3008016022723721]
# computed_metrics: [0.49461014095425904]
# Starting epoch 150
# Starting validation epoch 150
# computed_metrics: [0.2737374091377646]
# computed_metrics: [0.2737374091377646]
# computed_metrics: [0.5091514085553622]
# Starting epoch 151
# Starting validation epoch 151
# computed_metrics: [0.3293080762028963]
# computed_metrics: [0.3293080762028963]
# computed_metrics: [0.5787508477993698]
# Starting epoch 152
# Starting validation epoch 152
# computed_metrics: [0.2681813957762581]
# computed_metrics: [0.2681813957762581]
# computed_metrics: [0.5241171400877975]
# Starting epoch 153
# Starting validation epoch 153
# computed_metrics: [0.25450836465483795]
# computed_metrics: [0.25450836465483795]
# computed_metrics: [0.5166074510541548]
# Starting epoch 154
# Starting validation epoch 154
# computed_metrics: [0.2812412601170636]
# computed_metrics: [0.2812412601170636]
# computed_metrics: [0.5362858424538102]
# Starting epoch 155
# Starting validation epoch 155
# computed_metrics: [0.33155845701575287]
# computed_metrics: [0.33155845701575287]
# computed_metrics: [0.5591363932665545]
# Starting epoch 156
# Starting validation epoch 156
# computed_metrics: [0.32721075658831505]
# computed_metrics: [0.32721075658831505]
# computed_metrics: [0.5581701656746025]
# Starting epoch 157
# Starting validation epoch 157
# computed_metrics: [0.2974462724829063]
# computed_metrics: [0.2974462724829063]
# computed_metrics: [0.5426939292838767]
# Starting epoch 158
# Starting validation epoch 158
# computed_metrics: [0.262873671918795]
# computed_metrics: [0.262873671918795]
# computed_metrics: [0.5109582415589081]
# Starting epoch 159
# Starting validation epoch 159
# computed_metrics: [0.2738218765582172]
# computed_metrics: [0.2738218765582172]
# computed_metrics: [0.5373238533223412]
# Starting epoch 160
# Starting validation epoch 160
# computed_metrics: [0.37106654873781897]
# computed_metrics: [0.37106654873781897]
# computed_metrics: [0.5851156277768089]
# Starting epoch 161
# Starting validation epoch 161
# computed_metrics: [0.42584450997144596]
# computed_metrics: [0.42584450997144596]
# computed_metrics: [0.6322487973821301]
# Starting epoch 162
# Starting validation epoch 162
# computed_metrics: [0.4483422257155816]
# computed_metrics: [0.4483422257155816]
# computed_metrics: [0.6221064640313471]
# Starting epoch 163
# Starting validation epoch 163
# computed_metrics: [0.33765589991243694]
# computed_metrics: [0.33765589991243694]
# computed_metrics: [0.5409873165939917]
# Starting epoch 164
# Starting validation epoch 164
# computed_metrics: [0.317091250890768]
# computed_metrics: [0.317091250890768]
# computed_metrics: [0.5584080330534545]
# Starting epoch 165
# Starting validation epoch 165
# computed_metrics: [0.385368505189454]
# computed_metrics: [0.385368505189454]
# computed_metrics: [0.573563692676091]
# Starting epoch 166
# Starting validation epoch 166
# computed_metrics: [0.3830821459253034]
# computed_metrics: [0.3830821459253034]
# computed_metrics: [0.6142931546784396]
# Starting epoch 167
# Starting validation epoch 167
# computed_metrics: [0.3394205996527875]
# computed_metrics: [0.3394205996527875]
# computed_metrics: [0.5553422789514321]
# Starting epoch 168
# Starting validation epoch 168
# computed_metrics: [0.33381777749790215]
# computed_metrics: [0.33381777749790215]
# computed_metrics: [0.564997879706685]
# Starting epoch 169
# Starting validation epoch 169
# computed_metrics: [0.29218590647855464]
# computed_metrics: [0.29218590647855464]
# computed_metrics: [0.5297032915221214]
# Starting epoch 170
# Starting validation epoch 170
# computed_metrics: [0.29227737939292125]
# computed_metrics: [0.29227737939292125]
# computed_metrics: [0.5535566463179123]
# Starting epoch 171
# Starting validation epoch 171
# computed_metrics: [0.36306126493895835]
# computed_metrics: [0.36306126493895835]
# computed_metrics: [0.5835662594103613]
# Starting epoch 172
# Starting validation epoch 172
# computed_metrics: [0.32433277167337726]
# computed_metrics: [0.32433277167337726]
# computed_metrics: [0.562897545987758]
# Starting epoch 173
# Starting validation epoch 173
# computed_metrics: [0.28392560274627615]
# computed_metrics: [0.28392560274627615]
# computed_metrics: [0.5138564431948318]
# Starting epoch 174
# Starting validation epoch 174
# computed_metrics: [0.284294510803369]
# computed_metrics: [0.284294510803369]
# computed_metrics: [0.5282796353697203]
# Starting epoch 175
# Starting validation epoch 175
# computed_metrics: [0.30681381357183574]
# computed_metrics: [0.30681381357183574]
# computed_metrics: [0.5649301484537066]
# Starting epoch 176
# Starting validation epoch 176
# computed_metrics: [0.3332471529779279]
# computed_metrics: [0.3332471529779279]
# computed_metrics: [0.5668671096311596]
# Starting epoch 177
# Starting validation epoch 177
# computed_metrics: [0.38258512403762845]
# computed_metrics: [0.38258512403762845]
# computed_metrics: [0.5984423722756451]
# Starting epoch 178
# Starting validation epoch 178
# computed_metrics: [0.27510613289839436]
# computed_metrics: [0.27510613289839436]
# computed_metrics: [0.535672532190021]
# Starting epoch 179
# Starting validation epoch 179
# computed_metrics: [0.261380147524393]
# computed_metrics: [0.261380147524393]
# computed_metrics: [0.506402239637855]
# Starting epoch 180
# Starting validation epoch 180
# computed_metrics: [0.26081417129259515]
# computed_metrics: [0.26081417129259515]
# computed_metrics: [0.519398512107624]
# Starting epoch 181
# Starting validation epoch 181
# computed_metrics: [0.2549242360033282]
# computed_metrics: [0.2549242360033282]
# computed_metrics: [0.49060534569307135]
# Starting epoch 182
# Starting validation epoch 182
# computed_metrics: [0.24299122433364553]
# computed_metrics: [0.24299122433364553]
# computed_metrics: [0.5393320890990079]
# Starting epoch 183
# Starting validation epoch 183
# computed_metrics: [0.2403051828736233]
# computed_metrics: [0.2403051828736233]
# computed_metrics: [0.5331390587170022]
# Starting epoch 184
# Starting validation epoch 184
# computed_metrics: [0.2567561790334177]
# computed_metrics: [0.2567561790334177]
# computed_metrics: [0.5515214202849095]
# Starting epoch 185
# Starting validation epoch 185
# computed_metrics: [0.29345308752645033]
# computed_metrics: [0.29345308752645033]
# computed_metrics: [0.5760595562986864]
# Starting epoch 186
# Starting validation epoch 186
# computed_metrics: [0.2454100191696824]
# computed_metrics: [0.2454100191696824]
# computed_metrics: [0.5296654951659032]
# Starting epoch 187
# Starting validation epoch 187
# computed_metrics: [0.24968505023639787]
# computed_metrics: [0.24968505023639787]
# computed_metrics: [0.5324569926332512]
# Starting epoch 188
# Starting validation epoch 188
# computed_metrics: [0.32299382324629883]
# computed_metrics: [0.32299382324629883]
# computed_metrics: [0.5677713212453117]
# Starting epoch 189
# Starting validation epoch 189
# computed_metrics: [0.36942914464106635]
# computed_metrics: [0.36942914464106635]
# computed_metrics: [0.5842336177825875]
# Starting epoch 190
# Starting validation epoch 190
# computed_metrics: [0.3189479016081044]
# computed_metrics: [0.3189479016081044]
# computed_metrics: [0.5557728502624927]
# Starting epoch 191
# Starting validation epoch 191
# computed_metrics: [0.2673695277590961]
# computed_metrics: [0.2673695277590961]
# computed_metrics: [0.5237522508847711]
# Starting epoch 192
# Starting validation epoch 192
# computed_metrics: [0.3036423178023232]
# computed_metrics: [0.3036423178023232]
# computed_metrics: [0.5601322838202951]
# Starting epoch 193
# Starting validation epoch 193
# computed_metrics: [0.37849645907358864]
# computed_metrics: [0.37849645907358864]
# computed_metrics: [0.5833810898087464]
# Starting epoch 194
# Starting validation epoch 194
# computed_metrics: [0.36200658948838244]
# computed_metrics: [0.36200658948838244]
# computed_metrics: [0.6105709185181957]
# Starting epoch 195
# Starting validation epoch 195
# computed_metrics: [0.26164189039340807]
# computed_metrics: [0.26164189039340807]
# computed_metrics: [0.5502608908794305]
# Starting epoch 196
# Starting validation epoch 196
# computed_metrics: [0.3021575342719554]
# computed_metrics: [0.3021575342719554]
# computed_metrics: [0.549621496826542]
# Starting epoch 197
# Starting validation epoch 197
# computed_metrics: [0.3721407172009724]
# computed_metrics: [0.3721407172009724]
# computed_metrics: [0.602083652837922]
# Starting epoch 198
# Starting validation epoch 198
# computed_metrics: [0.36214451880135273]
# computed_metrics: [0.36214451880135273]
# computed_metrics: [0.6090237492881333]
# Starting epoch 199
# Starting validation epoch 199
# computed_metrics: [0.25257863534520597]
# computed_metrics: [0.25257863534520597]
# computed_metrics: [0.5226806452577472]
# Starting epoch 200
# Starting validation epoch 200
# computed_metrics: [0.291249229503625]
# computed_metrics: [0.291249229503625]
# computed_metrics: [0.5396676251429628]
# Starting epoch 201
# Starting validation epoch 201
# computed_metrics: [0.35638666249747386]
# computed_metrics: [0.35638666249747386]
# computed_metrics: [0.6190593618620829]
# Starting epoch 202
# Starting validation epoch 202
# computed_metrics: [0.3453403019096214]
# computed_metrics: [0.3453403019096214]
# computed_metrics: [0.6031677628396738]
# Starting epoch 203
# Starting validation epoch 203
# computed_metrics: [0.2603862618061137]
# computed_metrics: [0.2603862618061137]
# computed_metrics: [0.562207574209786]
# Starting epoch 204
# Starting validation epoch 204
# computed_metrics: [0.28224858826654786]
# computed_metrics: [0.28224858826654786]
# computed_metrics: [0.5483747442250119]
# Starting epoch 205
# Starting validation epoch 205
# computed_metrics: [0.33136903082687763]
# computed_metrics: [0.33136903082687763]
# computed_metrics: [0.5736749978837119]
# Starting epoch 206
# Starting validation epoch 206
# computed_metrics: [0.285396453783331]
# computed_metrics: [0.285396453783331]
# computed_metrics: [0.5506179477041967]
# Starting epoch 207
# Starting validation epoch 207
# computed_metrics: [0.25777771069027405]
# computed_metrics: [0.25777771069027405]
# computed_metrics: [0.5402440315758771]
# Starting epoch 208
# Starting validation epoch 208
# computed_metrics: [0.30017618727584444]
# computed_metrics: [0.30017618727584444]
# computed_metrics: [0.5727792140689527]
# Starting epoch 209
# Starting validation epoch 209
# computed_metrics: [0.2962606559467056]
# computed_metrics: [0.2962606559467056]
# computed_metrics: [0.5676860614272639]
# Starting epoch 210
# Starting validation epoch 210
# computed_metrics: [0.22890415489258753]
# computed_metrics: [0.22890415489258753]
# computed_metrics: [0.54244073876057]
# Starting epoch 211
# Starting validation epoch 211
# computed_metrics: [0.3288185498289006]
# computed_metrics: [0.3288185498289006]
# computed_metrics: [0.5657512104469694]
# Starting epoch 212
# Starting validation epoch 212
# computed_metrics: [0.4304476176478701]
# computed_metrics: [0.4304476176478701]
# computed_metrics: [0.6519738985738734]
# Starting epoch 213
# Starting validation epoch 213
# computed_metrics: [0.28462069449069977]
# computed_metrics: [0.28462069449069977]
# computed_metrics: [0.5553694098863866]
# Starting epoch 214
# Starting validation epoch 214
# computed_metrics: [0.29795706113247433]
# computed_metrics: [0.29795706113247433]
# computed_metrics: [0.5722478478572537]
# Starting epoch 215
# Starting validation epoch 215
# computed_metrics: [0.35014719034381564]
# computed_metrics: [0.35014719034381564]
# computed_metrics: [0.5860832311215434]
# Starting epoch 216
# Starting validation epoch 216
# computed_metrics: [0.3320613788224916]
# computed_metrics: [0.3320613788224916]
# computed_metrics: [0.5574794187055199]
# Starting epoch 217
# Starting validation epoch 217
# computed_metrics: [0.27315355688945314]
# computed_metrics: [0.27315355688945314]
# computed_metrics: [0.5251632709160348]
# Starting epoch 218
# Starting validation epoch 218
# computed_metrics: [0.2594499058884835]
# computed_metrics: [0.2594499058884835]
# computed_metrics: [0.5385133189681662]
# Starting epoch 219
# Starting validation epoch 219
# computed_metrics: [0.272471103546571]
# computed_metrics: [0.272471103546571]
# computed_metrics: [0.5422670763143761]
# Starting epoch 220
# Starting validation epoch 220
# computed_metrics: [0.248888351507074]
# computed_metrics: [0.248888351507074]
# computed_metrics: [0.5459842983906484]
# Starting epoch 221
# Starting validation epoch 221
# computed_metrics: [0.23929125499823878]
# computed_metrics: [0.23929125499823878]
# computed_metrics: [0.5524328473806787]
# Starting epoch 222
# Starting validation epoch 222
# computed_metrics: [0.245708344301206]
# computed_metrics: [0.245708344301206]
# computed_metrics: [0.5534750976588337]
# Starting epoch 223
# Starting validation epoch 223
# computed_metrics: [0.2443023866730261]
# computed_metrics: [0.2443023866730261]
# computed_metrics: [0.5659206663901382]
# Starting epoch 224
# Starting validation epoch 224
# computed_metrics: [0.2206973621233048]
# computed_metrics: [0.2206973621233048]
# computed_metrics: [0.5502242646300527]
# Starting epoch 225
# Starting validation epoch 225
# computed_metrics: [0.265383587243872]
# computed_metrics: [0.265383587243872]
# computed_metrics: [0.5291125894421225]
# Starting epoch 226
# Starting validation epoch 226
# computed_metrics: [0.2194855490809615]
# computed_metrics: [0.2194855490809615]
# computed_metrics: [0.5504804945719803]
# Starting epoch 227
# Starting validation epoch 227
# computed_metrics: [0.21562560858562765]
# computed_metrics: [0.21562560858562765]
# computed_metrics: [0.539059047298965]
# Starting epoch 228
# Starting validation epoch 228
# computed_metrics: [0.3012992332548648]
# computed_metrics: [0.3012992332548648]
# computed_metrics: [0.5932170960604761]
# Starting epoch 229
# Starting validation epoch 229
# computed_metrics: [0.2447707395516261]
# computed_metrics: [0.2447707395516261]
# computed_metrics: [0.558522727646971]
# Starting epoch 230
# Starting validation epoch 230
# computed_metrics: [0.1989762161868399]
# computed_metrics: [0.1989762161868399]
# computed_metrics: [0.5313503970667288]
# Starting epoch 231
# Starting validation epoch 231
# computed_metrics: [0.2931318005130314]
# computed_metrics: [0.2931318005130314]
# computed_metrics: [0.5633193071216469]
# Starting epoch 232
# Starting validation epoch 232
# computed_metrics: [0.30976425023787474]
# computed_metrics: [0.30976425023787474]
# computed_metrics: [0.5982770957138458]
# Starting epoch 233
# Starting validation epoch 233
# computed_metrics: [0.24762966622771346]
# computed_metrics: [0.24762966622771346]
# computed_metrics: [0.5514125052745873]
# Starting epoch 234
# Starting validation epoch 234
# computed_metrics: [0.33483775267454086]
# computed_metrics: [0.33483775267454086]
# computed_metrics: [0.5948024775380446]
# Starting epoch 235
# Starting validation epoch 235
# computed_metrics: [0.3952582597436532]
# computed_metrics: [0.3952582597436532]
# computed_metrics: [0.6216438317886044]
# Starting epoch 236
# Starting validation epoch 236
# computed_metrics: [0.31631015912816807]
# computed_metrics: [0.31631015912816807]
# computed_metrics: [0.5750792165667548]
# Starting epoch 237
# Starting validation epoch 237
# computed_metrics: [0.25925336571589813]
# computed_metrics: [0.25925336571589813]
# computed_metrics: [0.5572240797082838]
# Starting epoch 238
# Starting validation epoch 238
# computed_metrics: [0.2872079896568229]
# computed_metrics: [0.2872079896568229]
# computed_metrics: [0.533251128817375]
# Starting epoch 239
# Starting validation epoch 239
# computed_metrics: [0.3489596871815181]
# computed_metrics: [0.3489596871815181]
# computed_metrics: [0.6054154290535563]
# Starting epoch 240
# Starting validation epoch 240
# computed_metrics: [0.27987733722923]
# computed_metrics: [0.27987733722923]
# computed_metrics: [0.546640552134535]
# Starting epoch 241
# Starting validation epoch 241
# computed_metrics: [0.25010599559911006]
# computed_metrics: [0.25010599559911006]
# computed_metrics: [0.524146990495604]
# Starting epoch 242
# Starting validation epoch 242
# computed_metrics: [0.22873608499850992]
# computed_metrics: [0.22873608499850992]
# computed_metrics: [0.5192677218790562]
# Starting epoch 243
# Starting validation epoch 243
# computed_metrics: [0.29140660887358927]
# computed_metrics: [0.29140660887358927]
# computed_metrics: [0.5626810113780542]
# Starting epoch 244
# Starting validation epoch 244
# computed_metrics: [0.3609916305276912]
# computed_metrics: [0.3609916305276912]
# computed_metrics: [0.6090625378831678]
# Starting epoch 245
# Starting validation epoch 245
# computed_metrics: [0.2570550884863623]
# computed_metrics: [0.2570550884863623]
# computed_metrics: [0.5361856556043803]
# Starting epoch 246
# Starting validation epoch 246
# computed_metrics: [0.2655989928846721]
# computed_metrics: [0.2655989928846721]
# computed_metrics: [0.5523567732707502]
# Starting epoch 247
# Starting validation epoch 247
# computed_metrics: [0.34507625257903984]
# computed_metrics: [0.34507625257903984]
# computed_metrics: [0.6081343763877731]
# Starting epoch 248
# Starting validation epoch 248
# computed_metrics: [0.34190781822084876]
# computed_metrics: [0.34190781822084876]
# computed_metrics: [0.5846960535915707]
# Starting epoch 249
# Starting validation epoch 249
# computed_metrics: [0.24643798702561517]
# computed_metrics: [0.24643798702561517]
# computed_metrics: [0.5338961535913878]
# Starting epoch 250
# Starting validation epoch 250
# computed_metrics: [0.2931800809088401]
# computed_metrics: [0.2931800809088401]
# computed_metrics: [0.5830121140409106]
# Starting epoch 251
# Starting validation epoch 251
# computed_metrics: [0.2853357331722913]
# computed_metrics: [0.2853357331722913]
# computed_metrics: [0.5704622647969488]
# Starting epoch 252
# Starting validation epoch 252
# computed_metrics: [0.23412970546877074]
# computed_metrics: [0.23412970546877074]
# computed_metrics: [0.545237112717052]
# Starting epoch 253
# Starting validation epoch 253
# computed_metrics: [0.2740403566519954]
# computed_metrics: [0.2740403566519954]
# computed_metrics: [0.5528950920844868]
# Starting epoch 254
# Starting validation epoch 254
# computed_metrics: [0.2921947395755092]
# computed_metrics: [0.2921947395755092]
# computed_metrics: [0.5535889414657228]
# Starting epoch 255
# Starting validation epoch 255
# computed_metrics: [0.22801332680138406]
# computed_metrics: [0.22801332680138406]
# computed_metrics: [0.5392286844435191]
# Starting epoch 256
# Starting validation epoch 256
# computed_metrics: [0.28733454793543556]
# computed_metrics: [0.28733454793543556]
# computed_metrics: [0.5826435765285176]
# Starting epoch 257
# Starting validation epoch 257
# computed_metrics: [0.310405951470039]
# computed_metrics: [0.310405951470039]
# computed_metrics: [0.5865992560543939]
# Starting epoch 258
# Starting validation epoch 258
# computed_metrics: [0.2497106943458159]
# computed_metrics: [0.2497106943458159]
# computed_metrics: [0.5399401508692167]
# Starting epoch 259
# Starting validation epoch 259
# computed_metrics: [0.26964723429088744]
# computed_metrics: [0.26964723429088744]
# computed_metrics: [0.5318117660540594]
# Starting epoch 260
# Starting validation epoch 260
# computed_metrics: [0.33755958502722017]
# computed_metrics: [0.33755958502722017]
# computed_metrics: [0.5989252964713055]
# Starting epoch 261
# Starting validation epoch 261
# computed_metrics: [0.25754140052187635]
# computed_metrics: [0.25754140052187635]
# computed_metrics: [0.5451685395770834]
# Starting epoch 262
# Starting validation epoch 262
# computed_metrics: [0.2790227475363606]
# computed_metrics: [0.2790227475363606]
# computed_metrics: [0.5732464437207702]
# Starting epoch 263
# Starting validation epoch 263
# computed_metrics: [0.3264715163384368]
# computed_metrics: [0.3264715163384368]
# computed_metrics: [0.5846826936741943]
# Starting epoch 264
# Starting validation epoch 264
# computed_metrics: [0.22346111377931865]
# computed_metrics: [0.22346111377931865]
# computed_metrics: [0.5304260613004776]
# Starting epoch 265
# Starting validation epoch 265
# computed_metrics: [0.2818888772238283]
# computed_metrics: [0.2818888772238283]
# computed_metrics: [0.5682413599267674]
# Starting epoch 266
# Starting validation epoch 266
# computed_metrics: [0.3296215240847385]
# computed_metrics: [0.3296215240847385]
# computed_metrics: [0.5930264055686943]
# Starting epoch 267
# Starting validation epoch 267
# computed_metrics: [0.24781402177324718]
# computed_metrics: [0.24781402177324718]
# computed_metrics: [0.55575290129516]
# Starting epoch 268
# Starting validation epoch 268
# computed_metrics: [0.30743696750816224]
# computed_metrics: [0.30743696750816224]
# computed_metrics: [0.5826948911387118]
# Starting epoch 269
# Starting validation epoch 269
# computed_metrics: [0.2755386449902185]
# computed_metrics: [0.2755386449902185]
# computed_metrics: [0.5752756072792242]
# Starting epoch 270
# Starting validation epoch 270
# computed_metrics: [0.21065917723670904]
# computed_metrics: [0.21065917723670904]
# computed_metrics: [0.5392239652186507]
# Starting epoch 271
# Starting validation epoch 271
# computed_metrics: [0.28180886931619725]
# computed_metrics: [0.28180886931619725]
# computed_metrics: [0.5789973860517993]
# Starting epoch 272
# Starting validation epoch 272
# computed_metrics: [0.24672927809186807]
# computed_metrics: [0.24672927809186807]
# computed_metrics: [0.5384197926667891]
# Starting epoch 273
# Starting validation epoch 273
# computed_metrics: [0.2172206746332665]
# computed_metrics: [0.2172206746332665]
# computed_metrics: [0.5175505525458888]
# Starting epoch 274
# Starting validation epoch 274
# computed_metrics: [0.24677100591178286]
# computed_metrics: [0.24677100591178286]
# computed_metrics: [0.576689216400922]
# Starting epoch 275
# Starting validation epoch 275
# computed_metrics: [0.29294484569833723]
# computed_metrics: [0.29294484569833723]
# computed_metrics: [0.5950706474102835]
# Starting epoch 276
# Starting validation epoch 276
# computed_metrics: [0.24287943969393333]
# computed_metrics: [0.24287943969393333]
# computed_metrics: [0.5532796536586205]
# Starting epoch 277
# Starting validation epoch 277
# computed_metrics: [0.24089768876939202]
# computed_metrics: [0.24089768876939202]
# computed_metrics: [0.5404916277955332]
# Starting epoch 278
# Starting validation epoch 278
# computed_metrics: [0.2988633717618562]
# computed_metrics: [0.2988633717618562]
# computed_metrics: [0.596215405927203]
# Starting epoch 279
# Starting validation epoch 279
# computed_metrics: [0.24508297340512994]
# computed_metrics: [0.24508297340512994]
# computed_metrics: [0.5447998908771499]
# Starting epoch 280
# Starting validation epoch 280
# computed_metrics: [0.2223287293601768]
# computed_metrics: [0.2223287293601768]
# computed_metrics: [0.5422673801573769]
# Starting epoch 281
# Starting validation epoch 281
# computed_metrics: [0.263975268982998]
# computed_metrics: [0.263975268982998]
# computed_metrics: [0.5665781946636571]
# Starting epoch 282
# Starting validation epoch 282
# computed_metrics: [0.22308265243750605]
# computed_metrics: [0.22308265243750605]
# computed_metrics: [0.5582915800309496]
# Starting epoch 283
# Starting validation epoch 283
# computed_metrics: [0.21998465906900688]
# computed_metrics: [0.21998465906900688]
# computed_metrics: [0.5425097361287402]
# Starting epoch 284
# Starting validation epoch 284
# computed_metrics: [0.3405075958478651]
# computed_metrics: [0.3405075958478651]
# computed_metrics: [0.6190925444580391]
# Starting epoch 285
# Starting validation epoch 285
# computed_metrics: [0.2841892328055069]
# computed_metrics: [0.2841892328055069]
# computed_metrics: [0.5867309335341375]
# Starting epoch 286
# Starting validation epoch 286
# computed_metrics: [0.26183491995833985]
# computed_metrics: [0.26183491995833985]
# computed_metrics: [0.5510894992137482]
# Starting epoch 287
# Starting validation epoch 287
# computed_metrics: [0.32806602586519734]
# computed_metrics: [0.32806602586519734]
# ...
# computed_metrics: [0.2163726283556458]
# computed_metrics: [0.2163726283556458]
# computed_metrics: [0.5770675953890614]
# Starting epoch 453
# Starting validation epoch 453
# computed_metrics: [0.2941086770956309]
# computed_metrics: [0.2941086770956309]
# computed_metrics: [0.6198654742740369]
# Starting epoch 454
# Starting validation epoch 454
# computed_metrics: [0.1871853540358028]
# computed_metrics: [0.1871853540358028]
# computed_metrics: [0.5727155480961582]
# Starting epoch 455
# Starting validation epoch 455
# computed_metrics: [0.23972640902850992]
# computed_metrics: [0.23972640902850992]
# computed_metrics: [0.5921550541798066]
# Starting epoch 456
# Starting validation epoch 456
# computed_metrics: [0.17338252913696003]
# computed_metrics: [0.17338252913696003]
# computed_metrics: [0.5812161536110252]
# Starting epoch 457
# Starting validation epoch 457
# computed_metrics: [0.2360160626135397]
# computed_metrics: [0.2360160626135397]
# computed_metrics: [0.5936503284954743]
# Starting epoch 458
# Starting validation epoch 458
# computed_metrics: [0.19913886135343717]
# computed_metrics: [0.19913886135343717]
# computed_metrics: [0.5693416589683179]
# Starting epoch 459
# Starting validation epoch 459
# computed_metrics: [0.21432229284226334]
# computed_metrics: [0.21432229284226334]
# computed_metrics: [0.5855500470584275]
# Starting epoch 460
# Starting validation epoch 460
# computed_metrics: [0.22448003380914433]
# computed_metrics: [0.22448003380914433]
# computed_metrics: [0.5915572773889989]
# Starting epoch 461
# Starting validation epoch 461
# computed_metrics: [0.18051686846022608]
# computed_metrics: [0.18051686846022608]
# computed_metrics: [0.5770250260199414]
# Starting epoch 462
# Starting validation epoch 462
# computed_metrics: [0.25412806411080896]
# computed_metrics: [0.25412806411080896]
# computed_metrics: [0.5858158716116463]
# Starting epoch 463
# Starting validation epoch 463
# computed_metrics: [0.18036350321485306]
# computed_metrics: [0.18036350321485306]
# computed_metrics: [0.5650875261935042]
# Starting epoch 464
# Starting validation epoch 464
# computed_metrics: [0.24252867403427308]
# computed_metrics: [0.24252867403427308]
# computed_metrics: [0.5911667648837939]
# Starting epoch 465
# Starting validation epoch 465
# computed_metrics: [0.16027528862326182]
# computed_metrics: [0.16027528862326182]
# computed_metrics: [0.5649126991407946]
# Starting epoch 466
# Starting validation epoch 466
# computed_metrics: [0.24306025942700193]
# computed_metrics: [0.24306025942700193]
# computed_metrics: [0.60762389337652]
# Starting epoch 467
# Starting validation epoch 467
# computed_metrics: [0.20534447917910906]
# computed_metrics: [0.20534447917910906]
# computed_metrics: [0.5813474778082914]
# Starting epoch 468
# Starting validation epoch 468
# computed_metrics: [0.2091517760357492]
# computed_metrics: [0.2091517760357492]
# computed_metrics: [0.5772047603191736]
# Starting epoch 469
# Starting validation epoch 469
# computed_metrics: [0.19941136575125235]
# computed_metrics: [0.19941136575125235]
# computed_metrics: [0.5726249528780533]
# Starting epoch 470
# Starting validation epoch 470
# computed_metrics: [0.1565340666695347]
# computed_metrics: [0.1565340666695347]
# computed_metrics: [0.5623943856909073]
# Starting epoch 471
# Starting validation epoch 471
# computed_metrics: [0.2066331797304373]
# computed_metrics: [0.2066331797304373]
# computed_metrics: [0.6089571445380887]
# Starting epoch 472
# Starting validation epoch 472
# computed_metrics: [0.15730096168164914]
# computed_metrics: [0.15730096168164914]
# computed_metrics: [0.5690736245066504]
# Starting epoch 473
# Starting validation epoch 473
# computed_metrics: [0.21486502749378153]
# computed_metrics: [0.21486502749378153]
# computed_metrics: [0.5865678014850696]
# Starting epoch 474
# Starting validation epoch 474
# computed_metrics: [0.18141085054766373]
# computed_metrics: [0.18141085054766373]
# computed_metrics: [0.5694705650147489]
# Starting epoch 475
# Starting validation epoch 475
# computed_metrics: [0.2218217729638661]
# computed_metrics: [0.2218217729638661]
# computed_metrics: [0.5972130869427416]
# Starting epoch 476
# Starting validation epoch 476
# computed_metrics: [0.22615725362935493]
# computed_metrics: [0.22615725362935493]
# computed_metrics: [0.5960084524427997]
# Starting epoch 477
# Starting validation epoch 477
# computed_metrics: [0.16317001128397016]
# computed_metrics: [0.16317001128397016]
# computed_metrics: [0.5671108304461417]
# Starting epoch 478
# Starting validation epoch 478
# computed_metrics: [0.21517178720919206]
# computed_metrics: [0.21517178720919206]
# computed_metrics: [0.5661294951288185]
# Starting epoch 479
# Starting validation epoch 479
# computed_metrics: [0.15037618274295145]
# computed_metrics: [0.15037618274295145]
# computed_metrics: [0.5540242263887089]
# Starting epoch 480
# Starting validation epoch 480
# computed_metrics: [0.2432037203521624]
# computed_metrics: [0.2432037203521624]
# computed_metrics: [0.596963459679632]
# Starting epoch 481
# Starting validation epoch 481
# computed_metrics: [0.18828593452550596]
# computed_metrics: [0.18828593452550596]
# computed_metrics: [0.5710544619798709]
# Starting epoch 482
# Starting validation epoch 482
# computed_metrics: [0.22925744872599965]
# computed_metrics: [0.22925744872599965]
# computed_metrics: [0.5762907900838797]
# Starting epoch 483
# Starting validation epoch 483
# computed_metrics: [0.2068915387994373]
# computed_metrics: [0.2068915387994373]
# computed_metrics: [0.5828591259449114]
# Starting epoch 484
# Starting validation epoch 484
# computed_metrics: [0.19833096273260895]
# computed_metrics: [0.19833096273260895]
# computed_metrics: [0.5683516493376771]
# Starting epoch 485
# Starting validation epoch 485
# computed_metrics: [0.2540381360128811]
# computed_metrics: [0.2540381360128811]
# computed_metrics: [0.6020956776244427]
# Starting epoch 486
# Starting validation epoch 486
# computed_metrics: [0.19885204337547457]
# computed_metrics: [0.19885204337547457]
# computed_metrics: [0.5478293814592781]
# Starting epoch 487
# Starting validation epoch 487
# computed_metrics: [0.2351104066269037]
# computed_metrics: [0.2351104066269037]
# computed_metrics: [0.5779641512900152]
# Starting epoch 488
# Starting validation epoch 488
# computed_metrics: [0.18182524128386945]
# computed_metrics: [0.18182524128386945]
# computed_metrics: [0.5272288728528481]
# Starting epoch 489
# Starting validation epoch 489
# computed_metrics: [0.21782549406090856]
# computed_metrics: [0.21782549406090856]
# computed_metrics: [0.5611149107970866]
# Starting epoch 490
# Starting validation epoch 490
# computed_metrics: [0.2103193151265487]
# computed_metrics: [0.2103193151265487]
# computed_metrics: [0.5832631939837324]
# Starting epoch 491
# Starting validation epoch 491
# computed_metrics: [0.18791020064264463]
# computed_metrics: [0.18791020064264463]
# computed_metrics: [0.5744392874387658]
# Starting epoch 492
# Starting validation epoch 492
# computed_metrics: [0.2152261493153635]
# computed_metrics: [0.2152261493153635]
# computed_metrics: [0.5585555608319236]
# Starting epoch 493
# Starting validation epoch 493
# computed_metrics: [0.16830155652349238]
# computed_metrics: [0.16830155652349238]
# computed_metrics: [0.5628706577559542]
# Starting epoch 494
# Starting validation epoch 494
# computed_metrics: [0.19211132821938337]
# computed_metrics: [0.19211132821938337]
# computed_metrics: [0.5739004049721987]
# Starting epoch 495
# Starting validation epoch 495
# computed_metrics: [0.19610009349015553]
# computed_metrics: [0.19610009349015553]
# computed_metrics: [0.5721409655522218]
# Starting epoch 496
# Starting validation epoch 496
# computed_metrics: [0.16567173819739317]
# computed_metrics: [0.16567173819739317]
# computed_metrics: [0.576738257563648]
# Starting epoch 497
# Starting validation epoch 497
# computed_metrics: [0.22918746826048156]
# computed_metrics: [0.22918746826048156]
# computed_metrics: [0.5894296191103634]
# Starting epoch 498
# Starting validation epoch 498
# computed_metrics: [0.17719486596793263]
# computed_metrics: [0.17719486596793263]
# computed_metrics: [0.5855151063684769]
# Starting epoch 499
# Starting validation epoch 499
# computed_metrics: [0.19333253032469241]
# computed_metrics: [0.19333253032469241]
# computed_metrics: [0.5788751182868398]
# [4.098811251787589, 2.8731160689696864, 2.078290556517881, 1.4835527430324777, 1.162819141747877, 1.0202905211684017, 0.9504758428380553, 0.925883911507642, 0.8982001323030782, 0.9065828642640801, 0.8772657852931609, 0.8810359480037786, 0.8516353522444089, 0.8408593638948197, 0.8339927875688158, 0.8258077353579099, 0.8287466064023056, 0.8140294731968424, 0.7990224706098646, 0.782607394938645, 0.7712198094079423, 0.7631316918790679, 0.7569306560845352, 0.7532434659827163, 0.7381326690284045, 0.7160394456894811, 0.7080604202697303, 0.6719118647892474, 0.6627342250626095, 0.663883382137517, 0.6397392704692098, 0.6404297635931513, 0.6297717348904599, 0.6266658142484177, 0.6319631270649243, 0.5885165355088263, 0.5938673973031634, 0.5831584898628939, 0.5710589946476395, 0.642053144868223, 0.6092265282382182, 0.6116928939851248, 0.6141990198808875, 0.6222714992310604, 0.5889163834276494, 0.6346570070489295, 0.6076043803527348, 0.5954199985270363, 0.6299640239173462, 0.6176242975009621, 0.6524427626179177, 0.6245544315123169, 0.6284957312763928, 0.6095503060538391, 0.524125083787698, 0.5284625395179054, 0.5043802858616109, 0.4981748136884643, 0.4916319040099186, 0.4894728668345155, 0.5056559481953151, 0.4713667129919088, 0.4540154562196538, 0.44900255254438276, 0.4553933473447242, 0.46629654197088255, 0.44853098803681984, 
#  [0.27404036 0.55289509]
#  [0.29219474 0.55358894]
#  [0.22801333 0.53922868]
#  [0.28733455 0.58264358]
#  [0.31040595 0.58659926]
#  [0.24971069 0.53994015]
#  [0.26964723 0.53181177]
#  [0.33755959 0.5989253 ]
#  [0.2575414  0.54516854]
#  [0.27902275 0.57324644]
#  [0.32647152 0.58468269]
#  [0.22346111 0.53042606]
#  [0.28188888 0.56824136]
#  [0.32962152 0.59302641]
#  [0.24781402 0.5557529 ]
#  [0.30743697 0.58269489]
#  [0.27553864 0.57527561]
#  [0.21065918 0.53922397]
#  [0.28180887 0.57899739]
#  [0.24672928 0.53841979]
#  [0.21722067 0.51755055]
#  [0.24677101 0.57668922]
#  [0.29294485 0.59507065]
#  [0.24287944 0.55327965]
#  [0.24089769 0.54049163]
#  [0.29886337 0.59621541]
#  [0.24508297 0.54479989]
#  [0.22232873 0.54226738]
#  [0.26397527 0.56657819]
#  [0.22308265 0.55829158]
#  [0.21998466 0.54250974]
#  [0.3405076  0.61909254]
#  [0.28418923 0.58673093]
#  [0.26183492 0.5510895 ]
#  [0.32806603 0.56689116]
#  [0.2542427  0.55320684]
#  [0.29608762 0.58367933]
#  [0.31444772 0.60709399]
#  [0.2336822  0.54360804]
#  [0.26565906 0.56977188]
#  [0.33557113 0.57029026]
#  [0.2169398  0.54985008]
#  [0.27623631 0.58965867]
#  [0.2789632  0.58228097]
#  [0.22019748 0.56434759]
#  [0.33460895 0.61667066]
#  [0.21701191 0.55972865]
#  [0.25662448 0.56449542]
#  [0.25727513 0.58194182]
#  [0.22340782 0.55412176]
#  [0.28625897 0.57768818]
#  [0.21100725 0.55449003]
#  [0.25824114 0.58045881]
#  [0.24426964 0.57695721]
#  [0.19869282 0.55052687]
#  [0.2622308  0.57446544]
#  [0.20795326 0.55679338]
#  [0.22806135 0.55217784]
#  [0.24635747 0.59408607]
#  [0.20062637 0.55371962]
#  [0.23184374 0.56509941]
#  [0.23079276 0.56123875]
#  [0.19459805 0.54906331]
#  [0.23223669 0.57590744]
#  [0.19763893 0.56110398]
#  [0.20463828 0.56541353]
#  [0.24588339 0.55771421]
#  [0.19124579 0.53024356]
#  [0.25036316 0.5843987 ]
#  [0.22523013 0.58023382]
#  [0.1899425  0.57070885]
#  [0.22135967 0.56881366]
#  [0.20414397 0.55751854]
#  [0.175363   0.55508486]
#  [0.22975023 0.5959262 ]
#  [0.17853587 0.57820184]
#  [0.22630051 0.5816601 ]
#  [0.27237129 0.5963485 ]
#  [0.19599373 0.55104118]
#  [0.2696915  0.60079266]
#  [0.2545268  0.5988238 ]
#  [0.23304755 0.57760184]
#  [0.333166   0.61494901]
#  [0.24445571 0.55883413]
#  [0.22177618 0.565996  ]
#  [0.29149218 0.59147273]
#  [0.2172822  0.57388938]
#  [0.20635826 0.55810487]
#  [0.29323567 0.59931926]
#  [0.23226887 0.550948  ]
#  [0.2178604  0.53518605]
#  [0.32366581 0.61664527]
#  [0.22445055 0.56531163]
#  [0.2563822  0.55742804]
#  [0.28884604 0.6005679 ]
#  [0.20215805 0.53902691]
#  [0.29135186 0.5913135 ]
#  [0.24122423 0.55671804]
#  [0.21866664 0.58117274]
#  [0.25811849 0.59500894]
#  [0.17090796 0.56361851]
#  [0.25891359 0.59263382]
#  [0.22216623 0.5612679 ]
#  [0.20724332 0.56177347]
#  [0.2597776  0.58708212]
#  [0.18454612 0.55408085]
#  [0.24162355 0.58323507]
#  [0.21299488 0.57129513]
#  [0.17897112 0.5468602 ]
#  [0.26665908 0.60706298]
#  [0.20376292 0.57230761]
#  [0.22996632 0.574562  ]
#  [0.25718658 0.58370788]
#  [0.21211376 0.56005018]
#  [0.27339824 0.61131653]
#  [0.2271507  0.5941267 ]
#  [0.19626289 0.57530095]
#  [0.25653822 0.60957812]
#  [0.1886219  0.55598983]
#  [0.26190342 0.59172966]
#  [0.29561562 0.58828705]
#  [0.20399949 0.56344178]
#  [0.24643801 0.56340901]
#  [0.25778791 0.60136504]
#  [0.19360892 0.55669389]
#  [0.22441913 0.57072584]
#  [0.2243323  0.55190024]
#  [0.19292595 0.56036189]
#  [0.25423634 0.57095217]
#  [0.20907249 0.57381761]
#  [0.21663626 0.56786606]
#  [0.28226186 0.59379737]
#  [0.19101385 0.55087333]
#  [0.32649783 0.61646737]
#  [0.25122811 0.59105149]
#  [0.22225766 0.5665293 ]
#  [0.3075225  0.59583404]
#  [0.22002075 0.55559075]
#  [0.27208666 0.58183592]
#  [0.27952091 0.59829859]
#  [0.20181992 0.56820509]
#  [0.23174393 0.56230964]
#  [0.1994259  0.57209246]
#  [0.20337912 0.56447293]
#  [0.2787769  0.61258571]
#  [0.21885493 0.58821988]
#  [0.27035171 0.59207014]
#  [0.29894921 0.59588881]
#  [0.19675792 0.57981661]
#  [0.27738796 0.60610434]
#  [0.21908562 0.56239029]
#  [0.23073073 0.57482635]
#  [0.26478436 0.59731374]
#  [0.17709797 0.55245849]
#  [0.22398061 0.58414313]
#  [0.23650266 0.58501069]
#  [0.19457378 0.57888885]
#  [0.21797418 0.55245063]
#  [0.20693125 0.56356691]
#  [0.20644145 0.55733225]
#  [0.29108467 0.59694226]
#  [0.18047486 0.56262208]
#  [0.20988329 0.56265684]
#  [0.24973059 0.58314498]
#  [0.17903197 0.57241861]
#  [0.272172   0.59307136]
#  [0.23837309 0.62207892]
#  [0.19367171 0.5703809 ]
#  [0.27669052 0.58919661]
#  [0.21204051 0.56897486]
#  [0.28068918 0.60639727]
#  [0.27792024 0.60686273]
#  [0.19043409 0.54205292]
#  [0.3045828  0.60073255]
#  [0.22843892 0.5916797 ]
#  [0.29123361 0.61621314]
#  [0.30906612 0.6283746 ]
#  [0.2333763  0.52438482]
#  [0.26357476 0.56929495]
#  [0.20718107 0.56992325]
#  [0.23759677 0.58648851]
#  [0.26469365 0.60249581]
#  [0.2065143  0.57109427]
#  [0.29430645 0.57663801]
#  [0.20729419 0.57247049]
#  [0.23125011 0.56061401]
#  [0.1970091  0.5542022 ]
#  [0.17365827 0.54664232]
#  [0.21447601 0.56688122]
#  [0.15911378 0.54825996]
#  [0.21906557 0.57874435]
#  [0.2072401  0.57460888]
#  [0.18783171 0.57128755]
#  [0.25478069 0.59778535]
#  [0.17521087 0.56458026]
#  [0.27532642 0.59331533]
#  [0.22285845 0.58996643]
#  [0.26012802 0.58722457]
#  [0.26813827 0.5781814 ]
#  [0.21637263 0.5770676 ]
#  [0.29410868 0.61986547]
#  [0.18718535 0.57271555]
#  [0.23972641 0.59215505]
#  [0.17338253 0.58121615]
#  [0.23601606 0.59365033]
#  [0.19913886 0.56934166]
#  [0.21432229 0.58555005]
#  [0.22448003 0.59155728]
#  [0.18051687 0.57702503]
#  [0.25412806 0.58581587]
#  [0.1803635  0.56508753]
#  [0.24252867 0.59116676]
#  [0.16027529 0.5649127 ]
#  [0.24306026 0.60762389]
#  [0.20534448 0.58134748]
#  [0.20915178 0.57720476]
#  [0.19941137 0.57262495]
#  [0.15653407 0.56239439]
#  [0.20663318 0.60895714]
#  [0.15730096 0.56907362]
#  [0.21486503 0.5865678 ]
#  [0.18141085 0.56947057]
#  [0.22182177 0.59721309]
#  [0.22615725 0.59600845]
#  [0.16317001 0.56711083]
#  [0.21517179 0.5661295 ]
#  [0.15037618 0.55402423]
#  [0.24320372 0.59696346]
#  [0.18828593 0.57105446]
#  [0.22925745 0.57629079]
#  [0.20689154 0.58285913]
#  [0.19833096 0.56835165]
#  [0.25403814 0.60209568]
#  [0.19885204 0.54782938]
#  [0.23511041 0.57796415]
#  [0.18182524 0.52722887]
#  [0.21782549 0.56111491]
#  [0.21031932 0.58326319]
#  [0.1879102  0.57443929]
#  [0.21522615 0.55855556]
#  [0.16830156 0.56287066]
#  [0.19211133 0.5739004 ]
#  [0.19610009 0.57214097]
#  [0.16567174 0.57673826]
#  [0.22918747 0.58942962]
#  [0.17719487 0.58551511]
#  [0.19333253 0.57887512]]

# %%
model2 = GraphConvTensorGraph(len(tasks), dropout=0.5, batch_size=50, mode='regression',
                              C1_filtnum = C1_filtnum, C2_filtnum = C2_filtnum, D_nodenum = D_nodenum,
                              random_seed=random_seed, tensorboard=True, tensorboard_log_frequency=1, model_dir=model_dir)

# %%
model2.fit2(train_data,valid_data, metrics=[metric], nb_epoch=best_epoch+1, restore=False, deterministic=True)
# Out:
# /home/nagayasu/anaconda3/envs/deepchem/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Starting epoch 0
# Starting validation epoch 0
# computed_metrics: [4.242177748343793]
# computed_metrics: [4.242177748343793]
# computed_metrics: [4.244303847598986]
# Starting epoch 1
# Starting validation epoch 1
# computed_metrics: [2.6039832564332146]
# computed_metrics: [2.6039832564332146]
# computed_metrics: [2.6015326601238145]
# Starting epoch 2
# Starting validation epoch 2
# computed_metrics: [1.8610743932039326]
# computed_metrics: [1.8610743932039326]
# computed_metrics: [1.8585514985150962]
# Starting epoch 3
# Starting validation epoch 3
# computed_metrics: [1.3843480375291237]
# computed_metrics: [1.3843480375291237]
# computed_metrics: [1.363270013583151]
# Starting epoch 4
# Starting validation epoch 4
# computed_metrics: [1.1317406701330817]
# computed_metrics: [1.1317406701330817]
# computed_metrics: [1.098397276608129]
# Starting epoch 5
# Starting validation epoch 5
# computed_metrics: [1.021644634211206]
# computed_metrics: [1.021644634211206]
# computed_metrics: [0.9856193189094528]
# Starting epoch 6
# Starting validation epoch 6
# computed_metrics: [0.9629667211957597]
# computed_metrics: [0.9629667211957597]
# computed_metrics: [0.9279367685286245]
# Starting epoch 7
# Starting validation epoch 7
# computed_metrics: [0.9808313501026187]
# computed_metrics: [0.9808313501026187]
# computed_metrics: [0.93130134061051]
# Starting epoch 8
# Starting validation epoch 8
# computed_metrics: [0.8895469553413855]
# computed_metrics: [0.8895469553413855]
# computed_metrics: [0.8508863173349265]
# Starting epoch 9
# Starting validation epoch 9
# computed_metrics: [0.8921074812633903]
# computed_metrics: [0.8921074812633903]
# computed_metrics: [0.834408270666229]
# Starting epoch 10
# Starting validation epoch 10
# computed_metrics: [0.8233165425573489]
# computed_metrics: [0.8233165425573489]
# computed_metrics: [0.7814224710338714]
# Starting epoch 11
# Starting validation epoch 11
# computed_metrics: [0.8467179875617447]
# computed_metrics: [0.8467179875617447]
# computed_metrics: [0.783052599661994]
# Starting epoch 12
# Starting validation epoch 12
# computed_metrics: [0.841827437950331]
# computed_metrics: [0.841827437950331]
# computed_metrics: [0.7997561575911525]
# Starting epoch 13
# Starting validation epoch 13
# computed_metrics: [0.8311857934113945]
# computed_metrics: [0.8311857934113945]
# computed_metrics: [0.7815626057088076]
# Starting epoch 14
# Starting validation epoch 14
# computed_metrics: [0.8300800083289078]
# computed_metrics: [0.8300800083289078]
# computed_metrics: [0.7778492678138704]
# Starting epoch 15
# Starting validation epoch 15
# computed_metrics: [0.79269194786939]
# computed_metrics: [0.79269194786939]
# computed_metrics: [0.7323498456328548]
# Starting epoch 16
# Starting validation epoch 16
# computed_metrics: [0.7797930824531578]
# computed_metrics: [0.7797930824531578]
# computed_metrics: [0.7207834298818618]
# Starting epoch 17
# Starting validation epoch 17
# computed_metrics: [0.7760624819789036]
# computed_metrics: [0.7760624819789036]
# computed_metrics: [0.7248937171919466]
# Starting epoch 18
# Starting validation epoch 18
# computed_metrics: [0.7684459196227968]
# computed_metrics: [0.7684459196227968]
# computed_metrics: [0.7189490738151106]
# Starting epoch 19
# Starting validation epoch 19
# computed_metrics: [0.7694253928898535]
# computed_metrics: [0.7694253928898535]
# computed_metrics: [0.7053012963646731]
# Starting epoch 20
# Starting validation epoch 20
# computed_metrics: [0.7518969858467706]
# computed_metrics: [0.7518969858467706]
# computed_metrics: [0.6892296375380789]
# Starting epoch 21
# Starting validation epoch 21
# computed_metrics: [0.7595007971398118]
# computed_metrics: [0.7595007971398118]
# computed_metrics: [0.6970169004506415]
# Starting epoch 22
# Starting validation epoch 22
# computed_metrics: [0.7409177665366735]
# computed_metrics: [0.7409177665366735]
# computed_metrics: [0.6817631451486095]
# Starting epoch 23
# Starting validation epoch 23
# computed_metrics: [0.7390766681659477]
# computed_metrics: [0.7390766681659477]
# computed_metrics: [0.6684051339469221]
# Starting epoch 24
# Starting validation epoch 24
# computed_metrics: [0.7145826269576351]
# computed_metrics: [0.7145826269576351]
# computed_metrics: [0.6446825221846447]
# Starting epoch 25
# Starting validation epoch 25
# computed_metrics: [0.6975101041569399]
# computed_metrics: [0.6975101041569399]
# computed_metrics: [0.6296879151384236]
# Starting epoch 26
# Starting validation epoch 26
# computed_metrics: [0.6929576309129215]
# computed_metrics: [0.6929576309129215]
# computed_metrics: [0.6238423392549998]
# Starting epoch 27
# Starting validation epoch 27
# computed_metrics: [0.696737351569522]
# computed_metrics: [0.696737351569522]
# computed_metrics: [0.633045628980573]
# Starting epoch 28
# Starting validation epoch 28
# computed_metrics: [0.6689287082242857]
# computed_metrics: [0.6689287082242857]
# computed_metrics: [0.5926007564651725]
# Starting epoch 29
# Starting validation epoch 29
# computed_metrics: [0.6587526524792572]
# computed_metrics: [0.6587526524792572]
# computed_metrics: [0.6057096009073643]
# Starting epoch 30
# Starting validation epoch 30
# computed_metrics: [0.6523920935160288]
# computed_metrics: [0.6523920935160288]
# computed_metrics: [0.588596475773263]
# Starting epoch 31
# Starting validation epoch 31
# computed_metrics: [0.6436335815863575]
# computed_metrics: [0.6436335815863575]
# computed_metrics: [0.6168948728409815]
# Starting epoch 32
# Starting validation epoch 32
# computed_metrics: [0.6332921291257312]
# computed_metrics: [0.6332921291257312]
# computed_metrics: [0.5863482460043525]
# Starting epoch 33
# Starting validation epoch 33
# computed_metrics: [0.6148976069354313]
# computed_metrics: [0.6148976069354313]
# computed_metrics: [0.5883902008343618]
# Starting epoch 34
# Starting validation epoch 34
# computed_metrics: [0.6177941360918897]
# computed_metrics: [0.6177941360918897]
# computed_metrics: [0.5898365053726402]
# Starting epoch 35
# Starting validation epoch 35
# computed_metrics: [0.6298677724029395]
# computed_metrics: [0.6298677724029395]
# computed_metrics: [0.5994025651087102]
# Starting epoch 36
# Starting validation epoch 36
# computed_metrics: [0.5891686007441964]
# computed_metrics: [0.5891686007441964]
# computed_metrics: [0.559392658931014]
# Starting epoch 37
# Starting validation epoch 37
# computed_metrics: [0.5775398291342568]
# computed_metrics: [0.5775398291342568]
# computed_metrics: [0.5628068353897593]
# Starting epoch 38
# Starting validation epoch 38
# computed_metrics: [0.5718108244492102]
# computed_metrics: [0.5718108244492102]
# computed_metrics: [0.5590644277431235]
# Starting epoch 39
# Starting validation epoch 39
# computed_metrics: [0.5635460746047767]
# computed_metrics: [0.5635460746047767]
# computed_metrics: [0.540027045456149]
# Starting epoch 40
# Starting validation epoch 40
# computed_metrics: [0.5555768669997253]
# computed_metrics: [0.5555768669997253]
# computed_metrics: [0.5658975889309489]
# Starting epoch 41
# Starting validation epoch 41
# computed_metrics: [0.5728536718548968]
# computed_metrics: [0.5728536718548968]
# computed_metrics: [0.5834093911066341]
# Starting epoch 42
# Starting validation epoch 42
# computed_metrics: [0.5581831474244777]
# computed_metrics: [0.5581831474244777]
# computed_metrics: [0.5340166873262356]
# Starting epoch 43
# Starting validation epoch 43
# computed_metrics: [0.5403365454525488]
# computed_metrics: [0.5403365454525488]
# computed_metrics: [0.54206772780089]
# Starting epoch 44
# Starting validation epoch 44
# computed_metrics: [0.5688872481192848]
# computed_metrics: [0.5688872481192848]
# computed_metrics: [0.5978424582835032]
# Starting epoch 45
# Starting validation epoch 45
# computed_metrics: [0.5769201512693662]
# computed_metrics: [0.5769201512693662]
# computed_metrics: [0.572704835181577]
# Starting epoch 46
# Starting validation epoch 46
# computed_metrics: [0.5500720515075549]
# computed_metrics: [0.5500720515075549]
# computed_metrics: [0.5326421788556822]
# Starting epoch 47
# Starting validation epoch 47
# computed_metrics: [0.533560624466097]
# computed_metrics: [0.533560624466097]
# computed_metrics: [0.5365085361676971]
# Starting epoch 48
# Starting validation epoch 48
# computed_metrics: [0.5566679856940533]
# computed_metrics: [0.5566679856940533]
# computed_metrics: [0.5476993514219343]
# Starting epoch 49
# Starting validation epoch 49
# computed_metrics: [0.54366204908402]
# computed_metrics: [0.54366204908402]
# computed_metrics: [0.5282687919414891]
# Starting epoch 50
# Starting validation epoch 50
# computed_metrics: [0.5440044529947448]
# computed_metrics: [0.5440044529947448]
# computed_metrics: [0.5675891199650037]
# Starting epoch 51
# Starting validation epoch 51
# computed_metrics: [0.5316030648968494]
# computed_metrics: [0.5316030648968494]
# computed_metrics: [0.5208161646612426]
# Starting epoch 52
# Starting validation epoch 52
# computed_metrics: [0.6550041419076279]
# computed_metrics: [0.6550041419076279]
# computed_metrics: [0.6682349717854559]
# Starting epoch 53
# Starting validation epoch 53
# computed_metrics: [0.5308502586794113]
# computed_metrics: [0.5308502586794113]
# computed_metrics: [0.5405761578447453]
# Starting epoch 54
# Starting validation epoch 54
# computed_metrics: [0.5551004505380257]
# computed_metrics: [0.5551004505380257]
# computed_metrics: [0.5644829006917245]
# Starting epoch 55
# Starting validation epoch 55
# computed_metrics: [0.5396667756633201]
# computed_metrics: [0.5396667756633201]
# computed_metrics: [0.5048689976488127]
# Starting epoch 56
# Starting validation epoch 56
# computed_metrics: [0.5413460541853206]
# computed_metrics: [0.5413460541853206]
# computed_metrics: [0.5771242606140542]
# Starting epoch 57
# Starting validation epoch 57
# computed_metrics: [0.5239502073815931]
# computed_metrics: [0.5239502073815931]
# computed_metrics: [0.5307722885187423]
# Starting epoch 58
# Starting validation epoch 58
# computed_metrics: [0.4838970218013379]
# computed_metrics: [0.4838970218013379]
# computed_metrics: [0.5084464238449]
# Starting epoch 59
# Starting validation epoch 59
# computed_metrics: [0.5216754446804465]
# computed_metrics: [0.5216754446804465]
# computed_metrics: [0.5421752814343771]
# Starting epoch 60
# Starting validation epoch 60
# computed_metrics: [0.5302542615057794]
# computed_metrics: [0.5302542615057794]
# computed_metrics: [0.5510943623707115]
# Starting epoch 61
# Starting validation epoch 61
# computed_metrics: [0.4804806901620043]
# computed_metrics: [0.4804806901620043]
# computed_metrics: [0.5289566493499697]
# Starting epoch 62
# Starting validation epoch 62
# computed_metrics: [0.5334586365227203]
# computed_metrics: [0.5334586365227203]
# computed_metrics: [0.5702690052687241]
# Starting epoch 63
# Starting validation epoch 63
# computed_metrics: [0.48101990556638324]
# computed_metrics: [0.48101990556638324]
# computed_metrics: [0.5306759597055659]
# Starting epoch 64
# Starting validation epoch 64
# computed_metrics: [0.46966474974956146]
# computed_metrics: [0.46966474974956146]
# computed_metrics: [0.4941174074755978]
# Starting epoch 65
# Starting validation epoch 65
# computed_metrics: [0.46431584235728657]
# computed_metrics: [0.46431584235728657]
# computed_metrics: [0.5153274344593324]
# Starting epoch 66
# Starting validation epoch 66
# computed_metrics: [0.5479969603887773]
# computed_metrics: [0.5479969603887773]
# computed_metrics: [0.5899798215738788]
# Starting epoch 67
# Starting validation epoch 67
# computed_metrics: [0.660791996095269]
# computed_metrics: [0.660791996095269]
# computed_metrics: [0.7094013099730152]
# Starting epoch 68
# Starting validation epoch 68
# computed_metrics: [0.48812091972324373]
# computed_metrics: [0.48812091972324373]
# computed_metrics: [0.524238978664047]
# Starting epoch 69
# Starting validation epoch 69
# computed_metrics: [0.6797677452979727]
# computed_metrics: [0.6797677452979727]
# computed_metrics: [0.7305040752695439]
# Starting epoch 70
# Starting validation epoch 70
# computed_metrics: [0.6611918681545064]
# computed_metrics: [0.6611918681545064]
# computed_metrics: [0.6997774982464546]
# Starting epoch 71
# Starting validation epoch 71
# computed_metrics: [0.5714736873039066]
# computed_metrics: [0.5714736873039066]
# computed_metrics: [0.588181034290757]
# Starting epoch 72
# Starting validation epoch 72
# computed_metrics: [0.5289077901234236]
# computed_metrics: [0.5289077901234236]
# computed_metrics: [0.5512395786169926]
# Starting epoch 73
# Starting validation epoch 73
# computed_metrics: [0.5654173648086366]
# computed_metrics: [0.5654173648086366]
# computed_metrics: [0.6193022805113564]
# Starting epoch 74
# Starting validation epoch 74
# computed_metrics: [0.6288478765514487]
# computed_metrics: [0.6288478765514487]
# computed_metrics: [0.6758651304189345]
# Starting epoch 75
# Starting validation epoch 75
# computed_metrics: [0.5403189891731182]
# computed_metrics: [0.5403189891731182]
# computed_metrics: [0.5696452698056835]
# Starting epoch 76
# Starting validation epoch 76
# computed_metrics: [0.6077599987518605]
# computed_metrics: [0.6077599987518605]
# computed_metrics: [0.663141456505913]
# Starting epoch 77
# Starting validation epoch 77
# computed_metrics: [0.5791767999958953]
# computed_metrics: [0.5791767999958953]
# computed_metrics: [0.6186137269013536]
# Starting epoch 78
# Starting validation epoch 78
# computed_metrics: [0.5582051147620567]
# computed_metrics: [0.5582051147620567]
# computed_metrics: [0.598187209848183]
# Starting epoch 79
# Starting validation epoch 79
# computed_metrics: [0.587414931186243]
# computed_metrics: [0.587414931186243]
# computed_metrics: [0.6378706460359436]
# Starting epoch 80
# Starting validation epoch 80
# computed_metrics: [0.5910397656552705]
# computed_metrics: [0.5910397656552705]
# computed_metrics: [0.6473593919043242]
# Starting epoch 81
# Starting validation epoch 81
# computed_metrics: [0.49672169341173317]
# computed_metrics: [0.49672169341173317]
# computed_metrics: [0.5368970046205478]
# Starting epoch 82
# Starting validation epoch 82
# computed_metrics: [0.4647316111655569]
# computed_metrics: [0.4647316111655569]
# computed_metrics: [0.5105348727309754]
# Starting epoch 83
# Starting validation epoch 83
# computed_metrics: [0.5028080751178595]
# computed_metrics: [0.5028080751178595]
# computed_metrics: [0.5701930633001676]
# Starting epoch 84
# Starting validation epoch 84
# computed_metrics: [0.55977357286488]
# computed_metrics: [0.55977357286488]
# computed_metrics: [0.6375337670056295]
# Starting epoch 85
# Starting validation epoch 85
# computed_metrics: [0.48892952920071864]
# computed_metrics: [0.48892952920071864]
# computed_metrics: [0.57675256070971]
# Starting epoch 86
# Starting validation epoch 86
# computed_metrics: [0.4822904525047475]
# computed_metrics: [0.4822904525047475]
# computed_metrics: [0.5626820879127381]
# Starting epoch 87
# Starting validation epoch 87
# computed_metrics: [0.4795643758117922]
# computed_metrics: [0.4795643758117922]
# computed_metrics: [0.5688361791848354]
# Starting epoch 88
# Starting validation epoch 88
# computed_metrics: [0.48163107173381503]
# computed_metrics: [0.48163107173381503]
# computed_metrics: [0.5874614171359208]
# Starting epoch 89
# Starting validation epoch 89
# computed_metrics: [0.4956256865755043]
# computed_metrics: [0.4956256865755043]
# computed_metrics: [0.6112800504595554]
# Starting epoch 90
# Starting validation epoch 90
# computed_metrics: [0.45736766259516876]
# computed_metrics: [0.45736766259516876]
# computed_metrics: [0.5641895227583819]
# Starting epoch 91
# Starting validation epoch 91
# computed_metrics: [0.45961561600165496]
# computed_metrics: [0.45961561600165496]
# computed_metrics: [0.5767137935893585]
# Starting epoch 92
# Starting validation epoch 92
# computed_metrics: [0.4067406326797575]
# computed_metrics: [0.4067406326797575]
# computed_metrics: [0.5107222750216056]
# Starting epoch 93
# Starting validation epoch 93
# computed_metrics: [0.40053077769712586]
# computed_metrics: [0.40053077769712586]
# computed_metrics: [0.49247230941067394]
# Starting epoch 94
# Starting validation epoch 94
# computed_metrics: [0.4053386751915281]
# computed_metrics: [0.4053386751915281]
# computed_metrics: [0.5302192514977461]
# Starting epoch 95
# Starting validation epoch 95
# computed_metrics: [0.38722719192700733]
# computed_metrics: [0.38722719192700733]
# computed_metrics: [0.49052460093599637]
# Starting epoch 96
# Starting validation epoch 96
# computed_metrics: [0.4077322194201359]
# computed_metrics: [0.4077322194201359]
# computed_metrics: [0.528150734576322]
# Starting epoch 97
# Starting validation epoch 97
# computed_metrics: [0.39176642621972896]
# computed_metrics: [0.39176642621972896]
# computed_metrics: [0.5391091858770736]
# Starting epoch 98
# Starting validation epoch 98
# computed_metrics: [0.38970643502656677]
# computed_metrics: [0.38970643502656677]
# computed_metrics: [0.525541597964326]
# Starting epoch 99
# Starting validation epoch 99
# computed_metrics: [0.3870182604267027]
# computed_metrics: [0.3870182604267027]
# computed_metrics: [0.5206127458519549]
# Starting epoch 100
# Starting validation epoch 100
# computed_metrics: [0.38516050878063623]
# computed_metrics: [0.38516050878063623]
# computed_metrics: [0.5385623614987742]
# Starting epoch 101
# Starting validation epoch 101
# computed_metrics: [0.3543518865750128]
# computed_metrics: [0.3543518865750128]
# computed_metrics: [0.5088672783988869]
# Starting epoch 102
# Starting validation epoch 102
# computed_metrics: [0.35817486564231366]
# computed_metrics: [0.35817486564231366]
# computed_metrics: [0.5253688901873202]
# Starting epoch 103
# Starting validation epoch 103
# computed_metrics: [0.370333100182841]
# computed_metrics: [0.370333100182841]
# computed_metrics: [0.5185551949369551]
# Starting epoch 104
# Starting validation epoch 104
# computed_metrics: [0.34283952546999075]
# computed_metrics: [0.34283952546999075]
# computed_metrics: [0.5042333296536741]
# Starting epoch 105
# Starting validation epoch 105
# computed_metrics: [0.3457522044240338]
# computed_metrics: [0.3457522044240338]
# computed_metrics: [0.5197159168977029]
# Starting epoch 106
# Starting validation epoch 106
# computed_metrics: [0.36985822323643935]
# computed_metrics: [0.36985822323643935]
# computed_metrics: [0.512965148767735]
# Starting epoch 107
# Starting validation epoch 107
# computed_metrics: [0.3844607416291056]
# computed_metrics: [0.3844607416291056]
# computed_metrics: [0.5800561327073319]
# 11.724617349474054

# %%
model2.evaluate(train_data, metrics=[metric])
model2.evaluate(valid_data, metrics=[metric])
model2.evaluate(test_data, metrics=[metric])
# Out:
# computed_metrics: [0.3844607416291056]
# computed_metrics: [0.5800561327073319]
# computed_metrics: [0.5942052968465201]
# {'mean-mean_absolute_error': 0.5942052968465201}

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


a1 = np.reshape(train_data.ids, (-1,1))
a2 = np.reshape(model2.predict(train_data), (-1,1))
a3 = train_data.y

print(np.shape(a1))
print(np.shape(a2))
print(np.shape(a3))


a4 = np.concatenate((a1,a2,a3), axis=1)
#print(np.shape(a4))
#print(a4)

plt.scatter(a4[:,2], a4[:,1])
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()
# Out:
# (1412, 1)
# (1412, 1)
# (1412, 1)

# %%
a11 = np.reshape(valid_data.ids, (-1,1))
a21 = np.reshape(model2.predict(valid_data), (-1,1))
a31 = valid_data.y

a41 = np.concatenate((a11,a21,a31), axis=1)
#print(np.shape(a41))
#print(a41)

plt.scatter(a41[:,2], a41[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
a12 = np.reshape(test_data.ids, (-1,1))
a22 = np.reshape(model2.predict(test_data), (-1,1))
a32 = test_data.y

a42 = np.concatenate((a12,a22,a32), axis=1)
#print(np.shape(a42))
#print(a42)

plt.scatter(a42[:,2], a42[:,1],s=10)
plt.title("hDAT pIC50")
plt.xlabel("true pIC50")
plt.ylabel("predicted pIC50")
plt.grid(True)
plt.show()

# %%
import scipy as sp
from scipy.stats import pearsonr, spearmanr

x = a4[:,1].astype(np.float32)
y = a4[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a41[:,1].astype(np.float32)
y = a41[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))

x = a42[:,1].astype(np.float32)
y = a42[:,2].astype(np.float32)

print(pearsonr(x,y))
print(spearmanr(x,y))
# Out:
# (0.90826213, 0.0)
# SpearmanrResult(correlation=0.9098066621750059, pvalue=0.0)
# (0.7368813, 1.4240393358079035e-31)
# SpearmanrResult(correlation=0.7538526305009223, pvalue=9.542136146653421e-34)
# (0.79376745, 1.2287715320400377e-39)
# SpearmanrResult(correlation=0.7987584048809457, pvalue=1.8257037412574756e-40)
